# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm
import gc

from scipy import signal
import lightgbm as lgb

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 200)

import warnings
warnings.filterwarnings('ignore')

from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Out:
# Using TensorFlow backend.

# %%
X_train = pd.read_csv('../input/X_train.csv')
y_train = pd.read_csv('../input/y_train.csv')
X_test  = pd.read_csv('../input/X_test.csv')

# %%
targets = y_train['surface'].value_counts().index
print(targets)
print(y_train['surface'].value_counts())
# Out:
# Index(['concrete', 'soft_pvc', 'wood', 'tiled', 'fine_concrete',
#        'hard_tiles_large_space', 'soft_tiles', 'carpet', 'hard_tiles'],
#       dtype='object')
# concrete                  779
# soft_pvc                  732
# wood                      607
# tiled                     514
# fine_concrete             363
# hard_tiles_large_space    308
# soft_tiles                297
# carpet                    189
# hard_tiles                 21
# Name: surface, dtype: int64

# %%
target_to_id = {}
id_to_target = {}

for target in targets:
    if target not in target_to_id:
        new_id = len(target_to_id)
        target_to_id[target] = new_id
        id_to_target[new_id] = target

# %%
y_id = []
for i in range(len(y_train)):
    y_id.append(target_to_id[y_train['surface'].values[i]])
y_id = np.asarray(y_id)

# %%
class_num = len(targets)

# %%
y_id_one = np.zeros((len(y_id), class_num))
for i in range(len(y_id)):
    y_id_one[i, y_id[i]] = 1

# %%
def norm_quat(df):
    norm = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2 + df['orientation_W']**2)**0.5
    df['orientation_X'] /= norm
    df['orientation_Y'] /= norm
    df['orientation_Z'] /= norm
    df['orientation_W'] /= norm
    return df

# %%
import math

def quaternion_to_euler(x, y, z, w):
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.atan2(t0, t1)

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.asin(t2)

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.atan2(t3, t4)

    return X, Y, Z

# %%
X_train = norm_quat(X_train)
X_test = norm_quat(X_test)

# %%
def fe_step1 (df):
    """Quaternions to Euler Angles"""
    
    x = df['orientation_X'].values
    y = df['orientation_Y'].values
    z = df['orientation_Z'].values
    w = df['orientation_W'].values
    nx, ny, nz = np.zeros(len(x)), np.zeros(len(y)), np.zeros(len(z)),
    for i in tqdm(range(len(x))):
        xx, yy, zz = quaternion_to_euler(x[i], y[i], z[i], w[i])
        nx[i] = xx
        ny[i] = yy
        nz[i] = zz
    
    df['euler_X'] = nx
    df['euler_Y'] = ny
    df['euler_Z'] = nz
    return df

# %% [markdown]
# X_train = fe_step1(X_train)
# X_test = fe_step1(X_test)

# %%
def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))

# %%
def lowpass_filter(data, r=0.05):
    f_data = np.zeros_like(data)
    f_data[0] = data[0]
    for i in range(1, len(data)):
        if i % 128 == 0:
            f_data[i] = data[i]
        else:
            f_data[i] = r * data[i] + (1-r) * f_data[i-1]
    return f_data

# %%
for data in [X_train, X_test]:
    data['linear_acceleration_X'] = lowpass_filter(data['linear_acceleration_X'])
    data['linear_acceleration_Y'] = lowpass_filter(data['linear_acceleration_Y'])
    data['linear_acceleration_Z'] = lowpass_filter(data['linear_acceleration_Z'])
    data['angular_velocity_X'] = lowpass_filter(data['angular_velocity_X'])
    data['angular_velocity_Y'] = lowpass_filter(data['angular_velocity_Y'])
    data['angular_velocity_Z'] = lowpass_filter(data['angular_velocity_Z'])

# %%
cols = ['linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z']
df_peak = pd.DataFrame()

for i in tqdm(range(0, len(X_train), 128)):
    X_tr = X_train.iloc[i:i+128, :]
    df_cols = pd.DataFrame()
    for col in cols:
        peaks = signal.find_peaks(X_tr[col], rel_height=1.0)[0]
        peak_num = len(peaks)
        peak_width = signal.peak_widths(X_tr[col], peaks, rel_height=1.0)[0]
        peak_pro = signal.peak_prominences(X_tr[col], peaks)[0]
        
        if peak_num != 0:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[np.max(peak_width)],
                             col+'_peak_width_min':[np.min(peak_width)],
                             col+'_peak_width_mean':[np.mean(peak_width)],
                             col+'_peak_pro_max':[np.max(peak_pro)],
                             col+'_peak_pro_min':[np.min(peak_pro)],
                             col+'_peak_pro_mean':[np.mean(peak_pro)]
                            }, index=[i//128])
        else:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[0],
                             col+'_peak_width_min':[0],
                             col+'_peak_width_mean':[0],
                             col+'_peak_pro_max':[0],
                             col+'_peak_pro_min':[0],
                             col+'_peak_pro_mean':[0]
                            }, index=[i//128])
            
        df_cols = pd.concat([df_cols, peak_df], axis=1)
    df_peak = pd.concat([df_peak, df_cols], axis=0)
# Out:
# 100%|██████████| 3810/3810 [01:08<00:00, 55.62it/s]

# %%
cols = ['linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z']
df_peak_te = pd.DataFrame()

for i in tqdm(range(0, len(X_test), 128)):
    X_tr = X_test.iloc[i:i+128, :]
    df_cols = pd.DataFrame()
    for col in cols:
        peaks = signal.find_peaks(X_tr[col], rel_height=1.0)[0]
        peak_num = len(peaks)
        peak_width = signal.peak_widths(X_tr[col], peaks, rel_height=1.0)[0]
        peak_pro = signal.peak_prominences(X_tr[col], peaks)[0]
        
        if peak_num != 0:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[np.max(peak_width)],
                             col+'_peak_width_min':[np.min(peak_width)],
                             col+'_peak_width_mean':[np.mean(peak_width)],
                             col+'_peak_pro_max':[np.max(peak_pro)],
                             col+'_peak_pro_min':[np.min(peak_pro)],
                             col+'_peak_pro_mean':[np.mean(peak_pro)]
                            }, index=[i//128])
        else:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[0],
                             col+'_peak_width_min':[0],
                             col+'_peak_width_mean':[0],
                             col+'_peak_pro_max':[0],
                             col+'_peak_pro_min':[0],
                             col+'_peak_pro_mean':[0]
                            }, index=[i//128])
            
        df_cols = pd.concat([df_cols, peak_df], axis=1)
    df_peak_te = pd.concat([df_peak_te, df_cols], axis=0)
# Out:
# 100%|██████████| 3816/3816 [01:07<00:00, 56.58it/s]

# %%
df_peak.head()
# Out:
#    linear_acceleration_X_peak_num  linear_acceleration_X_peak_width_max  \
# 0                              18                             67.349799
# 1                              27                             33.713893
# 2                              42                             57.395712
# 3                              39                             36.895928
# 4                              14                             83.441060
#
#    linear_acceleration_X_peak_width_min  \
# 0                              1.020952
# 1                              1.014982
# 2                              1.010786
# 3                              1.018780
# 4                              1.011932
#
#    linear_acceleration_X_peak_width_mean  linear_acceleration_X_peak_pro_max  \
# 0                               8.738154                            0.869510
# 1                               4.154307                            0.537557
# 2                               5.210292                            0.295711
# 3                               3.726208                            0.628153
# 4                              11.847188                            0.460989
#
#    linear_acceleration_X_peak_pro_min  linear_acceleration_X_peak_pro_mean  \
# 0                            0.000358                             0.110924
# 1                            0.000869                             0.061414
# 2                            0.000664                             0.040441
# 3                            0.001037                             0.080369
# 4                            0.000241                             0.069680
#
#    linear_acceleration_Y_peak_num  linear_acceleration_Y_peak_width_max  \
# 0                               8                             50.696731
# 1                              13                             48.564414
# 2                              10                             53.496276
# 3                               5                             54.040205
# 4                               6                             55.824354
#
#    linear_acceleration_Y_peak_width_min  \
# 0                              1.395732
# 1                              1.004925
# 2                              1.265500
# 3                              1.028376
# 4                              1.533987
#
#    linear_acceleration_Y_peak_width_mean  linear_acceleration_Y_peak_pro_max  \
# 0                              12.711851                            1.320872
# 1                               8.686394                            2.080121
# 2                               9.771990                            1.693452
# 3                              19.295784                            4.109290
# 4                              13.385387                            1.090068
#
#    linear_acceleration_Y_peak_pro_min  linear_acceleration_Y_peak_pro_mean  \
# 0                            0.005401                             0.314191
# 1                            0.000290                             0.249105
# 2                            0.005750                             0.304578
# 3                            0.002904                             1.507230
# 4                            0.008584                             0.218788
#
#    linear_acceleration_Z_peak_num  linear_acceleration_Z_peak_width_max  \
# 0                              20                             56.355945
# 1                              22                            109.833935
# 2                              17                             28.214848
# 3                              21                             40.926006
# 4                              19                             52.447764
#
#    linear_acceleration_Z_peak_width_min  \
# 0                              1.150822
# 1                              1.575330
# 2                              1.327078
# 3                              1.165514
# 4                              1.196776
#
#    linear_acceleration_Z_peak_width_mean  linear_acceleration_Z_peak_pro_max  \
# 0                              10.368243                            0.378517
# 1                              12.974075                            0.639242
# 2                               6.505685                            0.306442
# 3                              10.832781                            0.977948
# 4                               9.038149                            0.256213
#
#    linear_acceleration_Z_peak_pro_min  linear_acceleration_Z_peak_pro_mean  \
# 0                            0.004492                             0.126852
# 1                            0.004951                             0.199470
# 2                            0.008605                             0.087387
# 3                            0.028928                             0.327467
# 4                            0.005018                             0.095783
#
#    angular_velocity_X_peak_num  angular_velocity_X_peak_width_max  \
# 0                           12                          39.834934
# 1                           17                          40.939492
# 2                           12                          54.990935
# 3                           14                          49.361726
# 4                           13                          60.704755
#
#    angular_velocity_X_peak_width_min  angular_velocity_X_peak_width_mean  \
# 0                           1.617261                            7.003719
# 1                           1.115794                            4.805293
# 2                           1.478589                           10.768762
# 3                           1.300930                            7.417091
# 4                           1.165449                            8.980491
#
#    angular_velocity_X_peak_pro_max  angular_velocity_X_peak_pro_min  \
# 0                         0.034600                         0.000301
# 1                         0.046299                         0.000237
# 2                         0.063062                         0.000331
# 3                         0.126019                         0.001908
# 4                         0.035348                         0.000088
#
#    angular_velocity_X_peak_pro_mean  angular_velocity_Y_peak_num  \
# 0                          0.004765                           20
# 1                          0.005848                           26
# 2                          0.010688                           30
# 3                          0.018159                           24
# 4                          0.005392                           15
#
#    angular_velocity_Y_peak_width_max  angular_velocity_Y_peak_width_min  \
# 0                          41.757057                           1.040009
# 1                          43.509612                           1.214623
# 2                          75.135188                           1.000653
# 3                          58.726325                           1.021230
# 4                          35.420688                           1.462859
#
#    angular_velocity_Y_peak_width_mean  angular_velocity_Y_peak_pro_max  \
# 0                            6.503980                         0.023187
# 1                            5.869483                         0.017523
# 2                            6.599449                         0.011325
# 3                            6.350322                         0.015169
# 4                            6.634628                         0.006241
#
#    angular_velocity_Y_peak_pro_min  angular_velocity_Y_peak_pro_mean  \
# 0                     6.329349e-05                          0.002656
# 1                     1.139008e-04                          0.003568
# 2                     7.132009e-07                          0.002586
# 3                     3.202688e-05                          0.003391
# 4                     8.749217e-05                          0.001295
#
#    angular_velocity_Z_peak_num  angular_velocity_Z_peak_width_max  \
# 0                           11                          42.250167
# 1                            5                          70.046581
# 2                           14                          24.152079
# 3                           14                          40.545125
# 4                            5                          46.757172
#
#    angular_velocity_Z_peak_width_min  angular_velocity_Z_peak_width_mean  \
# 0                           1.039925                            8.342229
# 1                          18.703546                           30.604017
# 2                           1.060126                            5.835102
# 3                           1.011690                            7.527733
# 4                          13.165737                           21.755833
#
#    angular_velocity_Z_peak_pro_max  angular_velocity_Z_peak_pro_min  \
# 0                         0.009851                         0.000008
# 1                         0.043476                         0.026268
# 2                         0.012037                         0.000043
# 3                         0.012205                         0.000015
# 4                         0.020428                         0.003924
#
#    angular_velocity_Z_peak_pro_mean
# 0                          0.002005
# 1                          0.034705
# 2                          0.002172
# 3                          0.002717
# 4                          0.009956

# %%
def feat_eng(df):
    data = pd.DataFrame()
    #df['linear_acceleration_Z'] += 9.80665
    #df['eulerX-Z'] = df['euler_X']-df['euler_Z']
    df['total_acce'] = (df['linear_acceleration_X']**2 + df['linear_acceleration_Y']**2 + df['linear_acceleration_Z']**2)**0.5
    #df['total_ang_cos'] = (df['angular_velocity_X_cos']**2 + df['angular_velocity_Y_cos']**2 + df['angular_velocity_Z_cos']**2)**0.5
    
    tmp_df = pd.concat([df['linear_acceleration_Z'], df['angular_velocity_X']], axis=1)
    scaler = MinMaxScaler(feature_range=(-1, 1))
    tmp_df = scaler.fit_transform(tmp_df)
    
    #df['total_angu'] = (df['angular_velocity_X']**2 + df['angular_velocity_Y']**2 + df['angular_velocity_Z']**2)**0.5
    
    #df['total_eule'] = (df['euler_X']**2 + df['euler_Y']**2 + df['euler_Z']**2)**0.5
    #df['total_xyz'] = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2)**0.5
    #df['total_acc/vel'] = df['total_acce']/df['total_angu']
    
    df_columns = df.columns[7:]
    for col in tqdm(df_columns):
        data[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        data[col + '_median'] = df.groupby(['series_id'])[col].median()
        data[col + '_max'] = df.groupby(['series_id'])[col].max()
        data[col + '_min'] = df.groupby(['series_id'])[col].min()
        data[col + '_std'] = df.groupby(['series_id'])[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        data[col + '_mean_abs_chg'] = df.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        data[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
        data[col + '_abs_max'] = df.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        data[col + '_abs_min'] = df.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        data[col + '_abs_avg'] = (data[col + '_abs_min'] + data[col + '_abs_max'])/2
        
        
    #data['corr_linZangX'] = np.correlate(np.abs(tmp_df[:, 0]), np.abs(tmp_df[:, 1]))
    return data

# %%
X_train = feat_eng(X_train)
X_test = feat_eng(X_test)
# Out:
# 100%|██████████| 7/7 [00:14<00:00,  2.11s/it]
# 100%|██████████| 7/7 [00:14<00:00,  2.12s/it]

# %%
X_train.shape
# Out:
# (3810, 84)

# %%
df_peak.shape
# Out:
# (3810, 42)

# %%
df_peak_te.shape
# Out:
# (3816, 42)

# %%
X_test.shape
# Out:
# (3816, 84)

# %%
X_train = pd.concat([X_train, df_peak], axis=1)
X_test = pd.concat([X_test, df_peak_te], axis=1)

# %%
data_col = X_train.columns

# %%
for data in [X_train, X_test]:
    data.fillna(0,inplace=True)
    data.replace(-np.inf,0,inplace=True)
    data.replace(np.inf,0,inplace=True)

# %% [markdown]
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

# %%
N_SPLITS = 5

# %%
import tensorflow as tf
from sklearn.metrics import roc_auc_score

def auroc(y_true, y_pred):
    return tf.py_function(roc_auc_score, (y_true, y_pred), tf.double)

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score

# %%
y = np.concatenate((np.zeros(len(X_train)), np.ones(len(X_test))), axis=0)
X = np.concatenate((X_train, X_test), axis=0)

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))

clf_2 = []
val_roc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'binary_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'binary',
               #'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }


for train_idx, val_idx in splits:
    X_tr, y_tr = X[train_idx, :], y[train_idx]
    X_val, y_val = X[val_idx, :], y[val_idx]
 
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)
    
    val_roc.append(roc_auc_score(y_val, (pred_lgb>0.5).astype(int)))
    
    pred_lgb = pd.DataFrame(pred_lgb, index=val_idx)
    val_pred = pd.concat([val_pred, pred_lgb], axis=0)
    
    clf_2.append(model_lgb)
# Out:
# [1]	valid_0's binary_logloss: 0.690237
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.687812
# [3]	valid_0's binary_logloss: 0.685976
# [4]	valid_0's binary_logloss: 0.684842
# [5]	valid_0's binary_logloss: 0.684248
# [6]	valid_0's binary_logloss: 0.683074
# [7]	valid_0's binary_logloss: 0.681704
# [8]	valid_0's binary_logloss: 0.681164
# [9]	valid_0's binary_logloss: 0.680301
# [10]	valid_0's binary_logloss: 0.679919
# [11]	valid_0's binary_logloss: 0.679525
# [12]	valid_0's binary_logloss: 0.679054
# [13]	valid_0's binary_logloss: 0.679135
# [14]	valid_0's binary_logloss: 0.679252
# [15]	valid_0's binary_logloss: 0.679426
# [16]	valid_0's binary_logloss: 0.679012
# [17]	valid_0's binary_logloss: 0.679043
# [18]	valid_0's binary_logloss: 0.679133
# [19]	valid_0's binary_logloss: 0.679787
# [20]	valid_0's binary_logloss: 0.679902
# [21]	valid_0's binary_logloss: 0.679984
# [22]	valid_0's binary_logloss: 0.680748
# [23]	valid_0's binary_logloss: 0.680925
# [24]	valid_0's binary_logloss: 0.681442
# [25]	valid_0's binary_logloss: 0.68165
# [26]	valid_0's binary_logloss: 0.682253
# [27]	valid_0's binary_logloss: 0.6821
# [28]	valid_0's binary_logloss: 0.68183
# [29]	valid_0's binary_logloss: 0.681694
# [30]	valid_0's binary_logloss: 0.681944
# [31]	valid_0's binary_logloss: 0.681923
# [32]	valid_0's binary_logloss: 0.682618
# [33]	valid_0's binary_logloss: 0.682678
# [34]	valid_0's binary_logloss: 0.682282
# [35]	valid_0's binary_logloss: 0.682428
# [36]	valid_0's binary_logloss: 0.682092
# [37]	valid_0's binary_logloss: 0.681703
# [38]	valid_0's binary_logloss: 0.681411
# [39]	valid_0's binary_logloss: 0.681414
# [40]	valid_0's binary_logloss: 0.681293
# [41]	valid_0's binary_logloss: 0.681295
# [42]	valid_0's binary_logloss: 0.681039
# [43]	valid_0's binary_logloss: 0.681157
# [44]	valid_0's binary_logloss: 0.681287
# [45]	valid_0's binary_logloss: 0.680461
# [46]	valid_0's binary_logloss: 0.680467
# Early stopping, best iteration is:
# [16]	valid_0's binary_logloss: 0.679012
# [1]	valid_0's binary_logloss: 0.690498
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.688358
# [3]	valid_0's binary_logloss: 0.68589
# [4]	valid_0's binary_logloss: 0.684775
# [5]	valid_0's binary_logloss: 0.683313
# [6]	valid_0's binary_logloss: 0.682234
# [7]	valid_0's binary_logloss: 0.681387
# [8]	valid_0's binary_logloss: 0.679955
# [9]	valid_0's binary_logloss: 0.678771
# [10]	valid_0's binary_logloss: 0.678486
# [11]	valid_0's binary_logloss: 0.678298
# [12]	valid_0's binary_logloss: 0.677268
# [13]	valid_0's binary_logloss: 0.676399
# [14]	valid_0's binary_logloss: 0.675926
# [15]	valid_0's binary_logloss: 0.67532
# [16]	valid_0's binary_logloss: 0.674949
# [17]	valid_0's binary_logloss: 0.67476
# [18]	valid_0's binary_logloss: 0.674076
# [19]	valid_0's binary_logloss: 0.674114
# [20]	valid_0's binary_logloss: 0.674413
# [21]	valid_0's binary_logloss: 0.674832
# [22]	valid_0's binary_logloss: 0.675141
# [23]	valid_0's binary_logloss: 0.675852
# [24]	valid_0's binary_logloss: 0.676521
# [25]	valid_0's binary_logloss: 0.676663
# [26]	valid_0's binary_logloss: 0.677448
# [27]	valid_0's binary_logloss: 0.677119
# [28]	valid_0's binary_logloss: 0.677445
# [29]	valid_0's binary_logloss: 0.67737
# [30]	valid_0's binary_logloss: 0.676953
# [31]	valid_0's binary_logloss: 0.676315
# [32]	valid_0's binary_logloss: 0.676562
# [33]	valid_0's binary_logloss: 0.67661
# [34]	valid_0's binary_logloss: 0.676629
# [35]	valid_0's binary_logloss: 0.677033
# [36]	valid_0's binary_logloss: 0.676947
# [37]	valid_0's binary_logloss: 0.676573
# [38]	valid_0's binary_logloss: 0.676128
# [39]	valid_0's binary_logloss: 0.676222
# [40]	valid_0's binary_logloss: 0.67666
# [41]	valid_0's binary_logloss: 0.677363
# [42]	valid_0's binary_logloss: 0.677888
# [43]	valid_0's binary_logloss: 0.6777
# [44]	valid_0's binary_logloss: 0.677956
# [45]	valid_0's binary_logloss: 0.677581
# [46]	valid_0's binary_logloss: 0.677092
# [47]	valid_0's binary_logloss: 0.677131
# [48]	valid_0's binary_logloss: 0.676915
# Early stopping, best iteration is:
# [18]	valid_0's binary_logloss: 0.674076
# [1]	valid_0's binary_logloss: 0.692688
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.692088
# [3]	valid_0's binary_logloss: 0.690845
# [4]	valid_0's binary_logloss: 0.690874
# [5]	valid_0's binary_logloss: 0.690041
# [6]	valid_0's binary_logloss: 0.689327
# [7]	valid_0's binary_logloss: 0.688688
# [8]	valid_0's binary_logloss: 0.687874
# [9]	valid_0's binary_logloss: 0.687095
# [10]	valid_0's binary_logloss: 0.686206
# [11]	valid_0's binary_logloss: 0.686648
# [12]	valid_0's binary_logloss: 0.686398
# [13]	valid_0's binary_logloss: 0.686803
# [14]	valid_0's binary_logloss: 0.687083
# [15]	valid_0's binary_logloss: 0.686642
# [16]	valid_0's binary_logloss: 0.686703
# [17]	valid_0's binary_logloss: 0.686753
# [18]	valid_0's binary_logloss: 0.687707
# [19]	valid_0's binary_logloss: 0.687857
# [20]	valid_0's binary_logloss: 0.687731
# [21]	valid_0's binary_logloss: 0.687334
# [22]	valid_0's binary_logloss: 0.687582
# [23]	valid_0's binary_logloss: 0.688495
# [24]	valid_0's binary_logloss: 0.688873
# [25]	valid_0's binary_logloss: 0.689498
# [26]	valid_0's binary_logloss: 0.689837
# [27]	valid_0's binary_logloss: 0.689926
# [28]	valid_0's binary_logloss: 0.69074
# [29]	valid_0's binary_logloss: 0.690311
# [30]	valid_0's binary_logloss: 0.690639
# [31]	valid_0's binary_logloss: 0.691211
# [32]	valid_0's binary_logloss: 0.691433
# [33]	valid_0's binary_logloss: 0.691669
# [34]	valid_0's binary_logloss: 0.691582
# [35]	valid_0's binary_logloss: 0.691494
# [36]	valid_0's binary_logloss: 0.692349
# [37]	valid_0's binary_logloss: 0.692531
# [38]	valid_0's binary_logloss: 0.692888
# [39]	valid_0's binary_logloss: 0.692857
# [40]	valid_0's binary_logloss: 0.69264
# Early stopping, best iteration is:
# [10]	valid_0's binary_logloss: 0.686206
# [1]	valid_0's binary_logloss: 0.690705
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.688358
# [3]	valid_0's binary_logloss: 0.686473
# [4]	valid_0's binary_logloss: 0.684633
# [5]	valid_0's binary_logloss: 0.683126
# [6]	valid_0's binary_logloss: 0.681727
# [7]	valid_0's binary_logloss: 0.680533
# [8]	valid_0's binary_logloss: 0.679256
# [9]	valid_0's binary_logloss: 0.678976
# [10]	valid_0's binary_logloss: 0.677629
# [11]	valid_0's binary_logloss: 0.677165
# [12]	valid_0's binary_logloss: 0.675848
# [13]	valid_0's binary_logloss: 0.675808
# [14]	valid_0's binary_logloss: 0.675782
# [15]	valid_0's binary_logloss: 0.675835
# [16]	valid_0's binary_logloss: 0.675358
# [17]	valid_0's binary_logloss: 0.674985
# [18]	valid_0's binary_logloss: 0.675167
# [19]	valid_0's binary_logloss: 0.675273
# [20]	valid_0's binary_logloss: 0.675617
# [21]	valid_0's binary_logloss: 0.676722
# [22]	valid_0's binary_logloss: 0.676178
# [23]	valid_0's binary_logloss: 0.676076
# [24]	valid_0's binary_logloss: 0.676209
# [25]	valid_0's binary_logloss: 0.675994
# [26]	valid_0's binary_logloss: 0.676185
# [27]	valid_0's binary_logloss: 0.675853
# [28]	valid_0's binary_logloss: 0.675544
# [29]	valid_0's binary_logloss: 0.675363
# [30]	valid_0's binary_logloss: 0.67518
# [31]	valid_0's binary_logloss: 0.674905
# [32]	valid_0's binary_logloss: 0.675323
# [33]	valid_0's binary_logloss: 0.675987
# [34]	valid_0's binary_logloss: 0.676267
# [35]	valid_0's binary_logloss: 0.676201
# [36]	valid_0's binary_logloss: 0.676325
# [37]	valid_0's binary_logloss: 0.676137
# [38]	valid_0's binary_logloss: 0.676095
# [39]	valid_0's binary_logloss: 0.676106
# [40]	valid_0's binary_logloss: 0.676437
# [41]	valid_0's binary_logloss: 0.675882
# [42]	valid_0's binary_logloss: 0.676676
# [43]	valid_0's binary_logloss: 0.676587
# [44]	valid_0's binary_logloss: 0.677409
# [45]	valid_0's binary_logloss: 0.677717
# [46]	valid_0's binary_logloss: 0.678059
# [47]	valid_0's binary_logloss: 0.678264
# [48]	valid_0's binary_logloss: 0.678024
# [49]	valid_0's binary_logloss: 0.677963
# [50]	valid_0's binary_logloss: 0.677983
# [51]	valid_0's binary_logloss: 0.677893
# [52]	valid_0's binary_logloss: 0.677805
# [53]	valid_0's binary_logloss: 0.677704
# [54]	valid_0's binary_logloss: 0.678111
# [55]	valid_0's binary_logloss: 0.678508
# [56]	valid_0's binary_logloss: 0.678594
# [57]	valid_0's binary_logloss: 0.678068
# [58]	valid_0's binary_logloss: 0.678193
# [59]	valid_0's binary_logloss: 0.678418
# [60]	valid_0's binary_logloss: 0.678795
# [61]	valid_0's binary_logloss: 0.678723
# Early stopping, best iteration is:
# [31]	valid_0's binary_logloss: 0.674905
# [1]	valid_0's binary_logloss: 0.692041
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.689899
# [3]	valid_0's binary_logloss: 0.68805
# [4]	valid_0's binary_logloss: 0.68656
# [5]	valid_0's binary_logloss: 0.685723
# [6]	valid_0's binary_logloss: 0.68453
# [7]	valid_0's binary_logloss: 0.684333
# [8]	valid_0's binary_logloss: 0.682996
# [9]	valid_0's binary_logloss: 0.682758
# [10]	valid_0's binary_logloss: 0.6816
# [11]	valid_0's binary_logloss: 0.681385
# [12]	valid_0's binary_logloss: 0.681924
# [13]	valid_0's binary_logloss: 0.681573
# [14]	valid_0's binary_logloss: 0.681425
# [15]	valid_0's binary_logloss: 0.68122
# [16]	valid_0's binary_logloss: 0.680627
# [17]	valid_0's binary_logloss: 0.680635
# [18]	valid_0's binary_logloss: 0.679603
# [19]	valid_0's binary_logloss: 0.679794
# [20]	valid_0's binary_logloss: 0.680757
# [21]	valid_0's binary_logloss: 0.681143
# [22]	valid_0's binary_logloss: 0.680989
# [23]	valid_0's binary_logloss: 0.681104
# [24]	valid_0's binary_logloss: 0.681511
# [25]	valid_0's binary_logloss: 0.680968
# [26]	valid_0's binary_logloss: 0.681327
# [27]	valid_0's binary_logloss: 0.681713
# [28]	valid_0's binary_logloss: 0.681504
# [29]	valid_0's binary_logloss: 0.682127
# [30]	valid_0's binary_logloss: 0.681329
# [31]	valid_0's binary_logloss: 0.682609
# [32]	valid_0's binary_logloss: 0.683023
# [33]	valid_0's binary_logloss: 0.68393
# [34]	valid_0's binary_logloss: 0.683734
# [35]	valid_0's binary_logloss: 0.684328
# [36]	valid_0's binary_logloss: 0.684142
# [37]	valid_0's binary_logloss: 0.684498
# [38]	valid_0's binary_logloss: 0.684849
# [39]	valid_0's binary_logloss: 0.684698
# [40]	valid_0's binary_logloss: 0.683756
# [41]	valid_0's binary_logloss: 0.683445
# [42]	valid_0's binary_logloss: 0.684163
# [43]	valid_0's binary_logloss: 0.684398
# [44]	valid_0's binary_logloss: 0.684744
# [45]	valid_0's binary_logloss: 0.68459
# [46]	valid_0's binary_logloss: 0.685301
# [47]	valid_0's binary_logloss: 0.685394
# [48]	valid_0's binary_logloss: 0.685561
# Early stopping, best iteration is:
# [18]	valid_0's binary_logloss: 0.679603

# %%
val_roc
# Out:
# [0.5550219180717594,
#  0.5671974489427354,
#  0.5435805616041114,
#  0.5600019607640788,
#  0.561313436737839]

# %%
feature_imp = np.zeros(X_train.shape[1])
for model in clf_2:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp, index=data_col).sort_values(by=0, ascending=False)
# Out:
#                                                            0
# linear_acceleration_Y_median                     1275.281301
# linear_acceleration_Y_mean_abs_chg                583.165280
# linear_acceleration_X_mean_abs_chg                528.371679
# angular_velocity_Z_abs_max                        458.825870
# linear_acceleration_X_peak_num                    404.121373
# linear_acceleration_Z_mean_abs_chg                400.712470
# angular_velocity_Z_peak_width_min                 394.821478
# angular_velocity_Z_mean_abs_chg                   386.116440
# angular_velocity_X_min                            377.544591
# linear_acceleration_Y_peak_width_mean             304.303672
# angular_velocity_Y_min                            302.244908
# linear_acceleration_Z_peak_pro_mean               292.782301
# linear_acceleration_X_peak_pro_mean               263.180141
# total_acce_mean_abs_chg                           261.728969
# angular_velocity_Y_median                         251.781911
# angular_velocity_X_abs_min                        238.212847
# linear_acceleration_Y_mean                        230.015738
# angular_velocity_Z_median                         224.236558
# linear_acceleration_Z_peak_width_min              219.599259
# angular_velocity_Y_std                            213.882451
# angular_velocity_Z_abs_avg                        210.056820
# linear_acceleration_Z_median                      195.091531
# angular_velocity_Z_min                            195.003579
# linear_acceleration_Y_maxtoMin                    188.675360
# linear_acceleration_Z_peak_width_max              182.847761
# linear_acceleration_Y_std                         179.372680
# linear_acceleration_Y_peak_pro_mean               179.303840
# linear_acceleration_X_min                         177.231310
# linear_acceleration_Z_peak_pro_min                177.109190
# linear_acceleration_Y_abs_max                     171.534830
# linear_acceleration_X_max                         169.371011
# angular_velocity_X_abs_avg                        167.042102
# angular_velocity_Y_max                            166.330943
# angular_velocity_Y_abs_max                        165.372001
# angular_velocity_Y_mean_abs_chg                   164.078492
# linear_acceleration_X_std                         161.582008
# linear_acceleration_X_peak_width_mean             159.122702
# linear_acceleration_Y_peak_width_min              158.698022
# total_acce_min                                    157.806410
# linear_acceleration_Y_peak_width_max              154.592581
# linear_acceleration_X_peak_width_max              154.408262
# angular_velocity_Y_abs_avg                        152.485080
# total_acce_mean_change_of_abs_change              150.968541
# angular_velocity_Z_peak_num                       147.983040
# linear_acceleration_Y_peak_pro_min                147.148550
# angular_velocity_Y_mean                           146.501631
# angular_velocity_Z_peak_pro_max                   146.292268
# angular_velocity_Y_peak_pro_max                   144.635031
# linear_acceleration_Y_min                         144.312991
# angular_velocity_X_peak_pro_min                   142.666240
# angular_velocity_Z_max                            135.233450
# angular_velocity_Z_abs_min                        133.933831
# angular_velocity_X_median                         133.629581
# linear_acceleration_Y_max                         130.096100
# linear_acceleration_X_range                       127.303102
# angular_velocity_X_peak_pro_max                   126.999142
# angular_velocity_Z_peak_pro_mean                  126.377971
# angular_velocity_X_mean_abs_chg                   125.793542
# linear_acceleration_X_abs_min                     123.941611
# linear_acceleration_Y_mean_change_of_abs_change   123.538860
# linear_acceleration_Y_peak_num                    118.851980
# linear_acceleration_Z_peak_width_mean             114.122850
# angular_velocity_Y_peak_width_max                 112.322141
# angular_velocity_Z_peak_width_mean                111.825661
# linear_acceleration_X_median                      111.134192
# angular_velocity_X_range                          109.892800
# angular_velocity_Z_peak_pro_min                   109.510240
# angular_velocity_X_mean                           109.488899
# angular_velocity_X_max                            109.466510
# linear_acceleration_Z_std                         107.465659
# angular_velocity_Y_maxtoMin                       104.110410
# angular_velocity_X_peak_width_mean                102.412670
# angular_velocity_Z_mean_change_of_abs_change       99.523859
# angular_velocity_Z_peak_width_max                  98.710711
# linear_acceleration_X_abs_max                      97.092530
# linear_acceleration_Z_min                          95.745140
# linear_acceleration_Z_mean                         95.185769
# linear_acceleration_X_peak_pro_min                 92.623610
# linear_acceleration_Z_peak_num                     91.948199
# angular_velocity_Y_peak_pro_min                    91.407701
# linear_acceleration_Y_range                        90.170260
# angular_velocity_Y_peak_width_mean                 90.111899
# angular_velocity_X_maxtoMin                        89.681691
# angular_velocity_Y_peak_width_min                  89.640871
# angular_velocity_Y_mean_change_of_abs_change       87.566111
# linear_acceleration_X_peak_width_min               86.532730
# angular_velocity_X_std                             85.212899
# linear_acceleration_Z_peak_pro_max                 85.199731
# angular_velocity_Y_peak_pro_mean                   84.902079
# angular_velocity_Z_mean                            84.371810
# total_acce_std                                     82.680550
# angular_velocity_Y_abs_min                         82.448791
# angular_velocity_Z_range                           81.731499
# linear_acceleration_Z_range                        79.687000
# angular_velocity_Z_maxtoMin                        78.756101
# linear_acceleration_Z_abs_max                      75.058802
# angular_velocity_X_abs_max                         74.403889
# linear_acceleration_Z_max                          71.024139
# angular_velocity_X_peak_width_max                  70.956750
# angular_velocity_X_peak_num                        69.845659
# linear_acceleration_Y_peak_pro_max                 67.875299
# angular_velocity_Y_peak_num                        66.055968
# angular_velocity_X_mean_change_of_abs_change       65.118929
# linear_acceleration_Y_abs_avg                      64.970790
# angular_velocity_X_peak_width_min                  63.634501
# linear_acceleration_Z_maxtoMin                     61.541911
# total_acce_range                                   58.045399
# linear_acceleration_X_peak_pro_max                 57.188000
# linear_acceleration_X_abs_avg                      55.251941
# total_acce_maxtoMin                                52.934800
# total_acce_max                                     49.395700
# linear_acceleration_X_mean                         48.160488
# total_acce_abs_max                                 44.733019
# total_acce_abs_avg                                 38.057110
# linear_acceleration_Y_abs_min                      37.925200
# linear_acceleration_Z_abs_min                      37.244900
# linear_acceleration_Z_mean_change_of_abs_change    35.557141
# angular_velocity_Y_range                           35.380700
# angular_velocity_X_peak_pro_mean                   34.459450
# linear_acceleration_X_maxtoMin                     28.167100
# total_acce_median                                  25.931400
# angular_velocity_Z_std                             24.668100
# linear_acceleration_X_mean_change_of_abs_change     9.838760
# total_acce_abs_min                                  0.000000
# total_acce_mean                                     0.000000
# linear_acceleration_Z_abs_avg                       0.000000

# %%
adv_val = []
for model in clf_2:
    adv_val.append(model.predict(X_train))

# %%
plt.plot(np.sort(np.mean(adv_val, axis=0)))

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X_train, y_id))

clf = []
val_acc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'multi_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'multiclass',
               'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }

for train_idx, val_idx in splits:
    X_tr, y_tr = X_train.iloc[train_idx, :], y_id[train_idx]
    X_val, y_val = X_train.iloc[val_idx, :], y_id[val_idx]
    
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)

    val_acc.append(accuracy_score(y_val, np.argmax(pred_lgb, axis=1)))

#pred_lgb = pd.DataFrame(pred_lgb, index=np.where(np.mean(adv_val, axis=0)>0.3))
#val_pred = pd.concat([val_pred, pred_lgb], axis=0)

clf.append(model_lgb)
# Out:
# [1]	valid_0's multi_logloss: 1.90048
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1
# [39]	valid_0's multi_logloss: 1.19816
# [40]	valid_0's multi_logloss: 1.19535
# [41]	valid_0's multi_logloss: 1.19172
# [42]	valid_0's multi_logloss: 1.18839
# [43]	valid_0's multi_logloss: 1.18553
# [44]	valid_0's multi_logloss: 1.18337
# [45]	valid_0's multi_logloss: 1.18041
# [46]	valid_0's multi_logloss: 1.178
# [47]	valid_0's multi_logloss: 1.17595
# [48]	valid_0's multi_logloss: 1.17358
# [49]	valid_0's multi_logloss: 1.17176
# [50]	valid_0's multi_logloss: 1.16892
# [51]	valid_0's multi_logloss: 1.16653
# [52]	valid_0's multi_logloss: 1.16473
# [53]	valid_0's multi_logloss: 1.16306
# [54]	valid_0's multi_logloss: 1.16162
# [55]	valid_0's multi_logloss: 1.16151
# [56]	valid_0's multi_logloss: 1.15947
# [57]	valid_0's multi_logloss: 1.15761
# [58]	valid_0's multi_logloss: 1.15587
# [59]	valid_0's multi_logloss: 1.15505
# [60]	valid_0's multi_logloss: 1.15461
# [61]	valid_0's multi_logloss: 1.15301
# [62]	valid_0's multi_logloss: 1.15304
# [63]	valid_0's multi_logloss: 1.15487
# [64]	valid_0's multi_logloss: 1.15445
# [65]	valid_0's multi_logloss: 1.15415
# [66]	valid_0's multi_logloss: 1.15204
# [67]	valid_0's multi_logloss: 1.15194
# [68]	valid_0's multi_logloss: 1.15215
# [69]	valid_0's multi_logloss: 1.1513
# [70]	valid_0's multi_logloss: 1.1499
# [71]	valid_0's multi_logloss: 1.14831
# [72]	valid_0's multi_logloss: 1.14757
# [73]	valid_0's multi_logloss: 1.14517
# [74]	valid_0's multi_logloss: 1.14482
# [75]	valid_0's multi_logloss: 1.14494
# [76]	valid_0's multi_logloss: 1.14383
# [77]	valid_0's multi_logloss: 1.14267
# [78]	valid_0's multi_logloss: 1.1422
# [79]	valid_0's multi_logloss: 1.14146
# [80]	valid_0's multi_logloss: 1.14174
# [81]	valid_0's multi_logloss: 1.14065
# [82]	valid_0's multi_logloss: 1.14042
# [83]	valid_0's multi_logloss: 1.14071
# [84]	valid_0's multi_logloss: 1.14225
# [85]	valid_0's multi_logloss: 1.14215
# [86]	valid_0's multi_logloss: 1.14193
# [87]	valid_0's multi_logloss: 1.14091
# [88]	valid_0's multi_logloss: 1.14223
# [89]	valid_0's multi_logloss: 1.14278
# [90]	valid_0's multi_logloss: 1.14213
# [91]	valid_0's multi_logloss: 1.14222
# [92]	valid_0's multi_logloss: 1.14261
# [93]	valid_0's multi_logloss: 1.14219
# [94]	valid_0's multi_logloss: 1.14279
# [95]	valid_0's multi_logloss: 1.1435
# [96]	valid_0's multi_logloss: 1.14308
# [97]	valid_0's multi_logloss: 1.14278
# [98]	valid_0's multi_logloss: 1.14355
# [99]	valid_0's multi_logloss: 1.14362
# [100]	valid_0's multi_logloss: 1.14517
# [101]	valid_0's multi_logloss: 1.14568
# [102]	valid_0's multi_logloss: 1.14498
# [103]	valid_0's multi_logloss: 1.14392
# [104]	valid_0's multi_logloss: 1.14448
# [64]	valid_0's multi_logloss: 1.1267
# [65]	valid_0's multi_logloss: 1.12663
# [66]	valid_0's multi_logloss: 1.12611
# [67]	valid_0's multi_logloss: 1.12671
# [68]	valid_0's multi_logloss: 1.1263
# [69]	valid_0's multi_logloss: 1.12596
# [70]	valid_0's multi_logloss: 1.12529
# [71]	valid_0's multi_logloss: 1.1243
# [72]	valid_0's multi_logloss: 1.12415
# [73]	valid_0's multi_logloss: 1.12431
# [74]	valid_0's multi_logloss: 1.12515
# [75]	valid_0's multi_logloss: 1.12541
# [76]	valid_0's multi_logloss: 1.12568
# [77]	valid_0's multi_logloss: 1.12538
# [78]	valid_0's multi_logloss: 1.12505
# [79]	valid_0's multi_logloss: 1.12492
# [80]	valid_0's multi_logloss: 1.12512
# [81]	valid_0's multi_logloss: 1.12517
# [82]	valid_0's multi_logloss: 1.12564
# [83]	valid_0's multi_logloss: 1.12523
# [84]	valid_0's multi_logloss: 1.12417
# [85]	valid_0's multi_logloss: 1.12352
# [86]	valid_0's multi_logloss: 1.12383
# [87]	valid_0's multi_logloss: 1.12334
# [88]	valid_0's multi_logloss: 1.12385
# [89]	valid_0's multi_logloss: 1.12389
# [90]	valid_0's multi_logloss: 1.12532
# [91]	valid_0's multi_logloss: 1.1257
# [92]	valid_0's multi_logloss: 1.12674
# [93]	valid_0's multi_logloss: 1.12636
# [94]	valid_0's multi_logloss: 1.12653
# [95]	valid_0's multi_logloss: 1.12741
# [96]	valid_0's multi_logloss: 1.12774
# [97]	valid_0's multi_logloss: 1.12776
# [98]	valid_0's multi_logloss: 1.12818
# [99]	valid_0's multi_logloss: 1.12876
# [100]	valid_0's multi_logloss: 1.12951
# [101]	valid_0's multi_logloss: 1.12954
# [102]	valid_0's multi_logloss: 1.12917
# [103]	valid_0's multi_logloss: 1.13005
# [104]	valid_0's multi_logloss: 1.13086
# [105]	valid_0's multi_logloss: 1.13012
# [106]	valid_0's multi_logloss: 1.13042
# [107]	valid_0's multi_logloss: 1.13027
# [108]	valid_0's multi_logloss: 1.13027
# [109]	valid_0's multi_logloss: 1.13098
# [110]	valid_0's multi_logloss: 1.13138
# [111]	valid_0's multi_logloss: 1.13147
# [112]	valid_0's multi_logloss: 1.13193
# [113]	valid_0's multi_logloss: 1.13254
# [114]	valid_0's multi_logloss: 1.13316
# [115]	valid_0's multi_logloss: 1.13434
# [116]	valid_0's multi_logloss: 1.13365
# [117]	valid_0's multi_logloss: 1.13485
# Early stopping, best iteration is:
# [87]	valid_0's multi_logloss: 1.12334

# %%
val_acc
# Out:
# [0.5443864229765013,
#  0.5843137254901961,
#  0.5656167979002624,
#  0.5789473684210527,
#  0.6116248348745046]

# %%
feature_imp = np.zeros(X_train.shape[1])
for model in clf:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp, index=data_col).sort_values(by=0, ascending=False)
# Out:
#                                                            0
# linear_acceleration_Z_mean_abs_chg               4374.871146
# angular_velocity_Y_mean_abs_chg                  4281.214543
# linear_acceleration_X_mean_abs_chg               2904.475697
# total_acce_mean_abs_chg                          1806.821165
# linear_acceleration_Y_mean_abs_chg               1668.233455
# angular_velocity_Z_min                           1435.486588
# linear_acceleration_Z_peak_pro_max               1273.201598
# angular_velocity_X_mean_abs_chg                  1263.669176
# linear_acceleration_X_peak_pro_mean              1249.552810
# linear_acceleration_X_peak_num                   1086.536993
# angular_velocity_Y_max                            885.958485
# angular_velocity_Z_mean_abs_chg                   780.472796
# angular_velocity_Y_peak_num                       768.341006
# angular_velocity_Z_abs_avg                        665.789707
# linear_acceleration_Y_peak_width_mean             645.974531
# linear_acceleration_Y_peak_pro_mean               598.243983
# linear_acceleration_Z_peak_pro_mean               597.650782
# angular_velocity_Z_abs_max                        503.916976
# linear_acceleration_X_peak_width_mean             498.140086
# linear_acceleration_Y_median                      488.810007
# angular_velocity_X_peak_pro_max                   486.610067
# linear_acceleration_Z_peak_num                    475.050807
# angular_velocity_Z_median                         456.122848
# linear_acceleration_Z_median                      449.027050
# angular_velocity_Z_peak_pro_mean                  435.180008
# angular_velocity_Y_peak_pro_mean                  431.151326
# angular_velocity_Z_abs_min                        426.977841
# angular_velocity_X_peak_num                       421.182945
# angular_velocity_X_peak_pro_mean                  414.628306
# linear_acceleration_Y_mean                        414.262082
# linear_acceleration_Y_peak_width_max              404.851728
# angular_velocity_Z_peak_width_mean                400.531059
# angular_velocity_Z_peak_width_max                 393.092823
# linear_acceleration_Y_peak_num                    382.376165
# linear_acceleration_X_mean_change_of_abs_change   380.782220
# angular_velocity_Z_max                            351.399206
# linear_acceleration_X_max                         348.049370
# linear_acceleration_Y_mean_change_of_abs_change   336.415404
# linear_acceleration_X_peak_pro_max                334.684260
# angular_velocity_Y_peak_pro_min                   325.525987
# angular_velocity_Z_peak_pro_max                   322.122789
# total_acce_min                                    321.115780
# angular_velocity_Y_abs_max                        320.332688
# angular_velocity_X_median                         312.241982
# angular_velocity_Y_maxtoMin                       307.680641
# angular_velocity_X_max                            303.399722
# linear_acceleration_Z_peak_width_mean             303.147083
# linear_acceleration_X_peak_width_max              298.615299
# angular_velocity_Y_peak_width_mean                292.231909
# angular_velocity_X_peak_width_min                 290.639991
# angular_velocity_X_peak_width_max                 286.258454
# linear_acceleration_Z_peak_width_max              280.666356
# angular_velocity_Z_std                            275.600667
# linear_acceleration_Y_peak_width_min              271.361256
# angular_velocity_Z_range                          271.114770
# angular_velocity_Y_peak_pro_max                   270.446981
# angular_velocity_Z_peak_width_min                 267.015926
# linear_acceleration_X_peak_width_min              266.408280
# linear_acceleration_X_peak_pro_min                263.047189
# angular_velocity_X_peak_width_mean                262.038385
# angular_velocity_X_min                            260.536740
# angular_velocity_Y_std                            259.243049
# angular_velocity_Y_abs_min                        256.007038
# angular_velocity_Y_median                         252.315605
# linear_acceleration_X_abs_min                     250.366231
# angular_velocity_Y_mean                           247.631640
# angular_velocity_Y_min                            242.293205
# angular_velocity_Z_peak_pro_min                   241.998463
# linear_acceleration_X_median                      239.760290
# linear_acceleration_Y_peak_pro_max                238.896846
# angular_velocity_X_mean_change_of_abs_change      237.639727
# linear_acceleration_Z_peak_pro_min                237.573495
# angular_velocity_X_peak_pro_min                   231.817667
# linear_acceleration_X_mean                        231.115366
# linear_acceleration_X_std                         231.074034
# angular_velocity_X_abs_min                        230.614111
# angular_velocity_Z_mean_change_of_abs_change      226.987509
# linear_acceleration_Z_mean_change_of_abs_change   224.448003
# linear_acceleration_Y_min                         222.324349
# angular_velocity_X_std                            220.574828
# total_acce_std                                    214.413916
# angular_velocity_Z_mean                           212.926594
# linear_acceleration_Y_abs_avg                     212.865951
# angular_velocity_X_abs_max                        209.147320
# linear_acceleration_X_maxtoMin                    208.596979
# linear_acceleration_Y_peak_pro_min                205.564407
# angular_velocity_Y_mean_change_of_abs_change      201.657232
# linear_acceleration_Z_min                         201.237422
# angular_velocity_Y_peak_width_min                 197.067997
# linear_acceleration_X_abs_avg                     196.914048
# angular_velocity_Y_peak_width_max                 196.572841
# angular_velocity_X_maxtoMin                       192.391547
# linear_acceleration_X_abs_max                     191.679606
# total_acce_median                                 186.908835
# angular_velocity_X_mean                           186.028789
# linear_acceleration_Z_peak_width_min              182.860397
# linear_acceleration_Y_maxtoMin                    180.577906
# linear_acceleration_X_range                       178.095440
# linear_acceleration_X_min                         170.305237
# linear_acceleration_Y_std                         168.049292
# angular_velocity_Z_maxtoMin                       165.692914
# angular_velocity_Y_abs_avg                        165.338396
# linear_acceleration_Y_range                       160.390918
# linear_acceleration_Y_max                         154.539816
# angular_velocity_X_abs_avg                        153.159787
# angular_velocity_X_range                          151.451981
# total_acce_mean_change_of_abs_change              145.826806
# linear_acceleration_Z_abs_max                     143.778166
# linear_acceleration_Z_range                       143.124551
# linear_acceleration_Z_mean                        134.742641
# total_acce_abs_avg                                127.243831
# angular_velocity_Y_range                          120.396433
# angular_velocity_Z_peak_num                       116.650327
# total_acce_range                                  110.485199
# linear_acceleration_Z_std                         100.812371
# linear_acceleration_Y_abs_max                      97.742898
# total_acce_mean                                    93.752789
# linear_acceleration_Z_abs_avg                      93.545231
# total_acce_maxtoMin                                89.674785
# linear_acceleration_Z_max                          86.201175
# linear_acceleration_Z_maxtoMin                     83.183430
# total_acce_max                                     76.305838
# total_acce_abs_min                                 47.724299
# linear_acceleration_Y_abs_min                      47.472066
# linear_acceleration_Z_abs_min                      43.982046
# total_acce_abs_max                                  9.803270

# %%
preds_test = []

for model in clf:
    preds_test.append(model.predict(X_test))

# %%
preds_test = np.argmax(np.mean(preds_test, axis=0), axis=1)

# %%
test_surface = []
for i in preds_test:
    test_surface.append(id_to_target[i])

# %%
test_surface = np.asarray(test_surface)

# %%
submission = pd.read_csv('../input/sample_submission.csv')

# %%
submission['surface'] = test_surface
submission.to_csv('../output/submission_4.csv', index=False)
submission.head()
# Out:
#    series_id        surface
# 0          0  fine_concrete
# 1          1       soft_pvc
# 2          2       concrete
# 3          3     soft_tiles
# 4          4     soft_tiles
