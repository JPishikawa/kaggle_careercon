# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm_notebook
import gc

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 200)

import warnings
warnings.filterwarnings('ignore')

# %%
X_train = pd.read_csv('../input/X_train.csv')
y_train = pd.read_csv('../input/y_train.csv')
X_test  = pd.read_csv('../input/X_test.csv')

# %%
X_train.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0       -0.75853       -0.63435
# 1    0_1          0                   1       -0.75853       -0.63434
# 2    0_2          0                   2       -0.75853       -0.63435
# 3    0_3          0                   3       -0.75852       -0.63436
# 4    0_4          0                   4       -0.75852       -0.63435
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.107650            0.017561
# 1       -0.10490       -0.10600            0.067851            0.029939
# 2       -0.10492       -0.10597            0.007275            0.028934
# 3       -0.10495       -0.10597           -0.013053            0.019448
# 4       -0.10495       -0.10596            0.005135            0.007652
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 0            0.000767               -0.74857                 2.1030
# 1            0.003385                0.33995                 1.5064
# 2           -0.005978               -0.26429                 1.5922
# 3           -0.008974                0.42684                 1.0993
# 4            0.005245               -0.50969                 1.4689
#
#    linear_acceleration_Z
# 0                -9.7532
# 1                -9.4128
# 2                -8.7267
# 3               -10.0960
# 4               -10.4410

# %%
X_train.shape
# Out:
# (487680, 13)

# %%
print(X_train['measurement_number'].max(), X_train['measurement_number'].min())
# Out:
# 127 0

# %%
print(X_train['series_id'].max(), X_train['series_id'].min())
# Out:
# 3809 0

# %%
y_train.head()
# Out:
#    series_id  group_id        surface
# 0          0        13  fine_concrete
# 1          1        31       concrete
# 2          2        20       concrete
# 3          3        31       concrete
# 4          4        22     soft_tiles

# %%
targets = y_train['surface'].value_counts().index
print(targets)
print(y_train['surface'].value_counts())
# Out:
# Index(['concrete', 'soft_pvc', 'wood', 'tiled', 'fine_concrete',
#        'hard_tiles_large_space', 'soft_tiles', 'carpet', 'hard_tiles'],
#       dtype='object')
# concrete                  779
# soft_pvc                  732
# wood                      607
# tiled                     514
# fine_concrete             363
# hard_tiles_large_space    308
# soft_tiles                297
# carpet                    189
# hard_tiles                 21
# Name: surface, dtype: int64

# %%
target_to_id = {}
id_to_target = {}

for target in targets:
    if target not in target_to_id:
        new_id = len(target_to_id)
        target_to_id[target] = new_id
        id_to_target[new_id] = target

# %%
target_to_id
# Out:
# [{'concrete': 0,
#   'soft_pvc': 1,
#   'wood': 2,
#   'tiled': 3,
#   'fine_concrete': 4,
#   'hard_tiles_large_space': 5,
#   'soft_tiles': 6,
#   'carpet': 7,
#   'hard_tiles': 8}]

# %%
y_id = []
for i in range(len(y_train)):
    y_id.append(target_to_id[y_train['surface'].values[i]])
y_id = np.asarray(y_id)

# %% [markdown]
# from sklearn.preprocessing import OneHotEncoder
# encorder = OneHotEncoder()

# %%
y_id_one = np.zeros((len(y_id), class_num))
for i in range(len(y_id)):
    y_id_one[i, y_id[i]] = 1

# %%
X_train = np.asarray(X_train.iloc[:, 3:])
X_test = np.asarray(X_test.iloc[:, 3:])

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = X_train.reshape((-1, 128, 10))
X_test = X_test.reshape((-1, 128, 10))

# %%
from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting
# Out:
# Using TensorFlow backend.

# %%
N_SPLITS = 5

# %%
class Attention(Layer):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3

        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return weighted_input

    def compute_output_shape(self, input_shape):
        return input_shape[0], input_shape[1], self.features_dim

# %%
class_num = len(targets)

# %%
def model_lstm(input_shape):
    # The shape was explained above, must have this order
    inp = Input(shape=(input_shape[1], input_shape[2],))
    # This is the LSTM layer
    # Bidirecional implies that the 160 chunks are calculated in both ways, 0 to 159 and 159 to zero
    # although it appear that just 0 to 159 way matter, I have tested with and without, and tha later worked best
    # 128 and 64 are the number of cells used, too many can overfit and too few can underfit
    x = Bidirectional(LSTM(128, return_sequences=True))(inp)
    # The second LSTM can give more fire power to the model, but can overfit it too
    x = Bidirectional(LSTM(64, return_sequences=True))(x)
    # Attention is a new tecnology that can be applyed to a Recurrent NN to give more meanings to a signal found in the middle
    # of the data, it helps more in longs chains of data. A normal RNN give all the responsibility of detect the signal
    # to the last cell. Google RNN Attention for more information :)
    x = Attention(input_shape[1])(x)
    
    x = Lambda(lambda x: K.sum(x, axis=1))(x)
    # A intermediate full connected (Dense) can help to deal with nonlinears outputs
    x = Dense(64, activation="tanh")(x)
    
    out = Dense(class_num, activation='softmax')(x)
    
    model = Model(inputs=inp, outputs=out)
  
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['categorical_accuracy'])
    
    return model

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X_train, y_id))
preds_val = []
y_val = []
# Then, iteract with each fold
# If you dont know, enumerate(['a', 'b', 'c']) returns [(0, 'a'), (1, 'b'), (2, 'c')]
for idx, (train_idx, val_idx) in enumerate(splits):
    K.clear_session() # I dont know what it do, but I imagine that it "clear session" :)
    print("Beginning fold {}".format(idx+1))
    # use the indexes to extract the folds in the train and validation data
    train_X, train_y, val_X, val_y = X_train[train_idx], y_id_one[train_idx], X_train[val_idx], y_id_one[val_idx]
    # instantiate the model for this fold
    model = model_lstm(train_X.shape)
    # This checkpoint helps to avoid overfitting. It just save the weights of the model if it delivered an
    # validation matthews_correlation greater than the last one.
    ckpt = ModelCheckpoint('weights_{}.h5'.format(idx), save_best_only=True, save_weights_only=True, verbose=1, monitor='val_categorical_accuracy', mode='max')
    # Train, train, train
    model.fit(train_X, train_y, batch_size=128, epochs=50, validation_data=[val_X, val_y], callbacks=[ckpt])
    # loads the best weights saved by the checkpoint
    model.load_weights('weights_{}.h5'.format(idx))
    # Add the predictions of the validation to the list preds_val
    preds_val.append(model.predict(val_X, batch_size=512))
    # and the val true y
    y_val.append(val_y)

# concatenates all and prints the shape    
preds_val = np.concatenate(preds_val)[...,0]
y_val = np.concatenate(y_val)
preds_val.shape, y_val.shape
# Out:
# Beginning fold 1
# Train on 3044 samples, validate on 766 samples
# Epoch 1/50
# 3044/3044 [==============================] - 25s 8ms/step - loss: 1.9699 - categorical_accuracy: 0.2618 - val_loss: 1.8872 - val_categorical_accuracy: 0.3394
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.33943, saving model to weights_0.h5
# Epoch 2/50
# 3044/3044 [==============================] - 20s 6ms/step - loss: 1.7916 - categorical_accuracy: 0.3469 - val_loss: 1.7366 - val_categorical_accuracy: 0.3890
#
# Epoch 00002: val_categorical_accuracy improved from 0.33943 to 0.38903, saving model to weights_0.h5
# Epoch 3/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.6514 - categorical_accuracy: 0.4103 - val_loss: 1.6071 - val_categorical_accuracy: 0.4452
#
# Epoch 00003: val_categorical_accuracy improved from 0.38903 to 0.44517, saving model to weights_0.h5
# Epoch 4/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.5808 - categorical_accuracy: 0.4396 - val_loss: 1.5869 - val_categorical_accuracy: 0.4086
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.44517
# Epoch 5/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.5301 - categorical_accuracy: 0.4392 - val_loss: 1.5623 - val_categorical_accuracy: 0.4595
#
# Epoch 00005: val_categorical_accuracy improved from 0.44517 to 0.45953, saving model to weights_0.h5
# Epoch 6/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.5015 - categorical_accuracy: 0.4698 - val_loss: 1.5013 - val_categorical_accuracy: 0.4687
#
# Epoch 00006: val_categorical_accuracy improved from 0.45953 to 0.46867, saving model to weights_0.h5
# Epoch 7/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.4539 - categorical_accuracy: 0.4750 - val_loss: 1.4803 - val_categorical_accuracy: 0.4778
#
# Epoch 00007: val_categorical_accuracy improved from 0.46867 to 0.47781, saving model to weights_0.h5
# Epoch 8/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.4544 - categorical_accuracy: 0.4639 - val_loss: 1.4884 - val_categorical_accuracy: 0.4700
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.47781
# Epoch 9/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.4979 - categorical_accuracy: 0.4422 - val_loss: 1.5325 - val_categorical_accuracy: 0.4439
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.47781
# Epoch 10/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.5173 - categorical_accuracy: 0.4356 - val_loss: 1.4325 - val_categorical_accuracy: 0.5052
#
# Epoch 00010: val_categorical_accuracy improved from 0.47781 to 0.50522, saving model to weights_0.h5
# Epoch 11/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.4817 - categorical_accuracy: 0.4415 - val_loss: 1.4297 - val_categorical_accuracy: 0.4739
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.50522
# Epoch 12/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.3956 - categorical_accuracy: 0.4865 - val_loss: 1.3500 - val_categorical_accuracy: 0.5444
#
# Epoch 00012: val_categorical_accuracy improved from 0.50522 to 0.54439, saving model to weights_0.h5
# Epoch 13/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.3586 - categorical_accuracy: 0.5069 - val_loss: 1.3946 - val_categorical_accuracy: 0.4830
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.54439
# Epoch 14/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.3081 - categorical_accuracy: 0.5102 - val_loss: 1.3097 - val_categorical_accuracy: 0.5222
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.54439
# Epoch 15/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.2432 - categorical_accuracy: 0.5375 - val_loss: 1.2672 - val_categorical_accuracy: 0.5379
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.54439
# Epoch 16/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.2396 - categorical_accuracy: 0.5437 - val_loss: 1.2582 - val_categorical_accuracy: 0.5392
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.54439
# Epoch 17/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1840 - categorical_accuracy: 0.5535 - val_loss: 1.2466 - val_categorical_accuracy: 0.5261
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.54439
# Epoch 18/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1935 - categorical_accuracy: 0.5470 - val_loss: 1.1798 - val_categorical_accuracy: 0.5692
#
# Epoch 00018: val_categorical_accuracy improved from 0.54439 to 0.56919, saving model to weights_0.h5
# Epoch 19/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1685 - categorical_accuracy: 0.5700 - val_loss: 1.2336 - val_categorical_accuracy: 0.5444
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.56919
# Epoch 20/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1573 - categorical_accuracy: 0.5700 - val_loss: 1.1791 - val_categorical_accuracy: 0.5653
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.56919
# Epoch 21/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1787 - categorical_accuracy: 0.5463 - val_loss: 1.2028 - val_categorical_accuracy: 0.5548
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.56919
# Epoch 22/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1551 - categorical_accuracy: 0.5529 - val_loss: 1.1526 - val_categorical_accuracy: 0.5640
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.56919
# Epoch 23/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1084 - categorical_accuracy: 0.5719 - val_loss: 1.2551 - val_categorical_accuracy: 0.5366
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.56919
# Epoch 24/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.2590 - categorical_accuracy: 0.5273 - val_loss: 1.3121 - val_categorical_accuracy: 0.5144
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.56919
# Epoch 25/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.2143 - categorical_accuracy: 0.5391 - val_loss: 1.2559 - val_categorical_accuracy: 0.5392
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.56919
# Epoch 26/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1199 - categorical_accuracy: 0.5762 - val_loss: 1.1383 - val_categorical_accuracy: 0.5640
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.56919
# Epoch 27/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1358 - categorical_accuracy: 0.5644 - val_loss: 1.1593 - val_categorical_accuracy: 0.5405
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.56919
# Epoch 28/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0978 - categorical_accuracy: 0.5667 - val_loss: 1.2211 - val_categorical_accuracy: 0.5300
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.56919
# Epoch 29/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1478 - categorical_accuracy: 0.5641 - val_loss: 1.3476 - val_categorical_accuracy: 0.4935
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.56919
# Epoch 30/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1950 - categorical_accuracy: 0.5519 - val_loss: 1.2386 - val_categorical_accuracy: 0.5640
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.56919
# Epoch 31/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1288 - categorical_accuracy: 0.5782 - val_loss: 1.1678 - val_categorical_accuracy: 0.5718
#
# Epoch 00031: val_categorical_accuracy improved from 0.56919 to 0.57180, saving model to weights_0.h5
# Epoch 32/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.1150 - categorical_accuracy: 0.5736 - val_loss: 1.1252 - val_categorical_accuracy: 0.5770
#
# Epoch 00032: val_categorical_accuracy improved from 0.57180 to 0.57702, saving model to weights_0.h5
# Epoch 33/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0573 - categorical_accuracy: 0.5854 - val_loss: 1.1008 - val_categorical_accuracy: 0.5822
# Epoch 00033: val_categorical_accuracy improved from 0.57702 to 0.58225, saving model to weights_0.h5
# Epoch 34/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0404 - categorical_accuracy: 0.5897 - val_loss: 1.1457 - val_categorical_accuracy: 0.5509
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.58225
# Epoch 35/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0163 - categorical_accuracy: 0.5979 - val_loss: 1.0634 - val_categorical_accuracy: 0.5731
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.58225
# Epoch 36/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 0.9878 - categorical_accuracy: 0.6176 - val_loss: 1.1049 - val_categorical_accuracy: 0.5822
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.58225
# Epoch 37/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 0.9730 - categorical_accuracy: 0.6209 - val_loss: 1.0294 - val_categorical_accuracy: 0.6005
#
# Epoch 00037: val_categorical_accuracy improved from 0.58225 to 0.60052, saving model to weights_0.h5
# Epoch 38/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0478 - categorical_accuracy: 0.5811 - val_loss: 1.1428 - val_categorical_accuracy: 0.5640
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.60052
# Epoch 39/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0926 - categorical_accuracy: 0.5637 - val_loss: 1.2389 - val_categorical_accuracy: 0.5131
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.60052
# Epoch 40/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0662 - categorical_accuracy: 0.5851 - val_loss: 1.1143 - val_categorical_accuracy: 0.5979
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.60052
# Epoch 41/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 0.9914 - categorical_accuracy: 0.6235 - val_loss: 1.0881 - val_categorical_accuracy: 0.5653
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.60052
# Epoch 42/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 0.9652 - categorical_accuracy: 0.6130 - val_loss: 1.0405 - val_categorical_accuracy: 0.6031
#
# Epoch 00042: val_categorical_accuracy improved from 0.60052 to 0.60313, saving model to weights_0.h5
# Epoch 43/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0264 - categorical_accuracy: 0.6022 - val_loss: 1.2338 - val_categorical_accuracy: 0.5183
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.60313
# Epoch 44/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0990 - categorical_accuracy: 0.5841 - val_loss: 1.1770 - val_categorical_accuracy: 0.5574
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.60313
# Epoch 45/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0086 - categorical_accuracy: 0.6107 - val_loss: 1.1743 - val_categorical_accuracy: 0.5614
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.60313
# Epoch 46/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0339 - categorical_accuracy: 0.5972 - val_loss: 1.1509 - val_categorical_accuracy: 0.5470
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.60313
# Epoch 47/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 0.9756 - categorical_accuracy: 0.6196 - val_loss: 1.0468 - val_categorical_accuracy: 0.5875
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.60313
# Epoch 48/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 1.0003 - categorical_accuracy: 0.6117 - val_loss: 1.1124 - val_categorical_accuracy: 0.5927
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.60313
# Epoch 49/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 0.9345 - categorical_accuracy: 0.6304 - val_loss: 1.0592 - val_categorical_accuracy: 0.5888
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.60313
# Epoch 50/50
# 3044/3044 [==============================] - 19s 6ms/step - loss: 0.9365 - categorical_accuracy: 0.6330 - val_loss: 1.0314 - val_categorical_accuracy: 0.6031
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.60313
# Beginning fold 2
# Train on 3045 samples, validate on 765 samples
# Epoch 1/50
# 3045/3045 [==============================] - 23s 8ms/step - loss: 1.9663 - categorical_accuracy: 0.2644 - val_loss: 1.8416 - val_categorical_accuracy: 0.3373
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.33725, saving model to weights_1.h5
# Epoch 2/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.7890 - categorical_accuracy: 0.3461 - val_loss: 1.7356 - val_categorical_accuracy: 0.3386
#
# Epoch 00002: val_categorical_accuracy improved from 0.33725 to 0.33856, saving model to weights_1.h5
# Epoch 3/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.6639 - categorical_accuracy: 0.3967 - val_loss: 1.6069 - val_categorical_accuracy: 0.4340
#
# Epoch 00003: val_categorical_accuracy improved from 0.33856 to 0.43399, saving model to weights_1.h5
# Epoch 4/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.5734 - categorical_accuracy: 0.4296 - val_loss: 1.5590 - val_categorical_accuracy: 0.4405
#
# Epoch 00004: val_categorical_accuracy improved from 0.43399 to 0.44052, saving model to weights_1.h5
# Epoch 5/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.5366 - categorical_accuracy: 0.4427 - val_loss: 1.5538 - val_categorical_accuracy: 0.4706
#
# Epoch 00005: val_categorical_accuracy improved from 0.44052 to 0.47059, saving model to weights_1.h5
# Epoch 6/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.4942 - categorical_accuracy: 0.4522 - val_loss: 1.5173 - val_categorical_accuracy: 0.4523
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.47059
# Epoch 7/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.5239 - categorical_accuracy: 0.4407 - val_loss: 1.5270 - val_categorical_accuracy: 0.4118
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.47059
# Epoch 8/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.4488 - categorical_accuracy: 0.4663 - val_loss: 1.3934 - val_categorical_accuracy: 0.4850
#
# Epoch 00008: val_categorical_accuracy improved from 0.47059 to 0.48497, saving model to weights_1.h5
# Epoch 9/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.3765 - categorical_accuracy: 0.5120 - val_loss: 1.3962 - val_categorical_accuracy: 0.4954
#
# Epoch 00009: val_categorical_accuracy improved from 0.48497 to 0.49542, saving model to weights_1.h5
# Epoch 10/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.3491 - categorical_accuracy: 0.5143 - val_loss: 1.3522 - val_categorical_accuracy: 0.5242
#
# Epoch 00010: val_categorical_accuracy improved from 0.49542 to 0.52418, saving model to weights_1.h5
# Epoch 11/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.3385 - categorical_accuracy: 0.5094 - val_loss: 1.4992 - val_categorical_accuracy: 0.4523
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.52418
# Epoch 12/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.3587 - categorical_accuracy: 0.4966 - val_loss: 1.3440 - val_categorical_accuracy: 0.5059
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.52418
# Epoch 13/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.3109 - categorical_accuracy: 0.5094 - val_loss: 1.3467 - val_categorical_accuracy: 0.5203
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.52418
# Epoch 14/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.3079 - categorical_accuracy: 0.5222 - val_loss: 1.2653 - val_categorical_accuracy: 0.5137
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.52418
# Epoch 15/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.2715 - categorical_accuracy: 0.5169 - val_loss: 1.2825 - val_categorical_accuracy: 0.5281
#
# Epoch 00015: val_categorical_accuracy improved from 0.52418 to 0.52810, saving model to weights_1.h5
# Epoch 16/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.2195 - categorical_accuracy: 0.5478 - val_loss: 1.2124 - val_categorical_accuracy: 0.5542
#
# Epoch 00016: val_categorical_accuracy improved from 0.52810 to 0.55425, saving model to weights_1.h5
# Epoch 17/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.1891 - categorical_accuracy: 0.5478 - val_loss: 1.2219 - val_categorical_accuracy: 0.5542
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.55425
# Epoch 18/50
# 3045/3045 [==============================] - 19s 6ms/step - loss: 1.1814 - categorical_accuracy: 0.5573 - val_loss: 1.1850 - val_categorical_accuracy: 0.5582
#
# Epoch 00018: val_categorical_accuracy improved from 0.55425 to 0.55817, saving model to weights_1.h5
# Epoch 19/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.2155 - categorical_accuracy: 0.5412 - val_loss: 1.2939 - val_categorical_accuracy: 0.5190
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.55817
# Epoch 20/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.3247 - categorical_accuracy: 0.5057 - val_loss: 1.3215 - val_categorical_accuracy: 0.5320
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.55817
# Epoch 21/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.2125 - categorical_accuracy: 0.5527 - val_loss: 1.1810 - val_categorical_accuracy: 0.5490
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.55817
# Epoch 22/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.1111 - categorical_accuracy: 0.5652 - val_loss: 1.1458 - val_categorical_accuracy: 0.5529
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.55817
# Epoch 23/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.1424 - categorical_accuracy: 0.5461 - val_loss: 1.1516 - val_categorical_accuracy: 0.5660
#
# Epoch 00023: val_categorical_accuracy improved from 0.55817 to 0.56601, saving model to weights_1.h5
# Epoch 24/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.1009 - categorical_accuracy: 0.5764 - val_loss: 1.1495 - val_categorical_accuracy: 0.5935
#
# Epoch 00024: val_categorical_accuracy improved from 0.56601 to 0.59346, saving model to weights_1.h5
# Epoch 25/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.1095 - categorical_accuracy: 0.5819 - val_loss: 1.1370 - val_categorical_accuracy: 0.5529
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.59346
# Epoch 26/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0880 - categorical_accuracy: 0.5734 - val_loss: 1.0948 - val_categorical_accuracy: 0.5634
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.59346
# Epoch 27/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0280 - categorical_accuracy: 0.5964 - val_loss: 1.0547 - val_categorical_accuracy: 0.5961
#
# Epoch 00027: val_categorical_accuracy improved from 0.59346 to 0.59608, saving model to weights_1.h5
# Epoch 28/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0358 - categorical_accuracy: 0.5908 - val_loss: 1.1157 - val_categorical_accuracy: 0.5699
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.59608
# Epoch 29/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0934 - categorical_accuracy: 0.5780 - val_loss: 1.0964 - val_categorical_accuracy: 0.5778
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.59608
# Epoch 30/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0557 - categorical_accuracy: 0.5826 - val_loss: 1.0933 - val_categorical_accuracy: 0.5804
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.59608
# Epoch 31/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0658 - categorical_accuracy: 0.5796 - val_loss: 1.0975 - val_categorical_accuracy: 0.5673
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.59608
# Epoch 32/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.3514 - categorical_accuracy: 0.5031 - val_loss: 1.6369 - val_categorical_accuracy: 0.3647
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.59608
# Epoch 33/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.5056 - categorical_accuracy: 0.4342 - val_loss: 1.4270 - val_categorical_accuracy: 0.4797
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.59608
# Epoch 34/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.2736 - categorical_accuracy: 0.5202 - val_loss: 1.1898 - val_categorical_accuracy: 0.5477
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.59608
# Epoch 35/50
# 3045/3045 [==============================] - 19s 6ms/step - loss: 1.1521 - categorical_accuracy: 0.5547 - val_loss: 1.2156 - val_categorical_accuracy: 0.5490
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.59608
# Epoch 36/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.1337 - categorical_accuracy: 0.5626 - val_loss: 1.1976 - val_categorical_accuracy: 0.5529
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.59608
# Epoch 37/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.1178 - categorical_accuracy: 0.5688 - val_loss: 1.1397 - val_categorical_accuracy: 0.5739
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.59608
# Epoch 38/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0684 - categorical_accuracy: 0.5941 - val_loss: 1.0803 - val_categorical_accuracy: 0.6078
#
# Epoch 00038: val_categorical_accuracy improved from 0.59608 to 0.60784, saving model to weights_1.h5
# Epoch 39/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0965 - categorical_accuracy: 0.5724 - val_loss: 1.1240 - val_categorical_accuracy: 0.5778
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.60784
# Epoch 40/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0720 - categorical_accuracy: 0.5878 - val_loss: 1.0769 - val_categorical_accuracy: 0.5922
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.60784
# Epoch 41/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 0.9941 - categorical_accuracy: 0.6158 - val_loss: 1.0165 - val_categorical_accuracy: 0.5974
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.60784
# Epoch 42/50
# 3045/3045 [==============================] - 19s 6ms/step - loss: 0.9999 - categorical_accuracy: 0.6059 - val_loss: 1.0793 - val_categorical_accuracy: 0.5725
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.60784
# Epoch 43/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 0.9888 - categorical_accuracy: 0.6062 - val_loss: 1.2020 - val_categorical_accuracy: 0.5647
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.60784
# Epoch 44/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0710 - categorical_accuracy: 0.5826 - val_loss: 1.1299 - val_categorical_accuracy: 0.5608
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.60784
# Epoch 45/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0095 - categorical_accuracy: 0.6082 - val_loss: 1.0569 - val_categorical_accuracy: 0.5856
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.60784
# Epoch 46/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 0.9721 - categorical_accuracy: 0.6194 - val_loss: 1.0436 - val_categorical_accuracy: 0.5935
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.60784
# Epoch 47/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 1.0199 - categorical_accuracy: 0.6046 - val_loss: 1.0539 - val_categorical_accuracy: 0.5895
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.60784
# Epoch 48/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 0.9830 - categorical_accuracy: 0.6187 - val_loss: 1.0390 - val_categorical_accuracy: 0.6013
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.60784
# Epoch 49/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 0.9335 - categorical_accuracy: 0.6355 - val_loss: 0.9712 - val_categorical_accuracy: 0.6301
# Epoch 00049: val_categorical_accuracy improved from 0.60784 to 0.63007, saving model to weights_1.h5
# Epoch 50/50
# 3045/3045 [==============================] - 18s 6ms/step - loss: 0.8938 - categorical_accuracy: 0.6571 - val_loss: 0.9415 - val_categorical_accuracy: 0.6458
#
# Epoch 00050: val_categorical_accuracy improved from 0.63007 to 0.64575, saving model to weights_1.h5
# Beginning fold 3
# Train on 3048 samples, validate on 762 samples
# Epoch 1/50
# 3048/3048 [==============================] - 23s 8ms/step - loss: 1.9693 - categorical_accuracy: 0.2802 - val_loss: 1.8608 - val_categorical_accuracy: 0.2966
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.29659, saving model to weights_2.h5
# Epoch 2/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.7736 - categorical_accuracy: 0.3396 - val_loss: 1.7138 - val_categorical_accuracy: 0.3990
#
# Epoch 00002: val_categorical_accuracy improved from 0.29659 to 0.39895, saving model to weights_2.h5
# Epoch 3/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.6269 - categorical_accuracy: 0.4173 - val_loss: 1.5589 - val_categorical_accuracy: 0.4514
#
# Epoch 00003: val_categorical_accuracy improved from 0.39895 to 0.45144, saving model to weights_2.h5
# Epoch 4/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.5165 - categorical_accuracy: 0.4675 - val_loss: 1.5057 - val_categorical_accuracy: 0.4685
#
# Epoch 00004: val_categorical_accuracy improved from 0.45144 to 0.46850, saving model to weights_2.h5
# Epoch 5/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.5572 - categorical_accuracy: 0.4324 - val_loss: 1.5477 - val_categorical_accuracy: 0.4449
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.46850
# Epoch 6/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.4950 - categorical_accuracy: 0.4639 - val_loss: 1.4821 - val_categorical_accuracy: 0.4357
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.46850
# Epoch 7/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.4482 - categorical_accuracy: 0.4780 - val_loss: 1.5235 - val_categorical_accuracy: 0.4764
#
# Epoch 00007: val_categorical_accuracy improved from 0.46850 to 0.47638, saving model to weights_2.h5
# Epoch 8/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.4140 - categorical_accuracy: 0.4934 - val_loss: 1.4271 - val_categorical_accuracy: 0.4948
#
# Epoch 00008: val_categorical_accuracy improved from 0.47638 to 0.49475, saving model to weights_2.h5
# Epoch 9/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.3606 - categorical_accuracy: 0.5013 - val_loss: 1.4327 - val_categorical_accuracy: 0.4856
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.49475
# Epoch 10/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.3436 - categorical_accuracy: 0.5213 - val_loss: 1.3880 - val_categorical_accuracy: 0.4869
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.49475
# Epoch 11/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.3171 - categorical_accuracy: 0.5148 - val_loss: 1.3624 - val_categorical_accuracy: 0.4961
#
# Epoch 00011: val_categorical_accuracy improved from 0.49475 to 0.49606, saving model to weights_2.h5
# Epoch 12/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.3094 - categorical_accuracy: 0.5266 - val_loss: 1.2957 - val_categorical_accuracy: 0.5197
#
# Epoch 00012: val_categorical_accuracy improved from 0.49606 to 0.51969, saving model to weights_2.h5
# Epoch 13/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.2639 - categorical_accuracy: 0.5354 - val_loss: 1.2859 - val_categorical_accuracy: 0.5210
#
# Epoch 00013: val_categorical_accuracy improved from 0.51969 to 0.52100, saving model to weights_2.h5
# Epoch 14/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.3778 - categorical_accuracy: 0.4961 - val_loss: 1.3832 - val_categorical_accuracy: 0.4633
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.52100
# Epoch 15/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.3120 - categorical_accuracy: 0.5164 - val_loss: 1.2846 - val_categorical_accuracy: 0.5000
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.52100
# Epoch 16/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.2163 - categorical_accuracy: 0.5436 - val_loss: 1.2477 - val_categorical_accuracy: 0.5341
#
# Epoch 00016: val_categorical_accuracy improved from 0.52100 to 0.53412, saving model to weights_2.h5
# Epoch 17/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.2310 - categorical_accuracy: 0.5420 - val_loss: 1.2826 - val_categorical_accuracy: 0.5223
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.53412
# Epoch 18/50
# 3048/3048 [==============================] - 19s 6ms/step - loss: 1.2090 - categorical_accuracy: 0.5367 - val_loss: 1.2095 - val_categorical_accuracy: 0.5223
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.53412
# Epoch 19/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.1424 - categorical_accuracy: 0.5643 - val_loss: 1.1239 - val_categorical_accuracy: 0.5643
#
# Epoch 00019: val_categorical_accuracy improved from 0.53412 to 0.56430, saving model to weights_2.h5
# Epoch 20/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.1205 - categorical_accuracy: 0.5686 - val_loss: 1.1322 - val_categorical_accuracy: 0.5656
#
# Epoch 00020: val_categorical_accuracy improved from 0.56430 to 0.56562, saving model to weights_2.h5
# Epoch 21/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.1125 - categorical_accuracy: 0.5764 - val_loss: 1.1647 - val_categorical_accuracy: 0.5315
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.56562
# Epoch 22/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.1099 - categorical_accuracy: 0.5659 - val_loss: 1.1631 - val_categorical_accuracy: 0.5486
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.56562
# Epoch 23/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.2170 - categorical_accuracy: 0.5325 - val_loss: 1.2843 - val_categorical_accuracy: 0.4829
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.56562
# Epoch 24/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.1641 - categorical_accuracy: 0.5568 - val_loss: 1.2026 - val_categorical_accuracy: 0.5157
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.56562
# Epoch 25/50
# 3048/3048 [==============================] - 19s 6ms/step - loss: 1.0903 - categorical_accuracy: 0.5807 - val_loss: 1.1548 - val_categorical_accuracy: 0.5499
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.56562
# Epoch 26/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0800 - categorical_accuracy: 0.5850 - val_loss: 1.0903 - val_categorical_accuracy: 0.5866
#
# Epoch 00026: val_categorical_accuracy improved from 0.56562 to 0.58661, saving model to weights_2.h5
# Epoch 27/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0708 - categorical_accuracy: 0.5991 - val_loss: 1.1687 - val_categorical_accuracy: 0.5669
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.58661
# Epoch 28/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.1495 - categorical_accuracy: 0.5617 - val_loss: 1.2859 - val_categorical_accuracy: 0.4987
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.58661
# Epoch 29/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.1636 - categorical_accuracy: 0.5495 - val_loss: 1.1144 - val_categorical_accuracy: 0.5617
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.58661
# Epoch 30/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0487 - categorical_accuracy: 0.5925 - val_loss: 1.0731 - val_categorical_accuracy: 0.5906
#
# Epoch 00030: val_categorical_accuracy improved from 0.58661 to 0.59055, saving model to weights_2.h5
# Epoch 31/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0351 - categorical_accuracy: 0.5974 - val_loss: 1.0364 - val_categorical_accuracy: 0.5932
# Epoch 00031: val_categorical_accuracy improved from 0.59055 to 0.59318, saving model to weights_2.h5
# Epoch 32/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0279 - categorical_accuracy: 0.6004 - val_loss: 1.0290 - val_categorical_accuracy: 0.5853
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.59318
# Epoch 33/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0146 - categorical_accuracy: 0.5965 - val_loss: 1.0815 - val_categorical_accuracy: 0.5735
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.59318
# Epoch 34/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0387 - categorical_accuracy: 0.6086 - val_loss: 1.0482 - val_categorical_accuracy: 0.6024
#
# Epoch 00034: val_categorical_accuracy improved from 0.59318 to 0.60236, saving model to weights_2.h5
# Epoch 35/50
# 3048/3048 [==============================] - 19s 6ms/step - loss: 1.0188 - categorical_accuracy: 0.5974 - val_loss: 1.0391 - val_categorical_accuracy: 0.5958
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.60236
# Epoch 36/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9706 - categorical_accuracy: 0.6155 - val_loss: 1.0102 - val_categorical_accuracy: 0.6024
#
# Epoch 00036: val_categorical_accuracy improved from 0.60236 to 0.60236, saving model to weights_2.h5
# Epoch 37/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9563 - categorical_accuracy: 0.6270 - val_loss: 1.0157 - val_categorical_accuracy: 0.6063
#
# Epoch 00037: val_categorical_accuracy improved from 0.60236 to 0.60630, saving model to weights_2.h5
# Epoch 38/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0578 - categorical_accuracy: 0.5843 - val_loss: 1.0646 - val_categorical_accuracy: 0.5984
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.60630
# Epoch 39/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9925 - categorical_accuracy: 0.5971 - val_loss: 1.0562 - val_categorical_accuracy: 0.5722
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.60630
# Epoch 40/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0094 - categorical_accuracy: 0.6063 - val_loss: 1.0877 - val_categorical_accuracy: 0.5656
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.60630
# Epoch 41/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9849 - categorical_accuracy: 0.6063 - val_loss: 0.9834 - val_categorical_accuracy: 0.6115
#
# Epoch 00041: val_categorical_accuracy improved from 0.60630 to 0.61155, saving model to weights_2.h5
# Epoch 42/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0568 - categorical_accuracy: 0.6037 - val_loss: 1.1164 - val_categorical_accuracy: 0.5669
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.61155
# Epoch 43/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0405 - categorical_accuracy: 0.6027 - val_loss: 1.0574 - val_categorical_accuracy: 0.5958
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.61155
# Epoch 44/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0154 - categorical_accuracy: 0.6119 - val_loss: 1.0333 - val_categorical_accuracy: 0.5761
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.61155
# Epoch 45/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9651 - categorical_accuracy: 0.6188 - val_loss: 1.0535 - val_categorical_accuracy: 0.5709
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.61155
# Epoch 46/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9934 - categorical_accuracy: 0.6093 - val_loss: 1.0356 - val_categorical_accuracy: 0.5892
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.61155
# Epoch 47/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9900 - categorical_accuracy: 0.6079 - val_loss: 1.0252 - val_categorical_accuracy: 0.5945
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.61155
# Epoch 48/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 1.0277 - categorical_accuracy: 0.5978 - val_loss: 1.0542 - val_categorical_accuracy: 0.5787
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.61155
# Epoch 49/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9707 - categorical_accuracy: 0.6158 - val_loss: 1.0363 - val_categorical_accuracy: 0.6037
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.61155
# Epoch 50/50
# 3048/3048 [==============================] - 18s 6ms/step - loss: 0.9505 - categorical_accuracy: 0.6204 - val_loss: 0.9901 - val_categorical_accuracy: 0.6037
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.61155
# Beginning fold 4
# Train on 3050 samples, validate on 760 samples
# Epoch 1/50
# 3050/3050 [==============================] - 22s 7ms/step - loss: 1.9598 - categorical_accuracy: 0.2685 - val_loss: 1.8196 - val_categorical_accuracy: 0.3066
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.30658, saving model to weights_3.h5
# Epoch 2/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.7672 - categorical_accuracy: 0.3459 - val_loss: 1.7384 - val_categorical_accuracy: 0.3750
#
# Epoch 00002: val_categorical_accuracy improved from 0.30658 to 0.37500, saving model to weights_3.h5
# Epoch 3/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.6584 - categorical_accuracy: 0.4128 - val_loss: 1.5912 - val_categorical_accuracy: 0.4592
#
# Epoch 00003: val_categorical_accuracy improved from 0.37500 to 0.45921, saving model to weights_3.h5
# Epoch 4/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.6022 - categorical_accuracy: 0.4318 - val_loss: 1.5979 - val_categorical_accuracy: 0.4329
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.45921
# Epoch 5/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.5202 - categorical_accuracy: 0.4649 - val_loss: 1.4845 - val_categorical_accuracy: 0.4829
#
# Epoch 00005: val_categorical_accuracy improved from 0.45921 to 0.48289, saving model to weights_3.h5
# Epoch 6/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.4975 - categorical_accuracy: 0.4685 - val_loss: 1.5094 - val_categorical_accuracy: 0.4776
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.48289
# Epoch 7/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.4615 - categorical_accuracy: 0.4584 - val_loss: 1.4100 - val_categorical_accuracy: 0.4592
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.48289
# Epoch 8/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3960 - categorical_accuracy: 0.4718 - val_loss: 1.3831 - val_categorical_accuracy: 0.4789
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.48289
# Epoch 9/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3612 - categorical_accuracy: 0.5059 - val_loss: 1.3497 - val_categorical_accuracy: 0.4947
#
# Epoch 00009: val_categorical_accuracy improved from 0.48289 to 0.49474, saving model to weights_3.h5
# Epoch 10/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3563 - categorical_accuracy: 0.4967 - val_loss: 1.3237 - val_categorical_accuracy: 0.5250
#
# Epoch 00010: val_categorical_accuracy improved from 0.49474 to 0.52500, saving model to weights_3.h5
# Epoch 11/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3301 - categorical_accuracy: 0.5174 - val_loss: 1.3081 - val_categorical_accuracy: 0.5039
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.52500
# Epoch 12/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3194 - categorical_accuracy: 0.5089 - val_loss: 1.3485 - val_categorical_accuracy: 0.4868
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.52500
# Epoch 13/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3469 - categorical_accuracy: 0.5013 - val_loss: 1.4354 - val_categorical_accuracy: 0.4724
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.52500
# Epoch 14/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3363 - categorical_accuracy: 0.4997 - val_loss: 1.2792 - val_categorical_accuracy: 0.5395
#
# Epoch 00014: val_categorical_accuracy improved from 0.52500 to 0.53947, saving model to weights_3.h5
# Epoch 15/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3253 - categorical_accuracy: 0.5154 - val_loss: 1.3794 - val_categorical_accuracy: 0.4750
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.53947
# Epoch 16/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2530 - categorical_accuracy: 0.5311 - val_loss: 1.2204 - val_categorical_accuracy: 0.5658
#
# Epoch 00016: val_categorical_accuracy improved from 0.53947 to 0.56579, saving model to weights_3.h5
# Epoch 17/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2131 - categorical_accuracy: 0.5469 - val_loss: 1.2606 - val_categorical_accuracy: 0.5250
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.56579
# Epoch 18/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2646 - categorical_accuracy: 0.5203 - val_loss: 1.2592 - val_categorical_accuracy: 0.5224
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.56579
# Epoch 19/50
# 3050/3050 [==============================] - 19s 6ms/step - loss: 1.2265 - categorical_accuracy: 0.5367 - val_loss: 1.2121 - val_categorical_accuracy: 0.5368
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.56579
# Epoch 20/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1969 - categorical_accuracy: 0.5397 - val_loss: 1.2366 - val_categorical_accuracy: 0.5118
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.56579
# Epoch 21/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2149 - categorical_accuracy: 0.5462 - val_loss: 1.2182 - val_categorical_accuracy: 0.5553
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.56579
# Epoch 22/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2356 - categorical_accuracy: 0.5521 - val_loss: 1.1667 - val_categorical_accuracy: 0.5618
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.56579
# Epoch 23/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1594 - categorical_accuracy: 0.5662 - val_loss: 1.1602 - val_categorical_accuracy: 0.5553
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.56579
# Epoch 24/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.3012 - categorical_accuracy: 0.5125 - val_loss: 1.2600 - val_categorical_accuracy: 0.5355
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.56579
# Epoch 25/50
# 3050/3050 [==============================] - 19s 6ms/step - loss: 1.2435 - categorical_accuracy: 0.5344 - val_loss: 1.2337 - val_categorical_accuracy: 0.5395
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.56579
# Epoch 26/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2094 - categorical_accuracy: 0.5426 - val_loss: 1.2811 - val_categorical_accuracy: 0.5145
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.56579
# Epoch 27/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2559 - categorical_accuracy: 0.5220 - val_loss: 1.2209 - val_categorical_accuracy: 0.5237
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.56579
# Epoch 28/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1979 - categorical_accuracy: 0.5423 - val_loss: 1.2092 - val_categorical_accuracy: 0.5184
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.56579
# Epoch 29/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1560 - categorical_accuracy: 0.5652 - val_loss: 1.1504 - val_categorical_accuracy: 0.5711
#
# Epoch 00029: val_categorical_accuracy improved from 0.56579 to 0.57105, saving model to weights_3.h5
# Epoch 30/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1299 - categorical_accuracy: 0.5820 - val_loss: 1.1084 - val_categorical_accuracy: 0.5921
#
# Epoch 00030: val_categorical_accuracy improved from 0.57105 to 0.59211, saving model to weights_3.h5
# Epoch 31/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1224 - categorical_accuracy: 0.5774 - val_loss: 1.1690 - val_categorical_accuracy: 0.5474
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.59211
# Epoch 32/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1713 - categorical_accuracy: 0.5580 - val_loss: 1.1659 - val_categorical_accuracy: 0.5421
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.59211
# Epoch 33/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1769 - categorical_accuracy: 0.5580 - val_loss: 1.1575 - val_categorical_accuracy: 0.5724
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.59211
# Epoch 34/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2185 - categorical_accuracy: 0.5538 - val_loss: 1.5926 - val_categorical_accuracy: 0.4632
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.59211
# Epoch 35/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2646 - categorical_accuracy: 0.5341 - val_loss: 1.1475 - val_categorical_accuracy: 0.5526
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.59211
# Epoch 36/50
# 3050/3050 [==============================] - 19s 6ms/step - loss: 1.1721 - categorical_accuracy: 0.5489 - val_loss: 1.2852 - val_categorical_accuracy: 0.4974
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.59211
# Epoch 37/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1941 - categorical_accuracy: 0.5433 - val_loss: 1.1771 - val_categorical_accuracy: 0.5355
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.59211
# Epoch 38/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1939 - categorical_accuracy: 0.5384 - val_loss: 1.3079 - val_categorical_accuracy: 0.4789
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.59211
# Epoch 39/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2598 - categorical_accuracy: 0.5174 - val_loss: 1.2383 - val_categorical_accuracy: 0.5079
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.59211
# Epoch 40/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1800 - categorical_accuracy: 0.5587 - val_loss: 1.1469 - val_categorical_accuracy: 0.5724
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.59211
# Epoch 41/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1011 - categorical_accuracy: 0.5767 - val_loss: 1.0914 - val_categorical_accuracy: 0.5579
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.59211
# Epoch 42/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.0593 - categorical_accuracy: 0.5882 - val_loss: 1.1125 - val_categorical_accuracy: 0.5776
#
# Epoch 00042: val_categorical_accuracy did not improve from 0.59211
# Epoch 43/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1689 - categorical_accuracy: 0.5574 - val_loss: 1.6797 - val_categorical_accuracy: 0.4553
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.59211
# Epoch 44/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.4093 - categorical_accuracy: 0.4892 - val_loss: 1.3679 - val_categorical_accuracy: 0.5066
#
# Epoch 00044: val_categorical_accuracy did not improve from 0.59211
# Epoch 45/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2969 - categorical_accuracy: 0.5193 - val_loss: 1.2854 - val_categorical_accuracy: 0.5355
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.59211
# Epoch 46/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.2053 - categorical_accuracy: 0.5364 - val_loss: 1.1983 - val_categorical_accuracy: 0.5474
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.59211
# Epoch 47/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1586 - categorical_accuracy: 0.5489 - val_loss: 1.2448 - val_categorical_accuracy: 0.5105
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.59211
# Epoch 48/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1576 - categorical_accuracy: 0.5610 - val_loss: 1.1692 - val_categorical_accuracy: 0.5539
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.59211
# Epoch 49/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.1527 - categorical_accuracy: 0.5472 - val_loss: 1.1722 - val_categorical_accuracy: 0.5368
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.59211
# Epoch 50/50
# 3050/3050 [==============================] - 18s 6ms/step - loss: 1.0965 - categorical_accuracy: 0.5810 - val_loss: 1.1349 - val_categorical_accuracy: 0.5934
#
# Epoch 00050: val_categorical_accuracy improved from 0.59211 to 0.59342, saving model to weights_3.h5
# Beginning fold 5
# Train on 3053 samples, validate on 757 samples
# Epoch 1/50
# 3053/3053 [==============================] - 23s 7ms/step - loss: 1.9839 - categorical_accuracy: 0.2715 - val_loss: 1.8567 - val_categorical_accuracy: 0.3316
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.33157, saving model to weights_4.h5
# Epoch 2/50
# 3053/3053 [==============================] - 19s 6ms/step - loss: 1.7930 - categorical_accuracy: 0.3554 - val_loss: 1.6888 - val_categorical_accuracy: 0.4188
#
# Epoch 00002: val_categorical_accuracy improved from 0.33157 to 0.41876, saving model to weights_4.h5
# Epoch 3/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.6463 - categorical_accuracy: 0.4330 - val_loss: 1.5966 - val_categorical_accuracy: 0.4267
#
# Epoch 00003: val_categorical_accuracy improved from 0.41876 to 0.42668, saving model to weights_4.h5
# Epoch 4/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.5744 - categorical_accuracy: 0.4350 - val_loss: 1.5172 - val_categorical_accuracy: 0.4624
#
# Epoch 00004: val_categorical_accuracy improved from 0.42668 to 0.46235, saving model to weights_4.h5
# Epoch 5/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.4887 - categorical_accuracy: 0.4592 - val_loss: 1.4448 - val_categorical_accuracy: 0.4901
#
# Epoch 00005: val_categorical_accuracy improved from 0.46235 to 0.49009, saving model to weights_4.h5
# Epoch 6/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.4178 - categorical_accuracy: 0.4913 - val_loss: 1.4052 - val_categorical_accuracy: 0.4967
#
# Epoch 00006: val_categorical_accuracy improved from 0.49009 to 0.49670, saving model to weights_4.h5
# Epoch 7/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.4018 - categorical_accuracy: 0.4972 - val_loss: 1.4337 - val_categorical_accuracy: 0.4729
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.49670
# Epoch 8/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.4344 - categorical_accuracy: 0.4733 - val_loss: 1.4439 - val_categorical_accuracy: 0.4967
#
# Epoch 00008: val_categorical_accuracy improved from 0.49670 to 0.49670, saving model to weights_4.h5
# Epoch 9/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.4038 - categorical_accuracy: 0.4864 - val_loss: 1.3755 - val_categorical_accuracy: 0.4835
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.49670
# Epoch 10/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.3915 - categorical_accuracy: 0.4848 - val_loss: 1.3663 - val_categorical_accuracy: 0.5020
#
# Epoch 00010: val_categorical_accuracy improved from 0.49670 to 0.50198, saving model to weights_4.h5
# Epoch 11/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.3228 - categorical_accuracy: 0.5100 - val_loss: 1.3221 - val_categorical_accuracy: 0.5310
#
# Epoch 00011: val_categorical_accuracy improved from 0.50198 to 0.53104, saving model to weights_4.h5
# Epoch 12/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.2789 - categorical_accuracy: 0.5290 - val_loss: 1.3255 - val_categorical_accuracy: 0.5350
#
# Epoch 00012: val_categorical_accuracy improved from 0.53104 to 0.53501, saving model to weights_4.h5
# Epoch 13/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.2664 - categorical_accuracy: 0.5339 - val_loss: 1.2759 - val_categorical_accuracy: 0.5099
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.53501
# Epoch 14/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.2077 - categorical_accuracy: 0.5467 - val_loss: 1.2257 - val_categorical_accuracy: 0.5482
#
# Epoch 00014: val_categorical_accuracy improved from 0.53501 to 0.54822, saving model to weights_4.h5
# Epoch 15/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.2404 - categorical_accuracy: 0.5460 - val_loss: 1.2588 - val_categorical_accuracy: 0.5363
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.54822
# Epoch 16/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.3348 - categorical_accuracy: 0.5054 - val_loss: 1.2620 - val_categorical_accuracy: 0.5376
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.54822
# Epoch 17/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.2224 - categorical_accuracy: 0.5509 - val_loss: 1.1825 - val_categorical_accuracy: 0.5509
#
# Epoch 00017: val_categorical_accuracy improved from 0.54822 to 0.55086, saving model to weights_4.h5
# Epoch 18/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1898 - categorical_accuracy: 0.5611 - val_loss: 1.1748 - val_categorical_accuracy: 0.5614
#
# Epoch 00018: val_categorical_accuracy improved from 0.55086 to 0.56143, saving model to weights_4.h5
# Epoch 19/50
# 3053/3053 [==============================] - 19s 6ms/step - loss: 1.1914 - categorical_accuracy: 0.5509 - val_loss: 1.2333 - val_categorical_accuracy: 0.5469
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.56143
# Epoch 20/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1711 - categorical_accuracy: 0.5624 - val_loss: 1.3577 - val_categorical_accuracy: 0.4690
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.56143
# Epoch 21/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1689 - categorical_accuracy: 0.5539 - val_loss: 1.1636 - val_categorical_accuracy: 0.5561
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.56143
# Epoch 22/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1203 - categorical_accuracy: 0.5798 - val_loss: 1.1563 - val_categorical_accuracy: 0.5575
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.56143
# Epoch 23/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1129 - categorical_accuracy: 0.5788 - val_loss: 1.1242 - val_categorical_accuracy: 0.5707
#
# Epoch 00023: val_categorical_accuracy improved from 0.56143 to 0.57067, saving model to weights_4.h5
# Epoch 24/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1139 - categorical_accuracy: 0.5781 - val_loss: 1.1716 - val_categorical_accuracy: 0.5509
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.57067
# Epoch 25/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0894 - categorical_accuracy: 0.5837 - val_loss: 1.1607 - val_categorical_accuracy: 0.5403
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.57067
# Epoch 26/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1305 - categorical_accuracy: 0.5614 - val_loss: 1.1341 - val_categorical_accuracy: 0.5720
#
# Epoch 00026: val_categorical_accuracy improved from 0.57067 to 0.57199, saving model to weights_4.h5
# Epoch 27/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0855 - categorical_accuracy: 0.5915 - val_loss: 1.1536 - val_categorical_accuracy: 0.5641
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.57199
# Epoch 28/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0602 - categorical_accuracy: 0.5968 - val_loss: 1.1554 - val_categorical_accuracy: 0.5627
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.57199
# Epoch 29/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0701 - categorical_accuracy: 0.5853 - val_loss: 1.0726 - val_categorical_accuracy: 0.5945
#
# Epoch 00029: val_categorical_accuracy improved from 0.57199 to 0.59445, saving model to weights_4.h5
# Epoch 30/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0228 - categorical_accuracy: 0.6017 - val_loss: 1.1723 - val_categorical_accuracy: 0.5482
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.59445
# Epoch 31/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1297 - categorical_accuracy: 0.5647 - val_loss: 1.1277 - val_categorical_accuracy: 0.5733
#
# Epoch 00031: val_categorical_accuracy did not improve from 0.59445
# Epoch 32/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1299 - categorical_accuracy: 0.5670 - val_loss: 1.1839 - val_categorical_accuracy: 0.5443
#
# Epoch 00032: val_categorical_accuracy did not improve from 0.59445
# Epoch 33/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.1028 - categorical_accuracy: 0.5771 - val_loss: 1.1301 - val_categorical_accuracy: 0.5707
#
# Epoch 00033: val_categorical_accuracy did not improve from 0.59445
# Epoch 34/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0558 - categorical_accuracy: 0.6053 - val_loss: 1.1058 - val_categorical_accuracy: 0.5892
#
# Epoch 00034: val_categorical_accuracy did not improve from 0.59445
# Epoch 35/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0382 - categorical_accuracy: 0.6033 - val_loss: 1.0917 - val_categorical_accuracy: 0.5878
#
# Epoch 00035: val_categorical_accuracy did not improve from 0.59445
# Epoch 36/50
# 3053/3053 [==============================] - 19s 6ms/step - loss: 1.0227 - categorical_accuracy: 0.6010 - val_loss: 1.1077 - val_categorical_accuracy: 0.5746
#
# Epoch 00036: val_categorical_accuracy did not improve from 0.59445
# Epoch 37/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0106 - categorical_accuracy: 0.6063 - val_loss: 1.1261 - val_categorical_accuracy: 0.5905
#
# Epoch 00037: val_categorical_accuracy did not improve from 0.59445
# Epoch 38/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0587 - categorical_accuracy: 0.5824 - val_loss: 1.0715 - val_categorical_accuracy: 0.5799
#
# Epoch 00038: val_categorical_accuracy did not improve from 0.59445
# Epoch 39/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0106 - categorical_accuracy: 0.5991 - val_loss: 1.0444 - val_categorical_accuracy: 0.5839
#
# Epoch 00039: val_categorical_accuracy did not improve from 0.59445
# Epoch 40/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 0.9582 - categorical_accuracy: 0.6168 - val_loss: 1.0187 - val_categorical_accuracy: 0.5945
#
# Epoch 00040: val_categorical_accuracy did not improve from 0.59445
# Epoch 41/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0656 - categorical_accuracy: 0.5843 - val_loss: 1.1850 - val_categorical_accuracy: 0.5667
#
# Epoch 00041: val_categorical_accuracy did not improve from 0.59445
# Epoch 42/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0216 - categorical_accuracy: 0.6063 - val_loss: 1.0236 - val_categorical_accuracy: 0.6050
#
# Epoch 00042: val_categorical_accuracy improved from 0.59445 to 0.60502, saving model to weights_4.h5
# Epoch 43/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0011 - categorical_accuracy: 0.6007 - val_loss: 1.1257 - val_categorical_accuracy: 0.5694
#
# Epoch 00043: val_categorical_accuracy did not improve from 0.60502
# Epoch 44/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 0.9671 - categorical_accuracy: 0.6083 - val_loss: 0.9949 - val_categorical_accuracy: 0.6209
#
# Epoch 00044: val_categorical_accuracy improved from 0.60502 to 0.62087, saving model to weights_4.h5
# Epoch 45/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 0.9394 - categorical_accuracy: 0.6168 - val_loss: 0.9971 - val_categorical_accuracy: 0.6143
#
# Epoch 00045: val_categorical_accuracy did not improve from 0.62087
# Epoch 46/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 0.9337 - categorical_accuracy: 0.6341 - val_loss: 1.0717 - val_categorical_accuracy: 0.5984
#
# Epoch 00046: val_categorical_accuracy did not improve from 0.62087
# Epoch 47/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0237 - categorical_accuracy: 0.5965 - val_loss: 1.0206 - val_categorical_accuracy: 0.5746
#
# Epoch 00047: val_categorical_accuracy did not improve from 0.62087
# Epoch 48/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 0.9330 - categorical_accuracy: 0.6171 - val_loss: 0.9850 - val_categorical_accuracy: 0.6077
#
# Epoch 00048: val_categorical_accuracy did not improve from 0.62087
# Epoch 49/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 0.9368 - categorical_accuracy: 0.6191 - val_loss: 0.9908 - val_categorical_accuracy: 0.6129
#
# Epoch 00049: val_categorical_accuracy did not improve from 0.62087
# Epoch 50/50
# 3053/3053 [==============================] - 18s 6ms/step - loss: 1.0841 - categorical_accuracy: 0.5699 - val_loss: 1.0832 - val_categorical_accuracy: 0.5839
#
# Epoch 00050: val_categorical_accuracy did not improve from 0.62087
# ((3810,), (3810, 9))
