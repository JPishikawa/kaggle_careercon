# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm
import gc

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 200)

import warnings
warnings.filterwarnings('ignore')

from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
X_train = pd.read_csv('../input/X_train.csv')
y_train = pd.read_csv('../input/y_train.csv')
X_test  = pd.read_csv('../input/X_test.csv')

# %%
targets = y_train['surface'].value_counts().index
print(targets)
print(y_train['surface'].value_counts())

# %%
target_to_id = {}
id_to_target = {}

for target in targets:
    if target not in target_to_id:
        new_id = len(target_to_id)
        target_to_id[target] = new_id
        id_to_target[new_id] = target

# %%
y_id = []
for i in range(len(y_train)):
    y_id.append(target_to_id[y_train['surface'].values[i]])
y_id = np.asarray(y_id)

# %%
class_num = len(targets)

# %%
y_id_one = np.zeros((len(y_id), class_num))
for i in range(len(y_id)):
    y_id_one[i, y_id[i]] = 1

# %%
def norm_quat(df):
    norm = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2 + df['orientation_W']**2)**0.5
    df['orientation_X'] /= norm
    df['orientation_Y'] /= norm
    df['orientation_Z'] /= norm
    df['orientation_W'] /= norm
    return df

# %%
import math

def quaternion_to_euler(x, y, z, w):
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.atan2(t0, t1)

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.asin(t2)

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.atan2(t3, t4)

    return X, Y, Z

# %%
X_train = norm_quat(X_train)
X_test = norm_quat(X_test)

# %%
def fe_step1 (df):
    """Quaternions to Euler Angles"""
    
    x = df['orientation_X'].values
    y = df['orientation_Y'].values
    z = df['orientation_Z'].values
    w = df['orientation_W'].values
    nx, ny, nz = np.zeros(len(x)), np.zeros(len(y)), np.zeros(len(z)),
    for i in tqdm(range(len(x))):
        xx, yy, zz = quaternion_to_euler(x[i], y[i], z[i], w[i])
        nx[i] = xx
        ny[i] = yy
        nz[i] = zz
    
    df['euler_X'] = nx
    df['euler_Y'] = ny
    df['euler_Z'] = nz
    return df

# %%
X_train = fe_step1(X_train)
X_test = fe_step1(X_test)

# %%
def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))

# %%
ang_list = ['angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z']

# %%
cos_list = ['angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z']

for data in [X_train, X_test]:
    for col in cos_list:
        data[col + '_cos'] = np.cos(data[col].values)

# %%
X_train.head()

# %%
def feat_eng(df):
    data = pd.DataFrame()
    df['linear_acceleration_Z'] += 9.80665
    df['eulerX-Z'] = df['euler_X']-df['euler_Z']
    df['total_acce'] = (df['linear_acceleration_X']**2 + df['linear_acceleration_Y']**2 + df['linear_acceleration_Z']**2)**0.5
    df['total_ang_cos'] = (df['angular_velocity_X_cos']**2 + df['angular_velocity_Y_cos']**2 + df['angular_velocity_Z_cos']**2)**0.5
    
    tmp_df = pd.concat([df['linear_acceleration_Z'], df['angular_velocity_X']], axis=1)
    scaler = MinMaxScaler(feature_range=(-1, 1))
    tmp_df = scaler.fit_transform(tmp_df)
    
    #df['total_angu'] = (df['angular_velocity_X']**2 + df['angular_velocity_Y']**2 + df['angular_velocity_Z']**2)**0.5
    
    #df['total_eule'] = (df['euler_X']**2 + df['euler_Y']**2 + df['euler_Z']**2)**0.5
    #df['total_xyz'] = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2)**0.5
    #df['total_acc/vel'] = df['total_acce']/df['total_angu']
    
    df_columns = df.columns[3:]
    for col in tqdm(df_columns):
        data[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        data[col + '_median'] = df.groupby(['series_id'])[col].median()
        data[col + '_max'] = df.groupby(['series_id'])[col].max()
        data[col + '_min'] = df.groupby(['series_id'])[col].min()
        data[col + '_std'] = df.groupby(['series_id'])[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        data[col + '_mean_abs_chg'] = df.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        data[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
        data[col + '_abs_max'] = df.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        data[col + '_abs_min'] = df.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        data[col + '_abs_avg'] = (data[col + '_abs_min'] + data[col + '_abs_max'])/2
        
        
    #data['corr_linZangX'] = np.correlate(np.abs(tmp_df[:, 0]), np.abs(tmp_df[:, 1]))
    return data

# %%
X_train = feat_eng(X_train)
X_test = feat_eng(X_test)

# %%
data_col = X_train.columns

# %%
for data in [X_train, X_test]:
    data.fillna(0,inplace=True)
    data.replace(-np.inf,0,inplace=True)
    data.replace(np.inf,0,inplace=True)

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
N_SPLITS = 5

# %%
import tensorflow as tf
from sklearn.metrics import roc_auc_score

def auroc(y_true, y_pred):
    return tf.py_function(roc_auc_score, (y_true, y_pred), tf.double)

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score

# %%
y = np.concatenate((np.zeros(len(X_train)), np.ones(len(X_test))), axis=0)
X = np.concatenate((X_train, X_test), axis=0)

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))

clf_2 = []
val_roc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'binary_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'binary',
               #'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }


for train_idx, val_idx in splits:
    X_tr, y_tr = X[train_idx, :], y[train_idx]
    X_val, y_val = X[val_idx, :], y[val_idx]
 
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)
    
    val_roc.append(roc_auc_score(y_val, (pred_lgb>0.5).astype(int)))
    
    pred_lgb = pd.DataFrame(pred_lgb, index=val_idx)
    val_pred = pd.concat([val_pred, pred_lgb], axis=0)
    
    clf_2.append(model_lgb)
# Out:
# [1]	valid_0's binary_logloss: 0.688478
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.685098
# [3]	valid_0's binary_logloss: 0.682749
# [4]	valid_0's binary_logloss: 0.680577
# [5]	valid_0's binary_logloss: 0.678298
# [6]	valid_0's binary_logloss: 0.677618
# [7]	valid_0's binary_logloss: 0.675856
# [8]	valid_0's binary_logloss: 0.674908
# [9]	valid_0's binary_logloss: 0.673652
# [10]	valid_0's binary_logloss: 0.672983
# [11]	valid_0's binary_logloss: 0.672175
# [12]	valid_0's binary_logloss: 0.671442
# [13]	valid_0's binary_logloss: 0.671537
# [14]	valid_0's binary_logloss: 0.671357
# [15]	valid_0's binary_logloss: 0.669894
# [16]	valid_0's binary_logloss: 0.669519
# [17]	valid_0's binary_logloss: 0.669497
# [18]	valid_0's binary_logloss: 0.669128
# [19]	valid_0's binary_logloss: 0.669368
# [20]	valid_0's binary_logloss: 0.669368
# [21]	valid_0's binary_logloss: 0.669317
# [22]	valid_0's binary_logloss: 0.668942
# [23]	valid_0's binary_logloss: 0.668763
# [24]	valid_0's binary_logloss: 0.668519
# [25]	valid_0's binary_logloss: 0.668551
# [26]	valid_0's binary_logloss: 0.667986
# [27]	valid_0's binary_logloss: 0.668034
# [28]	valid_0's binary_logloss: 0.667208
# [29]	valid_0's binary_logloss: 0.667624
# [30]	valid_0's binary_logloss: 0.667855
# [31]	valid_0's binary_logloss: 0.667199
# [32]	valid_0's binary_logloss: 0.667321
# [33]	valid_0's binary_logloss: 0.667394
# [34]	valid_0's binary_logloss: 0.667339
# [35]	valid_0's binary_logloss: 0.667773
# [36]	valid_0's binary_logloss: 0.667862
# [37]	valid_0's binary_logloss: 0.66802
# [38]	valid_0's binary_logloss: 0.668716
# [39]	valid_0's binary_logloss: 0.668975
# [40]	valid_0's binary_logloss: 0.668652
# [41]	valid_0's binary_logloss: 0.668587
# [42]	valid_0's binary_logloss: 0.66843
# [43]	valid_0's binary_logloss: 0.66808
# [44]	valid_0's binary_logloss: 0.668222
# [45]	valid_0's binary_logloss: 0.667977
# [46]	valid_0's binary_logloss: 0.667871
# [47]	valid_0's binary_logloss: 0.667995
# [48]	valid_0's binary_logloss: 0.668065
# [49]	valid_0's binary_logloss: 0.667889
# [50]	valid_0's binary_logloss: 0.667906
# [51]	valid_0's binary_logloss: 0.668156
# [52]	valid_0's binary_logloss: 0.668032
# [53]	valid_0's binary_logloss: 0.667949
# [54]	valid_0's binary_logloss: 0.668249
# [55]	valid_0's binary_logloss: 0.668874
# [56]	valid_0's binary_logloss: 0.66849
# [57]	valid_0's binary_logloss: 0.668749
# [58]	valid_0's binary_logloss: 0.668916
# [59]	valid_0's binary_logloss: 0.669175
# [60]	valid_0's binary_logloss: 0.668983
# [61]	valid_0's binary_logloss: 0.668986
# Early stopping, best iteration is:
# [31]	valid_0's binary_logloss: 0.667199
# [1]	valid_0's binary_logloss: 0.689611
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.68574
# [3]	valid_0's binary_logloss: 0.68318
# [4]	valid_0's binary_logloss: 0.680539
# [5]	valid_0's binary_logloss: 0.678518
# [6]	valid_0's binary_logloss: 0.676107
# [7]	valid_0's binary_logloss: 0.674291
# [8]	valid_0's binary_logloss: 0.672639
# [9]	valid_0's binary_logloss: 0.671748
# [10]	valid_0's binary_logloss: 0.670555
# [11]	valid_0's binary_logloss: 0.669415
# [12]	valid_0's binary_logloss: 0.669215
# [13]	valid_0's binary_logloss: 0.668783
# [14]	valid_0's binary_logloss: 0.668266
# [15]	valid_0's binary_logloss: 0.667709
# [16]	valid_0's binary_logloss: 0.667377
# [17]	valid_0's binary_logloss: 0.666404
# [18]	valid_0's binary_logloss: 0.666581
# [19]	valid_0's binary_logloss: 0.666627
# [20]	valid_0's binary_logloss: 0.666371
# [21]	valid_0's binary_logloss: 0.666201
# [22]	valid_0's binary_logloss: 0.665567
# [23]	valid_0's binary_logloss: 0.665046
# [24]	valid_0's binary_logloss: 0.664426
# [25]	valid_0's binary_logloss: 0.66474
# [26]	valid_0's binary_logloss: 0.664261
# [27]	valid_0's binary_logloss: 0.663616
# [28]	valid_0's binary_logloss: 0.663989
# [29]	valid_0's binary_logloss: 0.663632
# [30]	valid_0's binary_logloss: 0.662814
# [31]	valid_0's binary_logloss: 0.662539
# [32]	valid_0's binary_logloss: 0.662689
# [33]	valid_0's binary_logloss: 0.662886
# [34]	valid_0's binary_logloss: 0.662884
# [35]	valid_0's binary_logloss: 0.663213
# [36]	valid_0's binary_logloss: 0.663452
# [37]	valid_0's binary_logloss: 0.662948
# [38]	valid_0's binary_logloss: 0.663503
# [39]	valid_0's binary_logloss: 0.663563
# [40]	valid_0's binary_logloss: 0.663629
# [41]	valid_0's binary_logloss: 0.663722
# [42]	valid_0's binary_logloss: 0.663744
# [43]	valid_0's binary_logloss: 0.663535
# [44]	valid_0's binary_logloss: 0.663178
# [45]	valid_0's binary_logloss: 0.662812
# [46]	valid_0's binary_logloss: 0.663302
# [47]	valid_0's binary_logloss: 0.663304
# [48]	valid_0's binary_logloss: 0.662961
# [49]	valid_0's binary_logloss: 0.662824
# [50]	valid_0's binary_logloss: 0.6626
# [51]	valid_0's binary_logloss: 0.663135
# [52]	valid_0's binary_logloss: 0.662498
# [53]	valid_0's binary_logloss: 0.662311
# [54]	valid_0's binary_logloss: 0.662235
# [55]	valid_0's binary_logloss: 0.662058
# [56]	valid_0's binary_logloss: 0.66147
# [57]	valid_0's binary_logloss: 0.661403
# [58]	valid_0's binary_logloss: 0.660631
# [59]	valid_0's binary_logloss: 0.660047
# [60]	valid_0's binary_logloss: 0.659728
# [61]	valid_0's binary_logloss: 0.660219
# [62]	valid_0's binary_logloss: 0.660271
# [63]	valid_0's binary_logloss: 0.660415
# [64]	valid_0's binary_logloss: 0.660032
# [65]	valid_0's binary_logloss: 0.660503
# [66]	valid_0's binary_logloss: 0.660368
# [67]	valid_0's binary_logloss: 0.660067
# [68]	valid_0's binary_logloss: 0.660005
# [69]	valid_0's binary_logloss: 0.660165
# [70]	valid_0's binary_logloss: 0.660681
# [71]	valid_0's binary_logloss: 0.661027
# [72]	valid_0's binary_logloss: 0.660872
# [73]	valid_0's binary_logloss: 0.660552
# [74]	valid_0's binary_logloss: 0.660517
# [75]	valid_0's binary_logloss: 0.66031
# [76]	valid_0's binary_logloss: 0.659985
# [77]	valid_0's binary_logloss: 0.660232
# [78]	valid_0's binary_logloss: 0.660185
# [79]	valid_0's binary_logloss: 0.659645
# [80]	valid_0's binary_logloss: 0.659653
# [81]	valid_0's binary_logloss: 0.659376
# [82]	valid_0's binary_logloss: 0.658888
# [83]	valid_0's binary_logloss: 0.659727
# [84]	valid_0's binary_logloss: 0.659503
# [85]	valid_0's binary_logloss: 0.659416
# [86]	valid_0's binary_logloss: 0.659664
# [87]	valid_0's binary_logloss: 0.659252
# [88]	valid_0's binary_logloss: 0.659056
# [89]	valid_0's binary_logloss: 0.658568
# [90]	valid_0's binary_logloss: 0.65828
# [91]	valid_0's binary_logloss: 0.65853
# [92]	valid_0's binary_logloss: 0.658399
# [93]	valid_0's binary_logloss: 0.65828
# [94]	valid_0's binary_logloss: 0.658279
# [95]	valid_0's binary_logloss: 0.657938
# [96]	valid_0's binary_logloss: 0.658027
# [97]	valid_0's binary_logloss: 0.658283
# [98]	valid_0's binary_logloss: 0.6578
# [99]	valid_0's binary_logloss: 0.658323
# [100]	valid_0's binary_logloss: 0.658286
# [101]	valid_0's binary_logloss: 0.658542
# [102]	valid_0's binary_logloss: 0.658551
# [103]	valid_0's binary_logloss: 0.658583
# [104]	valid_0's binary_logloss: 0.658216
# [105]	valid_0's binary_logloss: 0.658389
# [106]	valid_0's binary_logloss: 0.658076
# [107]	valid_0's binary_logloss: 0.657907
# [108]	valid_0's binary_logloss: 0.657939
# [109]	valid_0's binary_logloss: 0.658178
# [110]	valid_0's binary_logloss: 0.658186
# [111]	valid_0's binary_logloss: 0.658425
# [112]	valid_0's binary_logloss: 0.658406
# [113]	valid_0's binary_logloss: 0.658153
# [114]	valid_0's binary_logloss: 0.658259
# [115]	valid_0's binary_logloss: 0.658099
# [116]	valid_0's binary_logloss: 0.657678
# [117]	valid_0's binary_logloss: 0.657544
# [118]	valid_0's binary_logloss: 0.657654
# [119]	valid_0's binary_logloss: 0.657473
# [120]	valid_0's binary_logloss: 0.657144
# [121]	valid_0's binary_logloss: 0.656995
# [122]	valid_0's binary_logloss: 0.656846
# [123]	valid_0's binary_logloss: 0.65664
# [124]	valid_0's binary_logloss: 0.656781
# [125]	valid_0's binary_logloss: 0.656907
# [126]	valid_0's binary_logloss: 0.65744
# [127]	valid_0's binary_logloss: 0.657807
# [128]	valid_0's binary_logloss: 0.657507
# [129]	valid_0's binary_logloss: 0.657357
# [130]	valid_0's binary_logloss: 0.65718
# [131]	valid_0's binary_logloss: 0.657083
# [132]	valid_0's binary_logloss: 0.656677
# [133]	valid_0's binary_logloss: 0.657379
# [134]	valid_0's binary_logloss: 0.657906
# [135]	valid_0's binary_logloss: 0.657365
# [136]	valid_0's binary_logloss: 0.657249
# [137]	valid_0's binary_logloss: 0.656589
# [138]	valid_0's binary_logloss: 0.656681
# [139]	valid_0's binary_logloss: 0.656464
# [140]	valid_0's binary_logloss: 0.656199
# [141]	valid_0's binary_logloss: 0.655814
# [142]	valid_0's binary_logloss: 0.655665
# [143]	valid_0's binary_logloss: 0.65552
# [144]	valid_0's binary_logloss: 0.655667
# [145]	valid_0's binary_logloss: 0.655608
# [146]	valid_0's binary_logloss: 0.654906
# [147]	valid_0's binary_logloss: 0.654571
# [148]	valid_0's binary_logloss: 0.654831
# [149]	valid_0's binary_logloss: 0.654339
# [150]	valid_0's binary_logloss: 0.654569
# [151]	valid_0's binary_logloss: 0.654402
# [152]	valid_0's binary_logloss: 0.654581
# [153]	valid_0's binary_logloss: 0.65488
# [154]	valid_0's binary_logloss: 0.655141
# [155]	valid_0's binary_logloss: 0.65523
# [156]	valid_0's binary_logloss: 0.655496
# [157]	valid_0's binary_logloss: 0.655728
# [158]	valid_0's binary_logloss: 0.656293
# [159]	valid_0's binary_logloss: 0.656266
# [160]	valid_0's binary_logloss: 0.656447
# [161]	valid_0's binary_logloss: 0.656417
# [162]	valid_0's binary_logloss: 0.656845
# [163]	valid_0's binary_logloss: 0.657225
# [164]	valid_0's binary_logloss: 0.656984
# [165]	valid_0's binary_logloss: 0.656753
# [166]	valid_0's binary_logloss: 0.656792
# [167]	valid_0's binary_logloss: 0.656586
# [168]	valid_0's binary_logloss: 0.656737
# [169]	valid_0's binary_logloss: 0.657063
# [170]	valid_0's binary_logloss: 0.657188
# [171]	valid_0's binary_logloss: 0.657773
# [172]	valid_0's binary_logloss: 0.657728
# [173]	valid_0's binary_logloss: 0.657752
# [174]	valid_0's binary_logloss: 0.657644
# [175]	valid_0's binary_logloss: 0.657365
# [176]	valid_0's binary_logloss: 0.657424
# [177]	valid_0's binary_logloss: 0.657555
# [178]	valid_0's binary_logloss: 0.65754
# [179]	valid_0's binary_logloss: 0.657509
# Early stopping, best iteration is:
# [149]	valid_0's binary_logloss: 0.654339
# [1]	valid_0's binary_logloss: 0.689988
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.687304
# [3]	valid_0's binary_logloss: 0.686187
# [4]	valid_0's binary_logloss: 0.685351
# [5]	valid_0's binary_logloss: 0.684166
# [6]	valid_0's binary_logloss: 0.683035
# [7]	valid_0's binary_logloss: 0.682215
# [8]	valid_0's binary_logloss: 0.6815
# [9]	valid_0's binary_logloss: 0.680662
# [10]	valid_0's binary_logloss: 0.680582
# [11]	valid_0's binary_logloss: 0.67919
# [12]	valid_0's binary_logloss: 0.678444
# [13]	valid_0's binary_logloss: 0.678048
# [14]	valid_0's binary_logloss: 0.677414
# [15]	valid_0's binary_logloss: 0.676807
# [16]	valid_0's binary_logloss: 0.676678
# [17]	valid_0's binary_logloss: 0.676112
# [18]	valid_0's binary_logloss: 0.67584
# [19]	valid_0's binary_logloss: 0.675719
# [20]	valid_0's binary_logloss: 0.675425
# [21]	valid_0's binary_logloss: 0.675418
# [22]	valid_0's binary_logloss: 0.675264
# [23]	valid_0's binary_logloss: 0.676161
# [24]	valid_0's binary_logloss: 0.675914
# [25]	valid_0's binary_logloss: 0.675836
# [26]	valid_0's binary_logloss: 0.675732
# [27]	valid_0's binary_logloss: 0.675023
# [28]	valid_0's binary_logloss: 0.675565
# [29]	valid_0's binary_logloss: 0.675559
# [30]	valid_0's binary_logloss: 0.675612
# [31]	valid_0's binary_logloss: 0.67546
# [32]	valid_0's binary_logloss: 0.676139
# [33]	valid_0's binary_logloss: 0.676778
# [34]	valid_0's binary_logloss: 0.676774
# [35]	valid_0's binary_logloss: 0.677313
# [36]	valid_0's binary_logloss: 0.677272
# [37]	valid_0's binary_logloss: 0.67735
# [38]	valid_0's binary_logloss: 0.677258
# [39]	valid_0's binary_logloss: 0.677369
# [40]	valid_0's binary_logloss: 0.676856
# [41]	valid_0's binary_logloss: 0.67704
# [42]	valid_0's binary_logloss: 0.676767
# [43]	valid_0's binary_logloss: 0.676441
# [44]	valid_0's binary_logloss: 0.676672
# [45]	valid_0's binary_logloss: 0.67655
# [46]	valid_0's binary_logloss: 0.676905
# [47]	valid_0's binary_logloss: 0.677396
# [48]	valid_0's binary_logloss: 0.677382
# [49]	valid_0's binary_logloss: 0.677421
# [50]	valid_0's binary_logloss: 0.677053
# [51]	valid_0's binary_logloss: 0.676767
# [52]	valid_0's binary_logloss: 0.677369
# [53]	valid_0's binary_logloss: 0.677884
# [54]	valid_0's binary_logloss: 0.678025
# [55]	valid_0's binary_logloss: 0.677823
# [56]	valid_0's binary_logloss: 0.677604
# [57]	valid_0's binary_logloss: 0.677168
# Early stopping, best iteration is:
# [27]	valid_0's binary_logloss: 0.675023
# [1]	valid_0's binary_logloss: 0.689469
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.685763
# [3]	valid_0's binary_logloss: 0.68317
# [4]	valid_0's binary_logloss: 0.680581
# [5]	valid_0's binary_logloss: 0.677883
# [6]	valid_0's binary_logloss: 0.67652
# [7]	valid_0's binary_logloss: 0.674703
# [8]	valid_0's binary_logloss: 0.674485
# [9]	valid_0's binary_logloss: 0.672455
# [10]	valid_0's binary_logloss: 0.672161
# [11]	valid_0's binary_logloss: 0.671784
# [12]	valid_0's binary_logloss: 0.671925
# [13]	valid_0's binary_logloss: 0.671048
# [14]	valid_0's binary_logloss: 0.671345
# [15]	valid_0's binary_logloss: 0.670753
# [16]	valid_0's binary_logloss: 0.670588
# [17]	valid_0's binary_logloss: 0.67013
# [18]	valid_0's binary_logloss: 0.670165
# [19]	valid_0's binary_logloss: 0.670391
# [20]	valid_0's binary_logloss: 0.67028
# [21]	valid_0's binary_logloss: 0.669833
# [22]	valid_0's binary_logloss: 0.669311
# [23]	valid_0's binary_logloss: 0.669211
# [24]	valid_0's binary_logloss: 0.669215
# [25]	valid_0's binary_logloss: 0.668121
# [26]	valid_0's binary_logloss: 0.667636
# [27]	valid_0's binary_logloss: 0.667353
# [28]	valid_0's binary_logloss: 0.667425
# [29]	valid_0's binary_logloss: 0.667236
# [30]	valid_0's binary_logloss: 0.666711
# [31]	valid_0's binary_logloss: 0.666305
# [32]	valid_0's binary_logloss: 0.666012
# [33]	valid_0's binary_logloss: 0.665696
# [34]	valid_0's binary_logloss: 0.665327
# [35]	valid_0's binary_logloss: 0.665541
# [36]	valid_0's binary_logloss: 0.665809
# [37]	valid_0's binary_logloss: 0.665936
# [38]	valid_0's binary_logloss: 0.666374
# [39]	valid_0's binary_logloss: 0.666018
# [40]	valid_0's binary_logloss: 0.665503
# [41]	valid_0's binary_logloss: 0.665272
# [42]	valid_0's binary_logloss: 0.664953
# [43]	valid_0's binary_logloss: 0.664791
# [44]	valid_0's binary_logloss: 0.664608
# [45]	valid_0's binary_logloss: 0.665176
# [46]	valid_0's binary_logloss: 0.665304
# [47]	valid_0's binary_logloss: 0.665688
# [48]	valid_0's binary_logloss: 0.665514
# [49]	valid_0's binary_logloss: 0.665345
# [50]	valid_0's binary_logloss: 0.665472
# [51]	valid_0's binary_logloss: 0.665721
# [52]	valid_0's binary_logloss: 0.665453
# [53]	valid_0's binary_logloss: 0.665559
# [54]	valid_0's binary_logloss: 0.665201
# [55]	valid_0's binary_logloss: 0.665243
# [56]	valid_0's binary_logloss: 0.664878
# [57]	valid_0's binary_logloss: 0.665602
# [58]	valid_0's binary_logloss: 0.66578
# [59]	valid_0's binary_logloss: 0.665628
# [60]	valid_0's binary_logloss: 0.666296
# [61]	valid_0's binary_logloss: 0.665966
# [62]	valid_0's binary_logloss: 0.666734
# [63]	valid_0's binary_logloss: 0.666961
# [64]	valid_0's binary_logloss: 0.667208
# [65]	valid_0's binary_logloss: 0.666769
# [66]	valid_0's binary_logloss: 0.666672
# [67]	valid_0's binary_logloss: 0.666989
# [68]	valid_0's binary_logloss: 0.667275
# [69]	valid_0's binary_logloss: 0.66726
# [70]	valid_0's binary_logloss: 0.666883
# [71]	valid_0's binary_logloss: 0.666882
# [72]	valid_0's binary_logloss: 0.666105
# [73]	valid_0's binary_logloss: 0.667108
# [74]	valid_0's binary_logloss: 0.666851
# Early stopping, best iteration is:
# [44]	valid_0's binary_logloss: 0.664608
# [1]	valid_0's binary_logloss: 0.689669
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.686403
# [3]	valid_0's binary_logloss: 0.684126
# [4]	valid_0's binary_logloss: 0.682444
# [5]	valid_0's binary_logloss: 0.681531
# [6]	valid_0's binary_logloss: 0.679821
# [7]	valid_0's binary_logloss: 0.67827
# [8]	valid_0's binary_logloss: 0.676893
# [9]	valid_0's binary_logloss: 0.675655
# [10]	valid_0's binary_logloss: 0.675284
# [11]	valid_0's binary_logloss: 0.674799
# [12]	valid_0's binary_logloss: 0.673847
# [13]	valid_0's binary_logloss: 0.673293
# [14]	valid_0's binary_logloss: 0.672519
# [15]	valid_0's binary_logloss: 0.671523
# [16]	valid_0's binary_logloss: 0.670752
# [17]	valid_0's binary_logloss: 0.670756
# [18]	valid_0's binary_logloss: 0.670342
# [19]	valid_0's binary_logloss: 0.670523
# [20]	valid_0's binary_logloss: 0.669607
# [21]	valid_0's binary_logloss: 0.669404
# [22]	valid_0's binary_logloss: 0.669066
# [23]	valid_0's binary_logloss: 0.669225
# [24]	valid_0's binary_logloss: 0.669005
# [25]	valid_0's binary_logloss: 0.668951
# [26]	valid_0's binary_logloss: 0.66861
# [27]	valid_0's binary_logloss: 0.668414
# [28]	valid_0's binary_logloss: 0.668344
# [29]	valid_0's binary_logloss: 0.667528
# [30]	valid_0's binary_logloss: 0.667084
# [31]	valid_0's binary_logloss: 0.6669
# [32]	valid_0's binary_logloss: 0.666105
# [33]	valid_0's binary_logloss: 0.666345
# [34]	valid_0's binary_logloss: 0.666726
# [35]	valid_0's binary_logloss: 0.666391
# [36]	valid_0's binary_logloss: 0.666805
# [37]	valid_0's binary_logloss: 0.666943
# [38]	valid_0's binary_logloss: 0.666467
# [39]	valid_0's binary_logloss: 0.666071
# [40]	valid_0's binary_logloss: 0.665736
# [41]	valid_0's binary_logloss: 0.666636
# [42]	valid_0's binary_logloss: 0.666365
# [43]	valid_0's binary_logloss: 0.665681
# [44]	valid_0's binary_logloss: 0.66568
# [45]	valid_0's binary_logloss: 0.66558
# [46]	valid_0's binary_logloss: 0.665515
# [47]	valid_0's binary_logloss: 0.664933
# [48]	valid_0's binary_logloss: 0.66448
# [49]	valid_0's binary_logloss: 0.664062
# [50]	valid_0's binary_logloss: 0.663916
# [51]	valid_0's binary_logloss: 0.664136
# [52]	valid_0's binary_logloss: 0.664201
# [53]	valid_0's binary_logloss: 0.663773
# [54]	valid_0's binary_logloss: 0.664304
# [55]	valid_0's binary_logloss: 0.664388
# [56]	valid_0's binary_logloss: 0.664719
# [57]	valid_0's binary_logloss: 0.66455
# [58]	valid_0's binary_logloss: 0.664438
# [59]	valid_0's binary_logloss: 0.664151
# [60]	valid_0's binary_logloss: 0.664179
# [61]	valid_0's binary_logloss: 0.664148
# [62]	valid_0's binary_logloss: 0.663819
# [63]	valid_0's binary_logloss: 0.664207
# [64]	valid_0's binary_logloss: 0.664297
# [65]	valid_0's binary_logloss: 0.664624
# [66]	valid_0's binary_logloss: 0.664861
# [67]	valid_0's binary_logloss: 0.665236
# [68]	valid_0's binary_logloss: 0.665721
# [69]	valid_0's binary_logloss: 0.665661
# [70]	valid_0's binary_logloss: 0.665733
# [71]	valid_0's binary_logloss: 0.666178
# [72]	valid_0's binary_logloss: 0.665986
# [73]	valid_0's binary_logloss: 0.66592
# [74]	valid_0's binary_logloss: 0.665348
# [75]	valid_0's binary_logloss: 0.665344
# [76]	valid_0's binary_logloss: 0.665338
# [77]	valid_0's binary_logloss: 0.664678
# [78]	valid_0's binary_logloss: 0.664956
# [79]	valid_0's binary_logloss: 0.665037
# [80]	valid_0's binary_logloss: 0.664943
# [81]	valid_0's binary_logloss: 0.665236
# [82]	valid_0's binary_logloss: 0.665429
# [83]	valid_0's binary_logloss: 0.665168
# Early stopping, best iteration is:
# [53]	valid_0's binary_logloss: 0.663773

# %%
val_roc
# Out:
# [0.5733465254016024,
#  0.6262284874941092,
#  0.5606486689163854,
#  0.5868756084388533,
#  0.5796766803232165]

# %%
feature_imp = np.zeros(X_train.shape[1])
for model in clf_2:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp, index=data_col).sort_values(by=0, ascending=False)
# Out:
#                                                             0
# linear_acceleration_Z_mean                        1785.265643
# linear_acceleration_Y_mean                        1747.756083
# linear_acceleration_X_mean_abs_chg                1056.513645
# angular_velocity_Y_min                             890.005814
# angular_velocity_X_maxtoMin                        863.585610
# angular_velocity_Y_maxtoMin                        824.710081
# linear_acceleration_X_maxtoMin                     721.743047
# total_acce_median                                  702.115022
# linear_acceleration_X_max                          666.368384
# total_ang_cos_mean_abs_chg                         652.382502
# linear_acceleration_X_median                       640.995499
# linear_acceleration_X_std                          585.890698
# angular_velocity_Y_median                          576.040062
# angular_velocity_Y_cos_mean_abs_chg                575.954881
# angular_velocity_X_mean_abs_chg                    575.917928
# linear_acceleration_Z_maxtoMin                     567.750826
# angular_velocity_Y_mean_abs_chg                    566.080328
# linear_acceleration_Z_median                       535.547068
# linear_acceleration_Y_abs_min                      524.519141
# linear_acceleration_X_abs_max                      524.129887
# total_ang_cos_max                                  519.925801
# angular_velocity_X_cos_mean_change_of_abs_change   515.413239
# angular_velocity_Z_mean_abs_chg                    492.184030
# total_acce_mean_abs_chg                            490.847351
# linear_acceleration_Y_median                       489.490291
# linear_acceleration_X_mean                         478.303219
# linear_acceleration_Z_abs_min                      463.716172
# angular_velocity_Y_cos_mean_change_of_abs_change   460.074701
# angular_velocity_Z_std                             458.688672
# linear_acceleration_X_abs_min                      455.732469
# linear_acceleration_Z_mean_change_of_abs_change    435.266978
# angular_velocity_Z_mean_change_of_abs_change       424.440068
# angular_velocity_Y_mean                            422.417737
# angular_velocity_X_abs_min                         421.896260
# angular_velocity_Z_cos_mean_change_of_abs_change   420.764578
# linear_acceleration_X_min                          419.755291
# angular_velocity_X_mean                            417.583019
# angular_velocity_Z_cos_std                         415.740340
# angular_velocity_Z_maxtoMin                        402.974729
# linear_acceleration_Z_max                          389.993170
# angular_velocity_X_median                          387.872131
# linear_acceleration_Y_std                          381.539559
# angular_velocity_Z_min                             378.125089
# total_acce_min                                     374.697941
# total_acce_mean_change_of_abs_change               373.264960
# total_acce_maxtoMin                                367.645111
# angular_velocity_Y_mean_change_of_abs_change       361.780301
# angular_velocity_X_min                             349.559572
# total_ang_cos_mean_change_of_abs_change            348.022921
# linear_acceleration_Y_min                          341.536388
# angular_velocity_X_cos_median                      337.488678
# angular_velocity_Y_std                             335.653851
# linear_acceleration_Y_mean_abs_chg                 327.355038
# total_acce_mean                                    320.228020
# linear_acceleration_Y_maxtoMin                     309.509241
# angular_velocity_Y_cos_median                      306.475688
# linear_acceleration_X_mean_change_of_abs_change    305.461692
# angular_velocity_Z_cos_mean_abs_chg                302.804241
# angular_velocity_Z_max                             300.930899
# angular_velocity_Y_max                             300.415230
# angular_velocity_X_cos_max                         297.977250
# total_ang_cos_median                               296.861894
# angular_velocity_Z_range                           285.278008
# angular_velocity_Z_cos_mean                        272.582572
# total_acce_std                                     263.059379
# linear_acceleration_Z_std                          261.820510
# angular_velocity_Y_cos_max                         259.165139
# angular_velocity_Y_cos_mean                        254.563690
# total_ang_cos_abs_max                              254.100901
# angular_velocity_X_cos_mean_abs_chg                247.533489
# angular_velocity_Z_median                          242.416679
# linear_acceleration_X_abs_avg                      242.130348
# angular_velocity_X_mean_change_of_abs_change       239.476629
# angular_velocity_Z_cos_abs_avg                     238.271832
# linear_acceleration_Z_mean_abs_chg                 234.808278
# linear_acceleration_X_range                        231.903907
# linear_acceleration_Y_range                        226.964280
# angular_velocity_Z_abs_min                         226.239911
# angular_velocity_Z_cos_maxtoMin                    224.584370
# linear_acceleration_Z_range                        223.797812
# linear_acceleration_Y_mean_change_of_abs_change    223.578358
# angular_velocity_Z_cos_median                      214.946072
# angular_velocity_Z_mean                            208.853311
# total_ang_cos_std                                  204.918290
# angular_velocity_Y_range                           204.381290
# total_acce_range                                   201.451620
# angular_velocity_Y_abs_min                         200.119322
# linear_acceleration_Z_min                          177.180840
# angular_velocity_X_cos_mean                        174.554171
# total_acce_abs_avg                                 168.585771
# angular_velocity_X_max                             159.121839
# total_ang_cos_range                                155.518178
# angular_velocity_Z_abs_max                         152.626700
# angular_velocity_Z_cos_range                       151.502160
# linear_acceleration_Y_abs_avg                      146.625370
# angular_velocity_X_cos_std                         146.502632
# total_ang_cos_mean                                 143.609408
# angular_velocity_Y_cos_std                         138.630100
# total_ang_cos_abs_avg                              138.624000
# angular_velocity_X_range                           137.859262
# angular_velocity_Z_cos_max                         137.608920
# total_acce_max                                     136.704420
# angular_velocity_X_cos_min                         135.382820
# angular_velocity_Z_abs_avg                         130.508001
# angular_velocity_X_cos_abs_max                     121.509250
# angular_velocity_Y_cos_range                       120.302650
# total_ang_cos_min                                  111.821121
# angular_velocity_X_abs_max                         109.013090
# linear_acceleration_Y_max                          108.324491
# angular_velocity_Y_abs_max                         107.494801
# total_acce_abs_min                                 107.053230
# angular_velocity_Y_abs_avg                         100.637961
# angular_velocity_Z_cos_min                         100.106850
# linear_acceleration_Z_abs_avg                       99.902069
# total_ang_cos_maxtoMin                              94.804929
# angular_velocity_Y_cos_min                          72.821160
# angular_velocity_Y_cos_abs_avg                      55.317881
# angular_velocity_X_cos_maxtoMin                     54.446900
# linear_acceleration_Z_abs_max                       48.337481
# angular_velocity_X_abs_avg                          46.760380
# angular_velocity_Y_cos_maxtoMin                     43.744560
# angular_velocity_X_std                              41.613511
# angular_velocity_Z_cos_abs_max                      34.676220
# angular_velocity_Y_cos_abs_max                      31.213950
# linear_acceleration_Y_abs_max                       24.083360
# angular_velocity_Z_cos_abs_min                      22.614010
# angular_velocity_Y_cos_abs_min                      14.906430
# angular_velocity_X_cos_abs_avg                      13.899660
# total_acce_abs_max                                  13.427690
# angular_velocity_X_cos_abs_min                      10.032660
# angular_velocity_X_cos_range                         7.874780
# total_ang_cos_abs_min                                4.604540

# %%
adv_val = []
for model in clf_2:
    adv_val.append(model.predict(X_train))

# %%
plt.plot(np.sort(np.mean(adv_val, axis=0)))

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X_train, y_id))

clf = []
val_acc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'multi_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'multiclass',
               'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }

for train_idx, val_idx in splits:
    X_tr, y_tr = X_train[train_idx, :], y_id[train_idx]
    X_val, y_val = X_train[val_idx, :], y_id[val_idx]
    
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)

    val_acc.append(accuracy_score(y_val, np.argmax(pred_lgb, axis=1)))

#pred_lgb = pd.DataFrame(pred_lgb, index=np.where(np.mean(adv_val, axis=0)>0.3))
#val_pred = pd.concat([val_pred, pred_lgb], axis=0)

clf.append(model_lgb)
# Out:
# [1]	valid_0's multi_logloss: 1.89466
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.81037
# [3]	valid_0's multi_logloss: 1.7379
# [4]	valid_0's multi_logloss: 1.68347
# [5]	valid_0's multi_logloss: 1.63279
# [6]	valid_0's multi_logloss: 1.58727
# [7]	valid_0's multi_logloss: 1.55046
# [8]	valid_0's multi_logloss: 1.51756
# [9]	valid_0's multi_logloss: 1.48684
# [10]	valid_0's multi_logloss: 1.45979
# [11]	valid_0's multi_logloss: 1.43589
# [12]	valid_0's multi_logloss: 1.41442
# [13]	valid_0's multi_logloss: 1.39373
# [14]	valid_0's multi_logloss: 1.37499
# [15]	valid_0's multi_logloss: 1.358
# [16]	valid_0's multi_logloss: 1.34273
# [17]	valid_0's multi_logloss: 1.32811
# [18]	valid_0's multi_logloss: 1.31505
# [19]	valid_0's multi_logloss: 1.30407
# [20]	valid_0's multi_logloss: 1.29104
# [21]	valid_0's multi_logloss: 1.28334
# [22]	valid_0's multi_logloss: 1.27524
# [23]	valid_0's multi_logloss: 1.26835
# [24]	valid_0's multi_logloss: 1.26121
# [25]	valid_0's multi_logloss: 1.25482
# [26]	valid_0's multi_logloss: 1.2487
# [27]	valid_0's multi_logloss: 1.24232
# [28]	valid_0's multi_logloss: 1.23498
# [29]	valid_0's multi_logloss: 1.22999
# [30]	valid_0's multi_logloss: 1.22341
# [31]	valid_0's multi_logloss: 1.21863
# [32]	valid_0's multi_logloss: 1.214
# [33]	valid_0's multi_logloss: 1.20978
# [34]	valid_0's multi_logloss: 1.20608
# [35]	valid_0's multi_logloss: 1.20377
# [36]	valid_0's multi_logloss: 1.20066
# [37]	valid_0's multi_logloss: 1.19873
# [38]	valid_0's multi_logloss: 1.19576
# [39]	valid_0's multi_logloss: 1.19481
# [40]	valid_0's multi_logloss: 1.1932
# [41]	valid_0's multi_logloss: 1.19116
# [42]	valid_0's multi_logloss: 1.18972
# [43]	valid_0's multi_logloss: 1.18728
# [44]	valid_0's multi_logloss: 1.18715
# [45]	valid_0's multi_logloss: 1.18511
# [46]	valid_0's multi_logloss: 1.18268
# [47]	valid_0's multi_logloss: 1.18
# [48]	valid_0's multi_logloss: 1.17942
# [49]	valid_0's multi_logloss: 1.17841
# [50]	valid_0's multi_logloss: 1.17697
# [51]	valid_0's multi_logloss: 1.17744
# [52]	valid_0's multi_logloss: 1.17795
# [53]	valid_0's multi_logloss: 1.1761
# [54]	valid_0's multi_logloss: 1.17503
# [55]	valid_0's multi_logloss: 1.17492
# [56]	valid_0's multi_logloss: 1.1742
# [57]	valid_0's multi_logloss: 1.17356
# [58]	valid_0's multi_logloss: 1.17366
# [59]	valid_0's multi_logloss: 1.17317
# [60]	valid_0's multi_logloss: 1.1733
# [61]	valid_0's multi_logloss: 1.17372
# [62]	valid_0's multi_logloss: 1.17346
# [63]	valid_0's multi_logloss: 1.17366
# [64]	valid_0's multi_logloss: 1.1731
# [65]	valid_0's multi_logloss: 1.17236
# [66]	valid_0's multi_logloss: 1.17213
# [67]	valid_0's multi_logloss: 1.17115
# [68]	valid_0's multi_logloss: 1.17059
# [69]	valid_0's multi_logloss: 1.17104
# [70]	valid_0's multi_logloss: 1.16998
# [71]	valid_0's multi_logloss: 1.17019
# [72]	valid_0's multi_logloss: 1.17032
# [73]	valid_0's multi_logloss: 1.17038
# [74]	valid_0's multi_logloss: 1.17249
# [75]	valid_0's multi_logloss: 1.17263
# [76]	valid_0's multi_logloss: 1.17285
# [77]	valid_0's multi_logloss: 1.17327
# [78]	valid_0's multi_logloss: 1.17342
# [79]	valid_0's multi_logloss: 1.17472
# [80]	valid_0's multi_logloss: 1.17574
# [81]	valid_0's multi_logloss: 1.17597
# [82]	valid_0's multi_logloss: 1.17483
# [83]	valid_0's multi_logloss: 1.17786
# [84]	valid_0's multi_logloss: 1.17891
# [85]	valid_0's multi_logloss: 1.17999
# [86]	valid_0's multi_logloss: 1.18152
# [87]	valid_0's multi_logloss: 1.1821
# [88]	valid_0's multi_logloss: 1.18234
# [89]	valid_0's multi_logloss: 1.18374
# [90]	valid_0's multi_logloss: 1.18477
# [91]	valid_0's multi_logloss: 1.18604
# [92]	valid_0's multi_logloss: 1.18644
# [93]	valid_0's multi_logloss: 1.18615
# [94]	valid_0's multi_logloss: 1.18591
# [95]	valid_0's multi_logloss: 1.18623
# [96]	valid_0's multi_logloss: 1.18562
# [97]	valid_0's multi_logloss: 1.18545
# [98]	valid_0's multi_logloss: 1.18583
# [99]	valid_0's multi_logloss: 1.18717
# [100]	valid_0's multi_logloss: 1.18775
# Early stopping, best iteration is:
# [70]	valid_0's multi_logloss: 1.16998
# [1]	valid_0's multi_logloss: 1.89826
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.80648
# [3]	valid_0's multi_logloss: 1.73625
# [4]	valid_0's multi_logloss: 1.67901
# [5]	valid_0's multi_logloss: 1.62733
# [6]	valid_0's multi_logloss: 1.58389
# [7]	valid_0's multi_logloss: 1.5421
# [8]	valid_0's multi_logloss: 1.50777
# [9]	valid_0's multi_logloss: 1.47632
# [10]	valid_0's multi_logloss: 1.44702
# [11]	valid_0's multi_logloss: 1.42042
# [12]	valid_0's multi_logloss: 1.39553
# [13]	valid_0's multi_logloss: 1.37359
# [14]	valid_0's multi_logloss: 1.3535
# [15]	valid_0's multi_logloss: 1.3366
# [16]	valid_0's multi_logloss: 1.32065
# [17]	valid_0's multi_logloss: 1.30602
# [18]	valid_0's multi_logloss: 1.29349
# [19]	valid_0's multi_logloss: 1.28177
# [20]	valid_0's multi_logloss: 1.26995
# [21]	valid_0's multi_logloss: 1.25783
# [22]	valid_0's multi_logloss: 1.2482
# [23]	valid_0's multi_logloss: 1.23893
# [24]	valid_0's multi_logloss: 1.2306
# [25]	valid_0's multi_logloss: 1.22336
# [26]	valid_0's multi_logloss: 1.21732
# [27]	valid_0's multi_logloss: 1.21135
# [28]	valid_0's multi_logloss: 1.20508
# [29]	valid_0's multi_logloss: 1.19926
# [30]	valid_0's multi_logloss: 1.19441
# [31]	valid_0's multi_logloss: 1.1903
# [32]	valid_0's multi_logloss: 1.18616
# [33]	valid_0's multi_logloss: 1.18164
# [34]	valid_0's multi_logloss: 1.17952
# [35]	valid_0's multi_logloss: 1.17464
# [36]	valid_0's multi_logloss: 1.17238
# [37]	valid_0's multi_logloss: 1.16848
# [38]	valid_0's multi_logloss: 1.16569
# [39]	valid_0's multi_logloss: 1.16304
# [40]	valid_0's multi_logloss: 1.16131
# [41]	valid_0's multi_logloss: 1.15822
# [42]	valid_0's multi_logloss: 1.15598
# [43]	valid_0's multi_logloss: 1.1548
# [44]	valid_0's multi_logloss: 1.15267
# [45]	valid_0's multi_logloss: 1.15118
# [46]	valid_0's multi_logloss: 1.14929
# [47]	valid_0's multi_logloss: 1.14738
# [48]	valid_0's multi_logloss: 1.14686
# [49]	valid_0's multi_logloss: 1.14619
# [50]	valid_0's multi_logloss: 1.14436
# [51]	valid_0's multi_logloss: 1.14444
# [52]	valid_0's multi_logloss: 1.14259
# [53]	valid_0's multi_logloss: 1.14165
# [54]	valid_0's multi_logloss: 1.1412
# [55]	valid_0's multi_logloss: 1.13944
# [56]	valid_0's multi_logloss: 1.13638
# [57]	valid_0's multi_logloss: 1.13459
# [58]	valid_0's multi_logloss: 1.13461
# [59]	valid_0's multi_logloss: 1.13288
# [60]	valid_0's multi_logloss: 1.13221
# [61]	valid_0's multi_logloss: 1.13236
# [62]	valid_0's multi_logloss: 1.13228
# [63]	valid_0's multi_logloss: 1.1307
# [64]	valid_0's multi_logloss: 1.13025
# [65]	valid_0's multi_logloss: 1.12968
# [66]	valid_0's multi_logloss: 1.12832
# [67]	valid_0's multi_logloss: 1.12788
# [68]	valid_0's multi_logloss: 1.12885
# [69]	valid_0's multi_logloss: 1.12978
# [70]	valid_0's multi_logloss: 1.12929
# [71]	valid_0's multi_logloss: 1.12692
# [72]	valid_0's multi_logloss: 1.12631
# [73]	valid_0's multi_logloss: 1.12755
# [74]	valid_0's multi_logloss: 1.12799
# [75]	valid_0's multi_logloss: 1.12875
# [76]	valid_0's multi_logloss: 1.12984
# [77]	valid_0's multi_logloss: 1.12867
# [78]	valid_0's multi_logloss: 1.12869
# [79]	valid_0's multi_logloss: 1.12833
# [80]	valid_0's multi_logloss: 1.12846
# [81]	valid_0's multi_logloss: 1.12802
# [82]	valid_0's multi_logloss: 1.12768
# [83]	valid_0's multi_logloss: 1.12728
# [84]	valid_0's multi_logloss: 1.12663
# [85]	valid_0's multi_logloss: 1.12713
# [86]	valid_0's multi_logloss: 1.12583
# [87]	valid_0's multi_logloss: 1.12594
# [88]	valid_0's multi_logloss: 1.12684
# [89]	valid_0's multi_logloss: 1.12752
# [90]	valid_0's multi_logloss: 1.12813
# [91]	valid_0's multi_logloss: 1.12855
# [92]	valid_0's multi_logloss: 1.12883
# [93]	valid_0's multi_logloss: 1.129
# [94]	valid_0's multi_logloss: 1.12851
# [95]	valid_0's multi_logloss: 1.12958
# [96]	valid_0's multi_logloss: 1.12982
# [97]	valid_0's multi_logloss: 1.12932
# [98]	valid_0's multi_logloss: 1.13026
# [99]	valid_0's multi_logloss: 1.13075
# [100]	valid_0's multi_logloss: 1.13217
# [101]	valid_0's multi_logloss: 1.1328
# [102]	valid_0's multi_logloss: 1.13378
# [103]	valid_0's multi_logloss: 1.13359
# [104]	valid_0's multi_logloss: 1.13324
# [105]	valid_0's multi_logloss: 1.1334
# [106]	valid_0's multi_logloss: 1.13446
# [107]	valid_0's multi_logloss: 1.13443
# [108]	valid_0's multi_logloss: 1.1353
# [109]	valid_0's multi_logloss: 1.13437
# [110]	valid_0's multi_logloss: 1.13436
# [111]	valid_0's multi_logloss: 1.13556
# [112]	valid_0's multi_logloss: 1.13538
# [113]	valid_0's multi_logloss: 1.13548
# [114]	valid_0's multi_logloss: 1.13585
# [115]	valid_0's multi_logloss: 1.13565
# [116]	valid_0's multi_logloss: 1.13629
# Early stopping, best iteration is:
# [86]	valid_0's multi_logloss: 1.12583
# [1]	valid_0's multi_logloss: 1.89561
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.81651
# [3]	valid_0's multi_logloss: 1.7475
# [4]	valid_0's multi_logloss: 1.68598
# [5]	valid_0's multi_logloss: 1.63874
# [6]	valid_0's multi_logloss: 1.59541
# [7]	valid_0's multi_logloss: 1.55674
# [8]	valid_0's multi_logloss: 1.52117
# [9]	valid_0's multi_logloss: 1.48783
# [10]	valid_0's multi_logloss: 1.46071
# [11]	valid_0's multi_logloss: 1.43653
# [12]	valid_0's multi_logloss: 1.41343
# [13]	valid_0's multi_logloss: 1.39256
# [14]	valid_0's multi_logloss: 1.37323
# [15]	valid_0's multi_logloss: 1.35812
# [16]	valid_0's multi_logloss: 1.34344
# [17]	valid_0's multi_logloss: 1.32908
# [18]	valid_0's multi_logloss: 1.31504
# [19]	valid_0's multi_logloss: 1.30421
# [20]	valid_0's multi_logloss: 1.2941
# [21]	valid_0's multi_logloss: 1.28277
# [22]	valid_0's multi_logloss: 1.27357
# [23]	valid_0's multi_logloss: 1.2644
# [24]	valid_0's multi_logloss: 1.25788
# [25]	valid_0's multi_logloss: 1.24863
# [26]	valid_0's multi_logloss: 1.24127
# [27]	valid_0's multi_logloss: 1.23583
# [28]	valid_0's multi_logloss: 1.22979
# [29]	valid_0's multi_logloss: 1.22506
# [30]	valid_0's multi_logloss: 1.22049
# [31]	valid_0's multi_logloss: 1.21403
# [32]	valid_0's multi_logloss: 1.20897
# [33]	valid_0's multi_logloss: 1.20442
# [34]	valid_0's multi_logloss: 1.20039
# [35]	valid_0's multi_logloss: 1.19761
# [36]	valid_0's multi_logloss: 1.1954
# [37]	valid_0's multi_logloss: 1.19247
# [38]	valid_0's multi_logloss: 1.18922
# [39]	valid_0's multi_logloss: 1.18631
# [40]	valid_0's multi_logloss: 1.18523
# [41]	valid_0's multi_logloss: 1.18349
# [42]	valid_0's multi_logloss: 1.18146
# [43]	valid_0's multi_logloss: 1.17951
# [44]	valid_0's multi_logloss: 1.1766
# [45]	valid_0's multi_logloss: 1.17501
# [46]	valid_0's multi_logloss: 1.17331
# [47]	valid_0's multi_logloss: 1.17124
# [48]	valid_0's multi_logloss: 1.17042
# [49]	valid_0's multi_logloss: 1.16938
# [50]	valid_0's multi_logloss: 1.16924
# [51]	valid_0's multi_logloss: 1.16724
# [52]	valid_0's multi_logloss: 1.16595
# [53]	valid_0's multi_logloss: 1.1635
# [54]	valid_0's multi_logloss: 1.16218
# [55]	valid_0's multi_logloss: 1.16255
# [56]	valid_0's multi_logloss: 1.16112
# [57]	valid_0's multi_logloss: 1.15981
# [58]	valid_0's multi_logloss: 1.1599
# [59]	valid_0's multi_logloss: 1.1591
# [60]	valid_0's multi_logloss: 1.15884
# [61]	valid_0's multi_logloss: 1.15895
# [62]	valid_0's multi_logloss: 1.15817
# [63]	valid_0's multi_logloss: 1.15819
# [64]	valid_0's multi_logloss: 1.15761
# [65]	valid_0's multi_logloss: 1.15698
# [66]	valid_0's multi_logloss: 1.1569
# [67]	valid_0's multi_logloss: 1.15622
# [68]	valid_0's multi_logloss: 1.15562
# [69]	valid_0's multi_logloss: 1.15575
# [70]	valid_0's multi_logloss: 1.15617
# [71]	valid_0's multi_logloss: 1.15802
# [72]	valid_0's multi_logloss: 1.15816
# [73]	valid_0's multi_logloss: 1.15801
# [74]	valid_0's multi_logloss: 1.15786
# [75]	valid_0's multi_logloss: 1.158
# [76]	valid_0's multi_logloss: 1.1584
# [77]	valid_0's multi_logloss: 1.15801
# [78]	valid_0's multi_logloss: 1.15937
# [79]	valid_0's multi_logloss: 1.15996
# [80]	valid_0's multi_logloss: 1.16032
# [81]	valid_0's multi_logloss: 1.16094
# [82]	valid_0's multi_logloss: 1.15999
# [83]	valid_0's multi_logloss: 1.15937
# [84]	valid_0's multi_logloss: 1.16053
# [85]	valid_0's multi_logloss: 1.15919
# [86]	valid_0's multi_logloss: 1.15892
# [87]	valid_0's multi_logloss: 1.15864
# [88]	valid_0's multi_logloss: 1.15937
# [89]	valid_0's multi_logloss: 1.15991
# [90]	valid_0's multi_logloss: 1.15925
# [91]	valid_0's multi_logloss: 1.16085
# [92]	valid_0's multi_logloss: 1.16096
# [93]	valid_0's multi_logloss: 1.16153
# [94]	valid_0's multi_logloss: 1.16254
# [95]	valid_0's multi_logloss: 1.16328
# [96]	valid_0's multi_logloss: 1.16375
# [97]	valid_0's multi_logloss: 1.16353
# [98]	valid_0's multi_logloss: 1.16379
# Early stopping, best iteration is:
# [68]	valid_0's multi_logloss: 1.15562
# [1]	valid_0's multi_logloss: 1.89181
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.80863
# [3]	valid_0's multi_logloss: 1.74805
# [4]	valid_0's multi_logloss: 1.69422
# [5]	valid_0's multi_logloss: 1.64765
# [6]	valid_0's multi_logloss: 1.60585
# [7]	valid_0's multi_logloss: 1.571
# [8]	valid_0's multi_logloss: 1.54051
# [9]	valid_0's multi_logloss: 1.51144
# [10]	valid_0's multi_logloss: 1.48373
# [11]	valid_0's multi_logloss: 1.46133
# [12]	valid_0's multi_logloss: 1.43858
# [13]	valid_0's multi_logloss: 1.41957
# [14]	valid_0's multi_logloss: 1.40101
# [15]	valid_0's multi_logloss: 1.38524
# [16]	valid_0's multi_logloss: 1.37078
# [17]	valid_0's multi_logloss: 1.35564
# [18]	valid_0's multi_logloss: 1.34501
# [19]	valid_0's multi_logloss: 1.33453
# [20]	valid_0's multi_logloss: 1.32549
# [21]	valid_0's multi_logloss: 1.31425
# [22]	valid_0's multi_logloss: 1.30623
# [23]	valid_0's multi_logloss: 1.29861
# [24]	valid_0's multi_logloss: 1.28878
# [25]	valid_0's multi_logloss: 1.28342
# [26]	valid_0's multi_logloss: 1.27637
# [27]	valid_0's multi_logloss: 1.27076
# [28]	valid_0's multi_logloss: 1.26677
# [29]	valid_0's multi_logloss: 1.26128
# [30]	valid_0's multi_logloss: 1.25785
# [31]	valid_0's multi_logloss: 1.25203
# [32]	valid_0's multi_logloss: 1.24861
# [33]	valid_0's multi_logloss: 1.24552
# [34]	valid_0's multi_logloss: 1.24171
# [35]	valid_0's multi_logloss: 1.2382
# [36]	valid_0's multi_logloss: 1.23528
# [37]	valid_0's multi_logloss: 1.23335
# [38]	valid_0's multi_logloss: 1.22981
# [39]	valid_0's multi_logloss: 1.22832
# [40]	valid_0's multi_logloss: 1.22714
# [41]	valid_0's multi_logloss: 1.2247
# [42]	valid_0's multi_logloss: 1.22256
# [43]	valid_0's multi_logloss: 1.22019
# [44]	valid_0's multi_logloss: 1.22022
# [45]	valid_0's multi_logloss: 1.22026
# [46]	valid_0's multi_logloss: 1.21862
# [47]	valid_0's multi_logloss: 1.21798
# [48]	valid_0's multi_logloss: 1.21736
# [49]	valid_0's multi_logloss: 1.21657
# [50]	valid_0's multi_logloss: 1.21554
# [51]	valid_0's multi_logloss: 1.2152
# [52]	valid_0's multi_logloss: 1.21541
# [53]	valid_0's multi_logloss: 1.21533
# [54]	valid_0's multi_logloss: 1.21516
# [55]	valid_0's multi_logloss: 1.21463
# [56]	valid_0's multi_logloss: 1.21435
# [57]	valid_0's multi_logloss: 1.2144
# [58]	valid_0's multi_logloss: 1.21536
# [59]	valid_0's multi_logloss: 1.21597
# [60]	valid_0's multi_logloss: 1.21535
# [61]	valid_0's multi_logloss: 1.21452
# [62]	valid_0's multi_logloss: 1.21561
# [63]	valid_0's multi_logloss: 1.21668
# [64]	valid_0's multi_logloss: 1.21896
# [65]	valid_0's multi_logloss: 1.21894
# [66]	valid_0's multi_logloss: 1.21851
# [67]	valid_0's multi_logloss: 1.22052
# [68]	valid_0's multi_logloss: 1.22041
# [69]	valid_0's multi_logloss: 1.22071
# [70]	valid_0's multi_logloss: 1.22295
# [71]	valid_0's multi_logloss: 1.22234
# [72]	valid_0's multi_logloss: 1.22315
# [73]	valid_0's multi_logloss: 1.22444
# [74]	valid_0's multi_logloss: 1.22587
# [75]	valid_0's multi_logloss: 1.22775
# [76]	valid_0's multi_logloss: 1.22857
# [77]	valid_0's multi_logloss: 1.22892
# [78]	valid_0's multi_logloss: 1.22904
# [79]	valid_0's multi_logloss: 1.22978
# [80]	valid_0's multi_logloss: 1.23008
# [81]	valid_0's multi_logloss: 1.23204
# [82]	valid_0's multi_logloss: 1.23203
# [83]	valid_0's multi_logloss: 1.23266
# [84]	valid_0's multi_logloss: 1.23376
# [85]	valid_0's multi_logloss: 1.23469
# [86]	valid_0's multi_logloss: 1.23486
# Early stopping, best iteration is:
# [56]	valid_0's multi_logloss: 1.21435
# [1]	valid_0's multi_logloss: 1.88397
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.79746
# [3]	valid_0's multi_logloss: 1.7253
# [4]	valid_0's multi_logloss: 1.66537
# [5]	valid_0's multi_logloss: 1.61259
# [6]	valid_0's multi_logloss: 1.56534
# [7]	valid_0's multi_logloss: 1.52428
# [8]	valid_0's multi_logloss: 1.48759
# [9]	valid_0's multi_logloss: 1.45526
# [10]	valid_0's multi_logloss: 1.42743
# [11]	valid_0's multi_logloss: 1.40278
# [12]	valid_0's multi_logloss: 1.37955
# [13]	valid_0's multi_logloss: 1.35791
# [14]	valid_0's multi_logloss: 1.34073
# [15]	valid_0's multi_logloss: 1.3227
# [16]	valid_0's multi_logloss: 1.30354
# [17]	valid_0's multi_logloss: 1.28935
# [18]	valid_0's multi_logloss: 1.27703
# [19]	valid_0's multi_logloss: 1.2665
# [20]	valid_0's multi_logloss: 1.25494
# [21]	valid_0's multi_logloss: 1.24349
# [22]	valid_0's multi_logloss: 1.23385
# [23]	valid_0's multi_logloss: 1.22495
# [24]	valid_0's multi_logloss: 1.2158
# [25]	valid_0's multi_logloss: 1.2086
# [26]	valid_0's multi_logloss: 1.19995
# [27]	valid_0's multi_logloss: 1.19175
# [28]	valid_0's multi_logloss: 1.18573
# [29]	valid_0's multi_logloss: 1.17965
# [30]	valid_0's multi_logloss: 1.17381
# [31]	valid_0's multi_logloss: 1.16908
# [32]	valid_0's multi_logloss: 1.16467
# [33]	valid_0's multi_logloss: 1.15921
# [34]	valid_0's multi_logloss: 1.15338
# [35]	valid_0's multi_logloss: 1.15017
# [36]	valid_0's multi_logloss: 1.14629
# [37]	valid_0's multi_logloss: 1.14144
# [38]	valid_0's multi_logloss: 1.13728
# [39]	valid_0's multi_logloss: 1.13357
# [40]	valid_0's multi_logloss: 1.13014
# [41]	valid_0's multi_logloss: 1.12725
# [42]	valid_0's multi_logloss: 1.1242
# [43]	valid_0's multi_logloss: 1.12257
# [44]	valid_0's multi_logloss: 1.11887
# [45]	valid_0's multi_logloss: 1.11626
# [46]	valid_0's multi_logloss: 1.11405
# [47]	valid_0's multi_logloss: 1.11215
# [48]	valid_0's multi_logloss: 1.11099
# [49]	valid_0's multi_logloss: 1.10923
# [50]	valid_0's multi_logloss: 1.10576
# [51]	valid_0's multi_logloss: 1.10496
# [52]	valid_0's multi_logloss: 1.10405
# [53]	valid_0's multi_logloss: 1.10354
# [54]	valid_0's multi_logloss: 1.10283
# [55]	valid_0's multi_logloss: 1.10128
# [56]	valid_0's multi_logloss: 1.10017
# [57]	valid_0's multi_logloss: 1.09992
# [58]	valid_0's multi_logloss: 1.09885
# [59]	valid_0's multi_logloss: 1.09746
# [60]	valid_0's multi_logloss: 1.09661
# [61]	valid_0's multi_logloss: 1.09731
# [62]	valid_0's multi_logloss: 1.09755
# [63]	valid_0's multi_logloss: 1.09699
# [64]	valid_0's multi_logloss: 1.09737
# [65]	valid_0's multi_logloss: 1.09766
# [66]	valid_0's multi_logloss: 1.09751
# [67]	valid_0's multi_logloss: 1.09698
# [68]	valid_0's multi_logloss: 1.0966
# [69]	valid_0's multi_logloss: 1.09758
# [70]	valid_0's multi_logloss: 1.09667
# [71]	valid_0's multi_logloss: 1.09538
# [72]	valid_0's multi_logloss: 1.09553
# [73]	valid_0's multi_logloss: 1.09639
# [74]	valid_0's multi_logloss: 1.09661
# [75]	valid_0's multi_logloss: 1.09722
# [76]	valid_0's multi_logloss: 1.09765
# [77]	valid_0's multi_logloss: 1.09835
# [78]	valid_0's multi_logloss: 1.09881
# [79]	valid_0's multi_logloss: 1.09861
# [80]	valid_0's multi_logloss: 1.09799
# [81]	valid_0's multi_logloss: 1.09836
# [82]	valid_0's multi_logloss: 1.09862
# [83]	valid_0's multi_logloss: 1.09975
# [84]	valid_0's multi_logloss: 1.10015
# [85]	valid_0's multi_logloss: 1.10082
# [86]	valid_0's multi_logloss: 1.10154
# [87]	valid_0's multi_logloss: 1.10113
# [88]	valid_0's multi_logloss: 1.10162
# [89]	valid_0's multi_logloss: 1.1026
# [90]	valid_0's multi_logloss: 1.10322
# [91]	valid_0's multi_logloss: 1.10368
# [92]	valid_0's multi_logloss: 1.10363
# [93]	valid_0's multi_logloss: 1.10344
# [94]	valid_0's multi_logloss: 1.10414
# [95]	valid_0's multi_logloss: 1.10521
# [96]	valid_0's multi_logloss: 1.10498
# [97]	valid_0's multi_logloss: 1.10519
# [98]	valid_0's multi_logloss: 1.10566
# [99]	valid_0's multi_logloss: 1.10591
# [100]	valid_0's multi_logloss: 1.10679
# [101]	valid_0's multi_logloss: 1.10778
# Early stopping, best iteration is:
# [71]	valid_0's multi_logloss: 1.09538

# %%
val_acc
# Out:
# [0.5704960835509139,
#  0.6052287581699346,
#  0.5918635170603674,
#  0.5789473684210527,
#  0.6129458388375165]

# %%
feature_imp = np.zeros(X_train.shape[1])
for model in clf:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp, index=data_col).sort_values(by=0, ascending=False)
# Out:
#                                                             0
# linear_acceleration_X_mean_abs_chg                3260.938405
# angular_velocity_Y_mean_abs_chg                   2916.687954
# linear_acceleration_Y_mean_abs_chg                2800.798305
# total_ang_cos_mean_abs_chg                        2698.170016
# total_acce_mean_abs_chg                           2672.922614
# angular_velocity_Z_min                            1831.917124
# linear_acceleration_Y_std                         1040.792771
# angular_velocity_Y_maxtoMin                        866.795791
# linear_acceleration_Y_max                          830.712829
# linear_acceleration_Y_mean                         767.832504
# angular_velocity_Z_mean_abs_chg                    745.553302
# linear_acceleration_Y_range                        642.587995
# linear_acceleration_Z_mean_abs_chg                 633.453672
# linear_acceleration_Z_mean                         627.842261
# linear_acceleration_Z_maxtoMin                     608.315668
# total_acce_mean                                    605.734153
# angular_velocity_Z_median                          602.097163
# angular_velocity_X_mean                            548.921413
# linear_acceleration_X_std                          545.996743
# angular_velocity_Y_max                             542.950115
# total_acce_max                                     527.518493
# linear_acceleration_Y_min                          522.248809
# linear_acceleration_X_median                       521.332708
# angular_velocity_X_mean_abs_chg                    508.004433
# linear_acceleration_Y_maxtoMin                     471.879959
# angular_velocity_Z_std                             471.419085
# linear_acceleration_Z_range                        457.213129
# linear_acceleration_Z_abs_min                      455.219341
# angular_velocity_Z_maxtoMin                        441.539839
# linear_acceleration_Z_min                          438.675148
# linear_acceleration_X_abs_avg                      438.182977
# angular_velocity_Z_range                           430.272342
# angular_velocity_X_cos_median                      430.029395
# angular_velocity_Y_cos_mean_abs_chg                422.922549
# total_acce_median                                  419.737373
# total_acce_std                                     413.318964
# angular_velocity_X_maxtoMin                        412.078633
# total_ang_cos_std                                  401.303068
# linear_acceleration_Z_std                          399.107278
# linear_acceleration_X_abs_max                      395.761434
# angular_velocity_Z_max                             391.809526
# linear_acceleration_X_range                        387.970925
# linear_acceleration_Z_max                          385.318989
# linear_acceleration_Y_abs_avg                      364.664881
# angular_velocity_X_median                          358.675958
# linear_acceleration_X_mean                         351.747611
# linear_acceleration_Y_median                       351.524569
# linear_acceleration_X_min                          349.288162
# linear_acceleration_X_max                          348.324059
# linear_acceleration_Z_median                       347.954361
# linear_acceleration_Y_abs_max                      345.112298
# linear_acceleration_X_abs_min                      341.992750
# angular_velocity_Y_cos_abs_avg                     333.485196
# linear_acceleration_X_maxtoMin                     329.092642
# total_ang_cos_abs_avg                              327.856706
# angular_velocity_X_cos_mean_change_of_abs_change   316.063003
# angular_velocity_Y_cos_mean_change_of_abs_change   314.537610
# angular_velocity_Y_std                             313.604904
# angular_velocity_Y_range                           309.872268
# total_ang_cos_median                               305.477341
# angular_velocity_Y_cos_range                       304.757184
# angular_velocity_Y_min                             301.854611
# total_acce_maxtoMin                                267.003676
# linear_acceleration_Y_mean_change_of_abs_change    254.825565
# angular_velocity_X_cos_mean_abs_chg                253.835744
# angular_velocity_Z_cos_mean_abs_chg                252.416412
# total_ang_cos_max                                  241.965269
# angular_velocity_Y_mean                            237.600409
# angular_velocity_Y_cos_std                         229.230811
# angular_velocity_Z_mean_change_of_abs_change       229.031738
# angular_velocity_X_min                             224.209688
# angular_velocity_X_mean_change_of_abs_change       217.456426
# angular_velocity_Z_mean                            216.096005
# angular_velocity_Z_cos_mean_change_of_abs_change   210.079860
# angular_velocity_Y_mean_change_of_abs_change       208.963242
# linear_acceleration_X_mean_change_of_abs_change    206.874617
# total_ang_cos_mean                                 202.743313
# total_acce_mean_change_of_abs_change               198.220857
# total_ang_cos_mean_change_of_abs_change            197.548536
# total_acce_min                                     195.263778
# angular_velocity_X_abs_min                         191.855794
# total_acce_abs_avg                                 185.009954
# linear_acceleration_Y_abs_min                      175.776997
# total_ang_cos_maxtoMin                             171.701165
# angular_velocity_Z_cos_std                         171.621118
# angular_velocity_Y_cos_mean                        165.009648
# angular_velocity_Y_cos_median                      164.132666
# angular_velocity_Y_abs_max                         160.073552
# linear_acceleration_Z_mean_change_of_abs_change    154.301755
# angular_velocity_Z_abs_avg                         151.598294
# total_ang_cos_min                                  149.320770
# angular_velocity_Y_abs_min                         147.469539
# angular_velocity_Z_cos_mean                        144.820034
# total_acce_range                                   141.586754
# linear_acceleration_Z_abs_max                      138.853941
# angular_velocity_X_max                             134.747850
# total_ang_cos_range                                129.989857
# angular_velocity_Z_abs_max                         125.057927
# angular_velocity_Z_cos_median                      125.008092
# angular_velocity_Y_abs_avg                         110.586682
# angular_velocity_Z_abs_min                         103.551449
# angular_velocity_X_std                             100.480301
# total_acce_abs_max                                  97.778254
# angular_velocity_Y_median                           94.927367
# angular_velocity_X_cos_max                          92.904094
# angular_velocity_X_cos_std                          87.222507
# angular_velocity_Z_cos_max                          86.368449
# angular_velocity_Z_cos_maxtoMin                     86.168768
# angular_velocity_X_cos_mean                         75.157808
# angular_velocity_Y_cos_max                          74.997414
# angular_velocity_X_range                            74.977417
# angular_velocity_Z_cos_range                        74.956700
# angular_velocity_Z_cos_min                          67.390660
# linear_acceleration_Z_abs_avg                       59.798778
# angular_velocity_Z_cos_abs_avg                      52.463518
# angular_velocity_Y_cos_maxtoMin                     50.317653
# angular_velocity_X_cos_abs_min                      49.393027
# total_ang_cos_abs_max                               34.547750
# angular_velocity_X_abs_max                          34.430124
# angular_velocity_X_cos_maxtoMin                     32.184439
# angular_velocity_Y_cos_abs_max                      25.234069
# angular_velocity_Y_cos_min                          24.854417
# angular_velocity_X_cos_min                          24.341445
# angular_velocity_X_cos_abs_max                      20.403844
# total_acce_abs_min                                  18.090515
# angular_velocity_X_cos_abs_avg                      16.961290
# angular_velocity_Z_cos_abs_max                      16.685080
# angular_velocity_X_abs_avg                          11.495690
# total_ang_cos_abs_min                               10.704710
# angular_velocity_X_cos_range                        10.666690
# angular_velocity_Z_cos_abs_min                       5.445840
# angular_velocity_Y_cos_abs_min                       3.576133

# %%
preds_test = []

for model in clf:
    preds_test.append(model.predict(X_test))

# %%
preds_test = np.argmax(np.mean(preds_test, axis=0), axis=1)

# %%
test_surface = []
for i in preds_test:
    test_surface.append(id_to_target[i])

# %%
test_surface = np.asarray(test_surface)

# %%
submission = pd.read_csv('../input/sample_submission.csv')

# %%
submission['surface'] = test_surface
submission.to_csv('../output/submission_1.csv', index=False)
submission.head()
# Out:
#    series_id        surface
# 0          0          tiled
# 1          1  fine_concrete
# 2          2       concrete
# 3          3     soft_tiles
# 4          4     soft_tiles
