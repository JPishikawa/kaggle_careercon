# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm
import gc

from scipy import signal
import lightgbm as lgb
from sklearn.metrics import accuracy_score

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 200)

import warnings
warnings.filterwarnings('ignore')

from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
X_train = pd.read_csv('../input/X_train.csv')
y_train = pd.read_csv('../input/y_train.csv')
X_test  = pd.read_csv('../input/X_test.csv')

# %%
targets = y_train['surface'].value_counts().index
print(targets)
print(y_train['surface'].value_counts())
# Out:
# Index(['concrete', 'soft_pvc', 'wood', 'tiled', 'fine_concrete',
#        'hard_tiles_large_space', 'soft_tiles', 'carpet', 'hard_tiles'],
#       dtype='object')
# concrete                  779
# soft_pvc                  732
# wood                      607
# tiled                     514
# fine_concrete             363
# hard_tiles_large_space    308
# soft_tiles                297
# carpet                    189
# hard_tiles                 21
# Name: surface, dtype: int64

# %%
target_to_id = {}
id_to_target = {}

for target in targets:
    if target not in target_to_id:
        new_id = len(target_to_id)
        target_to_id[target] = new_id
        id_to_target[new_id] = target

# %%
y_id = []
for i in range(len(y_train)):
    y_id.append(target_to_id[y_train['surface'].values[i]])
y_id = np.asarray(y_id)

# %%
class_num = len(targets)

# %%
y_id_one = np.zeros((len(y_id), class_num))
for i in range(len(y_id)):
    y_id_one[i, y_id[i]] = 1

# %%
def norm_quat(df):
    norm = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2 + df['orientation_W']**2)**0.5
    df['orientation_X'] /= norm
    df['orientation_Y'] /= norm
    df['orientation_Z'] /= norm
    df['orientation_W'] /= norm
    return df

# %%
import math

def quaternion_to_euler(x, y, z, w):
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.atan2(t0, t1)

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.asin(t2)

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.atan2(t3, t4)

    return X, Y, Z

# %%
X_train = norm_quat(X_train)
X_test = norm_quat(X_test)

# %%
def fe_step1 (df):
    """Quaternions to Euler Angles"""
    
    x = df['orientation_X'].values
    y = df['orientation_Y'].values
    z = df['orientation_Z'].values
    w = df['orientation_W'].values
    nx, ny, nz = np.zeros(len(x)), np.zeros(len(y)), np.zeros(len(z)),
    for i in tqdm(range(len(x))):
        xx, yy, zz = quaternion_to_euler(x[i], y[i], z[i], w[i])
        nx[i] = xx
        ny[i] = yy
        nz[i] = zz
    
    df['euler_X'] = nx
    df['euler_Y'] = ny
    df['euler_Z'] = nz
    return df

# %%
X_train = fe_step1(X_train)
X_test = fe_step1(X_test)
# Out:
# 100%|██████████| 487680/487680 [00:01<00:00, 302695.50it/s]
# 100%|██████████| 488448/488448 [00:01<00:00, 299882.01it/s]

# %%
def highpass_filter(df):
    n_samples = 128
    sample_duration = 0.01
    sample_rate = n_samples * (1 / sample_duration)

    nyquist = 0.5 * sample_rate
    norm_low_cutoff = 500 / nyquist

    sos = signal.butter(10, Wn=[norm_low_cutoff], btype='highpass', output='sos')
    filtered_sig = signal.sosfilt(sos, df)
    
    return filtered_sig

# %%
def lowpass_filter(data, r=0.3):
    f_data = np.zeros_like(data)
    f_data[0] = data[0]
    for i in range(1, len(data)):
        if i % 128 == 0:
            f_data[i] = data[i]
        else:
            f_data[i] = r * data[i] + (1-r) * f_data[i-1]
    return f_data

# %%
for data in [X_train, X_test]:
    data['linear_acceleration_X'] = lowpass_filter(data['linear_acceleration_X'])
    data['linear_acceleration_Y'] = lowpass_filter(data['linear_acceleration_Y'])
    data['linear_acceleration_Z'] = lowpass_filter(data['linear_acceleration_Z'])
    data['angular_velocity_X'] = highpass_filter(data['angular_velocity_X'])
    data['angular_velocity_Y'] = highpass_filter(data['angular_velocity_Y'])
    data['angular_velocity_Z'] = highpass_filter(data['angular_velocity_Z'])

# %%
def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))

# %%
train = X_train.loc[:, 'orientation_X':'orientation_W']
test = X_test.loc[:, 'orientation_X':'orientation_W']

train.columns = ['X','Y','Z','W']
test.columns = ['X','Y','Z','W']

for i in range(4):
    for j in range(i+1, 4):
        train[train.columns[i]+'-'+train.columns[j]] = train.iloc[:, i] - train.iloc[:, j]
        test[test.columns[i]+'-'+test.columns[j]] = test.iloc[:, i] - test.iloc[:, j]
        
train = pd.concat([train, X_train.loc[:, 'euler_X':'euler_Z']], axis=1)
test = pd.concat([test, X_test.loc[:, 'euler_X':'euler_Z']], axis=1)

# %%
for data in [train, test]:
    data['euler_X-Y'] = data['euler_X']-data['euler_Y']
    data['euler_X-Z'] = data['euler_X']-data['euler_Z']
    data['euler_Y-Z'] = data['euler_Y']-data['euler_Z']
    
train = pd.concat([X_train['series_id'], train], axis=1)
test = pd.concat([X_test['series_id'], test], axis=1)

# %%
X_train.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0      -0.758531      -0.634351
# 1    0_1          0                   1      -0.758532      -0.634342
# 2    0_2          0                   2      -0.758528      -0.634348
# 3    0_3          0                   3      -0.758516      -0.634357
# 4    0_4          0                   4      -0.758522      -0.634352
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.049000            0.007993
# 1       -0.10490       -0.10600           -0.045981            0.001089
# 2       -0.10492       -0.10597           -0.060919           -0.010782
# 3       -0.10495       -0.10597           -0.008044           -0.014070
# 4       -0.10495       -0.10596            0.040927           -0.007411
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 0            0.000349              -0.748570               2.103000
# 1            0.000993              -0.422014               1.924020
# 2           -0.005251              -0.374697               1.824474
# 3           -0.000219              -0.134236               1.606922
# 4            0.010239              -0.246872               1.565515
#
#    linear_acceleration_Z   euler_X   euler_Y   euler_Z
# 0              -9.753200  2.843273 -0.024668  1.396667
# 1              -9.651080  2.843201 -0.024662  1.396651
# 2              -9.373766  2.843222 -0.024728  1.396677
# 3              -9.590436  2.843183 -0.024769  1.396712
# 4              -9.845605  2.843197 -0.024785  1.396698

# %%
def rotation_matrix(q0, q1, q2, q3):
    r00 = q0**2 - q1**2 - q2**2 + q3**2
    r01 = 2 * (q0*q3 + q1*q2)
    r02 = 2 * (q1*q3 - q0*q2)
    r10 = 2 * (q1*q2 - q0*q3)
    r11 = q0**2 - q1**2 + q2**2 - q3**2
    r12 = 2 * (q2*q3 + q0*q1)
    r20 = 2 * (q0*q2 + q1*q3)
    r21 = 2 * (-q0*q1 + q2*q3)
    r22 = q0**2 - q1**2 - q2**2 + q3**2
    R = np.array([[r00, r01, r02],[r10, r11, r12],[r20, r21, r22]])
    return R

# %%
def rotated_acceleration(df):
    
    df['rotated_acceleration_X'] = 0
    df['rotated_acceleration_Y'] = 0
    df['rotated_acceleration_Z'] = 0
    #df['rotated_angvel_X'] = 0
    #df['rotated_angvel_Y'] = 0
    #df['rotated_angvel_Z'] = 0
    
    q0_all = df['orientation_X'].values
    q1_all = df['orientation_Y'].values
    q2_all = df['orientation_Z'].values
    q3_all = df['orientation_W'].values
    la_X = df['linear_acceleration_X'].values
    la_Y = df['linear_acceleration_Y'].values
    la_Z = df['linear_acceleration_Z'].values
    #av_X = df['angular_velocity_X'].values
    #av_Y = df['angular_velocity_Y'].values
    #av_Z = df['angular_velocity_Z'].values
    
    for i in tqdm(range(len(df))):
        q0 = q0_all[i]
        q1 = q1_all[i]
        q2 = q2_all[i]
        q3 = q3_all[i]
        
        R = rotation_matrix(q0, q1, q2, q3)
        la = np.array([la_X[i], la_Y[i], la_Z[i]])
        #av = np.array([av_X[i], av_Y[i], av_Z[i]])
        rotated_la = np.dot(R.T, la)
        #rotated_av = np.dot(R.T, av)
        
        df.loc[i, 'rotated_acceleration_X'] = rotated_la[0]
        df.loc[i, 'rotated_acceleration_Y'] = rotated_la[1]
        df.loc[i, 'rotated_acceleration_Z'] = rotated_la[2]
        #df.loc[i, 'rotated_angvel_X'] = rotated_av[0]
        #df.loc[i, 'rotated_angvel_Y'] = rotated_av[1]
        #df.loc[i, 'rotated_angvel_Z'] = rotated_av[2]
    
    return df

# %%
X_train = rotated_acceleration(X_train)
# Out:
# 100%|██████████| 487680/487680 [21:10<00:00, 383.74it/s]

# %%
X_test = rotated_acceleration(X_test)
# Out:
# 100%|██████████| 488448/488448 [22:03<00:00, 368.93it/s]

# %%
X_train['rotated_acceleration_Y'] = X_train['rotated_acceleration_Y'] - 9.80665
X_test['rotated_acceleration_Y'] = X_test['rotated_acceleration_Y'] - 9.80665

# %% [markdown]
# from multiprocessing import Pool

# %% [markdown]
# def process_subtrain(arg_tuple):
#     start, end, idx = arg_tuple
#     X_tr = X_train.iloc[start:end, :]
#     X_tr = rotated_acceleration(X_tr)
#     return idx, X_tr

# %% [markdown]
# all_chunks = []
#
# num_cores = 8
# total_size = len(X_train)
# chunk_size = total_size/num_cores
#
# for i in range(8):
#     start_idx = int(i * chunk_size)
#     end_idx = int(start_idx + chunk_size)
#     chunk = (start_idx, end_idx, i)
#     all_chunks.append(chunk)
#
# pool = Pool()
# results = pool.map(process_subtrain, all_chunks)
# results = sorted(results, key=lambda tup: tup[0])

# %% [markdown]
# X = np.concatenate([item[1] for item in results], axis=0)

# %% [markdown]
# train = pd.concat([train, X_train.loc[:, 'rotated_acceleration_X':'rotated_acceleration_Z']], axis=1)
# test = pd.concat([test, X_test.loc[:, 'rotated_acceleration_X':'rotated_acceleration_Z']], axis=1)

# %%
def feat_eng(df):
    data = pd.DataFrame()
    #df['total_rotated_acce'] = (df['rotated_acceleration_X']**2 + df['rotated_acceleration_Y']**2 + df['rotated_acceleration_Z']**2)**0.5
    
    df_columns = df.columns[1:]
    for col in tqdm(df_columns):
        data[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        #data[col + '_median'] = df.groupby(['series_id'])[col].median()
        data[col + '_max'] = df.groupby(['series_id'])[col].max()
        data[col + '_min'] = df.groupby(['series_id'])[col].min()
        data[col + '_std'] = df.groupby(['series_id'])[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        
        data[col + '_mean_abs_chg'] = df.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        data[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
        data[col + '_abs_max'] = df.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        data[col + '_abs_min'] = df.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        data[col + '_abs_avg'] = (data[col + '_abs_min'] + data[col + '_abs_max'])/2
        
        
    #data['corr_linZangX'] = np.correlate(np.abs(tmp_df[:, 0]), np.abs(tmp_df[:, 1]))
    return data

# %%
train = feat_eng(train)
test = feat_eng(test)
# Out:
# 100%|██████████| 16/16 [00:33<00:00,  2.07s/it]
# 100%|██████████| 16/16 [00:33<00:00,  2.07s/it]

# %%
data_col = train.columns

# %%
train.head()
# Out:
#              X_mean     X_max     X_min     X_std   X_range  X_maxtoMin  \
# series_id
# 0         -0.758666 -0.758219 -0.759527  0.000363  0.001308    0.998278
# 1         -0.958606 -0.958368 -0.958960  0.000151  0.000592    0.999383
# 2         -0.512057 -0.509443 -0.514337  0.001377  0.004895    0.990483
# 3         -0.939169 -0.938839 -0.939682  0.000227  0.000843    0.999103
# 4         -0.891301 -0.886729 -0.896891  0.002955  0.010162    0.988670
#
#            X_mean_abs_chg  X_mean_change_of_abs_change  X_abs_max  X_abs_min  \
# series_id
# 0                0.000016                 2.093952e-07   0.759527   0.758219
#
#            X-Y_mean   X-Y_max   X-Y_min   X-Y_std  X-Y_range  X-Y_maxtoMin  \
# series_id
# 0         -0.124658 -0.123700 -0.126469  0.000827   0.002770      0.978098
# 1         -1.200473 -1.199637 -1.201135  0.000384   0.001498      0.998753
# 2          0.334114  0.338352  0.330558  0.002160   0.007793      1.023577
# 3         -1.249309 -1.248535 -1.250488  0.000432   0.001952      0.998439
# 4         -1.319445 -1.313351 -1.324129  0.003211   0.010778      0.991861
#
#            X-Y_mean_abs_chg  X-Y_mean_change_of_abs_change  X-Y_abs_max  \
# series_id
# 0                  0.000031                   2.333339e-07     0.126469
# 1                  0.000055                   4.107781e-07     1.201135
# 2                  0.000064                  -6.983374e-07     0.338352
# 3                  0.000049                  -6.987718e-07     1.250488
# 4                  0.000085                   2.035742e-07     1.324129
#
#            X-Y_abs_min  X-Y_abs_avg  X-Z_mean   X-Z_max   X-Z_min   X-Z_std  \
# series_id
# 0             0.123700     0.125084 -0.653191 -0.652286 -0.654917  0.000619
# 1             1.199637     1.200386 -0.990256 -0.989340 -0.990791  0.000390
# 2             0.330558     0.334455 -0.382687 -0.379529 -0.385778  0.001808
# 3             1.248535     1.249511 -0.978124 -0.977423 -0.978674  0.000291
# 4             1.313351     1.318740 -0.951357 -0.948500 -0.955138  0.001995
#
#            X-Z_range  X-Z_maxtoMin  X-Z_mean_abs_chg  \
# series_id
# 0           0.002631      0.995983          0.000060
# 1           0.001451      0.998536          0.000043
# 2           0.006249      0.983801          0.000081
# 3           0.001251      0.998722          0.000048
# 4           0.006638      0.993051          0.000053
#
#            X-Z_mean_change_of_abs_change  X-Z_abs_max  X-Z_abs_min  \
# series_id
# 0                           3.037773e-07     0.654917     0.652286
# 1                           3.110039e-07     0.990791     0.989340
# 2                          -9.613932e-07     0.385778     0.379529
# 3                          -1.563981e-07     0.978674     0.977423
# 4                           1.505792e-08     0.955138     0.948500
#
#            X-Z_abs_avg  X-W_mean   X-W_max   X-W_min   X-W_std  X-W_range  \
# series_id
# 0             0.653602 -0.652196 -0.651518 -0.652918  0.000350   0.001400
# 1             0.990065 -0.811731 -0.810310 -0.812798  0.000601   0.002488
# 2             0.382653 -0.440975 -0.438862 -0.443056  0.001309   0.004194
# 3             0.978049 -0.796850 -0.794479 -0.800342  0.001554   0.005863
# 4             0.951819 -0.754840 -0.750429 -0.759941  0.002556   0.009511
#
#            X-W_maxtoMin  X-W_mean_abs_chg  X-W_mean_change_of_abs_change  \
# series_id
# 0              0.997856          0.000046                   7.006584e-07
# 1              0.996939          0.000120                  -2.504587e-06
# 2              0.990535          0.000057                  -1.057931e-06
# 3              0.992674          0.000220                  -5.040800e-06
# 4              0.987484          0.000087                  -1.846186e-07
#
#            X-W_abs_max  X-W_abs_min  X-W_abs_avg  Y-Z_mean   Y-Z_max  \
# series_id
# 0             0.652918     0.651518     0.652218 -0.528533 -0.527307
# 1             0.812798     0.810310     0.811554  0.210217  0.211105
# 2             0.443056     0.438862     0.440959 -0.716800 -0.715810
# 2             0.058326      2.845528     2.847297     2.843556     0.001087
# 3             0.180676      2.845777     2.852147     2.841355     0.002907
# 4             0.196634      2.842442     2.843737     2.841193     0.000742
#
#            euler_X_range  euler_X_maxtoMin  euler_X_mean_abs_chg  \
# series_id
# 0               0.003723          1.001311              0.000113
# 1               0.004713          1.001661              0.000212
# 2               0.003741          1.001315              0.000134
# 3               0.010792          1.003798              0.000403
# 4               0.002545          1.000896              0.000104
#
#            euler_X_mean_change_of_abs_change  euler_X_abs_max  \
# series_id
# 0                               8.529782e-07         2.843933
# 1                              -3.708373e-06         2.842328
# 2                              -4.923401e-06         2.847297
# 3                              -8.899584e-06         2.852147
# 4                              -4.214450e-07         2.843737
#
#            euler_X_abs_min  euler_X_abs_avg  euler_Y_mean  euler_Y_max  \
# series_id
# 0                 2.840210         2.842072     -0.025037    -0.023562
# 1                 2.837615         2.839972     -0.010369    -0.009109
# 2                 2.843556         2.845426     -0.012195    -0.011795
# 3                 2.841355         2.846751     -0.015107    -0.014645
# 4                 2.841193         2.842465     -0.009793    -0.009358
#
#            euler_Y_min  euler_Y_std  euler_Y_range  euler_Y_maxtoMin  \
# series_id
# 0            -0.025795     0.000503       0.002233          0.913436
# 1            -0.012073     0.000822       0.002963          0.754541
# 2            -0.012734     0.000173       0.000939          0.926271
# 3            -0.015697     0.000234       0.001053          0.932944
# 4            -0.010192     0.000241       0.000834          0.918147
#
#            euler_Y_mean_abs_chg  euler_Y_mean_change_of_abs_change  \
# series_id
# 0                      0.000065                       5.642347e-07
# 1                      0.000087                       8.424800e-11
# 2                      0.000067                      -2.344399e-07
# 3                      0.000085                      -1.048903e-06
# 4                      0.000028                       2.084157e-07
#
#            euler_Y_abs_max  euler_Y_abs_min  euler_Y_abs_avg  euler_Z_mean  \
# series_id
# 0                 0.025795         0.023562         0.024678      1.396035
# 1                 0.012073         0.009109         0.010591     -0.492730
# 2                 0.012734         0.011795         0.012264      2.055021
# 3                 0.015697         0.014645         0.015171     -0.635656
# 4                 0.010192         0.009358         0.009775     -0.894147
#
#            euler_Z_max  euler_Z_min  euler_Z_std  euler_Z_range  \
# series_id
# 0             1.397395     1.393224     0.001221       0.004170
# 1            -0.490164    -0.494641     0.001131       0.004478
# 2             2.061297     2.049675     0.003220       0.011622
# 3            -0.634289    -0.638338     0.000931       0.004048
# 4            -0.867984    -0.915038     0.013836       0.047054
#
#            euler_Z_maxtoMin  euler_Z_mean_abs_chg  \
# series_id
# 0                  1.002993              0.000049
# 1                  0.990948              0.000147
# 2                  1.005670              0.000097
# 3                  0.993658              0.000072
# 4                  0.948578              0.000371
#
#            euler_Z_mean_change_of_abs_change  euler_Z_abs_max  \
# series_id
# 0                               2.346825e-07         1.397395
# 1                               1.136899e-07         0.494641
# 2                              -7.319409e-07         2.061297
# 3                               1.306422e-07         0.638338
# 4                               5.328633e-07         0.915038
#
#            euler_Z_abs_min  euler_Z_abs_avg  euler_X-Y_mean  euler_X-Y_max  \
# series_id
# 0                 1.393224         1.395309        2.866771       2.868977
# 1                 0.490164         0.492402        2.850497       2.854401
# 2                 2.049675         2.055486        2.857723       2.859675
# 3                 0.634289         0.636313        2.860885       2.867289
# 4                 0.867984         0.891511        2.852235       2.853489
#
#            euler_X-Y_min  euler_X-Y_std  euler_X-Y_range  euler_X-Y_maxtoMin  \
# series_id
# 0               2.865416       0.000930         0.003561            1.001243
# 1               2.848084       0.001546         0.006317            1.002218
# 2               2.855612       0.001083         0.004063            1.001423
# 3               2.856275       0.002904         0.011014            1.003856
# 4               2.850834       0.000791         0.002655            1.000931
#
#            euler_X-Y_mean_abs_chg  euler_X-Y_mean_change_of_abs_change  \
# series_id
# 0                        0.000112                         1.417213e-06
# 1                        0.000226                        -1.823962e-06
# 2                        0.000148                        -5.946296e-06
# 3                        0.000389                        -7.726782e-06
# 4                        0.000101                        -2.130293e-07
#
#            euler_X-Y_abs_max  euler_X-Y_abs_min  euler_X-Y_abs_avg  \
# series_id
# 0                   2.868977           2.865416           2.867197
# 1                   2.854401           2.848084           2.851242
# 2                   2.859675           2.855612           2.857643
# 3                   2.867289           2.856275           2.861782
# 4                   2.853489           2.850834           2.852162
#
#            euler_X-Z_mean  euler_X-Z_max  euler_X-Z_min  euler_X-Z_std  \
# series_id
# 0                1.445699       1.449096       1.443602       0.001315
# 1                3.332859       3.335664       3.329928       0.001539
# 2                0.790507       0.797080       0.783851       0.003906
# 3                3.481433       3.487844       3.476248       0.003228
# 4                3.736590       3.756366       3.710972       0.013859
#
#            euler_X-Z_range  euler_X-Z_maxtoMin  euler_X-Z_mean_abs_chg  \
# series_id
# 0                 0.005494            1.003805                0.000126
# 1                 0.005736            1.001723                0.000264
# 2                 0.013229            1.016877                0.000174
# 3                 0.011596            1.003336                0.000441
# 4                 0.045394            1.012232                0.000358
#
#            euler_X-Z_mean_change_of_abs_change  euler_X-Z_abs_max  \
# series_id
# 0                                 1.332646e-06           1.449096
# 1                                -1.914639e-06           3.335664
# 2                                -2.519893e-06           0.797080
# 3                                -8.741006e-06           3.487844
# 4                                 9.543084e-07           3.756366
#
#            euler_X-Z_abs_min  euler_X-Z_abs_avg  euler_Y-Z_mean  \
# series_id
# 0                   1.443602           1.446349       -1.421072
# 1                   3.329928           3.332796        0.482362
# 2                   0.783851           0.790466       -2.067216
# 3                   3.476248           3.482046        0.620549
# 4                   3.710972           3.733669        0.884354
#
#            euler_Y-Z_max  euler_Y-Z_min  euler_Y-Z_std  euler_Y-Z_range  \
# series_id
# 0              -1.416831      -1.422772       0.001519         0.005940
# 1               0.485394       0.478307       0.001833         0.007087
# 2              -2.061470      -2.073870       0.003318         0.012400
# 3               0.623270       0.619112       0.000950         0.004158
# 4               0.905351       0.858398       0.013888         0.046953
#
#            euler_Y-Z_maxtoMin  euler_Y-Z_mean_abs_chg  \
# series_id
# 0                    0.995825                0.000099
# 1                    1.014817                0.000174
# 2                    0.994021                0.000132
# 3                    1.006716                0.000122
# 4                    1.054698                0.000370
#
#            euler_Y-Z_mean_change_of_abs_change  euler_Y-Z_abs_max  \
# series_id
# 0                                 8.456646e-08           1.422772
# 1                                -9.067669e-08           0.485394
# 2                                -9.663808e-07           2.073870
# 3                                -1.014224e-06           0.623270
# 4                                 7.412790e-07           0.905351
#
#            euler_Y-Z_abs_min  euler_Y-Z_abs_avg
# series_id
# 0                   1.416831           1.419801
# 1                   0.478307           0.481851
# 2                   2.061470           2.067670
# 3                   0.619112           0.621191
# 4                   0.858398           0.881874

# %%
for data in [train, test]:
    data.fillna(0,inplace=True)
    data.replace(-np.inf,0,inplace=True)
    data.replace(np.inf,0,inplace=True)

# %%
y_gr = y_train['group_id']

# %%
N_SPLITS=4

splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(train, y_gr))

clf = []
val_acc = []
val_pred = []
val_y = []

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'multi_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'multiclass',
               'num_class': 73,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }

for train_idx, val_idx in splits:
    X_tr, y_tr = np.asarray(train)[train_idx, :], y_gr[train_idx]
    X_val, y_val = np.asarray(train)[val_idx, :], y_gr[val_idx]
    
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)
    val_pred.append(pred_lgb)
    val_y.append(y_val)
    
    val_acc.append(accuracy_score(y_val, np.argmax(pred_lgb, axis=1)))

#pred_lgb = pd.DataFrame(pred_lgb, index=np.where(np.mean(adv_val, axis=0)>0.3))
#val_pred = pd.concat([val_pred, pred_lgb], axis=0)

    clf.append(model_lgb)
# Out:
# [1]	valid_0's multi_logloss: 2.61216
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 2.33308
# [3]	valid_0's multi_logloss: 2.1428
# [4]	valid_0's multi_logloss: 1.99276
# [5]	valid_0's multi_logloss: 1.86935
# [6]	valid_0's multi_logloss: 1.76401
# [7]	valid_0's multi_logloss: 1.67278
# [8]	valid_0's multi_logloss: 1.59233
# [9]	valid_0's multi_logloss: 1.52392
# [10]	valid_0's multi_logloss: 1.46028
# [11]	valid_0's multi_logloss: 1.40418
# [12]	valid_0's multi_logloss: 1.35263
# [13]	valid_0's multi_logloss: 1.30613
# [14]	valid_0's multi_logloss: 1.26478
# [15]	valid_0's multi_logloss: 1.22567
# [16]	valid_0's multi_logloss: 1.19131
# [17]	valid_0's multi_logloss: 1.15795
# [18]	valid_0's multi_logloss: 1.12816
# [19]	valid_0's multi_logloss: 1.10026
# [20]	valid_0's multi_logloss: 1.07663
# [21]	valid_0's multi_logloss: 1.05186
# [22]	valid_0's multi_logloss: 1.03121
# [23]	valid_0's multi_logloss: 1.01191
# [24]	valid_0's multi_logloss: 0.992796
# [25]	valid_0's multi_logloss: 0.97489
# [26]	valid_0's multi_logloss: 0.956464
# [27]	valid_0's multi_logloss: 0.941845
# [28]	valid_0's multi_logloss: 0.928089
# [103]	valid_0's multi_logloss: 0.713793
# [104]	valid_0's multi_logloss: 0.715572
# [105]	valid_0's multi_logloss: 0.717781
# [106]	valid_0's multi_logloss: 0.719854
# [107]	valid_0's multi_logloss: 0.721311
# [108]	valid_0's multi_logloss: 0.722432
# [109]	valid_0's multi_logloss: 0.723538
# Early stopping, best iteration is:
# [79]	valid_0's multi_logloss: 0.692735

# %%
val_acc
# Out:
# [0.8113590263691683, 0.7739583333333333, 0.8044871794871795, 0.802801724137931]

# %%
feature_imp = np.zeros(train.shape[1])
for model in clf:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp/4, index=data_col).sort_values(by=0, ascending=False)
# Out:
#                                                0
# euler_Y_mean_abs_chg                 4224.489498
# X-Z_mean                             3373.631012
# Z-W_min                              3237.186289
# X-Z_min                              2890.458451
# X-Y_max                              2838.941982
# Z_mean_abs_chg                       2696.913772
# Z_min                                2695.329689
# X_min                                2609.048634
# euler_Y_mean                         2459.761239
# X-Z_max                              2359.875565
# Y-W_max                              2263.991933
# euler_X-Y_mean_abs_chg               2248.078616
# euler_Y_min                          2245.632815
# W_mean_abs_chg                       2140.973514
# Y-W_min                              2009.524162
# Z-W_mean_abs_chg                     1928.545590
# X-Y_mean                             1926.486759
# euler_X_mean                         1880.680915
# euler_X_min                          1863.078357
# Z-W_mean                             1784.068456
# X-W_max                              1780.714955
# W_max                                1767.055407
# Z-W_abs_max                          1717.601026
# euler_X_max                          1717.039707
# Z-W_max                              1711.274922
# Z_max                                1697.063731
# Y-W_mean                             1695.788805
# X-Y_min                              1441.752661
# X-W_min                              1436.207775
# euler_Y_max                          1425.963794
# Y_max                                1383.826235
# Y-Z_min                              1305.512993
# X_max                                1295.094606
# euler_Y_abs_max                      1215.620334
# Z_mean                               1205.069290
# Y_mean                               1185.527147
# X_mean                               1179.908827
# Y-Z_mean                             1117.346214
# euler_X-Y_min                        1106.063679
# euler_Y_abs_min                      1087.843087
# euler_X_abs_avg                      1079.460296
# euler_X-Y_max                        1063.423719
# X-Y_abs_max                          1039.664615
# W_mean                               1038.189787
# Y-W_abs_max                          1027.721846
# Z_abs_max                            1008.964227
# euler_X_mean_abs_chg                  986.452858
# euler_Y_abs_avg                       981.376554
# X-Y_maxtoMin                          969.006393
# X-W_mean                              965.154235
# Y-W_abs_min                           948.845447
# euler_X-Y_mean                        813.801948
# W_min                                 797.510342
# euler_Z_min                           784.724843
# euler_X_range                         749.706117
# Y_min                                 745.084822
# W_abs_min                             725.931742
# euler_Y_maxtoMin                      709.397428
# Y-Z_mean_abs_chg                      668.829546
# euler_X_std                           657.526698
# euler_X-Y_abs_avg                     644.912934
# Y_maxtoMin                            626.909978
# X-W_abs_max                           621.228204
# Z-W_maxtoMin                          585.519656
# Y-Z_max                               577.087733
# Y-W_mean_abs_chg                      572.014158
# euler_X_abs_max                       561.121161
# X_abs_max                             554.495776
# euler_Y_range                         550.034722
# euler_Y_std                           547.253959
# euler_X-Y_std                         545.191987
# X-Z_abs_avg                           544.730324
# X-Z_abs_max                           534.142543
# X-W_mean_abs_chg                      530.969427
# euler_X-Y_range                       522.121828
# Z-W_abs_min                           510.118371
# euler_Z_maxtoMin                      494.869093
# Y-W_maxtoMin                          478.259237
# X-Z_maxtoMin                          473.447307
# euler_X_maxtoMin                      468.557987
# X_abs_min                             467.086927
# X-W_maxtoMin                          456.538882
# Z_abs_min                             448.768737
# X-Z_mean_abs_chg                      437.636042
# W_abs_avg                             437.207485
# Z-W_abs_avg                           433.799605
# W_abs_max                             433.183542
# euler_Y-Z_abs_min                     430.978930
# Y-Z_abs_max                           404.597058
# X-Y_mean_abs_chg                      401.716559
# X-Y_abs_min                           359.493051
# X_maxtoMin                            357.115532
# X_mean_abs_chg                        356.338169
# Z_maxtoMin                            351.690367
# W_maxtoMin                            351.356919
# euler_X-Z_abs_max                     340.563515
# Y_abs_max                             339.722696
# euler_Y-Z_maxtoMin                    330.738422
# euler_Y_mean_change_of_abs_change     327.502682
# euler_X-Z_max                         316.734986
# X-Y_abs_avg                           312.978939
# X-Y_mean_change_of_abs_change         306.521462
# Y_abs_min                             301.376767
# W_range                               279.648712
# X-Y_range                             248.166057
# Z-W_range                             243.835269
# Z_std                                 241.926289
# euler_X-Z_min                         235.559145
# euler_Y-Z_min                         232.655300
# Z-W_std                               230.910477
# X-Z_abs_min                           230.726697
# Z_abs_avg                             227.508919
# Z_mean_change_of_abs_change           225.453394
# X-W_std                               224.599672
# W_mean_change_of_abs_change           220.025184
# euler_X-Z_maxtoMin                    218.117287
# Y-Z_maxtoMin                          217.979903
# X-Y_std                               217.584591
# euler_Y-Z_mean_abs_chg                216.526921
# euler_X-Y_abs_max                     215.580823
# Y-Z_std                               212.096772
# euler_Z_std                           204.728971
# euler_Y-Z_max                         204.663701
# euler_X_mean_change_of_abs_change     194.483400
# euler_X-Z_abs_avg                     192.784013
# euler_X_abs_min                       190.251876
# X-Z_mean_change_of_abs_change         187.742610
# X-W_range                             185.903396
# X-W_mean_change_of_abs_change         185.711671
# Y_mean_abs_chg                        183.592799
# X-W_abs_min                           180.490412
# X_mean_change_of_abs_change           179.465959
# X_std                                 176.137799
# Z-W_mean_change_of_abs_change         175.624171
# euler_Y-Z_mean_change_of_abs_change   172.186086
# Y-W_abs_avg                           171.166573
# Y-W_std                               169.987971
# Z_range                               169.396382
# Y_range                               166.803275
# euler_X-Z_mean_abs_chg                163.645358
# euler_X-Y_abs_min                     162.442799
# euler_X-Z_mean                        158.115098
# Y-W_mean_change_of_abs_change         157.171287
# euler_Z_mean_change_of_abs_change     155.848583
# euler_X-Y_mean_change_of_abs_change   153.244707
# euler_Z_max                           150.488387
# W_std                                 131.089611
# Y_mean_change_of_abs_change           125.015673
# euler_Z_mean                          124.739606
# Y-Z_abs_min                           120.751070
# euler_X-Z_mean_change_of_abs_change   120.376862
# Y-W_range                             120.314295
# Y-Z_mean_change_of_abs_change         114.413800
# euler_X-Y_maxtoMin                    112.068885
# Y_std                                 107.197335
# X-Z_range                              89.994503
# euler_Z_mean_abs_chg                   83.211746
# X_range                                82.647364
# euler_Y-Z_abs_max                      80.075922
# X-Z_std                                75.315506
# euler_X-Z_range                        75.132068
# euler_Y-Z_std                          73.143295
# Y-Z_range                              73.047515
# euler_Z_abs_min                        71.545877
# euler_X-Z_std                          66.168478
# X_abs_avg                              66.096242
# euler_X-Z_abs_min                      50.941465
# euler_Y-Z_mean                         34.108505
# euler_Z_range                          29.467259
# X-W_abs_avg                            26.530844
# Y_abs_avg                              26.406335
# Y-Z_abs_avg                            25.746549
# euler_Y-Z_range                        25.447366
# euler_Z_abs_max                        21.865462
# euler_Y-Z_abs_avg                       9.103295
# euler_Z_abs_avg                         4.115826

# %%
from sklearn.metrics import roc_auc_score

# %%
X_train_reserve = X_train.copy()
X_test_reserve = X_test.copy()

# %%
X_train_reserve.to_csv('./rotated_train.csv')
X_test_reserve.to_csv('./rotated_test.csv')

# %%
def feat_eng(df):
    data = pd.DataFrame()

    df['total_acce'] = (df['linear_acceleration_X']**2 + df['linear_acceleration_Y']**2 + df['linear_acceleration_Z']**2)**0.5
    df['total_rotated'] = (df['rotated_acceleration_X']**2 + df['rotated_acceleration_Y']**2 + df['rotated_acceleration_Z']**2)**0.5
    #df['total_ang_cos'] = (df['angular_velocity_X_cos']**2 + df['angular_velocity_Y_cos']**2 + df['angular_velocity_Z_cos']**2)**0.5
    
    df = df.drop(columns=['euler_X'], axis=0)
    df = df.drop(columns=['euler_Y'], axis=0)
    df = df.drop(columns=['euler_Z'], axis=0)
    #df['total_angu'] = (df['angular_velocity_X']**2 + df['angular_velocity_Y']**2 + df['angular_velocity_Z']**2)**0.5
    
    #df['total_eule'] = (df['euler_X']**2 + df['euler_Y']**2 + df['euler_Z']**2)**0.5
    #df['total_xyz'] = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2)**0.5
    #df['total_acc/vel'] = df['total_acce']/df['total_angu']
    
    df_columns = df.columns[7:]
    for col in tqdm(df_columns):
        data[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        data[col + '_median'] = df.groupby(['series_id'])[col].median()
        data[col + '_max'] = df.groupby(['series_id'])[col].max()
        data[col + '_min'] = df.groupby(['series_id'])[col].min()
        data[col + '_std'] = df.groupby(['series_id'])[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        data[col + '_mean_abs_chg'] = df.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        data[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
        data[col + '_abs_max'] = df.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        data[col + '_abs_min'] = df.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        data[col + '_abs_avg'] = (data[col + '_abs_min'] + data[col + '_abs_max'])/2
        
        
    #data['corr_linZangX'] = np.correlate(np.abs(tmp_df[:, 0]), np.abs(tmp_df[:, 1]))
    return data

# %%
X_train.head()
# Out:
#            angular_velocity_X_mean  angular_velocity_X_median  \
# series_id
# 0                         0.000606                  -0.003281
# 1                        -0.000110                  -0.004165
# 2                        -0.000104                   0.004176
# 3                        -0.000980                  -0.004165
# 4                         0.000390                  -0.000655
#
#            angular_velocity_X_max  angular_velocity_X_min  \
# series_id
# 0                        0.097597               -0.100359
# 1                        0.179486               -0.198174
# 2                        0.093036               -0.125226
# 3                        0.410808               -0.398074
# 4                        0.079432               -0.081673
#
#            angular_velocity_X_std  angular_velocity_X_range  \
# series_id
# 0                        0.037477                  0.197956
# 1                        0.079273                  0.377660
# 2                        0.036439                  0.218262
# 3                        0.138277                  0.808882
# 4                        0.031496                  0.161105
#
#            angular_velocity_X_maxtoMin  angular_velocity_X_mean_abs_chg  \
# series_id
# 0                            -0.972476                         0.028929
# 1                            -0.905697                         0.063771
# 2                            -0.742945                         0.028808
# 3                            -1.031990                         0.107176
# 4                            -0.972554                         0.023166
#
#            angular_velocity_X_mean_change_of_abs_change  \
# series_id
# 0                                             -0.000540
# 1                                             -0.001595
# 2                                              0.000165
# 3                                             -0.002837
# 4                                             -0.000116
#
#            angular_velocity_X_abs_max  angular_velocity_X_abs_min  \
# series_id
# 0                            0.100359                    0.000107
# 1                            0.198174                    0.000626
# 2                            0.125226                    0.000693
# 3                            0.410808                    0.000460
# 4                            0.081673                    0.000981
#
#            angular_velocity_X_abs_avg  angular_velocity_Y_mean  \
# series_id
# 0                            0.050233                 0.000071
# 1                            0.099400                 0.000108
# 2                            0.062960                -0.000265
# 3                            0.205634                 0.000937
# 4                            0.041327                -0.000955
#
#            angular_velocity_Y_median  angular_velocity_Y_max  \
# series_id
# 0                          -0.000564                0.045390
# 1                          -0.001410                0.113061
# 2                           0.000333                0.090551
# 3                          -0.003439                0.125392
# 4                          -0.002589                0.052542
#
#            angular_velocity_Y_min  angular_velocity_Y_std  \
# series_id
# 0                       -0.063419                0.020777
# 1                       -0.131297                0.044342
# 2                       -0.101291                0.035535
# 3                       -0.154037                0.043004
# 4                       -0.072168                0.017189
#
#            angular_velocity_Y_range  angular_velocity_Y_maxtoMin  \
# series_id
# 0                          0.108810                    -0.715720
# 1                          0.244358                    -0.861107
# 2                          0.191842                    -0.893960
# 3                          0.279429                    -0.814034
# 4                          0.124710                    -0.728048
#
#            angular_velocity_Y_mean_abs_chg  \
# series_id
# 0                                 0.021811
# 1                                 0.043876
# 2                                 0.034830
# 3                                 0.042300
# 4                                 0.010807
#
#            angular_velocity_Y_mean_change_of_abs_change  \
# series_id
# 0                                              0.000169
# 1                                              0.000190
# 2                                             -0.000128
# 3                                             -0.000254
# 4                                             -0.000318
#
#            angular_velocity_Y_abs_max  angular_velocity_Y_abs_min  \
# series_id
# 0                            0.063419                    0.000168
# 1                            0.131297                    0.000053
# 2                            0.101291                    0.000049
# 3                            0.154037                    0.000146
# 4                            0.072168                    0.000072
#
#            angular_velocity_Y_abs_avg  angular_velocity_Z_mean  \
# series_id
# 0                            0.031794                -0.000400
# 1                            0.065675                 0.000853
# 2                            0.050670                -0.000197
# 3                            0.077091                -0.000461
# 4                            0.036120                 0.000408
#
#            angular_velocity_Z_median  angular_velocity_Z_max  \
# series_id
# 0                          -0.000551                0.032482
# 1                           0.001625                0.093227
# 2                           0.000286                0.086293
# 3                           0.001220                0.064880
# 4                           0.001068                0.072612
#
#            angular_velocity_Z_min  angular_velocity_Z_std  \
# series_id
# 0                       -0.024468                0.009399
# 1                       -0.090793                0.048279
# 2                       -0.095494                0.032242
# 3                       -0.071600                0.024167
# 4                       -0.041661                0.022075
#
#            angular_velocity_Z_range  angular_velocity_Z_maxtoMin  \
# series_id
# 0                          0.056950                    -1.327492
# 1                          0.184021                    -1.026808
# 2                          0.181786                    -0.903647
# 3                          0.136480                    -0.906142
# 4                          0.114273                    -1.742955
#
#            angular_velocity_Z_mean_abs_chg  \
# series_id
# 0                                 0.009038
# 1                                 0.019224
# 2                                 0.014750
# 3                                 0.019724
# 4                                 0.007394
#
#            angular_velocity_Z_mean_change_of_abs_change  \
# series_id
# 0                                              0.000093
# 1                                             -0.000366
# 2                                             -0.000026
# 3                                             -0.000494
# 4                                             -0.000696
#
#            angular_velocity_Z_abs_max  angular_velocity_Z_abs_min  \
# series_id
# 0                            0.032482                    0.000077
# 1                            0.093227                    0.000149
# 2                            0.095494                    0.000132
# 3                            0.071600                    0.000571
# 4                            0.072612                    0.000075
#
#            angular_velocity_Z_abs_avg  linear_acceleration_X_mean  \
# series_id
# 0                            0.016279                    0.261341
# 1                            0.046688                    0.163601
# 2                            0.047813                    0.177190
# 3                            0.036086                    0.226659
# 4                            0.036344                   -0.071336
#
#            linear_acceleration_X_median  linear_acceleration_X_max  \
# series_id
# 0                              0.285042                   1.648423
# 1                              0.005907                   2.184800
# 2                              0.214934                   1.052559
# 3                              0.161048                   2.651966
# 4                             -0.027444                   0.481878
#
#            linear_acceleration_X_min  linear_acceleration_X_std  \
# series_id
# 0                          -1.268349                   0.708672
# 1                          -0.871621                   0.626577
# 2                          -1.108061                   0.346165
# 3                          -0.989965                   0.686565
# 4                          -1.017074                   0.338622
#
#            linear_acceleration_X_range  linear_acceleration_X_maxtoMin  \
# series_id
# 0                             2.916772                       -1.299661
# 1                             3.056421                       -2.506593
# 2                             2.160620                       -0.949911
# 3                             3.641932                       -2.678848
# 4                             1.498953                       -0.473789
#
#            linear_acceleration_X_mean_abs_chg  \
# series_id
# 0                                    0.160546
# 1                                    0.265054
# 2                                    0.193576
# 3                                    0.369320
# 4                                    0.073541
#
#            linear_acceleration_X_mean_change_of_abs_change  \
# series_id
# 0                                                -0.002250
# 1                                                -0.003635
# 2                                                 0.000049
# 3                                                 0.004151
# 4                                                 0.000354
#
#            linear_acceleration_X_abs_max  linear_acceleration_X_abs_min  \
# series_id
# 0                               1.648423                       0.016849
# 1                               2.184800                       0.003728
# 2                               1.108061                       0.001093
# 3                               2.651966                       0.001294
# 4                               1.017074                       0.002765
#
#            linear_acceleration_X_abs_avg  linear_acceleration_Y_mean  \
# series_id
# 0                               0.832636                    3.002412
# 1                               1.094264                    2.772722
# 2                               0.554577                    2.897345
# 3                               1.326630                    2.720704
# 4                               0.509920                    2.981143
#
#            linear_acceleration_Y_median  linear_acceleration_Y_max  \
# series_id
# 0                              3.392663                   4.623803
# 1                              2.871693                   5.489065
# 2                              3.076755                   5.655919
# 3                              3.166031                   8.812608
# 4                              3.207887                   4.413960
#
#            linear_acceleration_Y_min  linear_acceleration_Y_std  \
# series_id
# 0                           0.540230                   1.236915
# 1                          -0.283137                   1.557537
# 2                          -0.462089                   1.529911
# 3                          -3.251800                   3.642410
# 4                           0.574627                   1.054487
#
#            linear_acceleration_Y_range  linear_acceleration_Y_maxtoMin  \
# series_id
# 0                             4.083573                        8.558946
# 1                             5.772201                      -19.386629
# 2                             6.118008                      -12.239887
# 3                            12.064407                       -2.710071
# 4                             3.839333                        7.681434
#
#            linear_acceleration_Y_mean_abs_chg  \
# series_id
# 0                                    0.173883
# 1                                    0.296476
# 2                                    0.249995
# 3                                    0.555371
# 4                                    0.128102
#
#            linear_acceleration_Y_mean_change_of_abs_change  \
# series_id
# 0                                                -0.000399
# 1                                                -0.001489
# 2                                                -0.000056
# 3                                                -0.003488
# 4                                                 0.001003
#
#            linear_acceleration_Y_abs_max  linear_acceleration_Y_abs_min  \
# series_id
# 0                               4.623803                       0.540230
# 1                               5.489065                       0.208964
# 2                               5.655919                       0.085409
# 3                               8.812608                       0.018518
# 4                               4.413960                       0.574627
#
#            linear_acceleration_Y_abs_avg  linear_acceleration_Z_mean  \
# series_id
# 0                               2.582017                   -9.314346
# 1                               2.849015                   -9.382948
# 2                               2.870664                   -9.329791
# 3                               4.415563                   -9.440360
# 4                               2.494294                   -9.358524
#
#            linear_acceleration_Z_median  linear_acceleration_Z_max  \
# series_id
# 0                             -9.312408                  -8.324252
# 1                             -9.333242                  -7.274143
# 2                             -9.340382                  -5.744200
# 3                             -9.290498                  -6.283890
# 4                             -9.358517                  -8.515674
#
#            linear_acceleration_Z_min  linear_acceleration_Z_std  \
# series_id
# 0                         -10.735116                   0.473874
# 1                         -13.109350                   0.847922
# 2                         -10.710896                   0.675885
# 3                         -13.624317                   1.300192
# 4                         -10.188441                   0.385351
#
#            linear_acceleration_Z_range  linear_acceleration_Z_maxtoMin  \
# series_id
# 0                             2.410865                        0.775423
# 1                             5.835207                        0.554882
# 2                             4.966696                        0.536295
# 3                             7.340427                        0.461226
# 4                             1.672767                        0.835817
#
#            linear_acceleration_Z_mean_abs_chg  \
# series_id
# 0                                    0.272874
# 1                                    0.527628
# 2                                    0.287600
# 3                                    0.865445
# 4                                    0.210181
#
#            linear_acceleration_Z_mean_change_of_abs_change  \
# series_id
# 0                                                 0.001272
# 1                                                -0.006774
# 2                                                 0.000202
# 3                                                -0.011674
# 4                                                 0.000310
#
#            linear_acceleration_Z_abs_max  linear_acceleration_Z_abs_min  \
# series_id
# 0                              10.735116                       8.324252
# 1                              13.109350                       7.274143
# 2                              10.710896                       5.744200
# 3                              13.624317                       6.283890
# 4                              10.188441                       8.515674
#
#            linear_acceleration_Z_abs_avg  rotated_acceleration_X_mean  \
# series_id
# 0                               9.529684                    -2.786008
# 1                              10.191747                     0.640771
# 2                               8.227548                    -2.016696
# 3                               9.954104                     1.036367
# 4                               9.352057                     1.476937
#
#            rotated_acceleration_X_median  rotated_acceleration_X_max  \
# series_id
# 0                              -2.784012                   -2.381788
# 1                               0.457868                    2.743717
# 2                              -1.997440                   -1.098183
# 3                               1.131861                    4.644175
# 4                               1.561688                    2.300707
#
#            rotated_acceleration_X_min  rotated_acceleration_X_std  \
# series_id
# 0                           -3.199514                    0.188563
# 1                           -1.006617                    0.845558
# 2                           -2.840675                    0.354680
# 3                           -1.460856                    1.112844
# 4                            0.745411                    0.363800
#
#            rotated_acceleration_X_range  rotated_acceleration_X_maxtoMin  \
# series_id
# 0                              0.817726                         0.744422
# 1                              3.750334                        -2.725682
# 2                              1.742493                         0.386592
# 3                              6.105031                        -3.179078
# 4                              1.555296                         3.086493
#
#            rotated_acceleration_X_mean_abs_chg  \
# series_id
# 0                                     0.085946
# 1                                     0.249657
# 2                                     0.134776
# 3                                     0.364618
# 4                                     0.073744
#
#            rotated_acceleration_X_mean_change_of_abs_change  \
# series_id
# 0                                                 -0.000212
# 1                                                 -0.004610
# 2                                                  0.000027
# 3                                                  0.000660
# 4                                                  0.000412
#
#            rotated_acceleration_X_abs_max  rotated_acceleration_X_abs_min  \
# series_id
# 0                                3.199514                        2.381788
# 1                                2.743717                        0.001901
# 2                                2.840675                        1.098183
# 3                                4.644175                        0.013670
# 4                                2.300707                        0.745411
#
#            rotated_acceleration_X_abs_avg  rotated_acceleration_Y_mean  \
# series_id
# 0                                2.790651                    -0.457298
# 1                                1.372809                   -11.693977
# 2                                1.969429                    -3.122883
# 3                                2.328923                   -13.050474
# 4                                1.523059                   -15.036692
#
#            rotated_acceleration_Y_median  rotated_acceleration_Y_max  \
# series_id
# 0                              -0.454697                    0.731032
# 1                             -11.459131                   -8.766004
# 2                              -3.219814                   -0.556854
# 3                             -12.409666                   -7.298656
# 4                             -14.968034                  -13.517113
#
#            rotated_acceleration_Y_min  rotated_acceleration_Y_std  \
# series_id
# 0                           -1.704916                    0.459176
# 1                          -15.946338                    1.393617
# 2                           -6.446817                    1.084209
# 3                          -19.902808                    3.205823
# 4                          -17.030841                    0.779250
#
#            rotated_acceleration_Y_range  rotated_acceleration_Y_maxtoMin  \
# series_id
# 0                              2.435948                        -0.428779
# 1                              7.180335                         0.549719
# 2                              5.889964                         0.086377
# 3                             12.604152                         0.366715
# 4                              3.513728                         0.793684
#
#            rotated_acceleration_Y_mean_abs_chg  \
# series_id
# 0                                     0.244647
# 1                                     0.433182
# 2                                     0.327579
# 3                                     0.821326
# 4                                     0.194222
#
#            rotated_acceleration_Y_mean_change_of_abs_change  \
# series_id
# 0                                                  0.001634
# 1                                                 -0.003622
# 2                                                  0.000164
# 3                                                 -0.010548
# 4                                                  0.000159
#
#            rotated_acceleration_Y_abs_max  rotated_acceleration_Y_abs_min  \
# series_id
# 0                                1.704916                        0.003739
# 1                               15.946338                        8.766004
# 2                                6.446817                        0.556854
# 3                               19.902808                        7.298656
# 4                               17.030841                       13.517113
#
#            rotated_acceleration_Y_abs_avg  rotated_acceleration_Z_mean  \
# series_id
# 0                                0.854328                     1.329938
# 1                               12.356171                    -9.580283
# 2                                3.501836                     6.903779
# 3                               13.600732                    -9.213461
# 4                               15.273977                    -8.178337
#
#            rotated_acceleration_Z_median  rotated_acceleration_Z_max  \
# series_id
# 0                               1.747534                    2.953737
# 1                              -9.621910                   -7.165724
# 2                               7.032563                    9.080385
# 3                              -9.209364                   -4.364744
# 4                              -8.493046                   -6.270627
#
#            rotated_acceleration_Z_min  rotated_acceleration_Z_std  \
# series_id
# 0                           -1.233324                    1.243816
# 1                          -11.425438                    0.891246
# 2                            4.360574                    1.227132
# 3                          -13.063699                    1.952122
# 4                           -9.284312                    0.827988
#
#            rotated_acceleration_Z_range  rotated_acceleration_Z_maxtoMin  \
# series_id
# 0                              4.187061                        -2.394940
# 1                              4.259714                         0.627173
# 2                              4.719810                         2.082383
# 3                              8.698955                         0.334112
# 4                              3.013685                         0.675400
#
#            rotated_acceleration_Z_mean_abs_chg  \
# series_id
# 0                                     0.197722
# 1                                     0.404630
# 2                                     0.203334
# 3                                     0.588761
# 4                                     0.132750
#
#            rotated_acceleration_Z_mean_change_of_abs_change  \
# series_id
# 0                                                  0.000060
# 1                                                 -0.005102
# 2                                                  0.000118
# 3                                                 -0.007304
# 4                                                  0.000925
#
#            rotated_acceleration_Z_abs_max  rotated_acceleration_Z_abs_min  \
# series_id
# 0                                2.953737                        0.029900
# 1                               11.425438                        7.165724
# 2                                9.080385                        4.360574
# 3                               13.063699                        4.364744
# 4                                9.284312                        6.270627
#
#            rotated_acceleration_Z_abs_avg  total_acce_mean  total_acce_median  \
# series_id
# 0                                1.491819         9.892753           9.941641
# 1                                9.295581         9.930341           9.926521
# 2                                6.720480         9.902159           9.945025
# 3                                8.714221        10.499400          10.662237
# 4                                7.777469         9.882643           9.930058
#
#            total_acce_max  total_acce_min  total_acce_std  total_acce_range  \
# series_id
# 0               10.888026        8.659276        0.462628          2.228750
# 1               13.113474        8.015228        0.811051          5.098246
# 2               11.163415        6.794325        0.561430          4.369090
# 3               13.971006        7.221134        1.287646          6.749872
# 4               10.659495        8.868287        0.416354          1.791208
#
#            total_acce_maxtoMin  total_acce_mean_abs_chg  \
# series_id
# 0                     1.257383                 0.241210
# 1                     1.636070                 0.466380
# 2                     1.643050                 0.240515
# 3                     1.934738                 0.746214
# 4                     1.201979                 0.192187
#
#            total_acce_mean_change_of_abs_change  total_acce_abs_max  \
# series_id
# 0                                      0.000690           10.888026
# 1                                     -0.006679           13.113474
# 2                                      0.000238           11.163415
# 3                                     -0.008815           13.971006
# 4                                      0.000683           10.659495
#
#            total_acce_abs_min  total_acce_abs_avg  total_rotated_mean  \
# series_id
# 0                    8.659276            9.773651            3.373560
# 1                    8.015228           10.564351           15.207690
# 2                    6.794325            8.978870            7.905883
# 3                    7.221134           10.596070           16.361546
# 4                    8.868287            9.763891           17.215018
#
#            total_rotated_median  total_rotated_max  total_rotated_min  \
# series_id
# 0                      3.349282           4.198141           2.658943
# 1                     15.101457          19.710547          12.518797
# 2                      8.046596          10.389493           5.222576
# 3                     15.965073          22.117047          12.389549
# 4                     17.188742          18.452243          16.132650
#
#            total_rotated_std  total_rotated_range  total_rotated_maxtoMin  \
# series_id
# 0                   0.373286             1.539198                1.578876
# 1                   1.049165             7.191750                1.574476
# 2                   1.333328             5.166917                1.989343
# 3                   1.952732             9.727498                1.785137
# 4                   0.477049             2.319593                1.143783
#
#            total_rotated_mean_abs_chg  \
# series_id
# 0                            0.089777
# 1                            0.536155
# 2                            0.217048
# 3                            0.880926
# 4                            0.211437
#
#            total_rotated_mean_change_of_abs_change  total_rotated_abs_max  \
# series_id
# 0                                        -0.000314               4.198141
# 1                                        -0.006686              19.710547
# 2                                        -0.000898              10.389493
# 3                                        -0.012699              22.117047
# 4                                         0.000303              18.452243
#
#            total_rotated_abs_min  total_rotated_abs_avg
# series_id
# 0                       2.658943               3.428542
# 1                      12.518797              16.114672
# 2                       5.222576               7.806034
# 3                      12.389549              17.253298
# 4                      16.132650              17.292446

# %%
X_train = feat_eng(X_train)
X_test = feat_eng(X_test)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
#   9%|▉         | 1/11 [00:02<00:20,  2.07s/it]
#  18%|█▊        | 2/11 [00:04<00:18,  2.07s/it]
#  27%|██▋       | 3/11 [00:06<00:16,  2.07s/it]
#  36%|███▋      | 4/11 [00:08<00:14,  2.08s/it]
#  45%|████▌     | 5/11 [00:10<00:12,  2.08s/it]
#  55%|█████▍    | 6/11 [00:12<00:10,  2.07s/it]
#  64%|██████▎   | 7/11 [00:14<00:08,  2.08s/it]
#  73%|███████▎  | 8/11 [00:16<00:06,  2.09s/it]
#  82%|████████▏ | 9/11 [00:18<00:04,  2.08s/it]
#  91%|█████████ | 10/11 [00:20<00:02,  2.08s/it]
# 100%|██████████| 11/11 [00:22<00:00,  2.07s/it]
#
#   0%|          | 0/11 [00:00<?, ?it/s]
#   9%|▉         | 1/11 [00:02<00:21,  2.10s/it]
#  18%|█▊        | 2/11 [00:04<00:18,  2.09s/it]
#  27%|██▋       | 3/11 [00:06<00:16,  2.10s/it]
#  36%|███▋      | 4/11 [00:08<00:14,  2.13s/it]
#  45%|████▌     | 5/11 [00:10<00:12,  2.16s/it]
#  55%|█████▍    | 6/11 [00:12<00:10,  2.19s/it]
#  64%|██████▎   | 7/11 [00:15<00:08,  2.20s/it]
#  73%|███████▎  | 8/11 [00:17<00:06,  2.18s/it]
#  82%|████████▏ | 9/11 [00:19<00:04,  2.15s/it]
#  91%|█████████ | 10/11 [00:21<00:02,  2.12s/it]
# 100%|██████████| 11/11 [00:23<00:00,  2.11s/it]

# %%
y = np.concatenate((np.zeros(len(X_train)), np.ones(len(X_test))), axis=0)
X = np.concatenate((X_train, X_test), axis=0)

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))

clf_2 = []
val_roc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'binary_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'binary',
               #'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }


for train_idx, val_idx in splits:
    X_tr, y_tr = X[train_idx, :], y[train_idx]
    X_val, y_val = X[val_idx, :], y[val_idx]
 
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)
    
    val_roc.append(roc_auc_score(y_val, (pred_lgb>0.5).astype(int)))
    
    pred_lgb = pd.DataFrame(pred_lgb, index=val_idx)
    val_pred = pd.concat([val_pred, pred_lgb], axis=0)
    
    clf_2.append(model_lgb)
# Out:
# [1]	valid_0's binary_logloss: 0.68334
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.676336
# [3]	valid_0's binary_logloss: 0.669112
# [4]	valid_0's binary_logloss: 0.662645
# [5]	valid_0's binary_logloss: 0.657857
# [6]	valid_0's binary_logloss: 0.65382
# [7]	valid_0's binary_logloss: 0.648721
# [8]	valid_0's binary_logloss: 0.643948
# [9]	valid_0's binary_logloss: 0.639753
# [10]	valid_0's binary_logloss: 0.636565
# [11]	valid_0's binary_logloss: 0.634422
# [12]	valid_0's binary_logloss: 0.631367
# [13]	valid_0's binary_logloss: 0.629279
# [14]	valid_0's binary_logloss: 0.626843
# [15]	valid_0's binary_logloss: 0.625203
# [16]	valid_0's binary_logloss: 0.623948
# [17]	valid_0's binary_logloss: 0.622189
# [18]	valid_0's binary_logloss: 0.619698
# [19]	valid_0's binary_logloss: 0.618736
# [20]	valid_0's binary_logloss: 0.618589
# [21]	valid_0's binary_logloss: 0.618156
# [22]	valid_0's binary_logloss: 0.617454
# [23]	valid_0's binary_logloss: 0.615696
# [24]	valid_0's binary_logloss: 0.614363
# [25]	valid_0's binary_logloss: 0.612711
# [26]	valid_0's binary_logloss: 0.611894
# [27]	valid_0's binary_logloss: 0.611288
# [28]	valid_0's binary_logloss: 0.610556
# [29]	valid_0's binary_logloss: 0.610217
# [30]	valid_0's binary_logloss: 0.610198
# [31]	valid_0's binary_logloss: 0.608831
# [32]	valid_0's binary_logloss: 0.607807
# [33]	valid_0's binary_logloss: 0.607857
# [34]	valid_0's binary_logloss: 0.607297
# [35]	valid_0's binary_logloss: 0.606274
# [36]	valid_0's binary_logloss: 0.60614
# [37]	valid_0's binary_logloss: 0.605792
# [38]	valid_0's binary_logloss: 0.605119
# [39]	valid_0's binary_logloss: 0.604387
# [40]	valid_0's binary_logloss: 0.603985
# [41]	valid_0's binary_logloss: 0.603723
# [42]	valid_0's binary_logloss: 0.603545
# [43]	valid_0's binary_logloss: 0.60374
# [44]	valid_0's binary_logloss: 0.603694
# [45]	valid_0's binary_logloss: 0.603527
# [46]	valid_0's binary_logloss: 0.603565
# [47]	valid_0's binary_logloss: 0.603564
# [48]	valid_0's binary_logloss: 0.60338
# [49]	valid_0's binary_logloss: 0.603789
# [50]	valid_0's binary_logloss: 0.603525
# [51]	valid_0's binary_logloss: 0.603294
# [52]	valid_0's binary_logloss: 0.602894
# [53]	valid_0's binary_logloss: 0.60278
# [54]	valid_0's binary_logloss: 0.602282
# [55]	valid_0's binary_logloss: 0.602487
# [56]	valid_0's binary_logloss: 0.601818
# [57]	valid_0's binary_logloss: 0.601769
# [58]	valid_0's binary_logloss: 0.601842
# [59]	valid_0's binary_logloss: 0.600456
# [60]	valid_0's binary_logloss: 0.600661
# [61]	valid_0's binary_logloss: 0.600546
# [62]	valid_0's binary_logloss: 0.599956
# [63]	valid_0's binary_logloss: 0.599102
# [64]	valid_0's binary_logloss: 0.599385
# [65]	valid_0's binary_logloss: 0.599236
# [66]	valid_0's binary_logloss: 0.599172
# [67]	valid_0's binary_logloss: 0.599533
# [68]	valid_0's binary_logloss: 0.599208
# [69]	valid_0's binary_logloss: 0.599159
# [70]	valid_0's binary_logloss: 0.59882
# [71]	valid_0's binary_logloss: 0.598671
# [72]	valid_0's binary_logloss: 0.59826
# [73]	valid_0's binary_logloss: 0.598207
# [74]	valid_0's binary_logloss: 0.598534
# [75]	valid_0's binary_logloss: 0.598256
# [76]	valid_0's binary_logloss: 0.597874
# [77]	valid_0's binary_logloss: 0.597704
# [78]	valid_0's binary_logloss: 0.597616
# [79]	valid_0's binary_logloss: 0.597725
# [80]	valid_0's binary_logloss: 0.597906
# [81]	valid_0's binary_logloss: 0.597945
# [82]	valid_0's binary_logloss: 0.598102
# [83]	valid_0's binary_logloss: 0.597873
# [84]	valid_0's binary_logloss: 0.597164
# [85]	valid_0's binary_logloss: 0.59677
# [86]	valid_0's binary_logloss: 0.597162
# [87]	valid_0's binary_logloss: 0.597365
# [88]	valid_0's binary_logloss: 0.597725
# [89]	valid_0's binary_logloss: 0.597581
# [90]	valid_0's binary_logloss: 0.596754
# [91]	valid_0's binary_logloss: 0.596642
# [92]	valid_0's binary_logloss: 0.596928
# [93]	valid_0's binary_logloss: 0.597229
# [94]	valid_0's binary_logloss: 0.597253
# [95]	valid_0's binary_logloss: 0.597242
# [96]	valid_0's binary_logloss: 0.596988
# [97]	valid_0's binary_logloss: 0.596979
# [98]	valid_0's binary_logloss: 0.596629
# [99]	valid_0's binary_logloss: 0.596521
# [100]	valid_0's binary_logloss: 0.59613
# [101]	valid_0's binary_logloss: 0.595749
# [102]	valid_0's binary_logloss: 0.595362
# [103]	valid_0's binary_logloss: 0.595248
# [104]	valid_0's binary_logloss: 0.595215
# [105]	valid_0's binary_logloss: 0.595556
# [106]	valid_0's binary_logloss: 0.595591
# [107]	valid_0's binary_logloss: 0.596043
# [108]	valid_0's binary_logloss: 0.595964
# [109]	valid_0's binary_logloss: 0.595724
# [110]	valid_0's binary_logloss: 0.595604
# [111]	valid_0's binary_logloss: 0.595959
# [112]	valid_0's binary_logloss: 0.594697
# [113]	valid_0's binary_logloss: 0.594543
# [114]	valid_0's binary_logloss: 0.594556
# [115]	valid_0's binary_logloss: 0.594945
# [116]	valid_0's binary_logloss: 0.59545
# [117]	valid_0's binary_logloss: 0.595761
# [118]	valid_0's binary_logloss: 0.595609
# [119]	valid_0's binary_logloss: 0.595311
# [120]	valid_0's binary_logloss: 0.595143
# [121]	valid_0's binary_logloss: 0.595036
# [122]	valid_0's binary_logloss: 0.59522
# [123]	valid_0's binary_logloss: 0.595125
# [124]	valid_0's binary_logloss: 0.594573
# [125]	valid_0's binary_logloss: 0.594314
# [126]	valid_0's binary_logloss: 0.594072
# [127]	valid_0's binary_logloss: 0.594043
# [128]	valid_0's binary_logloss: 0.593973
# [129]	valid_0's binary_logloss: 0.593956
# [130]	valid_0's binary_logloss: 0.593829
# [131]	valid_0's binary_logloss: 0.593639
# [132]	valid_0's binary_logloss: 0.59388
# [133]	valid_0's binary_logloss: 0.593472
# [134]	valid_0's binary_logloss: 0.593889
# [135]	valid_0's binary_logloss: 0.593445
# [136]	valid_0's binary_logloss: 0.593389
# [137]	valid_0's binary_logloss: 0.593548
# [138]	valid_0's binary_logloss: 0.592903
# [139]	valid_0's binary_logloss: 0.593064
# [140]	valid_0's binary_logloss: 0.59356
# [141]	valid_0's binary_logloss: 0.593892
# [142]	valid_0's binary_logloss: 0.593711
# [143]	valid_0's binary_logloss: 0.594201
# [144]	valid_0's binary_logloss: 0.592844
# [145]	valid_0's binary_logloss: 0.592903
# [146]	valid_0's binary_logloss: 0.592644
# [147]	valid_0's binary_logloss: 0.592368
# [148]	valid_0's binary_logloss: 0.592285
# [149]	valid_0's binary_logloss: 0.592385
# [150]	valid_0's binary_logloss: 0.59268
# [151]	valid_0's binary_logloss: 0.592763
# [152]	valid_0's binary_logloss: 0.592759
# [153]	valid_0's binary_logloss: 0.59261
# [154]	valid_0's binary_logloss: 0.59215
# [155]	valid_0's binary_logloss: 0.592458
# [156]	valid_0's binary_logloss: 0.59234
# [157]	valid_0's binary_logloss: 0.592434
# [158]	valid_0's binary_logloss: 0.593028
# [159]	valid_0's binary_logloss: 0.592333
# [160]	valid_0's binary_logloss: 0.592608
# [161]	valid_0's binary_logloss: 0.59252
# [162]	valid_0's binary_logloss: 0.591978
# [163]	valid_0's binary_logloss: 0.592309
# [164]	valid_0's binary_logloss: 0.592469
# [165]	valid_0's binary_logloss: 0.59262
# [166]	valid_0's binary_logloss: 0.592901
# [167]	valid_0's binary_logloss: 0.592581
# [168]	valid_0's binary_logloss: 0.592102
# [169]	valid_0's binary_logloss: 0.592184
# [170]	valid_0's binary_logloss: 0.592155
# [171]	valid_0's binary_logloss: 0.591506
# [172]	valid_0's binary_logloss: 0.591474
# [173]	valid_0's binary_logloss: 0.591584
# [174]	valid_0's binary_logloss: 0.591518
# [175]	valid_0's binary_logloss: 0.591959
# [176]	valid_0's binary_logloss: 0.59192
# [177]	valid_0's binary_logloss: 0.592106
# [178]	valid_0's binary_logloss: 0.592168
# [179]	valid_0's binary_logloss: 0.592469
# [180]	valid_0's binary_logloss: 0.592562
# [181]	valid_0's binary_logloss: 0.592682
# [182]	valid_0's binary_logloss: 0.592344
# [183]	valid_0's binary_logloss: 0.592314
# [184]	valid_0's binary_logloss: 0.592113
# [185]	valid_0's binary_logloss: 0.592238
# [186]	valid_0's binary_logloss: 0.591915
# [187]	valid_0's binary_logloss: 0.591722
# [188]	valid_0's binary_logloss: 0.591944
# [189]	valid_0's binary_logloss: 0.59198
# [190]	valid_0's binary_logloss: 0.591781
# [191]	valid_0's binary_logloss: 0.591579
# [192]	valid_0's binary_logloss: 0.591462
# [193]	valid_0's binary_logloss: 0.592142
# [194]	valid_0's binary_logloss: 0.592279
# [195]	valid_0's binary_logloss: 0.592908
# [196]	valid_0's binary_logloss: 0.592844
# [197]	valid_0's binary_logloss: 0.592106
# [198]	valid_0's binary_logloss: 0.592242
# [199]	valid_0's binary_logloss: 0.59245
# [200]	valid_0's binary_logloss: 0.592003
# [201]	valid_0's binary_logloss: 0.592298
# [202]	valid_0's binary_logloss: 0.592119
# [203]	valid_0's binary_logloss: 0.591634
# [204]	valid_0's binary_logloss: 0.591244
# [205]	valid_0's binary_logloss: 0.59144
# [206]	valid_0's binary_logloss: 0.591219
# [207]	valid_0's binary_logloss: 0.590932
# [208]	valid_0's binary_logloss: 0.590745
# [209]	valid_0's binary_logloss: 0.590826
# [210]	valid_0's binary_logloss: 0.590383
# [211]	valid_0's binary_logloss: 0.589709
# [212]	valid_0's binary_logloss: 0.589664
# [213]	valid_0's binary_logloss: 0.590067
# [214]	valid_0's binary_logloss: 0.590235
# [215]	valid_0's binary_logloss: 0.59048
# [216]	valid_0's binary_logloss: 0.590571
# [217]	valid_0's binary_logloss: 0.59063
# [218]	valid_0's binary_logloss: 0.590146
# [219]	valid_0's binary_logloss: 0.589938
# [220]	valid_0's binary_logloss: 0.589852
# [221]	valid_0's binary_logloss: 0.589634
# [222]	valid_0's binary_logloss: 0.589034
# [223]	valid_0's binary_logloss: 0.588731
# [224]	valid_0's binary_logloss: 0.588657
# [225]	valid_0's binary_logloss: 0.588658
# [226]	valid_0's binary_logloss: 0.588913
# [227]	valid_0's binary_logloss: 0.589434
# [228]	valid_0's binary_logloss: 0.589296
# [229]	valid_0's binary_logloss: 0.589383
# [230]	valid_0's binary_logloss: 0.589292
# [231]	valid_0's binary_logloss: 0.589271
# [232]	valid_0's binary_logloss: 0.589367
# [233]	valid_0's binary_logloss: 0.589351
# [234]	valid_0's binary_logloss: 0.589416
# [235]	valid_0's binary_logloss: 0.589029
# [236]	valid_0's binary_logloss: 0.589039
# [237]	valid_0's binary_logloss: 0.589289
# [238]	valid_0's binary_logloss: 0.589394
# [239]	valid_0's binary_logloss: 0.589408
# [240]	valid_0's binary_logloss: 0.589512
# [241]	valid_0's binary_logloss: 0.58946
# [242]	valid_0's binary_logloss: 0.589439
# [243]	valid_0's binary_logloss: 0.589313
# [244]	valid_0's binary_logloss: 0.589481
# [245]	valid_0's binary_logloss: 0.589458
# [246]	valid_0's binary_logloss: 0.589428
# [247]	valid_0's binary_logloss: 0.589406
# [248]	valid_0's binary_logloss: 0.589521
# [249]	valid_0's binary_logloss: 0.590175
# [250]	valid_0's binary_logloss: 0.59002
# [251]	valid_0's binary_logloss: 0.58989
# [252]	valid_0's binary_logloss: 0.589826
# [253]	valid_0's binary_logloss: 0.589901
# [254]	valid_0's binary_logloss: 0.590144
# Early stopping, best iteration is:
# [224]	valid_0's binary_logloss: 0.588657
# [1]	valid_0's binary_logloss: 0.682864
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.675315
# [3]	valid_0's binary_logloss: 0.668563
# [4]	valid_0's binary_logloss: 0.662549
# [5]	valid_0's binary_logloss: 0.657628
# [6]	valid_0's binary_logloss: 0.654022
# [7]	valid_0's binary_logloss: 0.650957
# [8]	valid_0's binary_logloss: 0.647431
# [9]	valid_0's binary_logloss: 0.643978
# [10]	valid_0's binary_logloss: 0.640878
# [11]	valid_0's binary_logloss: 0.639143
# [12]	valid_0's binary_logloss: 0.635953
# [13]	valid_0's binary_logloss: 0.633768
# [14]	valid_0's binary_logloss: 0.631481
# [15]	valid_0's binary_logloss: 0.629936
# [16]	valid_0's binary_logloss: 0.626937
# [17]	valid_0's binary_logloss: 0.625845
# [18]	valid_0's binary_logloss: 0.625043
# [19]	valid_0's binary_logloss: 0.624254
# [20]	valid_0's binary_logloss: 0.62161
# [21]	valid_0's binary_logloss: 0.620757
# [22]	valid_0's binary_logloss: 0.620224
# [23]	valid_0's binary_logloss: 0.619479
# [24]	valid_0's binary_logloss: 0.61934
# [25]	valid_0's binary_logloss: 0.617809
# [26]	valid_0's binary_logloss: 0.617354
# [27]	valid_0's binary_logloss: 0.617556
# [28]	valid_0's binary_logloss: 0.616665
# [29]	valid_0's binary_logloss: 0.615723
# [30]	valid_0's binary_logloss: 0.614317
# [31]	valid_0's binary_logloss: 0.614709
# [32]	valid_0's binary_logloss: 0.614193
# [33]	valid_0's binary_logloss: 0.614255
# [34]	valid_0's binary_logloss: 0.613995
# [35]	valid_0's binary_logloss: 0.614534
# [36]	valid_0's binary_logloss: 0.613907
# [37]	valid_0's binary_logloss: 0.61369
# [38]	valid_0's binary_logloss: 0.613144
# [39]	valid_0's binary_logloss: 0.613168
# [40]	valid_0's binary_logloss: 0.612753
# [41]	valid_0's binary_logloss: 0.612685
# [42]	valid_0's binary_logloss: 0.612518
# [43]	valid_0's binary_logloss: 0.612744
# [44]	valid_0's binary_logloss: 0.612802
# [45]	valid_0's binary_logloss: 0.612115
# [46]	valid_0's binary_logloss: 0.612371
# [47]	valid_0's binary_logloss: 0.612386
# [48]	valid_0's binary_logloss: 0.612354
# [49]	valid_0's binary_logloss: 0.612329
# [50]	valid_0's binary_logloss: 0.612114
# [51]	valid_0's binary_logloss: 0.612444
# [52]	valid_0's binary_logloss: 0.611492
# [53]	valid_0's binary_logloss: 0.611797
# [54]	valid_0's binary_logloss: 0.611604
# [55]	valid_0's binary_logloss: 0.611398
# [56]	valid_0's binary_logloss: 0.610972
# [57]	valid_0's binary_logloss: 0.611205
# [58]	valid_0's binary_logloss: 0.611452
# [59]	valid_0's binary_logloss: 0.611509
# [60]	valid_0's binary_logloss: 0.611555
# [61]	valid_0's binary_logloss: 0.611171
# [62]	valid_0's binary_logloss: 0.611359
# [63]	valid_0's binary_logloss: 0.611682
# [64]	valid_0's binary_logloss: 0.611848
# [65]	valid_0's binary_logloss: 0.611969
# [66]	valid_0's binary_logloss: 0.610328
# [67]	valid_0's binary_logloss: 0.610858
# [68]	valid_0's binary_logloss: 0.610494
# [69]	valid_0's binary_logloss: 0.610072
# [70]	valid_0's binary_logloss: 0.609562
# [71]	valid_0's binary_logloss: 0.609685
# [72]	valid_0's binary_logloss: 0.609858
# [73]	valid_0's binary_logloss: 0.609232
# [74]	valid_0's binary_logloss: 0.60917
# [75]	valid_0's binary_logloss: 0.609392
# [76]	valid_0's binary_logloss: 0.609147
# [77]	valid_0's binary_logloss: 0.609403
# [78]	valid_0's binary_logloss: 0.609577
# [79]	valid_0's binary_logloss: 0.609213
# [80]	valid_0's binary_logloss: 0.608974
# [81]	valid_0's binary_logloss: 0.609271
# [82]	valid_0's binary_logloss: 0.608968
# [83]	valid_0's binary_logloss: 0.609055
# [84]	valid_0's binary_logloss: 0.609121
# [85]	valid_0's binary_logloss: 0.609469
# [86]	valid_0's binary_logloss: 0.608714
# [87]	valid_0's binary_logloss: 0.608511
# [88]	valid_0's binary_logloss: 0.608276
# [89]	valid_0's binary_logloss: 0.608983
# [90]	valid_0's binary_logloss: 0.609162
# [91]	valid_0's binary_logloss: 0.609568
# [92]	valid_0's binary_logloss: 0.609613
# [93]	valid_0's binary_logloss: 0.609998
# [94]	valid_0's binary_logloss: 0.609697
# [95]	valid_0's binary_logloss: 0.609595
# [96]	valid_0's binary_logloss: 0.609349
# [97]	valid_0's binary_logloss: 0.609088
# [98]	valid_0's binary_logloss: 0.609235
# [99]	valid_0's binary_logloss: 0.609172
# [100]	valid_0's binary_logloss: 0.609218
# [101]	valid_0's binary_logloss: 0.609351
# [102]	valid_0's binary_logloss: 0.609832
# [103]	valid_0's binary_logloss: 0.609946
# [104]	valid_0's binary_logloss: 0.610187
# [105]	valid_0's binary_logloss: 0.610248
# [106]	valid_0's binary_logloss: 0.610512
# [107]	valid_0's binary_logloss: 0.610732
# [108]	valid_0's binary_logloss: 0.6109
# [109]	valid_0's binary_logloss: 0.61115
# [110]	valid_0's binary_logloss: 0.611024
# [111]	valid_0's binary_logloss: 0.610981
# [112]	valid_0's binary_logloss: 0.610629
# [113]	valid_0's binary_logloss: 0.611133
# [114]	valid_0's binary_logloss: 0.611221
# [115]	valid_0's binary_logloss: 0.611497
# [116]	valid_0's binary_logloss: 0.611487
# [117]	valid_0's binary_logloss: 0.611846
# [118]	valid_0's binary_logloss: 0.611693
# Early stopping, best iteration is:
# [88]	valid_0's binary_logloss: 0.608276
# [1]	valid_0's binary_logloss: 0.684764
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.676329
# [3]	valid_0's binary_logloss: 0.669974
# [4]	valid_0's binary_logloss: 0.663829
# [5]	valid_0's binary_logloss: 0.659615
# [6]	valid_0's binary_logloss: 0.654131
# [7]	valid_0's binary_logloss: 0.64979
# [8]	valid_0's binary_logloss: 0.646204
# [9]	valid_0's binary_logloss: 0.641856
# [10]	valid_0's binary_logloss: 0.638906
# [11]	valid_0's binary_logloss: 0.635296
# [12]	valid_0's binary_logloss: 0.632405
# [13]	valid_0's binary_logloss: 0.630231
# [14]	valid_0's binary_logloss: 0.628206
# [15]	valid_0's binary_logloss: 0.625439
# [16]	valid_0's binary_logloss: 0.623383
# [17]	valid_0's binary_logloss: 0.621915
# [18]	valid_0's binary_logloss: 0.619675
# [19]	valid_0's binary_logloss: 0.618408
# [20]	valid_0's binary_logloss: 0.617359
# [21]	valid_0's binary_logloss: 0.615787
# [22]	valid_0's binary_logloss: 0.61414
# [23]	valid_0's binary_logloss: 0.613844
# [24]	valid_0's binary_logloss: 0.613424
# [25]	valid_0's binary_logloss: 0.612983
# [26]	valid_0's binary_logloss: 0.612596
# [27]	valid_0's binary_logloss: 0.612872
# [28]	valid_0's binary_logloss: 0.611534
# [29]	valid_0's binary_logloss: 0.611735
# [30]	valid_0's binary_logloss: 0.609813
# [31]	valid_0's binary_logloss: 0.609943
# [32]	valid_0's binary_logloss: 0.609024
# [33]	valid_0's binary_logloss: 0.608823
# [34]	valid_0's binary_logloss: 0.608671
# [35]	valid_0's binary_logloss: 0.608604
# [36]	valid_0's binary_logloss: 0.608888
# [37]	valid_0's binary_logloss: 0.608372
# [38]	valid_0's binary_logloss: 0.608097
# [39]	valid_0's binary_logloss: 0.607822
# [40]	valid_0's binary_logloss: 0.607183
# [41]	valid_0's binary_logloss: 0.607378
# [42]	valid_0's binary_logloss: 0.607161
# [43]	valid_0's binary_logloss: 0.607105
# [44]	valid_0's binary_logloss: 0.606764
# [45]	valid_0's binary_logloss: 0.606773
# [46]	valid_0's binary_logloss: 0.606617
# [47]	valid_0's binary_logloss: 0.606032
# [48]	valid_0's binary_logloss: 0.605685
# [49]	valid_0's binary_logloss: 0.605755
# [50]	valid_0's binary_logloss: 0.60568
# [51]	valid_0's binary_logloss: 0.605866
# [52]	valid_0's binary_logloss: 0.605564
# [53]	valid_0's binary_logloss: 0.605107
# [54]	valid_0's binary_logloss: 0.605213
# [55]	valid_0's binary_logloss: 0.605197
# [56]	valid_0's binary_logloss: 0.605132
# [57]	valid_0's binary_logloss: 0.604151
# [58]	valid_0's binary_logloss: 0.60458
# [59]	valid_0's binary_logloss: 0.604598
# [60]	valid_0's binary_logloss: 0.604596
# [61]	valid_0's binary_logloss: 0.6047
# [62]	valid_0's binary_logloss: 0.604388
# [63]	valid_0's binary_logloss: 0.604632
# [64]	valid_0's binary_logloss: 0.604198
# [65]	valid_0's binary_logloss: 0.604115
# [66]	valid_0's binary_logloss: 0.604275
# [67]	valid_0's binary_logloss: 0.604157
# [68]	valid_0's binary_logloss: 0.60458
# [69]	valid_0's binary_logloss: 0.604485
# [70]	valid_0's binary_logloss: 0.6046
# [71]	valid_0's binary_logloss: 0.604961
# [72]	valid_0's binary_logloss: 0.604966
# [73]	valid_0's binary_logloss: 0.604639
# [74]	valid_0's binary_logloss: 0.604225
# [75]	valid_0's binary_logloss: 0.60391
# [76]	valid_0's binary_logloss: 0.603468
# [77]	valid_0's binary_logloss: 0.603013
# [78]	valid_0's binary_logloss: 0.602692
# [79]	valid_0's binary_logloss: 0.6028
# [80]	valid_0's binary_logloss: 0.60297
# [81]	valid_0's binary_logloss: 0.603041
# [82]	valid_0's binary_logloss: 0.602996
# [83]	valid_0's binary_logloss: 0.60322
# [84]	valid_0's binary_logloss: 0.603075
# [85]	valid_0's binary_logloss: 0.602838
# [86]	valid_0's binary_logloss: 0.602241
# [87]	valid_0's binary_logloss: 0.601851
# [88]	valid_0's binary_logloss: 0.601951
# [89]	valid_0's binary_logloss: 0.601638
# [90]	valid_0's binary_logloss: 0.601714
# [91]	valid_0's binary_logloss: 0.601434
# [92]	valid_0's binary_logloss: 0.601509
# [93]	valid_0's binary_logloss: 0.601975
# [94]	valid_0's binary_logloss: 0.601991
# [95]	valid_0's binary_logloss: 0.601767
# [96]	valid_0's binary_logloss: 0.601615
# [97]	valid_0's binary_logloss: 0.601496
# [98]	valid_0's binary_logloss: 0.601717
# [99]	valid_0's binary_logloss: 0.601409
# [100]	valid_0's binary_logloss: 0.601508
# [101]	valid_0's binary_logloss: 0.60127
# [102]	valid_0's binary_logloss: 0.60137
# [103]	valid_0's binary_logloss: 0.601703
# [104]	valid_0's binary_logloss: 0.602211
# [105]	valid_0's binary_logloss: 0.602607
# [106]	valid_0's binary_logloss: 0.603439
# [107]	valid_0's binary_logloss: 0.603896
# [108]	valid_0's binary_logloss: 0.604611
# [109]	valid_0's binary_logloss: 0.604603
# [110]	valid_0's binary_logloss: 0.604611
# [111]	valid_0's binary_logloss: 0.604286
# [112]	valid_0's binary_logloss: 0.604223
# [113]	valid_0's binary_logloss: 0.604268
# [114]	valid_0's binary_logloss: 0.603257
# [115]	valid_0's binary_logloss: 0.602546
# [116]	valid_0's binary_logloss: 0.602824
# [117]	valid_0's binary_logloss: 0.60275
# [118]	valid_0's binary_logloss: 0.602784
# [119]	valid_0's binary_logloss: 0.603102
# [120]	valid_0's binary_logloss: 0.603076
# [121]	valid_0's binary_logloss: 0.603562
# [122]	valid_0's binary_logloss: 0.603468
# [123]	valid_0's binary_logloss: 0.603964
# [124]	valid_0's binary_logloss: 0.604026
# [125]	valid_0's binary_logloss: 0.604208
# [126]	valid_0's binary_logloss: 0.604041
# [127]	valid_0's binary_logloss: 0.603874
# [128]	valid_0's binary_logloss: 0.603798
# [129]	valid_0's binary_logloss: 0.604355
# [130]	valid_0's binary_logloss: 0.604712
# [131]	valid_0's binary_logloss: 0.60483
# Early stopping, best iteration is:
# [101]	valid_0's binary_logloss: 0.60127
# [1]	valid_0's binary_logloss: 0.685324
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.676849
# [3]	valid_0's binary_logloss: 0.670779
# [4]	valid_0's binary_logloss: 0.66505
# [5]	valid_0's binary_logloss: 0.6607
# [6]	valid_0's binary_logloss: 0.655244
# [7]	valid_0's binary_logloss: 0.650339
# [8]	valid_0's binary_logloss: 0.645689
# [9]	valid_0's binary_logloss: 0.642288
# [10]	valid_0's binary_logloss: 0.639159
# [11]	valid_0's binary_logloss: 0.636115
# [12]	valid_0's binary_logloss: 0.633268
# [13]	valid_0's binary_logloss: 0.630318
# [14]	valid_0's binary_logloss: 0.629027
# [15]	valid_0's binary_logloss: 0.626937
# [16]	valid_0's binary_logloss: 0.625319
# [17]	valid_0's binary_logloss: 0.623728
# [18]	valid_0's binary_logloss: 0.621809
# [19]	valid_0's binary_logloss: 0.620489
# [20]	valid_0's binary_logloss: 0.619457
# [21]	valid_0's binary_logloss: 0.618344
# [22]	valid_0's binary_logloss: 0.616575
# [23]	valid_0's binary_logloss: 0.615867
# [24]	valid_0's binary_logloss: 0.614978
# [25]	valid_0's binary_logloss: 0.613395
# [26]	valid_0's binary_logloss: 0.613365
# [27]	valid_0's binary_logloss: 0.612732
# [28]	valid_0's binary_logloss: 0.611556
# [29]	valid_0's binary_logloss: 0.610588
# [30]	valid_0's binary_logloss: 0.611524
# [31]	valid_0's binary_logloss: 0.610874
# [32]	valid_0's binary_logloss: 0.6102
# [33]	valid_0's binary_logloss: 0.609539
# [34]	valid_0's binary_logloss: 0.609115
# [35]	valid_0's binary_logloss: 0.609286
# [36]	valid_0's binary_logloss: 0.609351
# [37]	valid_0's binary_logloss: 0.610042
# [38]	valid_0's binary_logloss: 0.610394
# [39]	valid_0's binary_logloss: 0.610284
# [40]	valid_0's binary_logloss: 0.609778
# [41]	valid_0's binary_logloss: 0.60945
# [42]	valid_0's binary_logloss: 0.6096
# [43]	valid_0's binary_logloss: 0.609673
# [44]	valid_0's binary_logloss: 0.609867
# [45]	valid_0's binary_logloss: 0.609624
# [46]	valid_0's binary_logloss: 0.610209
# [47]	valid_0's binary_logloss: 0.610485
# [48]	valid_0's binary_logloss: 0.610137
# [49]	valid_0's binary_logloss: 0.610933
# [50]	valid_0's binary_logloss: 0.610714
# [51]	valid_0's binary_logloss: 0.61053
# [52]	valid_0's binary_logloss: 0.609282
# [53]	valid_0's binary_logloss: 0.608406
# [54]	valid_0's binary_logloss: 0.608027
# [55]	valid_0's binary_logloss: 0.608196
# [56]	valid_0's binary_logloss: 0.608485
# [57]	valid_0's binary_logloss: 0.608244
# [58]	valid_0's binary_logloss: 0.608611
# [59]	valid_0's binary_logloss: 0.608561
# [60]	valid_0's binary_logloss: 0.60861
# [61]	valid_0's binary_logloss: 0.608665
# [62]	valid_0's binary_logloss: 0.608814
# [63]	valid_0's binary_logloss: 0.608866
# [64]	valid_0's binary_logloss: 0.609466
# [65]	valid_0's binary_logloss: 0.608591
# [66]	valid_0's binary_logloss: 0.608411
# [67]	valid_0's binary_logloss: 0.608202
# [68]	valid_0's binary_logloss: 0.607413
# [69]	valid_0's binary_logloss: 0.607635
# [70]	valid_0's binary_logloss: 0.607746
# [71]	valid_0's binary_logloss: 0.607074
# [72]	valid_0's binary_logloss: 0.607255
# [73]	valid_0's binary_logloss: 0.606399
# [74]	valid_0's binary_logloss: 0.606065
# [75]	valid_0's binary_logloss: 0.605821
# [76]	valid_0's binary_logloss: 0.605289
# [77]	valid_0's binary_logloss: 0.605393
# [78]	valid_0's binary_logloss: 0.605522
# [79]	valid_0's binary_logloss: 0.604374
# [80]	valid_0's binary_logloss: 0.604737
# [81]	valid_0's binary_logloss: 0.60487
# [82]	valid_0's binary_logloss: 0.604954
# [83]	valid_0's binary_logloss: 0.605157
# [84]	valid_0's binary_logloss: 0.605089
# [85]	valid_0's binary_logloss: 0.605495
# [86]	valid_0's binary_logloss: 0.604856
# [87]	valid_0's binary_logloss: 0.605143
# [88]	valid_0's binary_logloss: 0.604677
# [89]	valid_0's binary_logloss: 0.604957
# [90]	valid_0's binary_logloss: 0.60465
# [91]	valid_0's binary_logloss: 0.603967
# [92]	valid_0's binary_logloss: 0.603536
# [93]	valid_0's binary_logloss: 0.603604
# [94]	valid_0's binary_logloss: 0.603819
# [95]	valid_0's binary_logloss: 0.60365
# [96]	valid_0's binary_logloss: 0.603946
# [97]	valid_0's binary_logloss: 0.603808
# [98]	valid_0's binary_logloss: 0.604022
# [99]	valid_0's binary_logloss: 0.603871
# [100]	valid_0's binary_logloss: 0.603648
# [101]	valid_0's binary_logloss: 0.604135
# [102]	valid_0's binary_logloss: 0.604261
# [103]	valid_0's binary_logloss: 0.603994
# [104]	valid_0's binary_logloss: 0.601837
# [105]	valid_0's binary_logloss: 0.60178
# [106]	valid_0's binary_logloss: 0.601835
# [107]	valid_0's binary_logloss: 0.602426
# [108]	valid_0's binary_logloss: 0.601692
# [109]	valid_0's binary_logloss: 0.601621
# [110]	valid_0's binary_logloss: 0.601617
# [111]	valid_0's binary_logloss: 0.601773
# [112]	valid_0's binary_logloss: 0.601666
# [113]	valid_0's binary_logloss: 0.601943
# [114]	valid_0's binary_logloss: 0.602332
# [115]	valid_0's binary_logloss: 0.602384
# [116]	valid_0's binary_logloss: 0.602456
# [117]	valid_0's binary_logloss: 0.602779
# [118]	valid_0's binary_logloss: 0.602351
# [119]	valid_0's binary_logloss: 0.602337
# [120]	valid_0's binary_logloss: 0.602449
# [121]	valid_0's binary_logloss: 0.602548
# [122]	valid_0's binary_logloss: 0.603097
# [123]	valid_0's binary_logloss: 0.602405
# [124]	valid_0's binary_logloss: 0.602668
# [125]	valid_0's binary_logloss: 0.602869
# [126]	valid_0's binary_logloss: 0.602653
# [127]	valid_0's binary_logloss: 0.60326
# [128]	valid_0's binary_logloss: 0.603479
# [129]	valid_0's binary_logloss: 0.603792
# [130]	valid_0's binary_logloss: 0.604069
# [131]	valid_0's binary_logloss: 0.603867
# [132]	valid_0's binary_logloss: 0.60357
# [133]	valid_0's binary_logloss: 0.603407
# [134]	valid_0's binary_logloss: 0.603644
# [135]	valid_0's binary_logloss: 0.602894
# [136]	valid_0's binary_logloss: 0.602523
# [137]	valid_0's binary_logloss: 0.602531
# [138]	valid_0's binary_logloss: 0.602468
# [139]	valid_0's binary_logloss: 0.602381
# [140]	valid_0's binary_logloss: 0.602014
# Early stopping, best iteration is:
# [110]	valid_0's binary_logloss: 0.601617

# %%
val_roc
# Out:
# [0.6759152934240542,
#  0.6622741601606754,
#  0.6616006465479274,
#  0.6752495023166499]

# %%
feature_imp = np.zeros(X.shape[1])
for model in clf_2:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp, index=X_train.columns).sort_values(by=0, ascending=False)
# Out:
#                                                             0
# rotated_acceleration_Y_mean                       2166.857557
# rotated_acceleration_Y_median                     2056.640193
# rotated_acceleration_Z_max                        1886.185429
# rotated_acceleration_X_median                     1777.885679
# rotated_acceleration_Z_mean                       1746.509181
# total_rotated_mean_abs_chg                        1366.213458
# total_rotated_mean                                1351.796233
# rotated_acceleration_X_mean                       1343.400647
# rotated_acceleration_Z_mean_abs_chg               1341.344091
# linear_acceleration_Y_mean                        1227.917332
# total_rotated_median                              1223.199993
# linear_acceleration_X_mean                        1156.813992
# rotated_acceleration_X_max                        1101.985665
# angular_velocity_Y_mean_abs_chg                   1081.573550
# rotated_acceleration_X_mean_abs_chg               1064.496300
# linear_acceleration_Z_median                      1027.458341
# rotated_acceleration_X_maxtoMin                   1011.618053
# rotated_acceleration_Z_median                      970.987570
# linear_acceleration_X_mean_abs_chg                 943.247823
# rotated_acceleration_Z_maxtoMin                    830.521834
# rotated_acceleration_Z_min                         830.362935
# rotated_acceleration_Y_maxtoMin                    793.762775
# linear_acceleration_X_median                       772.161327
# rotated_acceleration_Z_std                         726.064408
# rotated_acceleration_Z_abs_max                     707.269498
# angular_velocity_Z_abs_min                         705.412511
# linear_acceleration_Y_median                       691.510242
# linear_acceleration_X_std                          689.653484
# angular_velocity_Z_mean_abs_chg                    679.778527
# angular_velocity_Y_min                             673.977803
# rotated_acceleration_X_abs_min                     673.014679
# linear_acceleration_Z_mean                         672.121878
# rotated_acceleration_Z_abs_min                     659.206212
# angular_velocity_Z_maxtoMin                        649.772296
# linear_acceleration_X_min                          647.143311
# angular_velocity_Y_abs_min                         624.133979
# rotated_acceleration_Z_range                       616.813332
# rotated_acceleration_Y_abs_min                     603.717641
# rotated_acceleration_Y_mean_abs_chg                602.977537
# linear_acceleration_Y_std                          594.751162
# linear_acceleration_X_maxtoMin                     593.051747
# angular_velocity_Z_median                          592.837890
# linear_acceleration_X_max                          592.826764
# rotated_acceleration_X_abs_avg                     587.091220
# linear_acceleration_Y_min                          568.910832
# angular_velocity_Z_mean                            567.022829
# total_acce_abs_avg                                 561.232033
# total_rotated_min                                  555.402339
# rotated_acceleration_Y_max                         539.543646
# angular_velocity_Y_median                          539.011100
# linear_acceleration_X_range                        533.018378
# linear_acceleration_Y_range                        528.140760
# rotated_acceleration_X_abs_max                     502.875530
# total_rotated_max                                  501.355477
# rotated_acceleration_X_min                         500.447232
# angular_velocity_Y_mean                            494.354691
# angular_velocity_X_mean_change_of_abs_change       492.979960
# rotated_acceleration_Z_abs_avg                     489.675149
# angular_velocity_Y_mean_change_of_abs_change       488.131700
# linear_acceleration_Y_abs_avg                      480.915152
# angular_velocity_X_mean                            475.754918
# rotated_acceleration_X_std                         474.108763
# linear_acceleration_Y_mean_abs_chg                 470.619356
# linear_acceleration_Y_maxtoMin                     470.438652
# linear_acceleration_X_abs_min                      467.128829
# rotated_acceleration_Y_min                         461.882277
# total_rotated_mean_change_of_abs_change            461.609469
# rotated_acceleration_Z_mean_change_of_abs_change   459.023549
# rotated_acceleration_X_mean_change_of_abs_change   452.183210
# linear_acceleration_Y_max                          451.482582
# angular_velocity_X_mean_abs_chg                    449.039742
# angular_velocity_X_std                             447.243224
# rotated_acceleration_Y_mean_change_of_abs_change   443.084839
# angular_velocity_X_maxtoMin                        435.690150
# angular_velocity_Z_mean_change_of_abs_change       434.119959
# linear_acceleration_Z_abs_avg                      422.561268
# angular_velocity_X_abs_min                         416.223562
# rotated_acceleration_Y_std                         415.681662
# total_acce_median                                  412.005170
# linear_acceleration_Y_abs_min                      406.069811
# linear_acceleration_X_abs_max                      403.044009
# linear_acceleration_X_mean_change_of_abs_change    395.233453
# total_rotated_range                                393.938090
# angular_velocity_Y_std                             386.356713
# total_acce_min                                     381.301961
# angular_velocity_X_median                          380.625431
# angular_velocity_Z_std                             372.598418
# angular_velocity_Y_max                             372.395165
# angular_velocity_Y_maxtoMin                        364.573540
# rotated_acceleration_X_range                       353.723750
# linear_acceleration_Y_mean_change_of_abs_change    349.562361
# total_acce_mean_change_of_abs_change               345.533823
# angular_velocity_Z_min                             338.613570
# angular_velocity_Y_range                           336.987921
# total_rotated_abs_avg                              329.081579
# rotated_acceleration_Y_abs_avg                     327.169039
# linear_acceleration_Z_mean_abs_chg                 312.930092
# rotated_acceleration_Y_range                       311.477039
# total_acce_mean_abs_chg                            310.951920
# total_rotated_std                                  295.862722
# total_acce_mean                                    289.435500
# total_acce_maxtoMin                                289.370900
# angular_velocity_Y_abs_max                         282.114770
# total_rotated_maxtoMin                             279.128253
# linear_acceleration_X_abs_avg                      266.046778
# linear_acceleration_Z_mean_change_of_abs_change    251.306222
# angular_velocity_X_min                             240.897780
# linear_acceleration_Z_std                          237.527520
# angular_velocity_Z_max                             237.222103
# total_acce_max                                     234.529142
# angular_velocity_X_range                           212.108939
# angular_velocity_X_max                             207.268599
# angular_velocity_X_abs_max                         192.983120
# total_acce_std                                     190.763050
# total_acce_range                                   187.596800
# linear_acceleration_Z_abs_max                      186.337680
# linear_acceleration_Z_min                          182.605718
# angular_velocity_Z_range                           177.766279
# linear_acceleration_Z_max                          163.434241
# linear_acceleration_Z_maxtoMin                     150.713260
# rotated_acceleration_Y_abs_max                     138.972399
# angular_velocity_Z_abs_max                         138.157100
# linear_acceleration_Z_range                        128.487629
# linear_acceleration_Y_abs_max                      125.529999
# linear_acceleration_Z_abs_min                      118.994670
# angular_velocity_X_abs_avg                         107.387541
# angular_velocity_Z_abs_avg                          97.714049
# angular_velocity_Y_abs_avg                          89.572690
# total_acce_abs_max                                  78.767129
# total_rotated_abs_min                               44.844870
# total_rotated_abs_max                               39.265080
# total_acce_abs_min                                  35.725010

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X_train, y_id))

clf_3 = []
val_acc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'multi_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'multiclass',
               'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }

for train_idx, val_idx in splits:
    X_tr, y_tr = X_train.iloc[train_idx, :], y_id[train_idx]
    X_val, y_val = X_train.iloc[val_idx, :], y_id[val_idx]
    
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)

    val_acc.append(accuracy_score(y_val, np.argmax(pred_lgb, axis=1)))

#pred_lgb = pd.DataFrame(pred_lgb, index=np.where(np.mean(adv_val, axis=0)>0.3))
#val_pred = pd.concat([val_pred, pred_lgb], axis=0)

clf_3.append(model_lgb)
# Out:
# [1]	valid_0's multi_logloss: 1.84563
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.71864
# [3]	valid_0's multi_logloss: 1.62027
# [4]	valid_0's multi_logloss: 1.53175
# [5]	valid_0's multi_logloss: 1.45628
# [6]	valid_0's multi_logloss: 1.389
# [7]	valid_0's multi_logloss: 1.33392
# [8]	valid_0's multi_logloss: 1.28629
# [9]	valid_0's multi_logloss: 1.23916
# [10]	valid_0's multi_logloss: 1.19933
# [11]	valid_0's multi_logloss: 1.16176
# [12]	valid_0's multi_logloss: 1.12726
# [13]	valid_0's multi_logloss: 1.09842
# [14]	valid_0's multi_logloss: 1.06967
# [15]	valid_0's multi_logloss: 1.04272
# [16]	valid_0's multi_logloss: 1.01995
# [17]	valid_0's multi_logloss: 0.995429
# [18]	valid_0's multi_logloss: 0.974075
# [19]	valid_0's multi_logloss: 0.955057
# [20]	valid_0's multi_logloss: 0.936545
# [21]	valid_0's multi_logloss: 0.920179
# [22]	valid_0's multi_logloss: 0.903914
# [23]	valid_0's multi_logloss: 0.889527
# [24]	valid_0's multi_logloss: 0.875519
# [25]	valid_0's multi_logloss: 0.863793
# [26]	valid_0's multi_logloss: 0.852218
# [27]	valid_0's multi_logloss: 0.841731
# [28]	valid_0's multi_logloss: 0.83268
# [29]	valid_0's multi_logloss: 0.823418
# [30]	valid_0's multi_logloss: 0.814665
# [31]	valid_0's multi_logloss: 0.806564
# [32]	valid_0's multi_logloss: 0.79777
# [33]	valid_0's multi_logloss: 0.789721
# [34]	valid_0's multi_logloss: 0.781672
# [35]	valid_0's multi_logloss: 0.776119
# [36]	valid_0's multi_logloss: 0.770527
# [37]	valid_0's multi_logloss: 0.765188
# [38]	valid_0's multi_logloss: 0.760164
# [108]	valid_0's multi_logloss: 0.65657
# [109]	valid_0's multi_logloss: 0.656559
# [110]	valid_0's multi_logloss: 0.656891
# [111]	valid_0's multi_logloss: 0.656713
# [112]	valid_0's multi_logloss: 0.656514
# [113]	valid_0's multi_logloss: 0.656502
# [114]	valid_0's multi_logloss: 0.656873
# [115]	valid_0's multi_logloss: 0.65706
# [116]	valid_0's multi_logloss: 0.658017
# [117]	valid_0's multi_logloss: 0.658803
# [118]	valid_0's multi_logloss: 0.657928
# [119]	valid_0's multi_logloss: 0.657318
# [120]	valid_0's multi_logloss: 0.656989
# [121]	valid_0's multi_logloss: 0.658048
# [122]	valid_0's multi_logloss: 0.657835
# [123]	valid_0's multi_logloss: 0.658615
# [124]	valid_0's multi_logloss: 0.659722
# [125]	valid_0's multi_logloss: 0.659679
# [126]	valid_0's multi_logloss: 0.660455
# [127]	valid_0's multi_logloss: 0.660953
# [128]	valid_0's multi_logloss: 0.661702
# [129]	valid_0's multi_logloss: 0.661254
# [130]	valid_0's multi_logloss: 0.66185
# Early stopping, best iteration is:
# [100]	valid_0's multi_logloss: 0.654131

# %%
val_acc
# Out:
# [0.7771966527196653,
#  0.7670514165792235,
#  0.7468487394957983,
#  0.7818756585879874]

# %%
feature_imp = np.zeros(X_train.shape[1])
for model in clf_3:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp, index=X_train.columns).sort_values(by=0, ascending=False)
# Out:
#                                                             0
# angular_velocity_Y_mean_abs_chg                   4546.861339
# rotated_acceleration_Z_mean_abs_chg               2537.041681
# rotated_acceleration_Z_mean                       2431.624621
# rotated_acceleration_Z_abs_max                    2071.468028
# rotated_acceleration_X_mean_abs_chg               2029.430260
# rotated_acceleration_Y_mean_abs_chg               1823.943768
# rotated_acceleration_Y_mean                       1502.416432
# rotated_acceleration_Z_median                     1488.764854
# linear_acceleration_X_mean_abs_chg                1377.471178
# linear_acceleration_Z_std                         1317.577646
# rotated_acceleration_X_min                        1208.699442
# total_acce_std                                    1195.609956
# rotated_acceleration_X_mean                       1191.695493
# rotated_acceleration_Z_abs_avg                    1169.512123
# linear_acceleration_Y_mean_abs_chg                 993.795612
# rotated_acceleration_X_max                         766.906747
# rotated_acceleration_Y_max                         731.752644
# rotated_acceleration_Z_max                         681.486812
# total_rotated_mean                                 627.028949
# linear_acceleration_X_abs_avg                      580.144669
# rotated_acceleration_X_std                         565.167308
# linear_acceleration_X_mean                         556.502576
# angular_velocity_Z_mean_abs_chg                    552.291294
# rotated_acceleration_X_abs_avg                     544.311545
# linear_acceleration_Y_mean                         537.656774
# rotated_acceleration_X_range                       528.100109
# rotated_acceleration_Y_median                      525.463552
# linear_acceleration_X_range                        522.797238
# total_rotated_std                                  495.859488
# rotated_acceleration_X_maxtoMin                    485.579811
# rotated_acceleration_Z_min                         483.003353
# angular_velocity_X_mean_abs_chg                    474.262033
# rotated_acceleration_Z_maxtoMin                    465.225365
# total_rotated_max                                  460.945366
# rotated_acceleration_X_median                      459.559570
# rotated_acceleration_Y_range                       459.025766
# total_acce_mean_abs_chg                            446.543839
# linear_acceleration_Y_range                        441.902734
# rotated_acceleration_Y_abs_min                     418.247706
# rotated_acceleration_Y_min                         417.304123
# rotated_acceleration_Z_abs_min                     413.720923
# angular_velocity_Z_mean_change_of_abs_change       410.481323
# rotated_acceleration_X_abs_max                     400.561087
# linear_acceleration_Y_min                          375.805928
# linear_acceleration_X_min                          369.595695
# linear_acceleration_X_median                       366.229899
# linear_acceleration_X_std                          364.495983
# linear_acceleration_Y_abs_avg                      363.362959
# total_acce_mean                                    360.724800
# linear_acceleration_Y_std                          356.805703
# rotated_acceleration_Y_abs_avg                     329.416045
# linear_acceleration_Z_median                       328.537699
# linear_acceleration_X_abs_max                      316.231667
# rotated_acceleration_Y_abs_max                     315.252639
# angular_velocity_Y_min                             311.917524
# linear_acceleration_Y_max                          301.325737
# total_rotated_maxtoMin                             296.586206
# linear_acceleration_Y_maxtoMin                     294.909560
# total_acce_range                                   291.775100
# total_rotated_mean_abs_chg                         287.557647
# rotated_acceleration_X_abs_min                     278.296788
# angular_velocity_Y_median                          278.290148
# linear_acceleration_X_max                          263.870778
# total_rotated_abs_avg                              246.008521
# total_rotated_median                               245.084185
# total_rotated_min                                  241.954360
# total_acce_min                                     240.162874
# angular_velocity_Z_std                             237.414991
# rotated_acceleration_Z_std                         232.258908
# total_acce_max                                     225.569129
# rotated_acceleration_Y_maxtoMin                    224.718721
# linear_acceleration_Z_mean                         221.810101
# linear_acceleration_Z_min                          211.988808
# angular_velocity_Y_std                             211.806847
# angular_velocity_Z_abs_min                         202.237037
# linear_acceleration_X_maxtoMin                     197.125786
# total_acce_abs_avg                                 194.992999
# rotated_acceleration_Z_range                       193.326364
# total_acce_median                                  189.758370
# rotated_acceleration_Y_std                         188.429693
# linear_acceleration_Z_mean_abs_chg                 182.400222
# linear_acceleration_Y_median                       176.827696
# angular_velocity_Y_abs_min                         176.384585
# rotated_acceleration_X_mean_change_of_abs_change   171.538417
# angular_velocity_Y_max                             162.357255
# total_acce_maxtoMin                                160.094375
# angular_velocity_Y_mean_change_of_abs_change       157.693006
# angular_velocity_Z_median                          149.695015
# angular_velocity_X_min                             148.011437
# angular_velocity_Z_maxtoMin                        145.002476
# angular_velocity_X_maxtoMin                        141.353025
# angular_velocity_Y_maxtoMin                        127.842065
# angular_velocity_Y_range                           125.086511
# angular_velocity_X_std                             124.147823
# linear_acceleration_Z_range                        121.106946
# linear_acceleration_Z_abs_max                      120.380191
# total_rotated_range                                119.202469
# linear_acceleration_Y_mean_change_of_abs_change    118.440206
# angular_velocity_Z_mean                            118.050865
# linear_acceleration_Z_abs_avg                      112.082182
# linear_acceleration_X_mean_change_of_abs_change    111.660536
# angular_velocity_Y_abs_max                         111.480420
# linear_acceleration_Y_abs_min                      107.460228
# linear_acceleration_Z_maxtoMin                     107.356816
# angular_velocity_X_abs_min                         107.251541
# angular_velocity_X_abs_max                         104.081988
# total_rotated_abs_max                              103.635368
# rotated_acceleration_Z_mean_change_of_abs_change   102.598211
# angular_velocity_Z_min                              99.822656
# linear_acceleration_Y_abs_max                       97.259932
# angular_velocity_Z_abs_max                          93.602495
# angular_velocity_Z_max                              92.599638
# linear_acceleration_X_abs_min                       86.598098
# angular_velocity_X_mean_change_of_abs_change        83.410136
# rotated_acceleration_Y_mean_change_of_abs_change    76.658017
# angular_velocity_Y_mean                             75.864175
# angular_velocity_X_median                           65.834480
# total_acce_mean_change_of_abs_change                63.555741
# angular_velocity_X_range                            61.969846
# linear_acceleration_Z_mean_change_of_abs_change     60.707241
# angular_velocity_Z_range                            55.680737
# total_rotated_abs_min                               54.036436
# linear_acceleration_Z_max                           52.439639
# total_rotated_mean_change_of_abs_change             51.749353
# angular_velocity_X_mean                             50.617800
# angular_velocity_X_max                              48.323953
# linear_acceleration_Z_abs_min                       44.809948
# angular_velocity_Y_abs_avg                          42.628802
# angular_velocity_Z_abs_avg                          37.876436
# total_acce_abs_max                                  21.986959
# total_acce_abs_min                                  21.028717
# angular_velocity_X_abs_avg                          19.004228

# %%
test_pred = []
for model in clf:
    pred_test = model.predict(test)
    test_pred.append(pred_test)

# %%
test_pred = (test_pred[0]+test_pred[1]+test_pred[2]+test_pred[3])/4

# %%
test_pr = pd.concat([pd.Series(np.argmax(test_pred, axis=1)), pd.Series(np.max(test_pred, axis=1))], axis=1)
test_pr.columns = ['group_id', 'prob']

# %%
test_pr
# Out:
#       group_id      prob
# 0           33  0.886673
# 1           31  0.750421
# 2           55  0.990812
# 3           15  0.517175
# 4           15  0.982744
# 5           62  0.996977
# 6           61  0.619200
# 7           61  0.425734
# 8           65  0.548020
# 9           65  0.590919
# 10          51  0.443062
# 11          11  0.774572
# 12          59  0.441289
# 13          41  0.429685
# 14          54  0.293203
# 15          38  0.729767
# 16           0  0.323417
# 17          15  0.232096
# 18          53  0.552671
# 19           6  0.937889
# 20          43  0.151220
# 21           0  0.777400
# 22          51  0.949983
# 23          59  0.999220
# 24          12  0.764138
# 25          43  0.630415
# 26          47  0.901137
# 27          47  0.484085
# 28          60  0.716068
# 29          62  0.573689
# 30          13  0.413891
# 31          21  0.974582
# 32          57  0.545087
# 33          51  0.970488
# 34          53  0.648990
# 35          18  0.442379
# 36          35  0.929556
# 37           9  0.843067
# 38          51  0.682774
# 39          43  0.707577
# 40          60  0.954868
# 41          51  0.782285
# 42          42  0.955296
# 43          23  0.309492
# 44          51  0.528800
# 45          25  0.484016
# 46          65  0.396695
# 47          25  0.994757
# 48          65  0.466323
# 49          65  0.527629
# 50          38  0.453831
# 51          15  0.681741
# 52          13  0.504797
# 53          10  0.518886
# 54          60  0.360960
# 55           2  0.883315
# 56          55  0.696927
# 57          65  0.908341
# 58          45  0.261348
# 59          39  0.123132
# 60          72  0.849936
# 61          62  0.998293
# 62           7  0.665624
# 63          62  0.193672
# 64          41  0.213072
# 65          58  0.456538
# 66          35  0.853616
# 67          35  0.795700
# 68           6  0.513049
# 69          35  0.206986
# 70          66  0.880897
# 71          51  0.726957
# 72          42  0.085961
# 73          23  0.630162
for i in range(73):
    gr = pd.DataFrame({'group_id':[i], 'surface':[y_train[y_train['group_id']==i]['surface'].iloc[0]]})
    gr_sr = pd.concat([gr_sr, gr], axis=0)

# %%
test_pr = test_pr.merge(gr_sr, how='left', on='group_id', sort=False)

# %%
test_gr_idx = test_pr[test_pr['prob']<=0.9].index

# %%
X_test.loc[test_gr_idx, :].head()
# Out:
#    angular_velocity_X_mean  angular_velocity_X_median  angular_velocity_X_max  \
# 0                 0.000527                  -0.002536                0.209879
# 1                -0.001429                   0.001512                0.139683
# 3                -0.000106                   0.000209                0.048927
# 6                 0.000617                  -0.004446                0.144813
# 7                 0.001221                   0.019509                0.685003
#
#    angular_velocity_X_min  angular_velocity_X_std  angular_velocity_X_range  \
# 0               -0.195518                0.080999                  0.405396
# 1               -0.218541                0.047952                  0.358224
# 3               -0.077246                0.021186                  0.126173
# 6               -0.075830                0.040604                  0.220642
# 7               -0.664819                0.237565                  1.349822
#
#    angular_velocity_X_maxtoMin  angular_velocity_X_mean_abs_chg  \
# 0                    -1.073450                         0.067576
# 1                    -0.639161                         0.031169
# 3                    -0.633402                         0.016593
# 6                    -1.909703                         0.029915
# 7                    -1.030360                         0.183251
#
#    angular_velocity_X_mean_change_of_abs_change  angular_velocity_X_abs_max  \
# 0                                      0.000313                    0.209879
# 1                                     -0.000402                    0.218541
# 3                                     -0.000248                    0.077246
# 6                                     -0.001260                    0.144813
# 7                                     -0.002203                    0.685003
#
#    angular_velocity_X_abs_min  angular_velocity_X_abs_avg  \
# 0                    0.000658                    0.105268
# 1                    0.000044                    0.109292
# 3                    0.000084                    0.038665
# 6                    0.000291                    0.072552
# 7                    0.006170                    0.345587
#
#    angular_velocity_Y_mean  angular_velocity_Y_median  angular_velocity_Y_max  \
# 0                 0.000534                  -0.000728                0.078114
# 1                -0.000342                   0.000056                0.051398
# 3                -0.000455                   0.000295                0.018543
# 6                 0.000787                   0.000556                0.174370
# 7                -0.000544                  -0.002047                0.194662
#
#    angular_velocity_Y_min  angular_velocity_Y_std  angular_velocity_Y_range  \
# 0               -0.092062                0.038020                  0.170176
# 1               -0.045701                0.021691                  0.097099
# 3               -0.022694                0.008853                  0.041237
# 6               -0.155939                0.045643                  0.330309
# 7               -0.177762                0.057858                  0.372424
#
#    angular_velocity_Y_maxtoMin  angular_velocity_Y_mean_abs_chg  \
# 0                    -0.848501                         0.039607
# 1                    -1.124649                         0.022339
# 3                    -0.817082                         0.007044
# 6                    -1.118195                         0.038355
# 7                    -1.095071                         0.051763
#
#    angular_velocity_Y_mean_change_of_abs_change  angular_velocity_Y_abs_max  \
# 0                                     -0.000194                    0.092062
# 1                                      0.000232                    0.051398
# 3                                     -0.000006                    0.022694
# 6                                     -0.000166                    0.174370
# 7                                     -0.000279                    0.194662
#
#    angular_velocity_Y_abs_min  angular_velocity_Y_abs_avg  \
# 0                    0.000488                    0.046275
# 1                    0.000061                    0.025729
# 3                    0.000010                    0.011352
# 6                    0.000132                    0.087251
# 7                    0.000155                    0.097408
#
#    angular_velocity_Z_mean  angular_velocity_Z_median  angular_velocity_Z_max  \
# 0                -0.001544                  -0.002706                0.079124
# 1                 0.001503                   0.000834                0.058009
# 3                 0.002761                   0.002596                0.081411
# 6                -0.002907                   0.001021                0.204577
# 7                 0.000874                   0.003797                0.093126
#
#    angular_velocity_Z_min  angular_velocity_Z_std  angular_velocity_Z_range  \
# 0               -0.077438                0.032418                  0.156562
# 1               -0.051589                0.027321                  0.109599
# 3               -0.068555                0.026704                  0.149966
# 6               -0.293419                0.084786                  0.497996
# 7               -0.118083                0.049403                  0.211209
#
#    angular_velocity_Z_maxtoMin  angular_velocity_Z_mean_abs_chg  \
# 0                    -1.021769                         0.019806
# 1                    -1.124443                         0.009928
# 3                    -1.187522                         0.006611
# 6                    -0.697217                         0.022658
# 7                    -0.788642                         0.036377
#
#    angular_velocity_Z_mean_change_of_abs_change  angular_velocity_Z_abs_max  \
# 0                                      0.000270                    0.079124
# 1                                      0.000161                    0.058009
# 3                                      0.000086                    0.081411
# 6                                     -0.000636                    0.293419
# 7                                     -0.000121                    0.118083
#
#    angular_velocity_Z_abs_min  angular_velocity_Z_abs_avg  \
# 0                    0.000638                    0.039881
# 1                    0.000792                    0.029401
# 3                    0.000039                    0.040725
# 6                    0.000693                    0.147056
# 7                    0.000358                    0.059221
#
#    linear_acceleration_X_mean  linear_acceleration_X_median  \
# 0                    0.137738                      0.099610
# 1                    0.041258                     -0.011506
# 3                    0.175677                      0.153055
# 6                    0.186091                      0.167608
# 7                   -0.065923                     -0.203137
#
#    linear_acceleration_X_max  linear_acceleration_X_min  \
# 0                   1.892403                  -1.462907
# 1                   1.472815                  -1.106017
# 3                   0.622510                  -0.369008
# 6                   1.694091                  -1.122858
# 7                   5.366221                  -6.819955
#
#    linear_acceleration_X_std  linear_acceleration_X_range  \
# 0                   0.644636                     3.355310
# 1                   0.584671                     2.578831
# 3                   0.204049                     0.991518
# 6                   0.652448                     2.816950
# 7                   2.954766                    12.186176
#
#    linear_acceleration_X_maxtoMin  linear_acceleration_X_mean_abs_chg  \
# 0                       -1.293591                            0.337759
# 1                       -1.331638                            0.146329
# 3                       -1.686983                            0.065853
# 6                       -1.508731                            0.244058
# 7                       -0.786841                            0.665497
#
#    linear_acceleration_X_mean_change_of_abs_change  \
# 0                                        -0.001286
# 1                                        -0.002420
# 3                                        -0.000405
# 6                                        -0.003527
# 7                                        -0.002725
#
#    linear_acceleration_X_abs_max  linear_acceleration_X_abs_min  \
# 0                       1.892403                       0.011278
# 1                       1.472815                       0.000602
# 3                       0.622510                       0.003487
# 6                       1.694091                       0.006734
# 7                       6.819955                       0.138788
#
#    linear_acceleration_X_abs_avg  linear_acceleration_Y_mean  \
# 0                       0.951841                    2.893241
# 1                       0.736708                    2.951856
# 3                       0.312999                    2.968651
# 6                       0.850413                    3.108106
# 7                       3.479371                    3.053736
#
#    linear_acceleration_Y_median  linear_acceleration_Y_max  \
# 0                      2.919398                   4.679984
# 1                      3.386089                   5.648670
# 3                      2.987517                   3.357884
# 6                      3.099533                   6.548771
# 7                      3.232261                   5.584511
#
#    linear_acceleration_Y_min  linear_acceleration_Y_std  \
# 0                   1.530144                   0.612544
# 1                  -0.429825                   1.795417
# 3                   2.517275                   0.198081
# 6                  -0.450903                   2.030110
# 7                   0.014867                   1.377536
#
#    linear_acceleration_Y_range  linear_acceleration_Y_maxtoMin  \
# 0                     3.149840                        3.058525
# 1                     6.078496                      -13.141779
# 3                     0.840609                        1.333936
# 6                     6.999673                      -14.523690
# 7                     5.569644                      375.632836
#
#    linear_acceleration_Y_mean_abs_chg  \
# 0                            0.293560
# 1                            0.239658
# 3                            0.065201
# 6                            0.259023
# 7                            0.737491
#
#    linear_acceleration_Y_mean_change_of_abs_change  \
# 0                                         0.003107
# 1                                        -0.001963
# 3                                         0.000272
# 6                                        -0.000659
# 7                                         0.002895
#
#    linear_acceleration_Y_abs_max  linear_acceleration_Y_abs_min  \
# 0                       4.679984                       1.530144
# 1                       5.648670                       0.000899
# 3                       3.357884                       2.517275
# 6                       6.548771                       0.003082
# 7                       5.584511                       0.014867
#
#    linear_acceleration_Y_abs_avg  linear_acceleration_Z_mean  \
# 0                       3.105064                   -9.272861
# 1                       2.824784                   -9.388576
# 3                       2.937579                   -9.341113
# 6                       3.275926                   -9.307932
# 7                       2.799689                   -9.478258
#
#    linear_acceleration_Z_median  linear_acceleration_Z_max  \
# 0                     -9.253101                  -5.543900
# 1                     -9.369192                  -7.494543
# 3                     -9.391062                  -8.588500
# 6                     -9.285323                  -7.683653
# 7                     -9.290565                  -0.907846
#
#    linear_acceleration_Z_min  linear_acceleration_Z_std  \
# 0                 -11.788810                   0.924199
# 1                 -11.249769                   0.531594
# 3                  -9.733270                   0.229445
# 6                 -11.257965                   0.643210
# 7                 -15.464100                   2.315135
#
#    linear_acceleration_Z_range  linear_acceleration_Z_maxtoMin  \
# 0                     6.244910                        0.470268
# 1                     3.755226                        0.666195
# 3                     1.144770                        0.882386
# 6                     3.574312                        0.682508
# 7                    14.556254                        0.058707
#
#    linear_acceleration_Z_mean_abs_chg  \
# 0                            0.607199
# 1                            0.279108
# 3                            0.137535
# 6                            0.310979
# 7                            1.508968
#
#    linear_acceleration_Z_mean_change_of_abs_change  \
# 0                                         0.003984
# 1                                         0.004986
# 3                                        -0.001084
# 6                                         0.005104
# 7                                         0.002132
#
#    linear_acceleration_Z_abs_max  linear_acceleration_Z_abs_min  \
# 0                      11.788810                       5.543900
# 1                      11.249769                       7.494543
# 3                       9.733270                       8.588500
# 6                      11.257965                       7.683653
# 7                      15.464100                       0.907846
#
#    linear_acceleration_Z_abs_avg  rotated_acceleration_X_mean  \
# 0                       8.666355                     0.696565
# 1                       9.372156                     0.972746
# 3                       9.160885                    -0.116830
# 6                       9.470809                     2.364421
# 7                       8.185973                     2.843221
#
#    rotated_acceleration_X_median  rotated_acceleration_X_max  \
# 0                       0.724738                    2.341777
# 1                       0.822856                    2.957158
# 3                      -0.114188                    0.396096
# 6                       2.368827                    3.351227
# 7                       2.814379                    4.889592
#
#    rotated_acceleration_X_min  rotated_acceleration_X_std  \
# 0                   -0.927213                    0.672642
# 1                   -0.154395                    0.707127
# 3                   -0.488120                    0.192276
# 6                    1.612933                    0.363772
# 7                    0.894450                    0.830226
#
#    rotated_acceleration_X_range  rotated_acceleration_X_maxtoMin  \
# 0                      3.268990                        -2.525609
# 1                      3.111553                       -19.153235
# 3                      0.884216                        -0.811473
# 6                      1.738294                         2.077723
# 7                      3.995143                         5.466594
#
#    rotated_acceleration_X_mean_abs_chg  \
# 0                             0.330683
# 1                             0.137695
# 3                             0.063063
# 6                             0.124344
# 7                             0.434660
#
#    rotated_acceleration_X_mean_change_of_abs_change  \
# 0                                         -0.000083
# 1                                          0.002237
# 3                                          0.000262
# 6                                          0.000351
# 7                                          0.001106
#
#    rotated_acceleration_X_abs_max  rotated_acceleration_X_abs_min  \
# 0                        2.341777                        0.022455
# 1                        2.957158                        0.001307
# 3                        0.488120                        0.000357
# 6                        3.351227                        1.612933
# 7                        4.889592                        0.894450
#
#    rotated_acceleration_X_abs_avg  rotated_acceleration_Y_mean  \
# 0                        1.182116                   -12.047090
# 1                        1.479233                   -13.270252
# 3                        0.244238                    -9.485447
# 6                        2.482080                   -17.254588
# 7                        2.892021                   -19.269956
#
#    rotated_acceleration_Y_median  rotated_acceleration_Y_max  \
# 0                     -11.978648                  -10.536158
# 1                     -12.949131                  -10.879253
# 3                      -9.466972                   -9.037052
# 6                     -17.013065                  -14.617310
# 7                     -19.250469                  -13.154559
#
#    rotated_acceleration_Y_min  rotated_acceleration_Y_std  \
# 0                  -13.919588                    0.638918
# 1                  -16.034048                    1.488349
# 3                   -9.880726                    0.206839
# 6                  -19.887521                    1.006635
# 7                  -25.130177                    2.320453
#
#    rotated_acceleration_Y_range  rotated_acceleration_Y_maxtoMin  \
# 0                      3.383431                         0.756930
# 1                      5.154795                         0.678509
# 3                      0.843674                         0.914614
# 6                      5.270211                         0.734999
# 7                     11.975618                         0.523457
#
#    rotated_acceleration_Y_mean_abs_chg  \
# 0                             0.311925
# 1                             0.310772
# 3                             0.087215
# 6                             0.334413
# 7                             1.379567
#
#    rotated_acceleration_Y_mean_change_of_abs_change  \
# 0                                          0.003931
# 1                                         -0.002129
# 3                                          0.000577
# 6                                          0.002644
# 7                                          0.002572
#
#    rotated_acceleration_Y_abs_max  rotated_acceleration_Y_abs_min  \
# 0                       13.919588                       10.536158
# 1                       16.034048                       10.879253
# 3                        9.880726                        9.037052
# 6                       19.887521                       14.617310
# 7                       25.130177                       13.154559
#
#    rotated_acceleration_Y_abs_avg  rotated_acceleration_Z_mean  \
# 0                       12.227873                     9.403173
# 1                       13.456651                    -9.157161
# 3                        9.458889                     9.795344
# 6                       17.252415                    -5.893706
# 7                       19.142368                    -1.398435
#
#    rotated_acceleration_Z_median  rotated_acceleration_Z_max  \
# 0                       9.376556                   11.955161
# 1                      -9.379300                   -7.115770
# 3                       9.814986                   10.170945
# 6                      -5.728794                   -2.570708
# 7                      -1.633542                    1.875953
#
#    rotated_acceleration_Z_min  rotated_acceleration_Z_std  \
# 0                    5.745154                    0.913195
# 1                  -10.753614                    1.028349
# 3                    9.169525                    0.213204
# 6                   -9.114565                    1.858758
# 7                   -4.748272                    1.543475
#
#    rotated_acceleration_Z_range  rotated_acceleration_Z_maxtoMin  \
# 0                      6.210006                         2.080912
# 1                      3.637844                         0.661710
# 3                      1.001419                         1.109212
# 6                      6.543857                         0.282044
# 7                      6.624226                        -0.395081
#
#    rotated_acceleration_Z_mean_abs_chg  \
# 0                             0.599245
# 1                             0.204600
# 3                             0.121294
# 6                             0.233771
# 7                             0.916170
#
#    rotated_acceleration_Z_mean_change_of_abs_change  \
# 0                                          0.003801
# 1                                          0.007317
# 3                                         -0.000530
# 6                                          0.000899
# 7                                          0.003039
#
#    rotated_acceleration_Z_abs_max  rotated_acceleration_Z_abs_min  \
# 0                       11.955161                        5.745154
# 1                       10.753614                        7.115770
# 3                       10.170945                        9.169525
# 6                        9.114565                        2.570708
# 7                        4.748272                        0.041548
#
#    rotated_acceleration_Z_abs_avg  total_acce_mean  total_acce_median  \
# 0                        8.850158         9.765265           9.684894
# 1                        8.934692        10.019777          10.026302
# 3                        9.670235         9.807544           9.825914
# 6                        5.842637        10.036029           9.908676
# 7                        2.394910        10.559835          10.359956
#
#    total_acce_max  total_acce_min  total_acce_std  total_acce_range  \
# 0       12.311647        6.959611        0.807782          5.352036
# 1       11.700192        7.778298        0.533571          3.921893
# 3       10.179361        9.204143        0.212234          0.975218
# 6       11.860798        8.649857        0.732712          3.210941
# 7       15.636746        6.735019        1.883564          8.901727
#
#    total_acce_maxtoMin  total_acce_mean_abs_chg  \
# 0             1.769014                 0.538158
# 1             1.504210                 0.228699
# 3             1.105954                 0.122297
# 6             1.371213                 0.281036
# 7             2.321708                 1.220756
#
#    total_acce_mean_change_of_abs_change  total_acce_abs_max  \
# 0                              0.003676           12.311647
# 1                              0.006541           11.700192
# 3                             -0.000426           10.179361
# 6                              0.004255           11.860798
# 7                              0.000743           15.636746
#
#    total_acce_abs_min  total_acce_abs_avg  total_rotated_mean  \
# 0            6.959611            9.635629           15.340652
# 1            7.778298            9.739245           16.245338
# 3            9.204143            9.691752           13.639133
# 6            8.649857           10.255328           18.497383
# 7            6.735019           11.185883           19.600812
#
#    total_rotated_median  total_rotated_max  total_rotated_min  \
# 0             15.345223          17.463499          14.135123
# 1             16.018893          18.114826          14.361959
# 3             13.658738          13.998700          13.203263
# 6             18.480507          20.558593          17.071075
# 7             19.648690          25.649826          14.062060
#
#    total_rotated_std  total_rotated_range  total_rotated_maxtoMin  \
# 0           0.621292             3.328376                1.235468
# 1           0.858725             3.752866                1.261306
# 3           0.186204             0.795438                1.060246
# 6           0.679838             3.487518                1.204294
# 7           2.369130            11.587766                1.824045
#
#    total_rotated_mean_abs_chg  total_rotated_mean_change_of_abs_change  \
# 0                    0.279557                                 0.000080
# 1                    0.303182                                 0.002147
# 3                    0.060282                                 0.001132
# 6                    0.314209                                 0.004248
# 7                    1.375999                                 0.001962
#
#    total_rotated_abs_max  total_rotated_abs_min  total_rotated_abs_avg
# 0              17.463499              14.135123              15.799311
# 1              18.114826              14.361959              16.238392
# 3              13.998700              13.203263              13.600982
# 6              20.558593              17.071075              18.814834
# 7              25.649826              14.062060              19.855943

# %%
preds_test = []

for model in clf_3:
    preds_test.append(model.predict(X_test.loc[test_gr_idx, :]))

# %%
preds_test = np.argmax(np.mean(preds_test, axis=0), axis=1)

# %%
test_surface = []
for i in preds_test:
    test_surface.append(id_to_target[i])

# %%
test_surface = np.asarray(test_surface)

# %%
preds_test = pd.DataFrame(test_surface, index=test_gr_idx, columns=['surface'])

# %%
preds_test.head()
# Out:
#                   surface
# 0  hard_tiles_large_space
# 1                  carpet
# 3              soft_tiles
# 6                soft_pvc
# 7  hard_tiles_large_space

# %%
preds_test = pd.concat([pd.DataFrame(test_pr[test_pr['prob']>0.9]['surface']), preds_test], axis=0).sort_index()

# %%
submission = pd.read_csv('../input/sample_submission.csv')

# %%
submission['surface'] = preds_test['surface']
submission.to_csv('../output/submission_7.csv', index=False)
submission.head()
# Out:
#    series_id                 surface
# 0          0  hard_tiles_large_space
# 1          1                  carpet
# 2          2                   tiled
# 3          3              soft_tiles
# 4          4              soft_tiles

# %%
cols = ['linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z']
df_peak = pd.DataFrame()

for i in tqdm(range(0, len(X_train), 128)):
    X_tr = X_train.iloc[i:i+128, :]
    df_cols = pd.DataFrame()
    for col in cols:
        peaks = signal.find_peaks(X_tr[col], rel_height=1.0)[0]
        peak_num = len(peaks)
        peak_width = signal.peak_widths(X_tr[col], peaks, rel_height=1.0)[0]
        peak_pro = signal.peak_prominences(X_tr[col], peaks)[0]
        
        if peak_num != 0:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[np.max(peak_width)],
                             col+'_peak_width_min':[np.min(peak_width)],
                             col+'_peak_width_mean':[np.mean(peak_width)],
                             col+'_peak_pro_max':[np.max(peak_pro)],
                             col+'_peak_pro_min':[np.min(peak_pro)],
                             col+'_peak_pro_mean':[np.mean(peak_pro)]
                            }, index=[i//128])
        else:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[0],
                             col+'_peak_width_min':[0],
                             col+'_peak_width_mean':[0],
                             col+'_peak_pro_max':[0],
                             col+'_peak_pro_min':[0],
                             col+'_peak_pro_mean':[0]
                            }, index=[i//128])
            
        df_cols = pd.concat([df_cols, peak_df], axis=1)
    df_peak = pd.concat([df_peak, df_cols], axis=0)

# %%
cols = ['linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z']
df_peak_te = pd.DataFrame()

for i in tqdm(range(0, len(X_test), 128)):
    X_tr = X_test.iloc[i:i+128, :]
    df_cols = pd.DataFrame()
    for col in cols:
        peaks = signal.find_peaks(X_tr[col], rel_height=1.0)[0]
        peak_num = len(peaks)
        peak_width = signal.peak_widths(X_tr[col], peaks, rel_height=1.0)[0]
        peak_pro = signal.peak_prominences(X_tr[col], peaks)[0]
        
        if peak_num != 0:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[np.max(peak_width)],
                             col+'_peak_width_min':[np.min(peak_width)],
                             col+'_peak_width_mean':[np.mean(peak_width)],
                             col+'_peak_pro_max':[np.max(peak_pro)],
                             col+'_peak_pro_min':[np.min(peak_pro)],
                             col+'_peak_pro_mean':[np.mean(peak_pro)]
                            }, index=[i//128])
        else:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[0],
                             col+'_peak_width_min':[0],
                             col+'_peak_width_mean':[0],
                             col+'_peak_pro_max':[0],
                             col+'_peak_pro_min':[0],
                             col+'_peak_pro_mean':[0]
                            }, index=[i//128])
            
        df_cols = pd.concat([df_cols, peak_df], axis=1)
    df_peak_te = pd.concat([df_peak_te, df_cols], axis=0)

# %%
df_peak.head()

# %%
def feat_eng(df):
    data = pd.DataFrame()
    #df['linear_acceleration_Z'] += 9.80665
    #df['eulerX-Z'] = df['euler_X']-df['euler_Z']
    df['total_acce'] = (df['linear_acceleration_X']**2 + df['linear_acceleration_Y']**2 + df['linear_acceleration_Z']**2)**0.5
#df['total_rotated'] = (df['rotated_acceleration_X']**2 + df['rotated_acceleration_Y']**2 + df['rotated_acceleration_Z']**2)**0.5
    #df['total_ang_cos'] = (df['angular_velocity_X_cos']**2 + df['angular_velocity_Y_cos']**2 + df['angular_velocity_Z_cos']**2)**0.5
    
    tmp_df = pd.concat([df['linear_acceleration_Z'], df['angular_velocity_X']], axis=1)
    scaler = MinMaxScaler(feature_range=(-1, 1))
    tmp_df = scaler.fit_transform(tmp_df)
    
    #df['total_angu'] = (df['angular_velocity_X']**2 + df['angular_velocity_Y']**2 + df['angular_velocity_Z']**2)**0.5
    
    #df['total_eule'] = (df['euler_X']**2 + df['euler_Y']**2 + df['euler_Z']**2)**0.5
    #df['total_xyz'] = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2)**0.5
    #df['total_acc/vel'] = df['total_acce']/df['total_angu']
    
    df_columns = df.columns[3:]
    for col in tqdm(df_columns):
        data[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        data[col + '_median'] = df.groupby(['series_id'])[col].median()
        data[col + '_max'] = df.groupby(['series_id'])[col].max()
        data[col + '_min'] = df.groupby(['series_id'])[col].min()
        data[col + '_std'] = df.groupby(['series_id'])[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        data[col + '_mean_abs_chg'] = df.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        data[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
        data[col + '_abs_max'] = df.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        data[col + '_abs_min'] = df.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        data[col + '_abs_avg'] = (data[col + '_abs_min'] + data[col + '_abs_max'])/2
        
        
    #data['corr_linZangX'] = np.correlate(np.abs(tmp_df[:, 0]), np.abs(tmp_df[:, 1]))
    return data

# %%
X_train = feat_eng(X_train)
X_test = feat_eng(X_test)

# %%
X_train.shape

# %%
df_peak.shape

# %%
df_peak_te.shape

# %%
X_test.shape

# %%
X_train = pd.concat([X_train, df_peak], axis=1)
X_test = pd.concat([X_test, df_peak_te], axis=1)

# %%
data_col = X_train.columns

# %%
for data in [X_train, X_test]:
    data.fillna(0,inplace=True)
    data.replace(-np.inf,0,inplace=True)
    data.replace(np.inf,0,inplace=True)

# %% [markdown]
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

# %%
N_SPLITS = 5

# %%
import tensorflow as tf
from sklearn.metrics import roc_auc_score

def auroc(y_true, y_pred):
    return tf.py_function(roc_auc_score, (y_true, y_pred), tf.double)

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score

# %%
y = np.concatenate((np.zeros(len(X_train)), np.ones(len(X_test))), axis=0)
X = np.concatenate((X_train, X_test), axis=0)

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))

clf_2 = []
val_roc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'binary_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'binary',
               #'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }


for train_idx, val_idx in splits:
    X_tr, y_tr = X[train_idx, :], y[train_idx]
    X_val, y_val = X[val_idx, :], y[val_idx]
 
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)
    
    val_roc.append(roc_auc_score(y_val, (pred_lgb>0.5).astype(int)))
    
    pred_lgb = pd.DataFrame(pred_lgb, index=val_idx)
    val_pred = pd.concat([val_pred, pred_lgb], axis=0)
    
    clf_2.append(model_lgb)

# %%
val_roc

# %%
feature_imp = np.zeros(X_train.shape[1])
for model in clf_2:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp/5, index=data_col).sort_values(by=0, ascending=False)

# %%
adv_val = []
for model in clf_2:
    adv_val.append(model.predict(X_train))

# %%
plt.plot(np.sort(np.mean(adv_val, axis=0)))

# %%
preds_test = []

for model in clf:
    preds_test.append(model.predict(X_test))

# %%
preds_test = np.argmax(np.mean(preds_test, axis=0), axis=1)

# %%
test_surface = []
for i in preds_test:
    test_surface.append(id_to_target[i])

# %%
test_surface = np.asarray(test_surface)

# %%
submission = pd.read_csv('../input/sample_submission.csv')

# %%
submission['surface'] = test_surface
submission.to_csv('../output/submission_6.csv', index=False)
submission.head()
