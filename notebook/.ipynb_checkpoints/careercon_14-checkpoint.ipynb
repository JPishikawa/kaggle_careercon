# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from tqdm import tqdm
import gc

from scipy import signal
import lightgbm as lgb
from sklearn.metrics import accuracy_score

pd.set_option('display.max_rows', 600)
pd.set_option('display.max_columns', 200)

import warnings
warnings.filterwarnings('ignore')

from keras.layers import * # Keras is the most friendly Neural Network library, this Kernel use a lot of layers classes
from keras.models import Model
from keras import backend as K # The backend give us access to tensorflow operations and allow us to create the Attention class
from keras import optimizers # Allow us to access the Adam class to modify some parameters
from sklearn.model_selection import GridSearchCV, StratifiedKFold # Used to use Kfold to train our model
from keras.callbacks import * # This object helps the model to train in a smarter way, avoiding overfitting

from sklearn.preprocessing import MinMaxScaler, StandardScaler
# Out:
# Using TensorFlow backend.

# %%
from sklearn.metrics import roc_auc_score

# %%
X_train = pd.read_csv('../input/X_train.csv')
y_train = pd.read_csv('../input/y_train.csv')
X_test  = pd.read_csv('../input/X_test.csv')

# %%
rotated_tr = pd.read_csv('./rotated_train.csv')
rotated_te = pd.read_csv('./rotated_test.csv')

# %%
rotated_tr.head()

# %%
targets = y_train['surface'].value_counts().index
print(targets)
print(y_train['surface'].value_counts())
# Out:
# Index(['concrete', 'soft_pvc', 'wood', 'tiled', 'fine_concrete',
#        'hard_tiles_large_space', 'soft_tiles', 'carpet', 'hard_tiles'],
#       dtype='object')
# concrete                  779
# soft_pvc                  732
# wood                      607
# tiled                     514
# fine_concrete             363
# hard_tiles_large_space    308
# soft_tiles                297
# carpet                    189
# hard_tiles                 21
# Name: surface, dtype: int64

# %%
target_to_id = {}
id_to_target = {}

for target in targets:
    if target not in target_to_id:
        new_id = len(target_to_id)
        target_to_id[target] = new_id
        id_to_target[new_id] = target

# %%
y_id = []
for i in range(len(y_train)):
    y_id.append(target_to_id[y_train['surface'].values[i]])
y_id = np.asarray(y_id)

# %%
class_num = len(targets)

# %%
y_id_one = np.zeros((len(y_id), class_num))
for i in range(len(y_id)):
    y_id_one[i, y_id[i]] = 1

# %%
def norm_quat(df):
    norm = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2 + df['orientation_W']**2)**0.5
    df['orientation_X'] /= norm
    df['orientation_Y'] /= norm
    df['orientation_Z'] /= norm
    df['orientation_W'] /= norm
    return df

# %%
import math

def quaternion_to_euler(x, y, z, w):
    t0 = +2.0 * (w * x + y * z)
    t1 = +1.0 - 2.0 * (x * x + y * y)
    X = math.atan2(t0, t1)

    t2 = +2.0 * (w * y - z * x)
    t2 = +1.0 if t2 > +1.0 else t2
    t2 = -1.0 if t2 < -1.0 else t2
    Y = math.asin(t2)

    t3 = +2.0 * (w * z + x * y)
    t4 = +1.0 - 2.0 * (y * y + z * z)
    Z = math.atan2(t3, t4)

    return X, Y, Z

# %%
X_train = norm_quat(X_train)
X_test = norm_quat(X_test)

# %%
def fe_step1 (df):
    """Quaternions to Euler Angles"""
    
    x = df['orientation_X'].values
    y = df['orientation_Y'].values
    z = df['orientation_Z'].values
    w = df['orientation_W'].values
    nx, ny, nz = np.zeros(len(x)), np.zeros(len(y)), np.zeros(len(z)),
    for i in tqdm(range(len(x))):
        xx, yy, zz = quaternion_to_euler(x[i], y[i], z[i], w[i])
        nx[i] = xx
        ny[i] = yy
        nz[i] = zz
    
    df['euler_X'] = nx
    df['euler_Y'] = ny
    df['euler_Z'] = nz
    return df

# %%
X_train = fe_step1(X_train)
X_test = fe_step1(X_test)

# %%
X_train.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0       -0.75853       -0.63435
# 1    0_1          0                   1       -0.75853       -0.63434
# 2    0_2          0                   2       -0.75853       -0.63435
# 3    0_3          0                   3       -0.75852       -0.63436
# 4    0_4          0                   4       -0.75852       -0.63435
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.107650            0.017561
# 1       -0.10490       -0.10600            0.067851            0.029939
# 2       -0.10492       -0.10597            0.007275            0.028934
# 3       -0.10495       -0.10597           -0.013053            0.019448
# 4       -0.10495       -0.10596            0.005135            0.007652
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 0            0.000767               -0.74857                 2.1030
# 1            0.003385                0.33995                 1.5064
# 2           -0.005978               -0.26429                 1.5922
# 3           -0.008974                0.42684                 1.0993
# 4            0.005245               -0.50969                 1.4689
#
#    linear_acceleration_Z
# 0                -9.7532
# 1                -9.4128
# 2                -8.7267
# 3               -10.0960
# 4               -10.4410

# %%
def highpass_filter(df):
    n_samples = 128
    sample_duration = 0.01
    sample_rate = n_samples * (1 / sample_duration)

    nyquist = 0.5 * sample_rate
    norm_low_cutoff = 500 / nyquist

    sos = signal.butter(10, Wn=[norm_low_cutoff], btype='highpass', output='sos')
    filtered_sig = signal.sosfilt(sos, df)
    
    return filtered_sig

# %%
def lowpass_filter(data, r=0.3):
    f_data = np.zeros_like(data)
    f_data[0] = data[0]
    for i in range(1, len(data)):
        if i % 128 == 0:
            f_data[i] = data[i]
        else:
            f_data[i] = r * data[i] + (1-r) * f_data[i-1]
    return f_data

# %%
for data in [X_train, X_test]:
    data['linear_acceleration_X'] = lowpass_filter(data['linear_acceleration_X'])
    data['linear_acceleration_Y'] = lowpass_filter(data['linear_acceleration_Y'])
    data['linear_acceleration_Z'] = lowpass_filter(data['linear_acceleration_Z'])
    data['angular_velocity_X'] = highpass_filter(data['angular_velocity_X'])
    data['angular_velocity_Y'] = highpass_filter(data['angular_velocity_Y'])
    data['angular_velocity_Z'] = highpass_filter(data['angular_velocity_Z'])

# %%
def lagged_feature(df):
    lag_list = [1]
    cols = ['angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z',
            'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z']
    
    for col in cols:
        for i in lag_list:
            df[col+'-'+str(i)] = 0
            df.loc[i: , col+'-'+str(i)] = df.loc[:len(df)-(i+1), col].values
            df[col+'-'+col+'-'+str(i)] = df[col] - df[col+'-'+str(i)]
            
            df = df.drop([col+'-'+str(i)], axis=1)
    return df

# %%
def num_integration(df):
    
    cols = ['angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z',
            'linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z']
    
    for col in cols:
        i = 1
        df[col+'-'+str(i)] = 0
        df.loc[i: , col+'-'+str(i)] = df.loc[:len(df)-(i+1), col].values
        df['tmp'+col] = 0.5 * (df[col] + df[col+'-'+str(i)])
        df['num_int_'+col] = 0
        for j in tqdm(range(0, len(df), 128)):
            df.loc[j:j+128, 'num_int'+col] = np.cumsum(df.loc[j:j+128, 'tmp'+col])

        df = df.drop([col+'-'+str(i)], axis=1)
        df = df.drop(['tmp'+col], axis=1)
    return df

# %%
X_train = lagged_feature(X_train)
X_test = lagged_feature(X_test)

# %%
np.__version__
# Out:
# '1.14.3'

# %%
X_train = num_integration(X_train)
X_test = num_integration(X_test)
# Out:
# 100%|██████████| 3810/3810 [00:05<00:00, 706.37it/s]
# 100%|██████████| 3810/3810 [00:05<00:00, 671.61it/s]
# 100%|██████████| 3810/3810 [00:05<00:00, 683.34it/s]
# 100%|██████████| 3810/3810 [00:05<00:00, 674.54it/s]
# 100%|██████████| 3810/3810 [00:05<00:00, 704.94it/s]
# 100%|██████████| 3810/3810 [00:05<00:00, 731.88it/s]
# 100%|██████████| 3816/3816 [00:05<00:00, 747.35it/s]
# 100%|██████████| 3816/3816 [00:05<00:00, 721.04it/s]
# 100%|██████████| 3816/3816 [00:05<00:00, 742.98it/s]
# 100%|██████████| 3816/3816 [00:05<00:00, 718.44it/s]
# 100%|██████████| 3816/3816 [00:05<00:00, 745.53it/s]
# 100%|██████████| 3816/3816 [00:05<00:00, 725.98it/s]

# %%
X_train.head()
# Out:
#   row_id  series_id  measurement_number  orientation_X  orientation_Y  \
# 0    0_0          0                   0       -0.75853       -0.63435
# 1    0_1          0                   1       -0.75853       -0.63434
# 2    0_2          0                   2       -0.75853       -0.63435
# 3    0_3          0                   3       -0.75852       -0.63436
# 4    0_4          0                   4       -0.75852       -0.63435
#
#    orientation_Z  orientation_W  angular_velocity_X  angular_velocity_Y  \
# 0       -0.10488       -0.10597            0.107650            0.017561
# 1       -0.10490       -0.10600            0.067851            0.029939
# 2       -0.10492       -0.10597            0.007275            0.028934
# 3       -0.10495       -0.10597           -0.013053            0.019448
# 4       -0.10495       -0.10596            0.005135            0.007652
#
#    angular_velocity_Z  linear_acceleration_X  linear_acceleration_Y  \
# 0            0.000767               -0.74857                 2.1030
# 1            0.003385                0.33995                 1.5064
# 2           -0.005978               -0.26429                 1.5922
# 3           -0.008974                0.42684                 1.0993
# 4            0.005245               -0.50969                 1.4689
#
#    linear_acceleration_Z
# 0                -9.7532
# 1                -9.4128
# 2                -8.7267
# 3               -10.0960
# 4               -10.4410

# %%
i=0
plt.plot(X_train.iloc[128*i:128*(i+1), :]['linear_acceleration_Y'])

# %% [markdown]
# for i in tqdm(range(0, len(X_train), 128)):
#     X_train = X_train.drop(index=[i+j for j in range(1)])

# %%
def mean_change_of_abs_change(x):
        return np.mean(np.diff(np.abs(np.diff(x))))

# %%
train = X_train.loc[:, 'orientation_X':'orientation_W']
test = X_test.loc[:, 'orientation_X':'orientation_W']

train.columns = ['X','Y','Z','W']
test.columns = ['X','Y','Z','W']

for i in range(4):
    for j in range(i+1, 4):
        train[train.columns[i]+'-'+train.columns[j]] = train.iloc[:, i] - train.iloc[:, j]
        test[test.columns[i]+'-'+test.columns[j]] = test.iloc[:, i] - test.iloc[:, j]
        
train = pd.concat([train, X_train.loc[:, 'euler_X':'euler_Z']], axis=1)
test = pd.concat([test, X_test.loc[:, 'euler_X':'euler_Z']], axis=1)

# %%
for data in [train, test]:
    data['euler_X-Y'] = data['euler_X']-data['euler_Y']
    data['euler_X-Z'] = data['euler_X']-data['euler_Z']
    data['euler_Y-Z'] = data['euler_Y']-data['euler_Z']
    
train = pd.concat([X_train['series_id'], train], axis=1)
test = pd.concat([X_test['series_id'], test], axis=1)

# %%
train.head()

# %%
X_train.head()

# %%
def rotation_matrix(q0, q1, q2, q3):
    r00 = q0**2 - q1**2 - q2**2 + q3**2
    r01 = 2 * (q0*q3 + q1*q2)
    r02 = 2 * (q1*q3 - q0*q2)
    r10 = 2 * (q1*q2 - q0*q3)
    r11 = q0**2 - q1**2 + q2**2 - q3**2
    r12 = 2 * (q2*q3 + q0*q1)
    r20 = 2 * (q0*q2 + q1*q3)
    r21 = 2 * (-q0*q1 + q2*q3)
    r22 = q0**2 - q1**2 - q2**2 + q3**2
    R = np.array([[r00, r01, r02],[r10, r11, r12],[r20, r21, r22]])
    return R

# %%
def rotated_acceleration(df):
    
    df['rotated_acceleration_X'] = 0
    df['rotated_acceleration_Y'] = 0
    df['rotated_acceleration_Z'] = 0
    #df['rotated_angvel_X'] = 0
    #df['rotated_angvel_Y'] = 0
    #df['rotated_angvel_Z'] = 0
    
    q0_all = df['orientation_X'].values
    q1_all = df['orientation_Y'].values
    q2_all = df['orientation_Z'].values
    q3_all = df['orientation_W'].values
    la_X = df['linear_acceleration_X'].values
    la_Y = df['linear_acceleration_Y'].values
    la_Z = df['linear_acceleration_Z'].values
    #av_X = df['angular_velocity_X'].values
    #av_Y = df['angular_velocity_Y'].values
    #av_Z = df['angular_velocity_Z'].values
    
    for i in tqdm(range(len(df))):
        q0 = q0_all[i]
        q1 = q1_all[i]
        q2 = q2_all[i]
        q3 = q3_all[i]
        
        R = rotation_matrix(q0, q1, q2, q3)
        la = np.array([la_X[i], la_Y[i], la_Z[i]])
        #av = np.array([av_X[i], av_Y[i], av_Z[i]])
        rotated_la = np.dot(R.T, la)
        #rotated_av = np.dot(R.T, av)
        
        df.loc[i, 'rotated_acceleration_X'] = rotated_la[0]
        df.loc[i, 'rotated_acceleration_Y'] = rotated_la[1]
        df.loc[i, 'rotated_acceleration_Z'] = rotated_la[2]
        #df.loc[i, 'rotated_angvel_X'] = rotated_av[0]
        #df.loc[i, 'rotated_angvel_Y'] = rotated_av[1]
        #df.loc[i, 'rotated_angvel_Z'] = rotated_av[2]
    
    return df

# %%
X_train = rotated_acceleration(X_train)

# %%
X_test = rotated_acceleration(X_test)

# %%
X_train['rotated_acceleration_Y'] = X_train['rotated_acceleration_Y'] - 9.80665
X_test['rotated_acceleration_Y'] = X_test['rotated_acceleration_Y'] - 9.80665

# %% [markdown]
# from multiprocessing import Pool

# %% [markdown]
# def process_subtrain(arg_tuple):
#     start, end, idx = arg_tuple
#     X_tr = X_train.iloc[start:end, :]
#     X_tr = rotated_acceleration(X_tr)
#     return idx, X_tr

# %% [markdown]
# all_chunks = []
#
# num_cores = 8
# total_size = len(X_train)
# chunk_size = total_size/num_cores
#
# for i in range(8):
#     start_idx = int(i * chunk_size)
#     end_idx = int(start_idx + chunk_size)
#     chunk = (start_idx, end_idx, i)
#     all_chunks.append(chunk)
#
# pool = Pool()
# results = pool.map(process_subtrain, all_chunks)
# results = sorted(results, key=lambda tup: tup[0])

# %% [markdown]
# X = np.concatenate([item[1] for item in results], axis=0)

# %% [markdown]
# train = pd.concat([train, X_train.loc[:, 'rotated_acceleration_X':'rotated_acceleration_Z']], axis=1)
# test = pd.concat([test, X_test.loc[:, 'rotated_acceleration_X':'rotated_acceleration_Z']], axis=1)

# %%
def feat_eng(df):
    data = pd.DataFrame()
    df['total_rotated_acce'] = (df['rotated_acceleration_X']**2 + df['rotated_acceleration_Y']**2 + df['rotated_acceleration_Z']**2)**0.5
    df['ang_XY'] = np.arctan2(df['X'], df['Y'])
    df['ang_ZW'] = np.arctan2(df['Z'], df['W'])
    
    df_columns = df.columns[1:]
    for col in tqdm(df_columns):
        data[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        #data[col + '_median'] = df.groupby(['series_id'])[col].median()
        data[col + '_max'] = df.groupby(['series_id'])[col].max()
        data[col + '_min'] = df.groupby(['series_id'])[col].min()
        data[col + '_std'] = df.groupby(['series_id'])[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        
        data[col + '_mean_abs_chg'] = df.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        data[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
        data[col + '_abs_max'] = df.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        data[col + '_abs_min'] = df.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        data[col + '_abs_avg'] = (data[col + '_abs_min'] + data[col + '_abs_max'])/2
        
        
    #data['corr_linZangX'] = np.correlate(np.abs(tmp_df[:, 0]), np.abs(tmp_df[:, 1]))
    return data

# %%
train = pd.concat([train, rotated_tr.loc[:, 'rotated_acceleration_X':'rotated_acceleration_Z']], axis=1)
test = pd.concat([test, rotated_te.loc[:, 'rotated_acceleration_X':'rotated_acceleration_Z']], axis=1)

# %%
train = feat_eng(train)
test = feat_eng(test)

# %%
data_col = train.columns

# %%
train.head()

# %%
for data in [train, test]:
    data.fillna(0,inplace=True)
    data.replace(-np.inf,0,inplace=True)
    data.replace(np.inf,0,inplace=True)

# %%
y_gr = y_train['group_id']

# %%
N_SPLITS=4

splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(train, y_gr))

clf = []
val_acc = []
val_pred = []
val_y = []

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'multi_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'multiclass',
               'num_class': 73,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }

for train_idx, val_idx in splits:
    X_tr, y_tr = np.asarray(train)[train_idx, :], y_gr[train_idx]
    X_val, y_val = np.asarray(train)[val_idx, :], y_gr[val_idx]
    
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)
    val_pred.append(pred_lgb)
    val_y.append(y_val)
    
    val_acc.append(accuracy_score(y_val, np.argmax(pred_lgb, axis=1)))

#pred_lgb = pd.DataFrame(pred_lgb, index=np.where(np.mean(adv_val, axis=0)>0.3))
#val_pred = pd.concat([val_pred, pred_lgb], axis=0)

    clf.append(model_lgb)

# %%
val_acc

# %%
feature_imp = np.zeros(train.shape[1])
for model in clf:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp/4, index=data_col).sort_values(by=0, ascending=False)

# %%
X_train_reserve = X_train.copy()
X_test_reserve = X_test.copy()

# %%
X_train_reserve.to_csv('./rotated_train.csv')
X_test_reserve.to_csv('./rotated_test.csv')

# %%
def feat_eng(df):
    data = pd.DataFrame()

    df['total_acce'] = (df['linear_acceleration_X']**2 + df['linear_acceleration_Y']**2 + df['linear_acceleration_Z']**2)**0.5
    #df['total_rotated'] = (df['rotated_acceleration_X']**2 + df['rotated_acceleration_Y']**2 + df['rotated_acceleration_Z']**2)**0.5
    #df['total_ang_cos'] = (df['angular_velocity_X_cos']**2 + df['angular_velocity_Y_cos']**2 + df['angular_velocity_Z_cos']**2)**0.5
    
    #df = df.drop(columns=['euler_X'], axis=0)
    #df = df.drop(columns=['euler_Y'], axis=0)
    #df = df.drop(columns=['euler_Z'], axis=0)
    #df['total_angu'] = (df['angular_velocity_X']**2 + df['angular_velocity_Y']**2 + df['angular_velocity_Z']**2)**0.5
    
    #df['total_eule'] = (df['euler_X']**2 + df['euler_Y']**2 + df['euler_Z']**2)**0.5
    #df['total_xyz'] = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2)**0.5
    #df['total_acc/vel'] = df['total_acce']/df['total_angu']
    
    df_columns = df.columns[7:]
    for col in tqdm(df_columns):
        data[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        data[col + '_median'] = df.groupby(['series_id'])[col].median()
        data[col + '_max'] = df.groupby(['series_id'])[col].max()
        data[col + '_min'] = df.groupby(['series_id'])[col].min()
        data[col + '_std'] = df.groupby(['series_id'])[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        data[col + '_mean_abs_chg'] = df.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        data[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
        data[col + '_abs_max'] = df.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        data[col + '_abs_min'] = df.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        data[col + '_abs_avg'] = (data[col + '_abs_min'] + data[col + '_abs_max'])/2
        
        
    #data['corr_linZangX'] = np.correlate(np.abs(tmp_df[:, 0]), np.abs(tmp_df[:, 1]))
    return data

# %%
X_train = feat_eng(X_train)
X_test = feat_eng(X_test)
# Out:
# 100%|██████████| 13/13 [00:27<00:00,  2.10s/it]
# 100%|██████████| 13/13 [00:27<00:00,  2.11s/it]

# %%
y = np.concatenate((np.zeros(len(X_train)), np.ones(len(X_test))), axis=0)
X = np.concatenate((X_train, X_test), axis=0)

# %%
N_SPLITS=4

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))

clf_2 = []
val_roc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'binary_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'binary',
               #'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }


for train_idx, val_idx in splits:
    X_tr, y_tr = X[train_idx, :], y[train_idx]
    X_val, y_val = X[val_idx, :], y[val_idx]
 
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)
    
    val_roc.append(roc_auc_score(y_val, (pred_lgb>0.5).astype(int)))
    
    pred_lgb = pd.DataFrame(pred_lgb, index=val_idx)
    val_pred = pd.concat([val_pred, pred_lgb], axis=0)
    
    clf_2.append(model_lgb)
# Out:
# [1]	valid_0's binary_logloss: 0.689738
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.686046
# [3]	valid_0's binary_logloss: 0.683914
# [4]	valid_0's binary_logloss: 0.682079
# [5]	valid_0's binary_logloss: 0.680158
# [6]	valid_0's binary_logloss: 0.678721
# [7]	valid_0's binary_logloss: 0.677352
# [8]	valid_0's binary_logloss: 0.676042
# [9]	valid_0's binary_logloss: 0.674686
# [10]	valid_0's binary_logloss: 0.673424
# [11]	valid_0's binary_logloss: 0.672613
# [12]	valid_0's binary_logloss: 0.672511
# [13]	valid_0's binary_logloss: 0.672185
# [14]	valid_0's binary_logloss: 0.671761
# [15]	valid_0's binary_logloss: 0.670733
# [16]	valid_0's binary_logloss: 0.67023
# [17]	valid_0's binary_logloss: 0.66991
# [18]	valid_0's binary_logloss: 0.669651
# [19]	valid_0's binary_logloss: 0.669555
# [20]	valid_0's binary_logloss: 0.668564
# [21]	valid_0's binary_logloss: 0.667779
# [22]	valid_0's binary_logloss: 0.667165
# [23]	valid_0's binary_logloss: 0.666964
# [24]	valid_0's binary_logloss: 0.667586
# [25]	valid_0's binary_logloss: 0.667772
# [26]	valid_0's binary_logloss: 0.66787
# [27]	valid_0's binary_logloss: 0.667301
# [28]	valid_0's binary_logloss: 0.667319
# [29]	valid_0's binary_logloss: 0.666349
# [30]	valid_0's binary_logloss: 0.666494
# [31]	valid_0's binary_logloss: 0.666469
# [32]	valid_0's binary_logloss: 0.666586
# [33]	valid_0's binary_logloss: 0.666847
# [34]	valid_0's binary_logloss: 0.667119
# [35]	valid_0's binary_logloss: 0.667228
# [36]	valid_0's binary_logloss: 0.667643
# [37]	valid_0's binary_logloss: 0.667385
# [38]	valid_0's binary_logloss: 0.667123
# [39]	valid_0's binary_logloss: 0.666887
# [40]	valid_0's binary_logloss: 0.666697
# [41]	valid_0's binary_logloss: 0.666946
# [42]	valid_0's binary_logloss: 0.667121
# [43]	valid_0's binary_logloss: 0.667086
# [44]	valid_0's binary_logloss: 0.666415
# [45]	valid_0's binary_logloss: 0.666
# [46]	valid_0's binary_logloss: 0.665902
# [47]	valid_0's binary_logloss: 0.665524
# [48]	valid_0's binary_logloss: 0.665403
# [49]	valid_0's binary_logloss: 0.665375
# [50]	valid_0's binary_logloss: 0.665351
# [51]	valid_0's binary_logloss: 0.665201
# [52]	valid_0's binary_logloss: 0.664767
# [53]	valid_0's binary_logloss: 0.665261
# [54]	valid_0's binary_logloss: 0.665315
# [55]	valid_0's binary_logloss: 0.666043
# [56]	valid_0's binary_logloss: 0.665816
# [57]	valid_0's binary_logloss: 0.666013
# [58]	valid_0's binary_logloss: 0.6661
# [59]	valid_0's binary_logloss: 0.665885
# [60]	valid_0's binary_logloss: 0.666213
# [61]	valid_0's binary_logloss: 0.66641
# [62]	valid_0's binary_logloss: 0.666448
# [63]	valid_0's binary_logloss: 0.666482
# [64]	valid_0's binary_logloss: 0.66642
# [65]	valid_0's binary_logloss: 0.666165
# [66]	valid_0's binary_logloss: 0.665824
# [67]	valid_0's binary_logloss: 0.665859
# [68]	valid_0's binary_logloss: 0.665689
# [69]	valid_0's binary_logloss: 0.665499
# [70]	valid_0's binary_logloss: 0.665821
# [71]	valid_0's binary_logloss: 0.66611
# [72]	valid_0's binary_logloss: 0.666593
# [73]	valid_0's binary_logloss: 0.666471
# [74]	valid_0's binary_logloss: 0.66595
# [75]	valid_0's binary_logloss: 0.665587
# [76]	valid_0's binary_logloss: 0.664954
# [77]	valid_0's binary_logloss: 0.664678
# [78]	valid_0's binary_logloss: 0.66482
# [79]	valid_0's binary_logloss: 0.665112
# [80]	valid_0's binary_logloss: 0.664718
# [81]	valid_0's binary_logloss: 0.66453
# [82]	valid_0's binary_logloss: 0.664287
# [83]	valid_0's binary_logloss: 0.664178
# [84]	valid_0's binary_logloss: 0.664647
# [85]	valid_0's binary_logloss: 0.664564
# [86]	valid_0's binary_logloss: 0.664866
# [87]	valid_0's binary_logloss: 0.665066
# [88]	valid_0's binary_logloss: 0.665486
# [89]	valid_0's binary_logloss: 0.66521
# [90]	valid_0's binary_logloss: 0.664567
# [91]	valid_0's binary_logloss: 0.664718
# [92]	valid_0's binary_logloss: 0.664621
# [93]	valid_0's binary_logloss: 0.664336
# [94]	valid_0's binary_logloss: 0.664686
# [95]	valid_0's binary_logloss: 0.664534
# [96]	valid_0's binary_logloss: 0.664676
# [97]	valid_0's binary_logloss: 0.664271
# [98]	valid_0's binary_logloss: 0.664783
# [99]	valid_0's binary_logloss: 0.66514
# [100]	valid_0's binary_logloss: 0.665689
# [101]	valid_0's binary_logloss: 0.666028
# [102]	valid_0's binary_logloss: 0.666552
# [103]	valid_0's binary_logloss: 0.666508
# [104]	valid_0's binary_logloss: 0.666783
# [105]	valid_0's binary_logloss: 0.666915
# [106]	valid_0's binary_logloss: 0.667005
# [107]	valid_0's binary_logloss: 0.667031
# [108]	valid_0's binary_logloss: 0.667254
# [109]	valid_0's binary_logloss: 0.667877
# [110]	valid_0's binary_logloss: 0.667806
# [111]	valid_0's binary_logloss: 0.668299
# [112]	valid_0's binary_logloss: 0.668691
# [113]	valid_0's binary_logloss: 0.668921
# Early stopping, best iteration is:
# [83]	valid_0's binary_logloss: 0.664178
# [1]	valid_0's binary_logloss: 0.689644
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.686485
# [3]	valid_0's binary_logloss: 0.684683
# [4]	valid_0's binary_logloss: 0.682449
# [5]	valid_0's binary_logloss: 0.680844
# [6]	valid_0's binary_logloss: 0.679059
# [7]	valid_0's binary_logloss: 0.677722
# [8]	valid_0's binary_logloss: 0.676128
# [9]	valid_0's binary_logloss: 0.6756
# [10]	valid_0's binary_logloss: 0.675679
# [11]	valid_0's binary_logloss: 0.675589
# [12]	valid_0's binary_logloss: 0.67524
# [13]	valid_0's binary_logloss: 0.674347
# [14]	valid_0's binary_logloss: 0.67342
# [15]	valid_0's binary_logloss: 0.673286
# [16]	valid_0's binary_logloss: 0.673299
# [17]	valid_0's binary_logloss: 0.673427
# [18]	valid_0's binary_logloss: 0.673102
# [19]	valid_0's binary_logloss: 0.673008
# [20]	valid_0's binary_logloss: 0.672767
# [21]	valid_0's binary_logloss: 0.673531
# [22]	valid_0's binary_logloss: 0.67334
# [23]	valid_0's binary_logloss: 0.673133
# [24]	valid_0's binary_logloss: 0.67374
# [25]	valid_0's binary_logloss: 0.673217
# [26]	valid_0's binary_logloss: 0.673211
# [27]	valid_0's binary_logloss: 0.672978
# [28]	valid_0's binary_logloss: 0.67295
# [29]	valid_0's binary_logloss: 0.673156
# [30]	valid_0's binary_logloss: 0.673227
# [31]	valid_0's binary_logloss: 0.672437
# [32]	valid_0's binary_logloss: 0.672088
# [33]	valid_0's binary_logloss: 0.672063
# [34]	valid_0's binary_logloss: 0.67208
# [35]	valid_0's binary_logloss: 0.671771
# [36]	valid_0's binary_logloss: 0.67152
# [37]	valid_0's binary_logloss: 0.671329
# [38]	valid_0's binary_logloss: 0.67096
# [39]	valid_0's binary_logloss: 0.671026
# [40]	valid_0's binary_logloss: 0.671006
# [41]	valid_0's binary_logloss: 0.671128
# [42]	valid_0's binary_logloss: 0.67171
# [43]	valid_0's binary_logloss: 0.672286
# [44]	valid_0's binary_logloss: 0.672158
# [45]	valid_0's binary_logloss: 0.670908
# [46]	valid_0's binary_logloss: 0.670958
# [47]	valid_0's binary_logloss: 0.670685
# [48]	valid_0's binary_logloss: 0.670783
# [49]	valid_0's binary_logloss: 0.671112
# [50]	valid_0's binary_logloss: 0.671558
# [51]	valid_0's binary_logloss: 0.671463
# [52]	valid_0's binary_logloss: 0.671798
# [53]	valid_0's binary_logloss: 0.671969
# [54]	valid_0's binary_logloss: 0.672237
# [55]	valid_0's binary_logloss: 0.67216
# [56]	valid_0's binary_logloss: 0.672645
# [57]	valid_0's binary_logloss: 0.672121
# [58]	valid_0's binary_logloss: 0.671568
# [59]	valid_0's binary_logloss: 0.671589
# [60]	valid_0's binary_logloss: 0.671066
# [61]	valid_0's binary_logloss: 0.671004
# [62]	valid_0's binary_logloss: 0.670792
# [63]	valid_0's binary_logloss: 0.670936
# [64]	valid_0's binary_logloss: 0.670552
# [65]	valid_0's binary_logloss: 0.670732
# [66]	valid_0's binary_logloss: 0.671204
# [67]	valid_0's binary_logloss: 0.671888
# [68]	valid_0's binary_logloss: 0.671987
# [69]	valid_0's binary_logloss: 0.672249
# [70]	valid_0's binary_logloss: 0.67303
# [71]	valid_0's binary_logloss: 0.672976
# [72]	valid_0's binary_logloss: 0.672983
# [73]	valid_0's binary_logloss: 0.673544
# [74]	valid_0's binary_logloss: 0.673677
# [75]	valid_0's binary_logloss: 0.674214
# [76]	valid_0's binary_logloss: 0.674835
# [77]	valid_0's binary_logloss: 0.674484
# [78]	valid_0's binary_logloss: 0.674592
# [79]	valid_0's binary_logloss: 0.674837
# [80]	valid_0's binary_logloss: 0.674613
# [81]	valid_0's binary_logloss: 0.674606
# [82]	valid_0's binary_logloss: 0.674592
# [83]	valid_0's binary_logloss: 0.674096
# [84]	valid_0's binary_logloss: 0.674287
# [85]	valid_0's binary_logloss: 0.674241
# [86]	valid_0's binary_logloss: 0.674432
# [87]	valid_0's binary_logloss: 0.674769
# [88]	valid_0's binary_logloss: 0.674722
# [89]	valid_0's binary_logloss: 0.674908
# [90]	valid_0's binary_logloss: 0.675104
# [91]	valid_0's binary_logloss: 0.675336
# [92]	valid_0's binary_logloss: 0.676207
# [93]	valid_0's binary_logloss: 0.676683
# [94]	valid_0's binary_logloss: 0.676728
# Early stopping, best iteration is:
# [64]	valid_0's binary_logloss: 0.670552
# [1]	valid_0's binary_logloss: 0.689607
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.686295
# [3]	valid_0's binary_logloss: 0.684704
# [4]	valid_0's binary_logloss: 0.682691
# [5]	valid_0's binary_logloss: 0.680886
# [6]	valid_0's binary_logloss: 0.679569
# [7]	valid_0's binary_logloss: 0.679035
# [8]	valid_0's binary_logloss: 0.678922
# [9]	valid_0's binary_logloss: 0.67719
# [10]	valid_0's binary_logloss: 0.675808
# [11]	valid_0's binary_logloss: 0.674965
# [12]	valid_0's binary_logloss: 0.674078
# [13]	valid_0's binary_logloss: 0.673073
# [14]	valid_0's binary_logloss: 0.672161
# [15]	valid_0's binary_logloss: 0.671361
# [16]	valid_0's binary_logloss: 0.670413
# [17]	valid_0's binary_logloss: 0.669826
# [18]	valid_0's binary_logloss: 0.669549
# [19]	valid_0's binary_logloss: 0.669878
# [20]	valid_0's binary_logloss: 0.668484
# [21]	valid_0's binary_logloss: 0.667957
# [22]	valid_0's binary_logloss: 0.667952
# [23]	valid_0's binary_logloss: 0.667414
# [24]	valid_0's binary_logloss: 0.667088
# [25]	valid_0's binary_logloss: 0.667182
# [26]	valid_0's binary_logloss: 0.665991
# [27]	valid_0's binary_logloss: 0.665712
# [28]	valid_0's binary_logloss: 0.66535
# [29]	valid_0's binary_logloss: 0.665224
# [30]	valid_0's binary_logloss: 0.665111
# [31]	valid_0's binary_logloss: 0.664828
# [32]	valid_0's binary_logloss: 0.6646
# [33]	valid_0's binary_logloss: 0.664502
# [34]	valid_0's binary_logloss: 0.664126
# [35]	valid_0's binary_logloss: 0.664234
# [36]	valid_0's binary_logloss: 0.66423
# [37]	valid_0's binary_logloss: 0.664396
# [38]	valid_0's binary_logloss: 0.663406
# [39]	valid_0's binary_logloss: 0.663329
# [40]	valid_0's binary_logloss: 0.66326
# [41]	valid_0's binary_logloss: 0.663582
# [42]	valid_0's binary_logloss: 0.663267
# [43]	valid_0's binary_logloss: 0.66315
# [44]	valid_0's binary_logloss: 0.663244
# [45]	valid_0's binary_logloss: 0.663074
# [46]	valid_0's binary_logloss: 0.662877
# [47]	valid_0's binary_logloss: 0.663239
# [48]	valid_0's binary_logloss: 0.66311
# [49]	valid_0's binary_logloss: 0.663173
# [50]	valid_0's binary_logloss: 0.662765
# [51]	valid_0's binary_logloss: 0.662892
# [52]	valid_0's binary_logloss: 0.663553
# [53]	valid_0's binary_logloss: 0.663869
# [54]	valid_0's binary_logloss: 0.663395
# [55]	valid_0's binary_logloss: 0.663438
# [56]	valid_0's binary_logloss: 0.663541
# [57]	valid_0's binary_logloss: 0.663886
# [58]	valid_0's binary_logloss: 0.662947
# [59]	valid_0's binary_logloss: 0.663322
# [60]	valid_0's binary_logloss: 0.663434
# [61]	valid_0's binary_logloss: 0.663459
# [62]	valid_0's binary_logloss: 0.663183
# [63]	valid_0's binary_logloss: 0.663291
# [64]	valid_0's binary_logloss: 0.663256
# [65]	valid_0's binary_logloss: 0.663683
# [66]	valid_0's binary_logloss: 0.664301
# [67]	valid_0's binary_logloss: 0.664597
# [68]	valid_0's binary_logloss: 0.664367
# [69]	valid_0's binary_logloss: 0.66406
# [70]	valid_0's binary_logloss: 0.664221
# [71]	valid_0's binary_logloss: 0.663881
# [72]	valid_0's binary_logloss: 0.664183
# [73]	valid_0's binary_logloss: 0.664848
# [74]	valid_0's binary_logloss: 0.66545
# [75]	valid_0's binary_logloss: 0.665362
# [76]	valid_0's binary_logloss: 0.665536
# [77]	valid_0's binary_logloss: 0.664816
# [78]	valid_0's binary_logloss: 0.66447
# [79]	valid_0's binary_logloss: 0.664778
# [80]	valid_0's binary_logloss: 0.665044
# Early stopping, best iteration is:
# [50]	valid_0's binary_logloss: 0.662765
# [1]	valid_0's binary_logloss: 0.688612
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's binary_logloss: 0.686076
# [3]	valid_0's binary_logloss: 0.683659
# [4]	valid_0's binary_logloss: 0.681325
# [5]	valid_0's binary_logloss: 0.679849
# [6]	valid_0's binary_logloss: 0.677291
# [7]	valid_0's binary_logloss: 0.676074
# [8]	valid_0's binary_logloss: 0.674247
# [9]	valid_0's binary_logloss: 0.673148
# [10]	valid_0's binary_logloss: 0.673386
# [11]	valid_0's binary_logloss: 0.671484
# [12]	valid_0's binary_logloss: 0.670862
# [13]	valid_0's binary_logloss: 0.671039
# [14]	valid_0's binary_logloss: 0.670336
# [15]	valid_0's binary_logloss: 0.670045
# [16]	valid_0's binary_logloss: 0.669848
# [17]	valid_0's binary_logloss: 0.669831
# [18]	valid_0's binary_logloss: 0.669721
# [19]	valid_0's binary_logloss: 0.669745
# [20]	valid_0's binary_logloss: 0.669755
# [21]	valid_0's binary_logloss: 0.669281
# [22]	valid_0's binary_logloss: 0.670045
# [23]	valid_0's binary_logloss: 0.669515
# [24]	valid_0's binary_logloss: 0.670095
# [25]	valid_0's binary_logloss: 0.669981
# [26]	valid_0's binary_logloss: 0.669772
# [27]	valid_0's binary_logloss: 0.669459
# [28]	valid_0's binary_logloss: 0.668317
# [29]	valid_0's binary_logloss: 0.668041
# [30]	valid_0's binary_logloss: 0.668486
# [31]	valid_0's binary_logloss: 0.668022
# [32]	valid_0's binary_logloss: 0.668241
# [33]	valid_0's binary_logloss: 0.667133
# [34]	valid_0's binary_logloss: 0.667763
# [35]	valid_0's binary_logloss: 0.667872
# [36]	valid_0's binary_logloss: 0.667608
# [37]	valid_0's binary_logloss: 0.667929
# [38]	valid_0's binary_logloss: 0.667782
# [39]	valid_0's binary_logloss: 0.668489
# [40]	valid_0's binary_logloss: 0.668501
# [41]	valid_0's binary_logloss: 0.66863
# [42]	valid_0's binary_logloss: 0.668412
# [43]	valid_0's binary_logloss: 0.668218
# [44]	valid_0's binary_logloss: 0.667694
# [45]	valid_0's binary_logloss: 0.667325
# [46]	valid_0's binary_logloss: 0.667321
# [47]	valid_0's binary_logloss: 0.668031
# [48]	valid_0's binary_logloss: 0.668155
# [49]	valid_0's binary_logloss: 0.668623
# [50]	valid_0's binary_logloss: 0.668676
# [51]	valid_0's binary_logloss: 0.668192
# [52]	valid_0's binary_logloss: 0.668132
# [53]	valid_0's binary_logloss: 0.668084
# [54]	valid_0's binary_logloss: 0.6682
# [55]	valid_0's binary_logloss: 0.668034
# [56]	valid_0's binary_logloss: 0.668142
# [57]	valid_0's binary_logloss: 0.668015
# [58]	valid_0's binary_logloss: 0.667815
# [59]	valid_0's binary_logloss: 0.668171
# [60]	valid_0's binary_logloss: 0.667516
# [61]	valid_0's binary_logloss: 0.667489
# [62]	valid_0's binary_logloss: 0.66738
# [63]	valid_0's binary_logloss: 0.667756
# Early stopping, best iteration is:
# [33]	valid_0's binary_logloss: 0.667133

# %%
val_roc
# Out:
# [0.5904459271284985, 0.5846675289992322, 0.5933673783979, 0.5665948769444884]

# %%
feature_imp = np.zeros(X.shape[1])
for model in clf_2:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp, index=X_train.columns).sort_values(by=0, ascending=False)
# Out:
#                                                              0
# num_intlinear_acceleration_Y_range                  877.448344
# linear_acceleration_X_mean_abs_chg                  713.307128
# num_intangular_velocity_X_std                       689.092428
# num_intlinear_acceleration_X_mean_abs_chg           685.905222
# num_intangular_velocity_X_range                     680.852715
# num_intlinear_acceleration_Y_std                    676.140405
# num_intlinear_acceleration_Z_std                    664.248516
# angular_velocity_Y_maxtoMin                         555.080149
# angular_velocity_X_min                              499.224513
# angular_velocity_Z_mean_abs_chg                     494.883611
# linear_acceleration_X_maxtoMin                      483.688122
# angular_velocity_Z_abs_max                          426.576357
# angular_velocity_Z_mean_change_of_abs_change        423.078890
# angular_velocity_X_maxtoMin                         422.793368
# num_intangular_velocity_Z_mean_change_of_abs_ch...  403.066579
# num_intangular_velocity_X_abs_max                   389.568347
# linear_acceleration_Z_mean                          381.367580
# angular_velocity_X_abs_min                          380.873392
# num_intlinear_acceleration_X_min                    380.607319
# angular_velocity_Y_mean_abs_chg                     373.721502
# angular_velocity_Y_min                              372.310238
# num_intangular_velocity_Y_abs_min                   371.424921
# angular_velocity_Z_maxtoMin                         353.617868
# angular_velocity_Z_std                              343.937932
# num_intlinear_acceleration_Y_mean                   326.796539
# num_intlinear_acceleration_Z_maxtoMin               320.357841
# num_intlinear_acceleration_Y_mean_abs_chg           315.633899
# linear_acceleration_Z_median                        313.829281
# angular_velocity_X_mean_change_of_abs_change        307.221868
# num_intangular_velocity_Y_mean_change_of_abs_ch...  305.458709
# linear_acceleration_Y_median                        305.171879
# angular_velocity_Y_abs_min                          304.668041
# linear_acceleration_Y_abs_min                       304.256130
# num_intlinear_acceleration_X_abs_min                303.826270
# num_intangular_velocity_Y_mean_abs_chg              294.650133
# num_intangular_velocity_Z_abs_min                   286.936931
# linear_acceleration_X_abs_min                       286.449001
# angular_velocity_Z_abs_min                          281.587049
# angular_velocity_X_mean_abs_chg                     280.704091
# num_intlinear_acceleration_X_max                    278.292681
# linear_acceleration_X_max                           277.992978
# num_intlinear_acceleration_Y_maxtoMin               276.575719
# angular_velocity_Z_abs_avg                          274.226279
# total_acce_mean_change_of_abs_change                272.100192
# linear_acceleration_X_abs_max                       271.386257
# num_intlinear_acceleration_Z_median                 270.294060
# angular_velocity_X_mean                             266.061719
# linear_acceleration_Y_mean_abs_chg                  260.725709
# num_intlinear_acceleration_Z_abs_avg                257.501920
# num_intlinear_acceleration_X_mean_change_of_abs...  255.415118
# linear_acceleration_X_std                           253.301700
# num_intangular_velocity_X_maxtoMin                  252.902797
# num_intlinear_acceleration_X_maxtoMin               249.901243
# angular_velocity_Y_max                              249.298290
# total_acce_min                                      244.465020
# angular_velocity_Y_range                            244.076688
# num_intangular_velocity_Z_min                       243.229831
# linear_acceleration_Y_std                           242.367010
# num_intlinear_acceleration_Z_mean_change_of_abs...  240.635240
# num_intlinear_acceleration_Y_mean_change_of_abs...  238.796830
# total_acce_mean_abs_chg                             234.714672
# num_intangular_velocity_X_abs_min                   232.158640
# num_intangular_velocity_Z_mean_abs_chg              228.332032
# total_acce_median                                   227.843898
# linear_acceleration_Y_min                           226.601690
# num_intlinear_acceleration_Y_median                 226.499141
# angular_velocity_Z_max                              225.457787
# num_intlinear_acceleration_X_std                    220.493178
# linear_acceleration_X_range                         219.010630
# num_intangular_velocity_X_mean_abs_chg              218.285661
# num_intangular_velocity_X_mean_change_of_abs_ch...  216.968030
# num_intangular_velocity_Z_maxtoMin                  216.483241
# angular_velocity_Y_std                              213.843738
# linear_acceleration_X_min                           206.619659
# linear_acceleration_Z_abs_avg                       205.631430
# num_intangular_velocity_Y_min                       204.582724
# num_intangular_velocity_Y_max                       204.164550
# linear_acceleration_Y_mean                          202.300809
# num_intlinear_acceleration_Z_range                  199.077419
# num_intangular_velocity_X_abs_avg                   197.907302
# linear_acceleration_X_median                        195.992899
# linear_acceleration_X_mean_change_of_abs_change     195.634849
# total_acce_maxtoMin                                 190.377311
# linear_acceleration_Z_maxtoMin                      189.936620
# num_intlinear_acceleration_Y_abs_avg                189.167869
# num_intlinear_acceleration_Z_max                    187.209171
# angular_velocity_Y_mean_change_of_abs_change        186.103889
# angular_velocity_Y_abs_max                          184.561581
# num_intlinear_acceleration_X_median                 179.859821
# num_intangular_velocity_Z_max                       179.840212
# total_acce_abs_avg                                  179.109160
# num_intlinear_acceleration_X_mean                   179.099198
# angular_velocity_Y_abs_avg                          178.562053
# angular_velocity_X_median                           178.108348
# linear_acceleration_Y_maxtoMin                      176.747040
# linear_acceleration_Y_mean_change_of_abs_change     175.156209
# num_intangular_velocity_X_min                       174.699870
# angular_velocity_Z_range                            171.998150
# num_intangular_velocity_X_median                    170.711941
# angular_velocity_X_max                              168.841880
# num_intlinear_acceleration_Y_min                    168.140302
# angular_velocity_Z_min                              166.182681
# num_intangular_velocity_Z_range                     165.049680
# num_intangular_velocity_Y_maxtoMin                  163.932740
# linear_acceleration_Y_abs_avg                       163.266509
# linear_acceleration_Z_mean_abs_chg                  161.012840
# num_intangular_velocity_Y_std                       154.729980
# linear_acceleration_Z_mean_change_of_abs_change     152.576968
# num_intlinear_acceleration_Y_max                    146.845798
# num_intlinear_acceleration_Z_mean_abs_chg           144.818949
# linear_acceleration_X_mean                          143.497530
# num_intlinear_acceleration_Z_mean                   142.163299
# angular_velocity_Y_median                           129.062310
# linear_acceleration_Z_range                         126.255430
# linear_acceleration_Z_max                           124.207541
# num_intlinear_acceleration_Z_min                    121.031031
# num_intangular_velocity_Y_abs_max                   119.988820
# num_intlinear_acceleration_X_range                  117.001549
# num_intlinear_acceleration_X_abs_max                116.099060
# total_acce_mean                                     112.847139
# linear_acceleration_Z_std                           112.165940
# num_intangular_velocity_X_max                       109.166619
# linear_acceleration_Y_range                         107.167569
# num_intlinear_acceleration_Z_abs_min                 97.249309
# linear_acceleration_Y_max                            96.920840
# linear_acceleration_Z_abs_min                        96.612610
# total_acce_max                                       95.751379
# angular_velocity_X_abs_max                           91.803918
# num_intangular_velocity_Y_median                     89.544180
# num_intangular_velocity_Z_abs_max                    88.916319
# angular_velocity_Y_mean                              78.279531
# angular_velocity_Z_mean                              77.820001
# linear_acceleration_X_abs_avg                        75.740661
# angular_velocity_X_range                             75.419850
# num_intangular_velocity_X_mean                       74.506730
# angular_velocity_X_std                               73.423301
# num_intangular_velocity_Y_abs_avg                    72.406310
# num_intlinear_acceleration_X_abs_avg                 69.031250
# num_intangular_velocity_Z_median                     68.933161
# total_acce_range                                     68.017271
# num_intangular_velocity_Y_range                      66.157010
# num_intangular_velocity_Y_mean                       59.742131
# num_intlinear_acceleration_Y_abs_min                 55.043270
# angular_velocity_Z_median                            52.717491
# total_acce_abs_min                                   47.170910
# num_intangular_velocity_Z_std                        46.348581
# num_intangular_velocity_Z_mean                       37.697539
# linear_acceleration_Z_min                            36.215190
# total_acce_std                                       35.010989
# linear_acceleration_Z_abs_max                        32.625610
# angular_velocity_X_abs_avg                           32.031900
# linear_acceleration_Y_abs_max                        18.321590
# total_acce_abs_max                                   14.995800
# num_intlinear_acceleration_Z_abs_max                 14.189000
# num_intlinear_acceleration_Y_abs_max                  7.624860
# num_intangular_velocity_Z_abs_avg                     0.000000

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X_train, y_id))

clf_3 = []
val_acc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'multi_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'multiclass',
               'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }

for train_idx, val_idx in splits:
    X_tr, y_tr = X_train.iloc[train_idx, :], y_id[train_idx]
    X_val, y_val = X_train.iloc[val_idx, :], y_id[val_idx]
    
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)

    val_acc.append(accuracy_score(y_val, np.argmax(pred_lgb, axis=1)))

#pred_lgb = pd.DataFrame(pred_lgb, index=np.where(np.mean(adv_val, axis=0)>0.3))
#val_pred = pd.concat([val_pred, pred_lgb], axis=0)

clf_3.append(model_lgb)
# Out:
# [1]	valid_0's multi_logloss: 1.8947
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.80756
# [3]	valid_0's multi_logloss: 1.73608
# [4]	valid_0's multi_logloss: 1.6793
# [5]	valid_0's multi_logloss: 1.62932
# [6]	valid_0's multi_logloss: 1.58549
# [7]	valid_0's multi_logloss: 1.54532
# [8]	valid_0's multi_logloss: 1.51138
# [9]	valid_0's multi_logloss: 1.48014
# [10]	valid_0's multi_logloss: 1.45269
# [11]	valid_0's multi_logloss: 1.42818
# [12]	valid_0's multi_logloss: 1.40616
# [13]	valid_0's multi_logloss: 1.3867
# [14]	valid_0's multi_logloss: 1.36918
# [15]	valid_0's multi_logloss: 1.35256
# [16]	valid_0's multi_logloss: 1.33814
# [17]	valid_0's multi_logloss: 1.32432
# [18]	valid_0's multi_logloss: 1.31099
# [19]	valid_0's multi_logloss: 1.29938
# [20]	valid_0's multi_logloss: 1.28725
# [21]	valid_0's multi_logloss: 1.27764
# [22]	valid_0's multi_logloss: 1.26906
# [23]	valid_0's multi_logloss: 1.26183
# [24]	valid_0's multi_logloss: 1.25298
# [25]	valid_0's multi_logloss: 1.24546
# [26]	valid_0's multi_logloss: 1.23846
# [27]	valid_0's multi_logloss: 1.23114
# [28]	valid_0's multi_logloss: 1.2272
# [29]	valid_0's multi_logloss: 1.22159
# [30]	valid_0's multi_logloss: 1.2171
# [31]	valid_0's multi_logloss: 1.21201
# [32]	valid_0's multi_logloss: 1.2099
# [33]	valid_0's multi_logloss: 1.20501
# [34]	valid_0's multi_logloss: 1.19993
# [35]	valid_0's multi_logloss: 1.1981
# [36]	valid_0's multi_logloss: 1.19455
# [37]	valid_0's multi_logloss: 1.19165
# [38]	valid_0's multi_logloss: 1.18957
# [39]	valid_0's multi_logloss: 1.18651
# [40]	valid_0's multi_logloss: 1.18421
# [41]	valid_0's multi_logloss: 1.18284
# [42]	valid_0's multi_logloss: 1.17958
# [43]	valid_0's multi_logloss: 1.17656
# [44]	valid_0's multi_logloss: 1.17459
# [45]	valid_0's multi_logloss: 1.17396
# [46]	valid_0's multi_logloss: 1.17349
# [47]	valid_0's multi_logloss: 1.17102
# [48]	valid_0's multi_logloss: 1.17036
# [49]	valid_0's multi_logloss: 1.16943
# [50]	valid_0's multi_logloss: 1.16768
# [51]	valid_0's multi_logloss: 1.16505
# [52]	valid_0's multi_logloss: 1.16463
# [53]	valid_0's multi_logloss: 1.16355
# [54]	valid_0's multi_logloss: 1.16254
# [55]	valid_0's multi_logloss: 1.16153
# [56]	valid_0's multi_logloss: 1.16173
# [57]	valid_0's multi_logloss: 1.16114
# [58]	valid_0's multi_logloss: 1.16004
# [59]	valid_0's multi_logloss: 1.1597
# [60]	valid_0's multi_logloss: 1.15859
# [61]	valid_0's multi_logloss: 1.15872
# [62]	valid_0's multi_logloss: 1.15937
# [63]	valid_0's multi_logloss: 1.15812
# [64]	valid_0's multi_logloss: 1.15867
# [65]	valid_0's multi_logloss: 1.1582
# [66]	valid_0's multi_logloss: 1.15937
# [67]	valid_0's multi_logloss: 1.16041
# [68]	valid_0's multi_logloss: 1.16168
# [69]	valid_0's multi_logloss: 1.16207
# [70]	valid_0's multi_logloss: 1.16085
# [71]	valid_0's multi_logloss: 1.16039
# [72]	valid_0's multi_logloss: 1.16063
# [73]	valid_0's multi_logloss: 1.15982
# [74]	valid_0's multi_logloss: 1.15884
# [75]	valid_0's multi_logloss: 1.1602
# [76]	valid_0's multi_logloss: 1.16184
# [77]	valid_0's multi_logloss: 1.16131
# [78]	valid_0's multi_logloss: 1.16295
# [79]	valid_0's multi_logloss: 1.16255
# [80]	valid_0's multi_logloss: 1.16316
# [81]	valid_0's multi_logloss: 1.16266
# [82]	valid_0's multi_logloss: 1.16363
# [83]	valid_0's multi_logloss: 1.16345
# [84]	valid_0's multi_logloss: 1.16459
# [85]	valid_0's multi_logloss: 1.16516
# [86]	valid_0's multi_logloss: 1.16568
# [87]	valid_0's multi_logloss: 1.16535
# [88]	valid_0's multi_logloss: 1.16587
# [89]	valid_0's multi_logloss: 1.16587
# [90]	valid_0's multi_logloss: 1.1668
# [91]	valid_0's multi_logloss: 1.16803
# [92]	valid_0's multi_logloss: 1.16743
# [93]	valid_0's multi_logloss: 1.16866
# Early stopping, best iteration is:
# [63]	valid_0's multi_logloss: 1.15812
# [1]	valid_0's multi_logloss: 1.89643
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.80791
# [3]	valid_0's multi_logloss: 1.74161
# [4]	valid_0's multi_logloss: 1.68595
# [5]	valid_0's multi_logloss: 1.63685
# [6]	valid_0's multi_logloss: 1.59368
# [7]	valid_0's multi_logloss: 1.5538
# [8]	valid_0's multi_logloss: 1.52102
# [9]	valid_0's multi_logloss: 1.49128
# [10]	valid_0's multi_logloss: 1.46361
# [11]	valid_0's multi_logloss: 1.43734
# [12]	valid_0's multi_logloss: 1.41462
# [13]	valid_0's multi_logloss: 1.39603
# [14]	valid_0's multi_logloss: 1.3776
# [15]	valid_0's multi_logloss: 1.36144
# [16]	valid_0's multi_logloss: 1.34754
# [17]	valid_0's multi_logloss: 1.33298
# [18]	valid_0's multi_logloss: 1.31956
# [19]	valid_0's multi_logloss: 1.30792
# [20]	valid_0's multi_logloss: 1.29773
# [21]	valid_0's multi_logloss: 1.28855
# [22]	valid_0's multi_logloss: 1.27934
# [23]	valid_0's multi_logloss: 1.27248
# [24]	valid_0's multi_logloss: 1.26548
# [25]	valid_0's multi_logloss: 1.25734
# [26]	valid_0's multi_logloss: 1.2516
# [27]	valid_0's multi_logloss: 1.24498
# [28]	valid_0's multi_logloss: 1.24077
# [29]	valid_0's multi_logloss: 1.23554
# [30]	valid_0's multi_logloss: 1.22999
# [31]	valid_0's multi_logloss: 1.22575
# [32]	valid_0's multi_logloss: 1.22156
# [33]	valid_0's multi_logloss: 1.21856
# [34]	valid_0's multi_logloss: 1.21477
# [35]	valid_0's multi_logloss: 1.21209
# [36]	valid_0's multi_logloss: 1.20956
# [37]	valid_0's multi_logloss: 1.20811
# [38]	valid_0's multi_logloss: 1.20515
# [39]	valid_0's multi_logloss: 1.20307
# [40]	valid_0's multi_logloss: 1.20156
# [41]	valid_0's multi_logloss: 1.20009
# [42]	valid_0's multi_logloss: 1.19806
# [43]	valid_0's multi_logloss: 1.19573
# [44]	valid_0's multi_logloss: 1.19404
# [45]	valid_0's multi_logloss: 1.19111
# [46]	valid_0's multi_logloss: 1.18948
# [47]	valid_0's multi_logloss: 1.18842
# [48]	valid_0's multi_logloss: 1.1863
# [49]	valid_0's multi_logloss: 1.18473
# [50]	valid_0's multi_logloss: 1.18456
# [51]	valid_0's multi_logloss: 1.18275
# [52]	valid_0's multi_logloss: 1.1814
# [53]	valid_0's multi_logloss: 1.18
# [54]	valid_0's multi_logloss: 1.17918
# [55]	valid_0's multi_logloss: 1.17958
# [56]	valid_0's multi_logloss: 1.17833
# [57]	valid_0's multi_logloss: 1.17752
# [58]	valid_0's multi_logloss: 1.17624
# [59]	valid_0's multi_logloss: 1.1758
# [60]	valid_0's multi_logloss: 1.17597
# [61]	valid_0's multi_logloss: 1.17603
# [62]	valid_0's multi_logloss: 1.17533
# [63]	valid_0's multi_logloss: 1.17496
# [64]	valid_0's multi_logloss: 1.17474
# [65]	valid_0's multi_logloss: 1.17437
# [66]	valid_0's multi_logloss: 1.17419
# [67]	valid_0's multi_logloss: 1.17421
# [68]	valid_0's multi_logloss: 1.17448
# [69]	valid_0's multi_logloss: 1.17438
# [70]	valid_0's multi_logloss: 1.17474
# [71]	valid_0's multi_logloss: 1.17416
# [72]	valid_0's multi_logloss: 1.17307
# [73]	valid_0's multi_logloss: 1.17354
# [74]	valid_0's multi_logloss: 1.17343
# [75]	valid_0's multi_logloss: 1.17306
# [76]	valid_0's multi_logloss: 1.17317
# [77]	valid_0's multi_logloss: 1.17351
# [78]	valid_0's multi_logloss: 1.1735
# [79]	valid_0's multi_logloss: 1.17405
# [80]	valid_0's multi_logloss: 1.17401
# [81]	valid_0's multi_logloss: 1.1742
# [82]	valid_0's multi_logloss: 1.17403
# [83]	valid_0's multi_logloss: 1.17397
# [84]	valid_0's multi_logloss: 1.174
# [85]	valid_0's multi_logloss: 1.17342
# [86]	valid_0's multi_logloss: 1.17308
# [87]	valid_0's multi_logloss: 1.1731
# [88]	valid_0's multi_logloss: 1.17354
# [89]	valid_0's multi_logloss: 1.17508
# [90]	valid_0's multi_logloss: 1.17593
# [91]	valid_0's multi_logloss: 1.17571
# [92]	valid_0's multi_logloss: 1.17702
# [93]	valid_0's multi_logloss: 1.17717
# [94]	valid_0's multi_logloss: 1.1781
# [95]	valid_0's multi_logloss: 1.17846
# [96]	valid_0's multi_logloss: 1.17867
# [97]	valid_0's multi_logloss: 1.17885
# [98]	valid_0's multi_logloss: 1.17915
# [99]	valid_0's multi_logloss: 1.17992
# [100]	valid_0's multi_logloss: 1.18069
# [101]	valid_0's multi_logloss: 1.18177
# [102]	valid_0's multi_logloss: 1.18201
# [103]	valid_0's multi_logloss: 1.18271
# [104]	valid_0's multi_logloss: 1.18279
# [105]	valid_0's multi_logloss: 1.1843
# Early stopping, best iteration is:
# [75]	valid_0's multi_logloss: 1.17306
# [1]	valid_0's multi_logloss: 1.88932
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.80294
# [3]	valid_0's multi_logloss: 1.73127
# [4]	valid_0's multi_logloss: 1.67488
# [5]	valid_0's multi_logloss: 1.62704
# [6]	valid_0's multi_logloss: 1.58292
# [7]	valid_0's multi_logloss: 1.54489
# [8]	valid_0's multi_logloss: 1.51047
# [9]	valid_0's multi_logloss: 1.4794
# [10]	valid_0's multi_logloss: 1.45198
# [11]	valid_0's multi_logloss: 1.4288
# [12]	valid_0's multi_logloss: 1.4061
# [13]	valid_0's multi_logloss: 1.3875
# [14]	valid_0's multi_logloss: 1.37075
# [15]	valid_0's multi_logloss: 1.35632
# [16]	valid_0's multi_logloss: 1.34188
# [17]	valid_0's multi_logloss: 1.32867
# [18]	valid_0's multi_logloss: 1.31631
# [19]	valid_0's multi_logloss: 1.30435
# [20]	valid_0's multi_logloss: 1.2937
# [21]	valid_0's multi_logloss: 1.28357
# [22]	valid_0's multi_logloss: 1.27637
# [23]	valid_0's multi_logloss: 1.26873
# [24]	valid_0's multi_logloss: 1.26274
# [25]	valid_0's multi_logloss: 1.25547
# [26]	valid_0's multi_logloss: 1.24729
# [27]	valid_0's multi_logloss: 1.24113
# [28]	valid_0's multi_logloss: 1.23544
# [29]	valid_0's multi_logloss: 1.23068
# [30]	valid_0's multi_logloss: 1.22518
# [31]	valid_0's multi_logloss: 1.22049
# [32]	valid_0's multi_logloss: 1.21483
# [33]	valid_0's multi_logloss: 1.20985
# [34]	valid_0's multi_logloss: 1.20511
# [35]	valid_0's multi_logloss: 1.20285
# [36]	valid_0's multi_logloss: 1.19983
# [37]	valid_0's multi_logloss: 1.19865
# [38]	valid_0's multi_logloss: 1.19614
# [39]	valid_0's multi_logloss: 1.19358
# [40]	valid_0's multi_logloss: 1.19124
# [41]	valid_0's multi_logloss: 1.18993
# [42]	valid_0's multi_logloss: 1.187
# [43]	valid_0's multi_logloss: 1.18655
# [44]	valid_0's multi_logloss: 1.18507
# [45]	valid_0's multi_logloss: 1.18518
# [46]	valid_0's multi_logloss: 1.18407
# [47]	valid_0's multi_logloss: 1.18248
# [48]	valid_0's multi_logloss: 1.18109
# [49]	valid_0's multi_logloss: 1.17957
# [50]	valid_0's multi_logloss: 1.17792
# [51]	valid_0's multi_logloss: 1.17677
# [52]	valid_0's multi_logloss: 1.17583
# [53]	valid_0's multi_logloss: 1.17701
# [54]	valid_0's multi_logloss: 1.17566
# [55]	valid_0's multi_logloss: 1.17333
# [56]	valid_0's multi_logloss: 1.17295
# [57]	valid_0's multi_logloss: 1.17451
# [58]	valid_0's multi_logloss: 1.17379
# [59]	valid_0's multi_logloss: 1.17359
# [60]	valid_0's multi_logloss: 1.17388
# [61]	valid_0's multi_logloss: 1.17341
# [62]	valid_0's multi_logloss: 1.17469
# [63]	valid_0's multi_logloss: 1.17403
# [64]	valid_0's multi_logloss: 1.17415
# [65]	valid_0's multi_logloss: 1.17327
# [66]	valid_0's multi_logloss: 1.17409
# [67]	valid_0's multi_logloss: 1.17489
# [68]	valid_0's multi_logloss: 1.17457
# [69]	valid_0's multi_logloss: 1.17565
# [70]	valid_0's multi_logloss: 1.1764
# [71]	valid_0's multi_logloss: 1.17704
# [72]	valid_0's multi_logloss: 1.1773
# [73]	valid_0's multi_logloss: 1.17823
# [74]	valid_0's multi_logloss: 1.17816
# [75]	valid_0's multi_logloss: 1.17745
# [76]	valid_0's multi_logloss: 1.17817
# [77]	valid_0's multi_logloss: 1.17807
# [78]	valid_0's multi_logloss: 1.17802
# [79]	valid_0's multi_logloss: 1.17843
# [80]	valid_0's multi_logloss: 1.17823
# [81]	valid_0's multi_logloss: 1.17816
# [82]	valid_0's multi_logloss: 1.17748
# [83]	valid_0's multi_logloss: 1.17578
# [84]	valid_0's multi_logloss: 1.17722
# [85]	valid_0's multi_logloss: 1.17633
# [86]	valid_0's multi_logloss: 1.17714
# Early stopping, best iteration is:
# [56]	valid_0's multi_logloss: 1.17295
# [1]	valid_0's multi_logloss: 1.8843
# Training until validation scores don't improve for 30 rounds.
# [2]	valid_0's multi_logloss: 1.79905
# [3]	valid_0's multi_logloss: 1.73164
# [4]	valid_0's multi_logloss: 1.67505
# [5]	valid_0's multi_logloss: 1.62423
# [6]	valid_0's multi_logloss: 1.58002
# [7]	valid_0's multi_logloss: 1.53902
# [8]	valid_0's multi_logloss: 1.5045
# [9]	valid_0's multi_logloss: 1.47321
# [10]	valid_0's multi_logloss: 1.44699
# [11]	valid_0's multi_logloss: 1.42148
# [12]	valid_0's multi_logloss: 1.39965
# [13]	valid_0's multi_logloss: 1.37796
# [14]	valid_0's multi_logloss: 1.35971
# [15]	valid_0's multi_logloss: 1.34335
# [16]	valid_0's multi_logloss: 1.32497
# [17]	valid_0's multi_logloss: 1.30899
# [18]	valid_0's multi_logloss: 1.29471
# [19]	valid_0's multi_logloss: 1.28342
# [20]	valid_0's multi_logloss: 1.27243
# [21]	valid_0's multi_logloss: 1.26033
# [22]	valid_0's multi_logloss: 1.25048
# [23]	valid_0's multi_logloss: 1.24322
# [24]	valid_0's multi_logloss: 1.23372
# [25]	valid_0's multi_logloss: 1.22656
# [26]	valid_0's multi_logloss: 1.21923
# [27]	valid_0's multi_logloss: 1.21324
# [28]	valid_0's multi_logloss: 1.20712
# [29]	valid_0's multi_logloss: 1.20097
# [30]	valid_0's multi_logloss: 1.19564
# [31]	valid_0's multi_logloss: 1.18925
# [32]	valid_0's multi_logloss: 1.18375
# [33]	valid_0's multi_logloss: 1.17808
# [34]	valid_0's multi_logloss: 1.17399
# [35]	valid_0's multi_logloss: 1.17093
# [36]	valid_0's multi_logloss: 1.16697
# [37]	valid_0's multi_logloss: 1.16372
# [38]	valid_0's multi_logloss: 1.16083
# [39]	valid_0's multi_logloss: 1.15819
# [40]	valid_0's multi_logloss: 1.15629
# [41]	valid_0's multi_logloss: 1.15309
# [42]	valid_0's multi_logloss: 1.1511
# [43]	valid_0's multi_logloss: 1.14726
# [44]	valid_0's multi_logloss: 1.14542
# [45]	valid_0's multi_logloss: 1.14397
# [46]	valid_0's multi_logloss: 1.14226
# [47]	valid_0's multi_logloss: 1.14188
# [48]	valid_0's multi_logloss: 1.13965
# [49]	valid_0's multi_logloss: 1.13768
# [50]	valid_0's multi_logloss: 1.1353
# [51]	valid_0's multi_logloss: 1.13521
# [52]	valid_0's multi_logloss: 1.13402
# [53]	valid_0's multi_logloss: 1.13322
# [54]	valid_0's multi_logloss: 1.13284
# [55]	valid_0's multi_logloss: 1.132
# [56]	valid_0's multi_logloss: 1.1311
# [57]	valid_0's multi_logloss: 1.13025
# [58]	valid_0's multi_logloss: 1.12917
# [59]	valid_0's multi_logloss: 1.12813
# [60]	valid_0's multi_logloss: 1.12688
# [61]	valid_0's multi_logloss: 1.1267
# [62]	valid_0's multi_logloss: 1.12609
# [63]	valid_0's multi_logloss: 1.12623
# [64]	valid_0's multi_logloss: 1.12644
# [65]	valid_0's multi_logloss: 1.12563
# [66]	valid_0's multi_logloss: 1.12593
# [67]	valid_0's multi_logloss: 1.12575
# [68]	valid_0's multi_logloss: 1.12582
# [69]	valid_0's multi_logloss: 1.12475
# [70]	valid_0's multi_logloss: 1.12338
# [71]	valid_0's multi_logloss: 1.12373
# [72]	valid_0's multi_logloss: 1.12292
# [73]	valid_0's multi_logloss: 1.12129
# [74]	valid_0's multi_logloss: 1.12157
# [75]	valid_0's multi_logloss: 1.12227
# [76]	valid_0's multi_logloss: 1.12218
# [77]	valid_0's multi_logloss: 1.12049
# [78]	valid_0's multi_logloss: 1.12166
# [79]	valid_0's multi_logloss: 1.12163
# [80]	valid_0's multi_logloss: 1.12108
# [81]	valid_0's multi_logloss: 1.12057
# [82]	valid_0's multi_logloss: 1.12093
# [83]	valid_0's multi_logloss: 1.12062
# [84]	valid_0's multi_logloss: 1.12193
# [85]	valid_0's multi_logloss: 1.12255
# [86]	valid_0's multi_logloss: 1.12276
# [87]	valid_0's multi_logloss: 1.12315
# [88]	valid_0's multi_logloss: 1.1244
# [89]	valid_0's multi_logloss: 1.12468
# [90]	valid_0's multi_logloss: 1.12563
# [91]	valid_0's multi_logloss: 1.12517
# [92]	valid_0's multi_logloss: 1.12624
# [93]	valid_0's multi_logloss: 1.12582
# [94]	valid_0's multi_logloss: 1.12701
# [95]	valid_0's multi_logloss: 1.1278
# [96]	valid_0's multi_logloss: 1.12856
# [97]	valid_0's multi_logloss: 1.12956
# [98]	valid_0's multi_logloss: 1.1299
# [99]	valid_0's multi_logloss: 1.13058
# [100]	valid_0's multi_logloss: 1.13077
# [101]	valid_0's multi_logloss: 1.13096
# [102]	valid_0's multi_logloss: 1.13159
# [103]	valid_0's multi_logloss: 1.13189
# [104]	valid_0's multi_logloss: 1.13249
# [105]	valid_0's multi_logloss: 1.13371
# [106]	valid_0's multi_logloss: 1.13544
# [107]	valid_0's multi_logloss: 1.13661
# Early stopping, best iteration is:
# [77]	valid_0's multi_logloss: 1.12049

# %%
val_acc
# Out:
# [0.5889121338912134,
#  0.5897166841552991,
#  0.5913865546218487,
#  0.5974710221285564]

# %%
feature_imp = np.zeros(X_train.shape[1])
for model in clf_3:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp, index=X_train.columns).sort_values(by=0, ascending=False)
# Out:
#                                                               0
# linear_acceleration_Y_mean_abs_chg                  3539.257020
# angular_velocity_Y_mean_abs_chg                     3178.671721
# linear_acceleration_X_mean_abs_chg                  3032.315880
# linear_acceleration_Z_mean_abs_chg                  1791.173344
# total_acce_mean                                     1428.171771
# angular_velocity_Z_min                              1174.502069
# num_intlinear_acceleration_X_mean_abs_chg           1083.259375
# total_acce_std                                       933.308454
# angular_velocity_Y_maxtoMin                          873.019508
# total_acce_mean_abs_chg                              812.927923
# linear_acceleration_Y_max                            705.127751
# num_intangular_velocity_X_range                      674.395397
# angular_velocity_Z_mean_abs_chg                      663.754366
# linear_acceleration_Y_std                            646.812109
# num_intangular_velocity_X_std                        624.561624
# angular_velocity_Z_range                             579.775497
# angular_velocity_Y_abs_max                           571.823282
# linear_acceleration_Y_maxtoMin                       529.803187
# angular_velocity_Y_max                               519.688243
# num_intlinear_acceleration_Z_std                     509.778759
# linear_acceleration_X_abs_avg                        500.694725
# angular_velocity_Z_median                            482.930958
# linear_acceleration_Y_range                          477.622619
# num_intlinear_acceleration_Y_std                     461.227564
# num_intangular_velocity_Z_median                     442.885784
# num_intangular_velocity_X_abs_max                    442.216131
# total_acce_abs_avg                                   440.743941
# angular_velocity_Y_abs_avg                           437.396641
# linear_acceleration_Y_min                            433.580428
# angular_velocity_Y_std                               431.372018
# linear_acceleration_X_std                            419.524374
# angular_velocity_X_mean                              362.568331
# num_intangular_velocity_Y_mean_abs_chg               357.520192
# angular_velocity_X_mean_abs_chg                      348.456680
# linear_acceleration_Y_abs_avg                        326.364585
# angular_velocity_Z_std                               315.701272
# angular_velocity_Z_abs_avg                           308.886408
# linear_acceleration_Z_max                            307.290379
# num_intlinear_acceleration_Y_mean                    306.610593
# num_intangular_velocity_X_mean_change_of_abs_ch...   304.698208
# angular_velocity_Y_min                               302.316823
# linear_acceleration_Y_mean                           296.466788
# num_intlinear_acceleration_X_std                     294.632533
# linear_acceleration_Z_median                         291.387325
# num_intangular_velocity_Z_mean_change_of_abs_ch...   290.276364
# linear_acceleration_X_abs_min                        287.251695
# num_intlinear_acceleration_Y_mean_change_of_abs...   286.992691
# linear_acceleration_X_min                            277.576796
# angular_velocity_Z_max                               275.627056
# angular_velocity_Z_maxtoMin                          273.726955
# angular_velocity_Z_abs_max                           270.184975
# num_intlinear_acceleration_X_mean_change_of_abs...   268.453676
# linear_acceleration_X_maxtoMin                       268.141229
# angular_velocity_X_maxtoMin                          265.805736
# num_intlinear_acceleration_Y_median                  261.896208
# linear_acceleration_Z_min                            260.547470
# angular_velocity_Y_range                             259.361900
# total_acce_max                                       254.685728
# num_intlinear_acceleration_Y_maxtoMin                244.522104
# angular_velocity_X_mean_change_of_abs_change         244.345706
# num_intlinear_acceleration_X_max                     232.142396
# angular_velocity_X_max                               229.980898
# total_acce_median                                    228.811884
# num_intlinear_acceleration_Y_mean_abs_chg            227.162336
# linear_acceleration_Z_abs_avg                        225.634048
# angular_velocity_X_abs_min                           216.265165
# linear_acceleration_X_median                         216.090552
# linear_acceleration_Z_std                            208.141849
# linear_acceleration_X_mean_change_of_abs_change      206.985702
# num_intangular_velocity_X_min                        203.983401
# angular_velocity_Y_mean_change_of_abs_change         203.950186
# angular_velocity_X_std                               203.833872
# angular_velocity_Y_abs_min                           202.130438
# total_acce_range                                     200.886286
# linear_acceleration_Y_median                         200.795694
# linear_acceleration_X_mean                           198.041978
# linear_acceleration_X_range                          196.498612
# linear_acceleration_Z_maxtoMin                       193.050396
# angular_velocity_X_min                               190.722108
# total_acce_maxtoMin                                  186.398711
# linear_acceleration_Z_range                          185.137280
# linear_acceleration_X_max                            183.773653
# total_acce_min                                       182.932095
# linear_acceleration_Z_mean                           182.906040
# num_intangular_velocity_X_max                        182.136481
# linear_acceleration_Z_abs_min                        177.451264
# linear_acceleration_Y_mean_change_of_abs_change      175.476253
# num_intangular_velocity_Z_maxtoMin                   173.590920
# num_intangular_velocity_Y_abs_min                    173.318011
# num_intlinear_acceleration_X_min                     169.850853
# linear_acceleration_X_abs_max                        167.505197
# num_intangular_velocity_Z_abs_min                    167.369271
# num_intlinear_acceleration_X_maxtoMin                166.689505
# num_intangular_velocity_X_abs_min                    166.550149
# num_intlinear_acceleration_X_median                  163.583330
# num_intlinear_acceleration_X_range                   163.202448
# num_intlinear_acceleration_X_abs_min                 148.481387
# num_intlinear_acceleration_Z_mean_change_of_abs...   147.517170
# num_intangular_velocity_Y_mean_change_of_abs_ch...   145.110959
# linear_acceleration_Y_abs_min                        143.898118
# num_intlinear_acceleration_Z_median                  143.221508
# angular_velocity_X_median                            142.878241
# num_intangular_velocity_X_maxtoMin                   141.891303
# num_intangular_velocity_X_abs_avg                    140.534447
# num_intlinear_acceleration_Y_range                   134.990757
# angular_velocity_Z_mean_change_of_abs_change         134.927759
# num_intlinear_acceleration_Z_maxtoMin                132.497265
# num_intangular_velocity_Z_range                      131.672790
# num_intlinear_acceleration_Z_min                     131.107113
# angular_velocity_Y_mean                              127.485066
# num_intangular_velocity_Z_std                        125.156041
# num_intangular_velocity_Z_max                        122.237669
# num_intangular_velocity_X_mean_abs_chg               120.857813
# linear_acceleration_Z_mean_change_of_abs_change      119.672438
# num_intangular_velocity_Y_mean                       119.531994
# num_intlinear_acceleration_X_abs_max                 118.816894
# num_intlinear_acceleration_Y_min                     117.973907
# angular_velocity_Y_median                            110.587288
# num_intlinear_acceleration_Z_range                   108.913556
# num_intlinear_acceleration_Z_abs_avg                 105.704203
# linear_acceleration_Z_abs_max                        104.923821
# num_intangular_velocity_Y_range                      104.600376
# angular_velocity_Z_abs_min                           103.037662
# num_intangular_velocity_Z_mean                       101.835741
# num_intangular_velocity_Y_median                      99.460825
# num_intangular_velocity_X_mean                        97.758874
# angular_velocity_Z_mean                               94.144921
# num_intlinear_acceleration_Z_mean                     93.211816
# num_intangular_velocity_Y_maxtoMin                    92.801321
# total_acce_mean_change_of_abs_change                  90.337559
# num_intangular_velocity_Z_mean_abs_chg                89.859886
# num_intangular_velocity_Y_std                         89.268480
# num_intlinear_acceleration_X_abs_avg                  87.756536
# num_intlinear_acceleration_X_mean                     87.374321
# num_intlinear_acceleration_Y_max                      85.824089
# num_intangular_velocity_Y_min                         85.560660
# total_acce_abs_max                                    84.016340
# num_intlinear_acceleration_Y_abs_avg                  79.701651
# num_intlinear_acceleration_Z_max                      79.336895
# num_intlinear_acceleration_Z_mean_abs_chg             79.257566
# num_intangular_velocity_X_median                      77.090807
# num_intangular_velocity_Z_abs_avg                     76.245274
# num_intangular_velocity_Y_abs_max                     76.210680
# linear_acceleration_Y_abs_max                         73.923191
# num_intangular_velocity_Z_min                         72.027062
# num_intlinear_acceleration_Y_abs_min                  70.907033
# num_intangular_velocity_Y_max                         69.015825
# num_intlinear_acceleration_Z_abs_max                  68.769851
# num_intangular_velocity_Z_abs_max                     67.767470
# angular_velocity_X_abs_avg                            60.453391
# num_intlinear_acceleration_Z_abs_min                  57.258086
# angular_velocity_X_range                              52.289247
# num_intangular_velocity_Y_abs_avg                     46.712510
# angular_velocity_X_abs_max                            36.722878
# total_acce_abs_min                                    30.322780
# num_intlinear_acceleration_Y_abs_max                   9.354339

# %%
test_pred = []
for model in clf:
    pred_test = model.predict(test)
    test_pred.append(pred_test)

# %%
test_pred = (test_pred[0]+test_pred[1]+test_pred[2]+test_pred[3])/4

# %%
test_pr = pd.concat([pd.Series(np.argmax(test_pred, axis=1)), pd.Series(np.max(test_pred, axis=1))], axis=1)
test_pr.columns = ['group_id', 'prob']

# %%
test_pr

# %%
gr_sr = pd.DataFrame()
for i in range(73):
    gr = pd.DataFrame({'group_id':[i], 'surface':[y_train[y_train['group_id']==i]['surface'].iloc[0]]})
    gr_sr = pd.concat([gr_sr, gr], axis=0)

# %%
test_pr = test_pr.merge(gr_sr, how='left', on='group_id', sort=False)

# %%
test_gr_idx = test_pr[test_pr['prob']<=0.9].index

# %%
X_test.loc[test_gr_idx, :].head()

# %%
preds_test = []

for model in clf_3:
    preds_test.append(model.predict(X_test.loc[test_gr_idx, :]))

# %%
preds_test = np.argmax(np.mean(preds_test, axis=0), axis=1)

# %%
test_surface = []
for i in preds_test:
    test_surface.append(id_to_target[i])

# %%
test_surface = np.asarray(test_surface)

# %%
preds_test = pd.DataFrame(test_surface, index=test_gr_idx, columns=['surface'])

# %%
preds_test.head()

# %%
preds_test = pd.concat([pd.DataFrame(test_pr[test_pr['prob']>0.9]['surface']), preds_test], axis=0).sort_index()

# %%
submission = pd.read_csv('../input/sample_submission.csv')

# %%
submission['surface'] = preds_test['surface']
submission.to_csv('../output/submission_7.csv', index=False)
submission.head()

# %%
cols = ['linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z']
df_peak = pd.DataFrame()

for i in tqdm(range(0, len(X_train), 128)):
    X_tr = X_train.iloc[i:i+128, :]
    df_cols = pd.DataFrame()
    for col in cols:
        peaks = signal.find_peaks(X_tr[col], rel_height=1.0)[0]
        peak_num = len(peaks)
        peak_width = signal.peak_widths(X_tr[col], peaks, rel_height=1.0)[0]
        peak_pro = signal.peak_prominences(X_tr[col], peaks)[0]
        
        if peak_num != 0:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[np.max(peak_width)],
                             col+'_peak_width_min':[np.min(peak_width)],
                             col+'_peak_width_mean':[np.mean(peak_width)],
                             col+'_peak_pro_max':[np.max(peak_pro)],
                             col+'_peak_pro_min':[np.min(peak_pro)],
                             col+'_peak_pro_mean':[np.mean(peak_pro)]
                            }, index=[i//128])
        else:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[0],
                             col+'_peak_width_min':[0],
                             col+'_peak_width_mean':[0],
                             col+'_peak_pro_max':[0],
                             col+'_peak_pro_min':[0],
                             col+'_peak_pro_mean':[0]
                            }, index=[i//128])
            
        df_cols = pd.concat([df_cols, peak_df], axis=1)
    df_peak = pd.concat([df_peak, df_cols], axis=0)

# %%
cols = ['linear_acceleration_X', 'linear_acceleration_Y', 'linear_acceleration_Z', 'angular_velocity_X', 'angular_velocity_Y', 'angular_velocity_Z']
df_peak_te = pd.DataFrame()

for i in tqdm(range(0, len(X_test), 128)):
    X_tr = X_test.iloc[i:i+128, :]
    df_cols = pd.DataFrame()
    for col in cols:
        peaks = signal.find_peaks(X_tr[col], rel_height=1.0)[0]
        peak_num = len(peaks)
        peak_width = signal.peak_widths(X_tr[col], peaks, rel_height=1.0)[0]
        peak_pro = signal.peak_prominences(X_tr[col], peaks)[0]
        
        if peak_num != 0:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[np.max(peak_width)],
                             col+'_peak_width_min':[np.min(peak_width)],
                             col+'_peak_width_mean':[np.mean(peak_width)],
                             col+'_peak_pro_max':[np.max(peak_pro)],
                             col+'_peak_pro_min':[np.min(peak_pro)],
                             col+'_peak_pro_mean':[np.mean(peak_pro)]
                            }, index=[i//128])
        else:
            peak_df = pd.DataFrame({
                             col+'_peak_num':[peak_num], 
                             col+'_peak_width_max':[0],
                             col+'_peak_width_min':[0],
                             col+'_peak_width_mean':[0],
                             col+'_peak_pro_max':[0],
                             col+'_peak_pro_min':[0],
                             col+'_peak_pro_mean':[0]
                            }, index=[i//128])
            
        df_cols = pd.concat([df_cols, peak_df], axis=1)
    df_peak_te = pd.concat([df_peak_te, df_cols], axis=0)

# %%
df_peak.head()

# %%
def feat_eng(df):
    data = pd.DataFrame()
    #df['linear_acceleration_Z'] += 9.80665
    #df['eulerX-Z'] = df['euler_X']-df['euler_Z']
    df['total_acce'] = (df['linear_acceleration_X']**2 + df['linear_acceleration_Y']**2 + df['linear_acceleration_Z']**2)**0.5
#df['total_rotated'] = (df['rotated_acceleration_X']**2 + df['rotated_acceleration_Y']**2 + df['rotated_acceleration_Z']**2)**0.5
    #df['total_ang_cos'] = (df['angular_velocity_X_cos']**2 + df['angular_velocity_Y_cos']**2 + df['angular_velocity_Z_cos']**2)**0.5
    
    tmp_df = pd.concat([df['linear_acceleration_Z'], df['angular_velocity_X']], axis=1)
    scaler = MinMaxScaler(feature_range=(-1, 1))
    tmp_df = scaler.fit_transform(tmp_df)
    
    #df['total_angu'] = (df['angular_velocity_X']**2 + df['angular_velocity_Y']**2 + df['angular_velocity_Z']**2)**0.5
    
    #df['total_eule'] = (df['euler_X']**2 + df['euler_Y']**2 + df['euler_Z']**2)**0.5
    #df['total_xyz'] = (df['orientation_X']**2 + df['orientation_Y']**2 + df['orientation_Z']**2)**0.5
    #df['total_acc/vel'] = df['total_acce']/df['total_angu']
    
    df_columns = df.columns[3:]
    for col in tqdm(df_columns):
        data[col + '_mean'] = df.groupby(['series_id'])[col].mean()
        data[col + '_median'] = df.groupby(['series_id'])[col].median()
        data[col + '_max'] = df.groupby(['series_id'])[col].max()
        data[col + '_min'] = df.groupby(['series_id'])[col].min()
        data[col + '_std'] = df.groupby(['series_id'])[col].std()
        data[col + '_range'] = data[col + '_max'] - data[col + '_min']
        data[col + '_maxtoMin'] = data[col + '_max'] / data[col + '_min']
        data[col + '_mean_abs_chg'] = df.groupby(['series_id'])[col].apply(lambda x: np.mean(np.abs(np.diff(x))))
        data[col + '_mean_change_of_abs_change'] = df.groupby('series_id')[col].apply(mean_change_of_abs_change)
        data[col + '_abs_max'] = df.groupby(['series_id'])[col].apply(lambda x: np.max(np.abs(x)))
        data[col + '_abs_min'] = df.groupby(['series_id'])[col].apply(lambda x: np.min(np.abs(x)))
        data[col + '_abs_avg'] = (data[col + '_abs_min'] + data[col + '_abs_max'])/2
        
        
    #data['corr_linZangX'] = np.correlate(np.abs(tmp_df[:, 0]), np.abs(tmp_df[:, 1]))
    return data

# %%
X_train = feat_eng(X_train)
X_test = feat_eng(X_test)

# %%
X_train.shape

# %%
df_peak.shape

# %%
df_peak_te.shape

# %%
X_test.shape

# %%
X_train = pd.concat([X_train, df_peak], axis=1)
X_test = pd.concat([X_test, df_peak_te], axis=1)

# %%
data_col = X_train.columns

# %%
for data in [X_train, X_test]:
    data.fillna(0,inplace=True)
    data.replace(-np.inf,0,inplace=True)
    data.replace(np.inf,0,inplace=True)

# %% [markdown]
# scaler = StandardScaler()
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
# X_test = scaler.transform(X_test)

# %%
N_SPLITS = 5

# %%
import tensorflow as tf
from sklearn.metrics import roc_auc_score

def auroc(y_true, y_pred):
    return tf.py_function(roc_auc_score, (y_true, y_pred), tf.double)

# %%
import lightgbm as lgb
from sklearn.metrics import accuracy_score

# %%
y = np.concatenate((np.zeros(len(X_train)), np.ones(len(X_test))), axis=0)
X = np.concatenate((X_train, X_test), axis=0)

# %%
splits = list(StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=2019).split(X, y))

clf_2 = []
val_roc = []
val_pred = pd.DataFrame()

lgb_params = {
               'feature_fraction': 0.8,
               'metric': 'binary_logloss',
               'nthread':8, 
               'learning_rate': 0.1, 
               'objective': 'binary',
               #'num_class': class_num,
               'num_leaves': 2**4,
               'verbose':0, 
               'seed':123
              }


for train_idx, val_idx in splits:
    X_tr, y_tr = X[train_idx, :], y[train_idx]
    X_val, y_val = X[val_idx, :], y[val_idx]
 
    model_lgb = lgb.train(lgb_params, lgb.Dataset(X_tr, label=y_tr), 500,\
                           valid_sets=lgb.Dataset(X_val, label=y_val), early_stopping_rounds=30)
    pred_lgb = model_lgb.predict(X_val)
    
    val_roc.append(roc_auc_score(y_val, (pred_lgb>0.5).astype(int)))
    
    pred_lgb = pd.DataFrame(pred_lgb, index=val_idx)
    val_pred = pd.concat([val_pred, pred_lgb], axis=0)
    
    clf_2.append(model_lgb)

# %%
val_roc

# %%
feature_imp = np.zeros(X_train.shape[1])
for model in clf_2:
    feature_imp+=model.feature_importance(importance_type='gain')

pd.DataFrame(feature_imp/5, index=data_col).sort_values(by=0, ascending=False)

# %%
adv_val = []
for model in clf_2:
    adv_val.append(model.predict(X_train))

# %%
plt.plot(np.sort(np.mean(adv_val, axis=0)))

# %%
preds_test = []

for model in clf:
    preds_test.append(model.predict(X_test))

# %%
preds_test = np.argmax(np.mean(preds_test, axis=0), axis=1)

# %%
test_surface = []
for i in preds_test:
    test_surface.append(id_to_target[i])

# %%
test_surface = np.asarray(test_surface)

# %%
submission = pd.read_csv('../input/sample_submission.csv')

# %%
submission['surface'] = test_surface
submission.to_csv('../output/submission_6.csv', index=False)
submission.head()
